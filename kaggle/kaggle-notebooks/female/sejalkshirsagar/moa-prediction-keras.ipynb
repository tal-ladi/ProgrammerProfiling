# %% [markdown]
# Our aim is to predict multiple targets of the Mechanism of Action (MoA) response(s) of different samples (`sig_id`), given various inputs such as gene expression data and cell viability data.

# %% [markdown]
# # 1. Import Packages

# %%
import os
import random
import numpy as np 
import pandas as pd 
import tensorflow as tf
from sklearn.metrics import log_loss
from sklearn.model_selection import KFold

# %%
SEED = 9
def all_seeds(s):
    random.seed(s)
    os.environ['PYTHONHASHSEED'] = str(s)
    np.random.seed(s)
    tf.random.set_seed(s)
    
all_seeds(SEED)

# %% [markdown]
# # 2. Load Data

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/lish-moa/test_features.csv
# /kaggle/input/lish-moa/train_drug.csv
# /kaggle/input/lish-moa/train_features.csv
# /kaggle/input/lish-moa/train_targets_scored.csv
# /kaggle/input/lish-moa/train_targets_nonscored.csv
# /kaggle/input/lish-moa/sample_submission.csv

# %%
test_df = pd.read_csv('../input/lish-moa/test_features.csv')
train_df = pd.read_csv('../input/lish-moa/train_features.csv')
tr_target_df = pd.read_csv('../input/lish-moa/train_targets_scored.csv')
sample_df = pd.read_csv('../input/lish-moa/sample_submission.csv')

target_cols = tr_target_df.columns[1:]
N_TARGETS = len(target_cols)

# %% [markdown]
# # 3. Preprocess Data

# %%
def preprocess_df(df):
    df['cp_type'] = (df['cp_type'] == 'trt_cp').astype(int)
    df['cp_dose'] = (df['cp_dose'] == 'D2').astype(int)
    return df

x_train = preprocess_df(train_df.drop(columns="sig_id"))
y_train = tr_target_df.drop(columns="sig_id")
x_test = preprocess_df(test_df.drop(columns="sig_id"))

N_FEATURES = x_train.shape[1]

# %%
print("Number of Features:",N_FEATURES)
print("Number of Targets:",N_TARGETS)
print("x_train shape:",x_train.shape)
print("y_train shape:",y_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# Number of Features: 875
# Number of Targets: 206
# x_train shape: (23814, 875)
# y_train shape: (23814, 206)
# x_test shape: (3982, 875)

# %% [markdown]
# # 4. Building Model

# %%
EPOCHS = 64
BATCH_SIZE = 128
FOLDS = 5
REPEATS = 5
LR = 0.0008
N_TARGETS = len(target_cols)

def multi_log_loss(y_true, y_pred):
    losses = []
    for col in y_true.columns:
        losses.append(log_loss(y_true.loc[:, col], y_pred.loc[:, col]))
    return np.mean(losses)

# %%
def my_model():
    model = tf.keras.Sequential([
        
                tf.keras.layers.Input(N_FEATURES), 
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.1),
        
                tf.keras.layers.Dense(3500, activation="relu"),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.4),
        
                tf.keras.layers.Dense(1750, activation="relu"),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2),
                
                tf.keras.layers.Dense(875, activation="relu"),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.1),
                
                tf.keras.layers.Dense(412, activation="relu"),
                tf.keras.layers.BatchNormalization(),
                tf.keras.layers.Dropout(0.2),
        
                tf.keras.layers.Dense(N_TARGETS, activation="sigmoid") 
            ])
    
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = LR),
                  loss = 'binary_crossentropy', 
                  metrics = ["accuracy"])
    return model

# %% [markdown]
# # 5. Training

# %%
def train(resume_models = None, repeat_number = 0, folds = 5, skip_folds = 0):
    
    models = []
    oof_pred = y_train.copy()  

    kfold = KFold(folds, shuffle = True, random_state = 9)
    for fold, (i_tr, i_va) in enumerate(kfold.split(x_train)):

        print('-'*85)
        print(f'Repeat {repeat_number}, Fold {fold}')
        
        cb_lr_schedule = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss', 
                                                              factor = 0.4, 
                                                              patience = 1, 
                                                              verbose = 2, 
                                                              min_delta = 0.0001, 
                                                              mode = 'auto')
        
        cb_early_stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                                         min_delta = 0, 
                                                         patience = 4, 
                                                         verbose = 1, 
                                                         mode = 'min')
        
        checkpt_path = f'repeat:{repeat_number}_Fold:{fold}.hdf5'
        cb_checkpt = tf.keras.callbacks.ModelCheckpoint(checkpt_path, 
                                                        monitor = 'val_loss', 
                                                        verbose = 2, 
                                                        save_best_only = True, 
                                                        save_weights_only = True, 
                                                        mode = 'min')

        model = my_model()
        model.fit(x_train.values[i_tr], y_train.values[i_tr],
                  validation_data = (x_train.values[i_va], y_train.values[i_va]),
                  callbacks = [cb_lr_schedule, cb_early_stop, cb_checkpt],
                  epochs = EPOCHS, 
                  batch_size = BATCH_SIZE, 
                  verbose = 2)
        
        model.load_weights(checkpt_path)
        oof_pred.loc[i_va, :] = model.predict(x_train.values[i_va])
        models.append(model)

    return models, oof_pred

# %%
models = []
oof_pred = []

for i in range(REPEATS):
    m, oof = train(repeat_number = i, folds = FOLDS)
    print('-'*85)
    models = models + m
    oof_pred.append(oof)
# Out:
# -------------------------------------------------------------------------------------
# Repeat 0, Fold 0
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.07935, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.4460 - accuracy: 0.0222 - val_loss: 0.0793 - val_accuracy: 0.0292
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.07935 to 0.02535, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0399 - accuracy: 0.0388 - val_loss: 0.0253 - val_accuracy: 0.0407
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02535 to 0.02052, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0227 - accuracy: 0.0553 - val_loss: 0.0205 - val_accuracy: 0.0831
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.02052 to 0.01867, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0197 - accuracy: 0.0764 - val_loss: 0.0187 - val_accuracy: 0.0779
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01867 to 0.01770, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0181 - accuracy: 0.0934 - val_loss: 0.0177 - val_accuracy: 0.0846
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01770 to 0.01692, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0173 - accuracy: 0.1070 - val_loss: 0.0169 - val_accuracy: 0.1258
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01692 to 0.01653, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0165 - accuracy: 0.1203 - val_loss: 0.0165 - val_accuracy: 0.1018
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01653 to 0.01629, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0161 - accuracy: 0.1254 - val_loss: 0.0163 - val_accuracy: 0.1092
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01629 to 0.01611, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0155 - accuracy: 0.1292 - val_loss: 0.0161 - val_accuracy: 0.1285
# Epoch 10/64
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00010: val_loss improved from 0.01611 to 0.01610, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0152 - accuracy: 0.1427 - val_loss: 0.0161 - val_accuracy: 0.1151
# Epoch 11/64
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00011: val_loss improved from 0.01610 to 0.01602, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0144 - accuracy: 0.1571 - val_loss: 0.0160 - val_accuracy: 0.1270
# Epoch 12/64
#
# Epoch 00012: val_loss improved from 0.01602 to 0.01585, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 26s - loss: 0.0138 - accuracy: 0.1678 - val_loss: 0.0158 - val_accuracy: 0.1226
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00013: val_loss improved from 0.01585 to 0.01583, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1715 - val_loss: 0.0158 - val_accuracy: 0.1239
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00014: val_loss improved from 0.01583 to 0.01582, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0132 - accuracy: 0.1876 - val_loss: 0.0158 - val_accuracy: 0.1245
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00015: val_loss improved from 0.01582 to 0.01581, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0131 - accuracy: 0.1905 - val_loss: 0.0158 - val_accuracy: 0.1232
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00016: val_loss improved from 0.01581 to 0.01580, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.1911 - val_loss: 0.0158 - val_accuracy: 0.1235
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00017: val_loss did not improve from 0.01580
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.1950 - val_loss: 0.0158 - val_accuracy: 0.1239
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00018: val_loss did not improve from 0.01580
# 149/149 - 22s - loss: 0.0129 - accuracy: 0.1937 - val_loss: 0.0158 - val_accuracy: 0.1241
# Epoch 19/64
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.097151764246519e-07.
#
# Epoch 00019: val_loss did not improve from 0.01580
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.1922 - val_loss: 0.0158 - val_accuracy: 0.1239
# Epoch 20/64
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 8.388607284359751e-08.
#
# Epoch 00020: val_loss improved from 0.01580 to 0.01580, saving model to repeat:0_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.1930 - val_loss: 0.0158 - val_accuracy: 0.1239
# Epoch 21/64
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.355442856900481e-08.
#
# Epoch 00021: val_loss did not improve from 0.01580
# 149/149 - 22s - loss: 0.0132 - accuracy: 0.1906 - val_loss: 0.0158 - val_accuracy: 0.1239
# Epoch 22/64
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.3421771427601926e-08.
#
# Epoch 00022: val_loss did not improve from 0.01580
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.1919 - val_loss: 0.0158 - val_accuracy: 0.1235
# Epoch 23/64
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.368708499986497e-09.
#
# Epoch 00023: val_loss did not improve from 0.01580
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.1938 - val_loss: 0.0158 - val_accuracy: 0.1237
# Epoch 24/64
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.1474834355217353e-09.
#
# Epoch 00024: val_loss did not improve from 0.01580
# 149/149 - 22s - loss: 0.0131 - accuracy: 0.1933 - val_loss: 0.0158 - val_accuracy: 0.1239
# Epoch 00024: early stopping
# -------------------------------------------------------------------------------------
# Repeat 0, Fold 1
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.07072, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 22s - loss: 0.4472 - accuracy: 0.0231 - val_loss: 0.0707 - val_accuracy: 0.0252
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.07072 to 0.02382, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0399 - accuracy: 0.0345 - val_loss: 0.0238 - val_accuracy: 0.0319
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02382 to 0.01986, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0228 - accuracy: 0.0487 - val_loss: 0.0199 - val_accuracy: 0.0676
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.01986 to 0.01823, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0200 - accuracy: 0.0730 - val_loss: 0.0182 - val_accuracy: 0.0768
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01823 to 0.01729, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0185 - accuracy: 0.0925 - val_loss: 0.0173 - val_accuracy: 0.0886
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01729 to 0.01662, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0176 - accuracy: 0.1027 - val_loss: 0.0166 - val_accuracy: 0.1190
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01662 to 0.01618, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0169 - accuracy: 0.1196 - val_loss: 0.0162 - val_accuracy: 0.1033
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01618 to 0.01579, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0163 - accuracy: 0.1260 - val_loss: 0.0158 - val_accuracy: 0.1083
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01579 to 0.01557, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0157 - accuracy: 0.1380 - val_loss: 0.0156 - val_accuracy: 0.1396
# Epoch 10/64
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00010: val_loss improved from 0.01557 to 0.01548, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0153 - accuracy: 0.1456 - val_loss: 0.0155 - val_accuracy: 0.1165
# Epoch 11/64
#
# Epoch 00011: val_loss improved from 0.01548 to 0.01533, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0144 - accuracy: 0.1630 - val_loss: 0.0153 - val_accuracy: 0.1209
# Epoch 12/64
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00012: val_loss did not improve from 0.01533
# 149/149 - 21s - loss: 0.0140 - accuracy: 0.1818 - val_loss: 0.0153 - val_accuracy: 0.1239
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00013: val_loss improved from 0.01533 to 0.01526, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0134 - accuracy: 0.1917 - val_loss: 0.0153 - val_accuracy: 0.1239
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00014: val_loss improved from 0.01526 to 0.01523, saving model to repeat:0_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.2024 - val_loss: 0.0152 - val_accuracy: 0.1237
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00015: val_loss did not improve from 0.01523
# 149/149 - 21s - loss: 0.0129 - accuracy: 0.2064 - val_loss: 0.0152 - val_accuracy: 0.1232
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00016: val_loss did not improve from 0.01523
# 149/149 - 26s - loss: 0.0128 - accuracy: 0.2092 - val_loss: 0.0152 - val_accuracy: 0.1241
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00017: val_loss did not improve from 0.01523
# 149/149 - 22s - loss: 0.0128 - accuracy: 0.2093 - val_loss: 0.0152 - val_accuracy: 0.1235
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00018: val_loss did not improve from 0.01523
# 149/149 - 21s - loss: 0.0127 - accuracy: 0.2090 - val_loss: 0.0152 - val_accuracy: 0.1232
# Epoch 00018: early stopping
# -------------------------------------------------------------------------------------
# Repeat 0, Fold 2
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.07039, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 23s - loss: 0.4428 - accuracy: 0.0296 - val_loss: 0.0704 - val_accuracy: 0.0464
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.07039 to 0.02346, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0388 - accuracy: 0.0423 - val_loss: 0.0235 - val_accuracy: 0.0785
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02346 to 0.01947, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0224 - accuracy: 0.0646 - val_loss: 0.0195 - val_accuracy: 0.0672
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.01947 to 0.01785, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0196 - accuracy: 0.0842 - val_loss: 0.0178 - val_accuracy: 0.0915
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01785 to 0.01688, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0182 - accuracy: 0.1000 - val_loss: 0.0169 - val_accuracy: 0.0938
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01688 to 0.01620, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0172 - accuracy: 0.1108 - val_loss: 0.0162 - val_accuracy: 0.1381
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01620 to 0.01603, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0166 - accuracy: 0.1200 - val_loss: 0.0160 - val_accuracy: 0.1073
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01603 to 0.01566, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0160 - accuracy: 0.1283 - val_loss: 0.0157 - val_accuracy: 0.1447
# Epoch 9/64
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00009: val_loss did not improve from 0.01566
# 149/149 - 22s - loss: 0.0155 - accuracy: 0.1423 - val_loss: 0.0157 - val_accuracy: 0.1258
# Epoch 10/64
#
# Epoch 00010: val_loss improved from 0.01566 to 0.01537, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0148 - accuracy: 0.1591 - val_loss: 0.0154 - val_accuracy: 0.1300
# Epoch 11/64
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00011: val_loss improved from 0.01537 to 0.01532, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0142 - accuracy: 0.1736 - val_loss: 0.0153 - val_accuracy: 0.1256
# Epoch 12/64
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00012: val_loss improved from 0.01532 to 0.01528, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0137 - accuracy: 0.1846 - val_loss: 0.0153 - val_accuracy: 0.1228
# Epoch 13/64
#
# Epoch 00013: val_loss improved from 0.01528 to 0.01525, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0133 - accuracy: 0.1930 - val_loss: 0.0153 - val_accuracy: 0.1270
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00014: val_loss improved from 0.01525 to 0.01522, saving model to repeat:0_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0132 - accuracy: 0.2000 - val_loss: 0.0152 - val_accuracy: 0.1268
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00015: val_loss did not improve from 0.01522
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.2030 - val_loss: 0.0152 - val_accuracy: 0.1264
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00016: val_loss did not improve from 0.01522
# 149/149 - 21s - loss: 0.0129 - accuracy: 0.2053 - val_loss: 0.0152 - val_accuracy: 0.1256
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00017: val_loss did not improve from 0.01522
# 149/149 - 21s - loss: 0.0129 - accuracy: 0.2071 - val_loss: 0.0152 - val_accuracy: 0.1251
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00018: val_loss did not improve from 0.01522
# 149/149 - 22s - loss: 0.0128 - accuracy: 0.2097 - val_loss: 0.0152 - val_accuracy: 0.1258
# Epoch 00018: early stopping
# -------------------------------------------------------------------------------------
# Repeat 0, Fold 3
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.06352, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 22s - loss: 0.4466 - accuracy: 0.0177 - val_loss: 0.0635 - val_accuracy: 0.0076
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.06352 to 0.02400, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0391 - accuracy: 0.0347 - val_loss: 0.0240 - val_accuracy: 0.0617
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02400 to 0.02022, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0225 - accuracy: 0.0488 - val_loss: 0.0202 - val_accuracy: 0.0697
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.02022 to 0.01885, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0198 - accuracy: 0.0723 - val_loss: 0.0188 - val_accuracy: 0.0758
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01885 to 0.01767, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 23s - loss: 0.0181 - accuracy: 0.0923 - val_loss: 0.0177 - val_accuracy: 0.1155
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01767 to 0.01704, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0173 - accuracy: 0.1089 - val_loss: 0.0170 - val_accuracy: 0.0976
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01704 to 0.01648, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0165 - accuracy: 0.1181 - val_loss: 0.0165 - val_accuracy: 0.1243
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01648 to 0.01623, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 23s - loss: 0.0160 - accuracy: 0.1239 - val_loss: 0.0162 - val_accuracy: 0.1062
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01623 to 0.01604, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0155 - accuracy: 0.1387 - val_loss: 0.0160 - val_accuracy: 0.1140
# Epoch 10/64
#
# Epoch 00010: val_loss improved from 0.01604 to 0.01594, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0151 - accuracy: 0.1422 - val_loss: 0.0159 - val_accuracy: 0.1172
# Epoch 11/64
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00011: val_loss did not improve from 0.01594
# 149/149 - 21s - loss: 0.0148 - accuracy: 0.1566 - val_loss: 0.0165 - val_accuracy: 0.1461
# Epoch 12/64
#
# Epoch 00012: val_loss improved from 0.01594 to 0.01566, saving model to repeat:0_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0138 - accuracy: 0.1789 - val_loss: 0.0157 - val_accuracy: 0.1302
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00013: val_loss did not improve from 0.01566
# 149/149 - 22s - loss: 0.0132 - accuracy: 0.1904 - val_loss: 0.0157 - val_accuracy: 0.1260
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00014: val_loss did not improve from 0.01566
# 149/149 - 21s - loss: 0.0125 - accuracy: 0.2135 - val_loss: 0.0157 - val_accuracy: 0.1262
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00015: val_loss did not improve from 0.01566
# 149/149 - 21s - loss: 0.0121 - accuracy: 0.2229 - val_loss: 0.0157 - val_accuracy: 0.1258
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00016: val_loss did not improve from 0.01566
# 149/149 - 22s - loss: 0.0119 - accuracy: 0.2296 - val_loss: 0.0157 - val_accuracy: 0.1266
# Epoch 00016: early stopping
# -------------------------------------------------------------------------------------
# Repeat 0, Fold 4
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.06479, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 21s - loss: 0.4456 - accuracy: 0.0188 - val_loss: 0.0648 - val_accuracy: 0.0164
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.06479 to 0.02382, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0388 - accuracy: 0.0411 - val_loss: 0.0238 - val_accuracy: 0.0344
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02382 to 0.02011, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0224 - accuracy: 0.0641 - val_loss: 0.0201 - val_accuracy: 0.0580
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.02011 to 0.01852, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0195 - accuracy: 0.0827 - val_loss: 0.0185 - val_accuracy: 0.0798
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01852 to 0.01773, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0180 - accuracy: 0.0980 - val_loss: 0.0177 - val_accuracy: 0.1184
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01773 to 0.01679, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0172 - accuracy: 0.1124 - val_loss: 0.0168 - val_accuracy: 0.1002
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01679 to 0.01641, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0164 - accuracy: 0.1184 - val_loss: 0.0164 - val_accuracy: 0.1037
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01641 to 0.01609, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0159 - accuracy: 0.1288 - val_loss: 0.0161 - val_accuracy: 0.1063
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01609 to 0.01584, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 23s - loss: 0.0154 - accuracy: 0.1399 - val_loss: 0.0158 - val_accuracy: 0.1237
# Epoch 10/64
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00010: val_loss did not improve from 0.01584
# 149/149 - 21s - loss: 0.0149 - accuracy: 0.1514 - val_loss: 0.0159 - val_accuracy: 0.1180
# Epoch 11/64
#
# Epoch 00011: val_loss improved from 0.01584 to 0.01562, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0141 - accuracy: 0.1712 - val_loss: 0.0156 - val_accuracy: 0.1205
# Epoch 12/64
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00012: val_loss did not improve from 0.01562
# 149/149 - 21s - loss: 0.0135 - accuracy: 0.1869 - val_loss: 0.0157 - val_accuracy: 0.1243
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00013: val_loss improved from 0.01562 to 0.01554, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0129 - accuracy: 0.2066 - val_loss: 0.0155 - val_accuracy: 0.1254
# Epoch 14/64
#
# Epoch 00014: val_loss improved from 0.01554 to 0.01550, saving model to repeat:0_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0125 - accuracy: 0.2159 - val_loss: 0.0155 - val_accuracy: 0.1258
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00015: val_loss did not improve from 0.01550
# 149/149 - 22s - loss: 0.0123 - accuracy: 0.2239 - val_loss: 0.0155 - val_accuracy: 0.1285
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00016: val_loss did not improve from 0.01550
# 149/149 - 22s - loss: 0.0122 - accuracy: 0.2284 - val_loss: 0.0155 - val_accuracy: 0.1281
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00017: val_loss did not improve from 0.01550
# 149/149 - 22s - loss: 0.0121 - accuracy: 0.2280 - val_loss: 0.0155 - val_accuracy: 0.1287
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00018: val_loss did not improve from 0.01550
# 149/149 - 22s - loss: 0.0120 - accuracy: 0.2339 - val_loss: 0.0155 - val_accuracy: 0.1285
# Epoch 00018: early stopping
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# Repeat 1, Fold 0
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.07791, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 24s - loss: 0.4469 - accuracy: 0.0208 - val_loss: 0.0779 - val_accuracy: 0.0279
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.07791 to 0.02444, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0393 - accuracy: 0.0385 - val_loss: 0.0244 - val_accuracy: 0.0680
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02444 to 0.02068, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0228 - accuracy: 0.0549 - val_loss: 0.0207 - val_accuracy: 0.0634
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.02068 to 0.01864, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0197 - accuracy: 0.0766 - val_loss: 0.0186 - val_accuracy: 0.0796
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01864 to 0.01751, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0181 - accuracy: 0.0937 - val_loss: 0.0175 - val_accuracy: 0.0911
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01751 to 0.01694, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0171 - accuracy: 0.1062 - val_loss: 0.0169 - val_accuracy: 0.1022
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01694 to 0.01648, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0164 - accuracy: 0.1207 - val_loss: 0.0165 - val_accuracy: 0.1067
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01648 to 0.01635, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0159 - accuracy: 0.1272 - val_loss: 0.0163 - val_accuracy: 0.1127
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01635 to 0.01607, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0154 - accuracy: 0.1372 - val_loss: 0.0161 - val_accuracy: 0.1214
# Epoch 10/64
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00010: val_loss improved from 0.01607 to 0.01598, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0150 - accuracy: 0.1490 - val_loss: 0.0160 - val_accuracy: 0.1176
# Epoch 11/64
#
# Epoch 00011: val_loss improved from 0.01598 to 0.01575, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0141 - accuracy: 0.1662 - val_loss: 0.0157 - val_accuracy: 0.1253
# Epoch 12/64
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00012: val_loss did not improve from 0.01575
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1793 - val_loss: 0.0158 - val_accuracy: 0.1287
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00013: val_loss improved from 0.01575 to 0.01574, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0129 - accuracy: 0.1938 - val_loss: 0.0157 - val_accuracy: 0.1274
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00014: val_loss improved from 0.01574 to 0.01570, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 21s - loss: 0.0125 - accuracy: 0.2095 - val_loss: 0.0157 - val_accuracy: 0.1283
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00015: val_loss improved from 0.01570 to 0.01569, saving model to repeat:1_Fold:0.hdf5
# 149/149 - 22s - loss: 0.0123 - accuracy: 0.2147 - val_loss: 0.0157 - val_accuracy: 0.1298
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00016: val_loss did not improve from 0.01569
# 149/149 - 21s - loss: 0.0122 - accuracy: 0.2162 - val_loss: 0.0157 - val_accuracy: 0.1300
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00017: val_loss did not improve from 0.01569
# 149/149 - 22s - loss: 0.0121 - accuracy: 0.2210 - val_loss: 0.0157 - val_accuracy: 0.1293
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00018: val_loss did not improve from 0.01569
# 149/149 - 22s - loss: 0.0121 - accuracy: 0.2207 - val_loss: 0.0157 - val_accuracy: 0.1295
# Epoch 19/64
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.097151764246519e-07.
#
# Epoch 00019: val_loss did not improve from 0.01569
# 149/149 - 21s - loss: 0.0122 - accuracy: 0.2215 - val_loss: 0.0157 - val_accuracy: 0.1302
# Epoch 00019: early stopping
# -------------------------------------------------------------------------------------
# Repeat 1, Fold 1
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.08140, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 22s - loss: 0.4456 - accuracy: 0.0260 - val_loss: 0.0814 - val_accuracy: 0.0367
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.08140 to 0.02398, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0393 - accuracy: 0.0414 - val_loss: 0.0240 - val_accuracy: 0.0632
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02398 to 0.01969, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0225 - accuracy: 0.0631 - val_loss: 0.0197 - val_accuracy: 0.0638
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.01969 to 0.01790, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0196 - accuracy: 0.0821 - val_loss: 0.0179 - val_accuracy: 0.1020
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01790 to 0.01706, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0183 - accuracy: 0.0961 - val_loss: 0.0171 - val_accuracy: 0.0878
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01706 to 0.01639, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0175 - accuracy: 0.1081 - val_loss: 0.0164 - val_accuracy: 0.1218
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01639 to 0.01597, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0166 - accuracy: 0.1162 - val_loss: 0.0160 - val_accuracy: 0.1037
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01597 to 0.01571, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0162 - accuracy: 0.1224 - val_loss: 0.0157 - val_accuracy: 0.1094
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01571 to 0.01554, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0156 - accuracy: 0.1349 - val_loss: 0.0155 - val_accuracy: 0.1140
# Epoch 10/64
#
# Epoch 00010: val_loss improved from 0.01554 to 0.01544, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 23s - loss: 0.0152 - accuracy: 0.1489 - val_loss: 0.0154 - val_accuracy: 0.1161
# Epoch 11/64
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00011: val_loss did not improve from 0.01544
# 149/149 - 21s - loss: 0.0147 - accuracy: 0.1490 - val_loss: 0.0157 - val_accuracy: 0.1193
# Epoch 12/64
#
# Epoch 00012: val_loss improved from 0.01544 to 0.01530, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 22s - loss: 0.0138 - accuracy: 0.1783 - val_loss: 0.0153 - val_accuracy: 0.1253
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00013: val_loss did not improve from 0.01530
# 149/149 - 22s - loss: 0.0132 - accuracy: 0.1932 - val_loss: 0.0154 - val_accuracy: 0.1222
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00014: val_loss improved from 0.01530 to 0.01527, saving model to repeat:1_Fold:1.hdf5
# 149/149 - 23s - loss: 0.0125 - accuracy: 0.2155 - val_loss: 0.0153 - val_accuracy: 0.1251
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00015: val_loss did not improve from 0.01527
# 149/149 - 22s - loss: 0.0121 - accuracy: 0.2274 - val_loss: 0.0153 - val_accuracy: 0.1295
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00016: val_loss did not improve from 0.01527
# 149/149 - 21s - loss: 0.0120 - accuracy: 0.2331 - val_loss: 0.0153 - val_accuracy: 0.1289
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00017: val_loss did not improve from 0.01527
# 149/149 - 22s - loss: 0.0118 - accuracy: 0.2391 - val_loss: 0.0153 - val_accuracy: 0.1300
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00018: val_loss did not improve from 0.01527
# 149/149 - 21s - loss: 0.0118 - accuracy: 0.2404 - val_loss: 0.0153 - val_accuracy: 0.1304
# Epoch 00018: early stopping
# -------------------------------------------------------------------------------------
# Repeat 1, Fold 2
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.07350, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.4456 - accuracy: 0.0164 - val_loss: 0.0735 - val_accuracy: 0.0353
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.07350 to 0.02401, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0395 - accuracy: 0.0396 - val_loss: 0.0240 - val_accuracy: 0.0724
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02401 to 0.01975, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0227 - accuracy: 0.0589 - val_loss: 0.0198 - val_accuracy: 0.0789
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.01975 to 0.01830, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0198 - accuracy: 0.0806 - val_loss: 0.0183 - val_accuracy: 0.0829
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01830 to 0.01724, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0182 - accuracy: 0.0981 - val_loss: 0.0172 - val_accuracy: 0.1121
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01724 to 0.01622, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0172 - accuracy: 0.1103 - val_loss: 0.0162 - val_accuracy: 0.1272
# Epoch 7/64
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00007: val_loss improved from 0.01622 to 0.01621, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0167 - accuracy: 0.1192 - val_loss: 0.0162 - val_accuracy: 0.1088
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01621 to 0.01586, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0160 - accuracy: 0.1263 - val_loss: 0.0159 - val_accuracy: 0.1241
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01586 to 0.01567, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0156 - accuracy: 0.1362 - val_loss: 0.0157 - val_accuracy: 0.1247
# Epoch 10/64
#
# Epoch 00010: val_loss improved from 0.01567 to 0.01557, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0153 - accuracy: 0.1440 - val_loss: 0.0156 - val_accuracy: 0.1136
# Epoch 11/64
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00011: val_loss improved from 0.01557 to 0.01550, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0148 - accuracy: 0.1563 - val_loss: 0.0155 - val_accuracy: 0.1295
# Epoch 12/64
#
# Epoch 00012: val_loss improved from 0.01550 to 0.01541, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0145 - accuracy: 0.1668 - val_loss: 0.0154 - val_accuracy: 0.1184
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00013: val_loss improved from 0.01541 to 0.01540, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0141 - accuracy: 0.1706 - val_loss: 0.0154 - val_accuracy: 0.1216
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00014: val_loss improved from 0.01540 to 0.01534, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0138 - accuracy: 0.1827 - val_loss: 0.0153 - val_accuracy: 0.1230
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00015: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0137 - accuracy: 0.1870 - val_loss: 0.0154 - val_accuracy: 0.1207
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00016: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1861 - val_loss: 0.0153 - val_accuracy: 0.1214
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00017: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1901 - val_loss: 0.0153 - val_accuracy: 0.1214
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00018: val_loss improved from 0.01534 to 0.01534, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1883 - val_loss: 0.0153 - val_accuracy: 0.1220
# Epoch 19/64
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.097151764246519e-07.
#
# Epoch 00019: val_loss did not improve from 0.01534
# 149/149 - 23s - loss: 0.0134 - accuracy: 0.1884 - val_loss: 0.0153 - val_accuracy: 0.1216
# Epoch 20/64
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 8.388607284359751e-08.
#
# Epoch 00020: val_loss did not improve from 0.01534
# 149/149 - 21s - loss: 0.0134 - accuracy: 0.1905 - val_loss: 0.0153 - val_accuracy: 0.1226
# Epoch 21/64
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.355442856900481e-08.
#
# Epoch 00021: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1882 - val_loss: 0.0153 - val_accuracy: 0.1216
# Epoch 22/64
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.3421771427601926e-08.
#
# Epoch 00022: val_loss improved from 0.01534 to 0.01534, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0136 - accuracy: 0.1895 - val_loss: 0.0153 - val_accuracy: 0.1218
# Epoch 23/64
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.368708499986497e-09.
#
# Epoch 00023: val_loss did not improve from 0.01534
# 149/149 - 21s - loss: 0.0134 - accuracy: 0.1889 - val_loss: 0.0153 - val_accuracy: 0.1222
# Epoch 24/64
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.1474834355217353e-09.
#
# Epoch 00024: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1905 - val_loss: 0.0153 - val_accuracy: 0.1214
# Epoch 25/64
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 8.58993409735831e-10.
#
# Epoch 00025: val_loss improved from 0.01534 to 0.01534, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0135 - accuracy: 0.1901 - val_loss: 0.0153 - val_accuracy: 0.1214
# Epoch 26/64
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 3.4359737277611657e-10.
#
# Epoch 00026: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1884 - val_loss: 0.0153 - val_accuracy: 0.1209
# Epoch 27/64
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.3743894911044663e-10.
#
# Epoch 00027: val_loss improved from 0.01534 to 0.01534, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1908 - val_loss: 0.0153 - val_accuracy: 0.1214
# Epoch 28/64
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 5.497557964417865e-11.
#
# Epoch 00028: val_loss improved from 0.01534 to 0.01534, saving model to repeat:1_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1896 - val_loss: 0.0153 - val_accuracy: 0.1207
# Epoch 29/64
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 2.1990231857671463e-11.
#
# Epoch 00029: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1893 - val_loss: 0.0153 - val_accuracy: 0.1220
# Epoch 30/64
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 8.796093020624341e-12.
#
# Epoch 00030: val_loss did not improve from 0.01534
# 149/149 - 21s - loss: 0.0135 - accuracy: 0.1879 - val_loss: 0.0153 - val_accuracy: 0.1222
# Epoch 31/64
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 3.518437277638675e-12.
#
# Epoch 00031: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1894 - val_loss: 0.0153 - val_accuracy: 0.1218
# Epoch 32/64
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.4073749110554701e-12.
#
# Epoch 00032: val_loss did not improve from 0.01534
# 149/149 - 22s - loss: 0.0135 - accuracy: 0.1884 - val_loss: 0.0153 - val_accuracy: 0.1220
# Epoch 00032: early stopping
# -------------------------------------------------------------------------------------
# Repeat 1, Fold 3
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.07508, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.4439 - accuracy: 0.0204 - val_loss: 0.0751 - val_accuracy: 0.0453
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.07508 to 0.02362, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0391 - accuracy: 0.0435 - val_loss: 0.0236 - val_accuracy: 0.0670
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02362 to 0.01998, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0225 - accuracy: 0.0626 - val_loss: 0.0200 - val_accuracy: 0.0632
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.01998 to 0.01856, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0195 - accuracy: 0.0872 - val_loss: 0.0186 - val_accuracy: 0.1025
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01856 to 0.01736, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 23s - loss: 0.0179 - accuracy: 0.1021 - val_loss: 0.0174 - val_accuracy: 0.1075
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01736 to 0.01680, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0170 - accuracy: 0.1133 - val_loss: 0.0168 - val_accuracy: 0.1035
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01680 to 0.01638, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0164 - accuracy: 0.1219 - val_loss: 0.0164 - val_accuracy: 0.1054
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01638 to 0.01609, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0158 - accuracy: 0.1306 - val_loss: 0.0161 - val_accuracy: 0.1090
# Epoch 9/64
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00009: val_loss did not improve from 0.01609
# 149/149 - 21s - loss: 0.0154 - accuracy: 0.1387 - val_loss: 0.0161 - val_accuracy: 0.1193
# Epoch 10/64
#
# Epoch 00010: val_loss improved from 0.01609 to 0.01580, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0146 - accuracy: 0.1590 - val_loss: 0.0158 - val_accuracy: 0.1178
# Epoch 11/64
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00011: val_loss improved from 0.01580 to 0.01579, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0143 - accuracy: 0.1678 - val_loss: 0.0158 - val_accuracy: 0.1178
# Epoch 12/64
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00012: val_loss improved from 0.01579 to 0.01570, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0137 - accuracy: 0.1829 - val_loss: 0.0157 - val_accuracy: 0.1222
# Epoch 13/64
#
# Epoch 00013: val_loss improved from 0.01570 to 0.01569, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0133 - accuracy: 0.1908 - val_loss: 0.0157 - val_accuracy: 0.1197
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00014: val_loss improved from 0.01569 to 0.01567, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0132 - accuracy: 0.1948 - val_loss: 0.0157 - val_accuracy: 0.1216
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00015: val_loss did not improve from 0.01567
# 149/149 - 24s - loss: 0.0130 - accuracy: 0.1991 - val_loss: 0.0157 - val_accuracy: 0.1214
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00016: val_loss did not improve from 0.01567
# 149/149 - 22s - loss: 0.0129 - accuracy: 0.2024 - val_loss: 0.0157 - val_accuracy: 0.1218
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00017: val_loss did not improve from 0.01567
# 149/149 - 21s - loss: 0.0129 - accuracy: 0.2036 - val_loss: 0.0157 - val_accuracy: 0.1218
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00018: val_loss improved from 0.01567 to 0.01567, saving model to repeat:1_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0129 - accuracy: 0.2037 - val_loss: 0.0157 - val_accuracy: 0.1222
# Epoch 19/64
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.097151764246519e-07.
#
# Epoch 00019: val_loss did not improve from 0.01567
# 149/149 - 22s - loss: 0.0129 - accuracy: 0.2018 - val_loss: 0.0157 - val_accuracy: 0.1222
# Epoch 20/64
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 8.388607284359751e-08.
#
# Epoch 00020: val_loss did not improve from 0.01567
# 149/149 - 23s - loss: 0.0129 - accuracy: 0.2049 - val_loss: 0.0157 - val_accuracy: 0.1222
# Epoch 21/64
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.355442856900481e-08.
#
# Epoch 00021: val_loss did not improve from 0.01567
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.2054 - val_loss: 0.0157 - val_accuracy: 0.1222
# Epoch 22/64
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.3421771427601926e-08.
#
# Epoch 00022: val_loss did not improve from 0.01567
# 149/149 - 21s - loss: 0.0129 - accuracy: 0.2039 - val_loss: 0.0157 - val_accuracy: 0.1220
# Epoch 00022: early stopping
# -------------------------------------------------------------------------------------
# Repeat 1, Fold 4
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.06588, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 22s - loss: 0.4461 - accuracy: 0.0229 - val_loss: 0.0659 - val_accuracy: 0.0260
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.06588 to 0.02497, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0395 - accuracy: 0.0368 - val_loss: 0.0250 - val_accuracy: 0.0653
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02497 to 0.01984, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0226 - accuracy: 0.0545 - val_loss: 0.0198 - val_accuracy: 0.0529
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.01984 to 0.01850, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0197 - accuracy: 0.0740 - val_loss: 0.0185 - val_accuracy: 0.0771
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01850 to 0.01770, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0181 - accuracy: 0.0919 - val_loss: 0.0177 - val_accuracy: 0.0884
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01770 to 0.01683, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0173 - accuracy: 0.1039 - val_loss: 0.0168 - val_accuracy: 0.0916
# Epoch 7/64
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00007: val_loss improved from 0.01683 to 0.01683, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0166 - accuracy: 0.1124 - val_loss: 0.0168 - val_accuracy: 0.1046
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01683 to 0.01610, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0158 - accuracy: 0.1293 - val_loss: 0.0161 - val_accuracy: 0.1109
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01610 to 0.01595, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0155 - accuracy: 0.1352 - val_loss: 0.0159 - val_accuracy: 0.1109
# Epoch 10/64
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00010: val_loss improved from 0.01595 to 0.01590, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0151 - accuracy: 0.1467 - val_loss: 0.0159 - val_accuracy: 0.1147
# Epoch 11/64
#
# Epoch 00011: val_loss improved from 0.01590 to 0.01579, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0147 - accuracy: 0.1565 - val_loss: 0.0158 - val_accuracy: 0.1201
# Epoch 12/64
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00012: val_loss improved from 0.01579 to 0.01573, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0144 - accuracy: 0.1643 - val_loss: 0.0157 - val_accuracy: 0.1165
# Epoch 13/64
#
# Epoch 00013: val_loss improved from 0.01573 to 0.01567, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0140 - accuracy: 0.1729 - val_loss: 0.0157 - val_accuracy: 0.1189
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00014: val_loss improved from 0.01567 to 0.01567, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0140 - accuracy: 0.1760 - val_loss: 0.0157 - val_accuracy: 0.1201
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00015: val_loss improved from 0.01567 to 0.01567, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0138 - accuracy: 0.1833 - val_loss: 0.0157 - val_accuracy: 0.1205
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00016: val_loss did not improve from 0.01567
# 149/149 - 22s - loss: 0.0138 - accuracy: 0.1832 - val_loss: 0.0157 - val_accuracy: 0.1210
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00017: val_loss improved from 0.01567 to 0.01566, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0137 - accuracy: 0.1820 - val_loss: 0.0157 - val_accuracy: 0.1210
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00018: val_loss did not improve from 0.01566
# 149/149 - 21s - loss: 0.0137 - accuracy: 0.1830 - val_loss: 0.0157 - val_accuracy: 0.1210
# Epoch 19/64
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.097151764246519e-07.
#
# Epoch 00019: val_loss improved from 0.01566 to 0.01566, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0137 - accuracy: 0.1846 - val_loss: 0.0157 - val_accuracy: 0.1205
# Epoch 20/64
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 8.388607284359751e-08.
#
# Epoch 00020: val_loss improved from 0.01566 to 0.01566, saving model to repeat:1_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0137 - accuracy: 0.1842 - val_loss: 0.0157 - val_accuracy: 0.1207
# Epoch 21/64
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.355442856900481e-08.
#
# Epoch 00021: val_loss did not improve from 0.01566
# 149/149 - 24s - loss: 0.0137 - accuracy: 0.1842 - val_loss: 0.0157 - val_accuracy: 0.1212
# Epoch 22/64
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.3421771427601926e-08.
#
# Epoch 00022: val_loss did not improve from 0.01566
# 149/149 - 21s - loss: 0.0136 - accuracy: 0.1855 - val_loss: 0.0157 - val_accuracy: 0.1210
# Epoch 23/64
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.368708499986497e-09.
#
# Epoch 00023: val_loss did not improve from 0.01566
# 149/149 - 21s - loss: 0.0136 - accuracy: 0.1805 - val_loss: 0.0157 - val_accuracy: 0.1212
# Epoch 24/64
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.1474834355217353e-09.
#
# Epoch 00024: val_loss did not improve from 0.01566
# ...
# Epoch 12/64
#
# Epoch 00012: val_loss improved from 0.01542 to 0.01530, saving model to repeat:4_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0137 - accuracy: 0.1831 - val_loss: 0.0153 - val_accuracy: 0.1222
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00013: val_loss did not improve from 0.01530
# 149/149 - 21s - loss: 0.0131 - accuracy: 0.1982 - val_loss: 0.0153 - val_accuracy: 0.1251
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00014: val_loss improved from 0.01530 to 0.01527, saving model to repeat:4_Fold:1.hdf5
# 149/149 - 21s - loss: 0.0125 - accuracy: 0.2193 - val_loss: 0.0153 - val_accuracy: 0.1272
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00015: val_loss did not improve from 0.01527
# 149/149 - 21s - loss: 0.0120 - accuracy: 0.2275 - val_loss: 0.0153 - val_accuracy: 0.1272
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00016: val_loss did not improve from 0.01527
# 149/149 - 22s - loss: 0.0118 - accuracy: 0.2396 - val_loss: 0.0153 - val_accuracy: 0.1270
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00017: val_loss did not improve from 0.01527
# 149/149 - 21s - loss: 0.0117 - accuracy: 0.2403 - val_loss: 0.0153 - val_accuracy: 0.1277
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00018: val_loss did not improve from 0.01527
# 149/149 - 21s - loss: 0.0117 - accuracy: 0.2418 - val_loss: 0.0153 - val_accuracy: 0.1272
# Epoch 00018: early stopping
# -------------------------------------------------------------------------------------
# Repeat 4, Fold 2
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.08284, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.4483 - accuracy: 0.0200 - val_loss: 0.0828 - val_accuracy: 0.0412
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.08284 to 0.02492, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0401 - accuracy: 0.0403 - val_loss: 0.0249 - val_accuracy: 0.0703
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02492 to 0.01986, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0227 - accuracy: 0.0609 - val_loss: 0.0199 - val_accuracy: 0.0974
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.01986 to 0.01801, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0197 - accuracy: 0.0800 - val_loss: 0.0180 - val_accuracy: 0.0821
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01801 to 0.01698, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0183 - accuracy: 0.0920 - val_loss: 0.0170 - val_accuracy: 0.0903
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01698 to 0.01636, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0174 - accuracy: 0.1026 - val_loss: 0.0164 - val_accuracy: 0.1323
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01636 to 0.01599, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0167 - accuracy: 0.1123 - val_loss: 0.0160 - val_accuracy: 0.1079
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01599 to 0.01578, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0161 - accuracy: 0.1246 - val_loss: 0.0158 - val_accuracy: 0.1115
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01578 to 0.01559, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0156 - accuracy: 0.1375 - val_loss: 0.0156 - val_accuracy: 0.1455
# Epoch 10/64
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00010: val_loss improved from 0.01559 to 0.01553, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 21s - loss: 0.0153 - accuracy: 0.1483 - val_loss: 0.0155 - val_accuracy: 0.1459
# Epoch 11/64
#
# Epoch 00011: val_loss improved from 0.01553 to 0.01534, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0144 - accuracy: 0.1660 - val_loss: 0.0153 - val_accuracy: 0.1241
# Epoch 12/64
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00012: val_loss improved from 0.01534 to 0.01531, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 23s - loss: 0.0140 - accuracy: 0.1735 - val_loss: 0.0153 - val_accuracy: 0.1354
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00013: val_loss improved from 0.01531 to 0.01530, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0134 - accuracy: 0.1908 - val_loss: 0.0153 - val_accuracy: 0.1247
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00014: val_loss improved from 0.01530 to 0.01525, saving model to repeat:4_Fold:2.hdf5
# 149/149 - 22s - loss: 0.0130 - accuracy: 0.1958 - val_loss: 0.0153 - val_accuracy: 0.1256
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00015: val_loss did not improve from 0.01525
# 149/149 - 22s - loss: 0.0129 - accuracy: 0.2030 - val_loss: 0.0153 - val_accuracy: 0.1256
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00016: val_loss did not improve from 0.01525
# 149/149 - 21s - loss: 0.0128 - accuracy: 0.2012 - val_loss: 0.0153 - val_accuracy: 0.1241
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00017: val_loss did not improve from 0.01525
# 149/149 - 22s - loss: 0.0128 - accuracy: 0.2063 - val_loss: 0.0153 - val_accuracy: 0.1235
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00018: val_loss did not improve from 0.01525
# 149/149 - 22s - loss: 0.0127 - accuracy: 0.2067 - val_loss: 0.0153 - val_accuracy: 0.1241
# Epoch 00018: early stopping
# -------------------------------------------------------------------------------------
# Repeat 4, Fold 3
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.08404, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 23s - loss: 0.4468 - accuracy: 0.0284 - val_loss: 0.0840 - val_accuracy: 0.0139
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.08404 to 0.02471, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0402 - accuracy: 0.0378 - val_loss: 0.0247 - val_accuracy: 0.0640
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02471 to 0.02023, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0227 - accuracy: 0.0553 - val_loss: 0.0202 - val_accuracy: 0.0624
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.02023 to 0.01864, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0197 - accuracy: 0.0835 - val_loss: 0.0186 - val_accuracy: 0.0775
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01864 to 0.01782, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0182 - accuracy: 0.0965 - val_loss: 0.0178 - val_accuracy: 0.1102
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01782 to 0.01707, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0173 - accuracy: 0.1137 - val_loss: 0.0171 - val_accuracy: 0.1083
# Epoch 7/64
#
# Epoch 00007: val_loss improved from 0.01707 to 0.01645, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0166 - accuracy: 0.1204 - val_loss: 0.0165 - val_accuracy: 0.1142
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01645 to 0.01624, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0159 - accuracy: 0.1268 - val_loss: 0.0162 - val_accuracy: 0.1090
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01624 to 0.01603, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0154 - accuracy: 0.1396 - val_loss: 0.0160 - val_accuracy: 0.1203
# Epoch 10/64
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00010: val_loss improved from 0.01603 to 0.01597, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 22s - loss: 0.0151 - accuracy: 0.1511 - val_loss: 0.0160 - val_accuracy: 0.1165
# Epoch 11/64
#
# Epoch 00011: val_loss improved from 0.01597 to 0.01580, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0143 - accuracy: 0.1682 - val_loss: 0.0158 - val_accuracy: 0.1327
# Epoch 12/64
#
# Epoch 00012: val_loss improved from 0.01580 to 0.01570, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0137 - accuracy: 0.1842 - val_loss: 0.0157 - val_accuracy: 0.1239
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00013: val_loss did not improve from 0.01570
# 149/149 - 22s - loss: 0.0132 - accuracy: 0.1915 - val_loss: 0.0158 - val_accuracy: 0.1266
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00014: val_loss improved from 0.01570 to 0.01565, saving model to repeat:4_Fold:3.hdf5
# 149/149 - 21s - loss: 0.0125 - accuracy: 0.2165 - val_loss: 0.0157 - val_accuracy: 0.1316
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00015: val_loss did not improve from 0.01565
# 149/149 - 22s - loss: 0.0120 - accuracy: 0.2277 - val_loss: 0.0157 - val_accuracy: 0.1312
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00016: val_loss did not improve from 0.01565
# 149/149 - 22s - loss: 0.0118 - accuracy: 0.2351 - val_loss: 0.0157 - val_accuracy: 0.1314
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00017: val_loss did not improve from 0.01565
# 149/149 - 21s - loss: 0.0118 - accuracy: 0.2379 - val_loss: 0.0157 - val_accuracy: 0.1316
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00018: val_loss did not improve from 0.01565
# 149/149 - 22s - loss: 0.0117 - accuracy: 0.2431 - val_loss: 0.0157 - val_accuracy: 0.1312
# Epoch 00018: early stopping
# -------------------------------------------------------------------------------------
# Repeat 4, Fold 4
# Epoch 1/64
#
# Epoch 00001: val_loss improved from inf to 0.07699, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 21s - loss: 0.4468 - accuracy: 0.0168 - val_loss: 0.0770 - val_accuracy: 0.0160
# Epoch 2/64
#
# Epoch 00002: val_loss improved from 0.07699 to 0.02421, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0391 - accuracy: 0.0428 - val_loss: 0.0242 - val_accuracy: 0.0649
# Epoch 3/64
#
# Epoch 00003: val_loss improved from 0.02421 to 0.01995, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0224 - accuracy: 0.0593 - val_loss: 0.0199 - val_accuracy: 0.0590
# Epoch 4/64
#
# Epoch 00004: val_loss improved from 0.01995 to 0.01844, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 23s - loss: 0.0195 - accuracy: 0.0795 - val_loss: 0.0184 - val_accuracy: 0.0874
# Epoch 5/64
#
# Epoch 00005: val_loss improved from 0.01844 to 0.01753, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0179 - accuracy: 0.0962 - val_loss: 0.0175 - val_accuracy: 0.1199
# Epoch 6/64
#
# Epoch 00006: val_loss improved from 0.01753 to 0.01673, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0171 - accuracy: 0.1130 - val_loss: 0.0167 - val_accuracy: 0.0964
# Epoch 7/64
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00031999999191612005.
#
# Epoch 00007: val_loss did not improve from 0.01673
# 149/149 - 21s - loss: 0.0165 - accuracy: 0.1177 - val_loss: 0.0175 - val_accuracy: 0.1014
# Epoch 8/64
#
# Epoch 00008: val_loss improved from 0.01673 to 0.01610, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0159 - accuracy: 0.1288 - val_loss: 0.0161 - val_accuracy: 0.1056
# Epoch 9/64
#
# Epoch 00009: val_loss improved from 0.01610 to 0.01598, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0155 - accuracy: 0.1379 - val_loss: 0.0160 - val_accuracy: 0.1121
# Epoch 10/64
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00012799999676644803.
#
# Epoch 00010: val_loss improved from 0.01598 to 0.01595, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0151 - accuracy: 0.1479 - val_loss: 0.0160 - val_accuracy: 0.1117
# Epoch 11/64
#
# Epoch 00011: val_loss improved from 0.01595 to 0.01582, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0147 - accuracy: 0.1563 - val_loss: 0.0158 - val_accuracy: 0.1163
# Epoch 12/64
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00012: val_loss improved from 0.01582 to 0.01578, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0144 - accuracy: 0.1641 - val_loss: 0.0158 - val_accuracy: 0.1174
# Epoch 13/64
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.0480000239331277e-05.
#
# Epoch 00013: val_loss improved from 0.01578 to 0.01576, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0141 - accuracy: 0.1737 - val_loss: 0.0158 - val_accuracy: 0.1199
# Epoch 14/64
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 8.191999950213359e-06.
#
# Epoch 00014: val_loss improved from 0.01576 to 0.01575, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0140 - accuracy: 0.1781 - val_loss: 0.0158 - val_accuracy: 0.1197
# Epoch 15/64
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.276799907325767e-06.
#
# Epoch 00015: val_loss improved from 0.01575 to 0.01574, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0139 - accuracy: 0.1804 - val_loss: 0.0157 - val_accuracy: 0.1201
# Epoch 16/64
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.3107199265505188e-06.
#
# Epoch 00016: val_loss improved from 0.01574 to 0.01574, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0139 - accuracy: 0.1812 - val_loss: 0.0157 - val_accuracy: 0.1207
# Epoch 17/64
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 5.242879524303135e-07.
#
# Epoch 00017: val_loss did not improve from 0.01574
# 149/149 - 22s - loss: 0.0139 - accuracy: 0.1790 - val_loss: 0.0157 - val_accuracy: 0.1207
# Epoch 18/64
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 2.097151764246519e-07.
#
# Epoch 00018: val_loss improved from 0.01574 to 0.01574, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0139 - accuracy: 0.1822 - val_loss: 0.0157 - val_accuracy: 0.1203
# Epoch 19/64
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 8.388607284359751e-08.
#
# Epoch 00019: val_loss did not improve from 0.01574
# 149/149 - 23s - loss: 0.0139 - accuracy: 0.1819 - val_loss: 0.0157 - val_accuracy: 0.1212
# Epoch 20/64
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 3.355442856900481e-08.
#
# Epoch 00020: val_loss improved from 0.01574 to 0.01574, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 22s - loss: 0.0139 - accuracy: 0.1799 - val_loss: 0.0157 - val_accuracy: 0.1210
# Epoch 21/64
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.3421771427601926e-08.
#
# Epoch 00021: val_loss improved from 0.01574 to 0.01574, saving model to repeat:4_Fold:4.hdf5
# 149/149 - 21s - loss: 0.0139 - accuracy: 0.1816 - val_loss: 0.0157 - val_accuracy: 0.1210
# Epoch 22/64
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 5.368708499986497e-09.
#
# Epoch 00022: val_loss did not improve from 0.01574
# 149/149 - 22s - loss: 0.0138 - accuracy: 0.1847 - val_loss: 0.0157 - val_accuracy: 0.1210
# Epoch 23/64
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.1474834355217353e-09.
#
# Epoch 00023: val_loss did not improve from 0.01574
# 149/149 - 21s - loss: 0.0138 - accuracy: 0.1804 - val_loss: 0.0157 - val_accuracy: 0.1212
# Epoch 24/64
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 8.58993409735831e-10.
#
# Epoch 00024: val_loss did not improve from 0.01574
# 149/149 - 21s - loss: 0.0139 - accuracy: 0.1800 - val_loss: 0.0157 - val_accuracy: 0.1207
# Epoch 25/64
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.4359737277611657e-10.
#
# Epoch 00025: val_loss did not improve from 0.01574
# 149/149 - 25s - loss: 0.0138 - accuracy: 0.1818 - val_loss: 0.0157 - val_accuracy: 0.1210
# Epoch 00025: early stopping
# -------------------------------------------------------------------------------------

# %% [markdown]
# # 6. Mean OOF Log Loss

# %%
mean_oof_pred = y_train.copy()
mean_oof_pred.loc[:, target_cols] = 0
for i, p in enumerate(oof_pred):
    print(f"Repeat {i} OOF Log Loss: {multi_log_loss(y_train, p)}")
    mean_oof_pred.loc[:, target_cols] += p[target_cols]

mean_oof_pred.loc[:, target_cols] /= len(oof_pred)
print(f"Mean OOF Log Loss: {multi_log_loss(y_train, mean_oof_pred)}")
mean_oof_pred.loc[x_train['cp_type'] == 0, target_cols] = 0
print(f"Mean OOF Log Loss (ctl adjusted): {multi_log_loss(y_train, mean_oof_pred)}")
# Out:
# Repeat 0 OOF Log Loss: 0.015483665395740838
# Repeat 1 OOF Log Loss: 0.01552470895805344
# Repeat 2 OOF Log Loss: 0.015517090891618757
# Repeat 3 OOF Log Loss: 0.015605339865058434
# Repeat 4 OOF Log Loss: 0.01553044152174556
# Mean OOF Log Loss: 0.015222323265951992
# Mean OOF Log Loss (ctl adjusted): 0.015186998066889489

# %% [markdown]
# # 7. Predictions and Submission File

# %%
test_pred = sample_df.copy()
test_pred[target_cols] = 0

for model in models:
    test_pred.loc[:,target_cols] += model.predict(x_test)
test_pred.loc[:,target_cols] /= len(models)
test_pred.loc[x_test['cp_type'] == 0, target_cols] = 0
test_pred.to_csv('submission.csv', index=False)

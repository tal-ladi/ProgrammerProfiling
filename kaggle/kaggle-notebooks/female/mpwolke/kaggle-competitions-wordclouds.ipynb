# %% [markdown]
# #Published on November 12, 2022   By Marília Prata (mpwolke)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import cv2
from wordcloud import WordCloud, ImageColorGenerator

import urllib
import random

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/meta-kaggle/KernelTags.csv
# /kaggle/input/meta-kaggle/KernelVersionCompetitionSources.csv
# /kaggle/input/meta-kaggle/Datasets.csv
# /kaggle/input/meta-kaggle/KernelVersionKernelSources.csv
# /kaggle/input/meta-kaggle/KernelVotes.csv
# /kaggle/input/meta-kaggle/Submissions.csv
# /kaggle/input/meta-kaggle/KernelLanguages.csv
# /kaggle/input/meta-kaggle/Users.csv
# /kaggle/input/meta-kaggle/ForumMessageVotes.csv
# /kaggle/input/meta-kaggle/Competitions.csv
# /kaggle/input/meta-kaggle/DatasetTaskSubmissions.csv
# /kaggle/input/meta-kaggle/UserAchievements.csv
# /kaggle/input/meta-kaggle/UserOrganizations.csv
# /kaggle/input/meta-kaggle/Teams.csv
# /kaggle/input/meta-kaggle/UserFollowers.csv
# /kaggle/input/meta-kaggle/CompetitionTags.csv
# /kaggle/input/meta-kaggle/Kernels.csv
# /kaggle/input/meta-kaggle/Organizations.csv
# /kaggle/input/meta-kaggle/Datasources.csv
# /kaggle/input/meta-kaggle/ForumTopics.csv
# /kaggle/input/meta-kaggle/DatasetVersions.csv
# /kaggle/input/meta-kaggle/DatasetVotes.csv
# /kaggle/input/meta-kaggle/TeamMemberships.csv
# /kaggle/input/meta-kaggle/Forums.csv
# /kaggle/input/meta-kaggle/KernelVersions.csv
# /kaggle/input/meta-kaggle/ForumMessages.csv
# /kaggle/input/meta-kaggle/KernelVersionDatasetSources.csv
# /kaggle/input/meta-kaggle/Episodes.csv
# /kaggle/input/meta-kaggle/EpisodeAgents.csv
# /kaggle/input/meta-kaggle/Tags.csv
# /kaggle/input/meta-kaggle/DatasetTasks.csv
# /kaggle/input/meta-kaggle/DatasetTags.csv

# %% [markdown]
# ![](https://slideplayer.com/slide/9981175/32/images/2/kaggle+What+is+Kaggle+A+data+science+competitions+%3A.jpg)slideplayer.com

# %%
df = pd.read_csv("/kaggle/input/meta-kaggle/Competitions.csv", delimiter=',', encoding='utf8')
pd.set_option('display.max_columns', None)
df.tail()
# Out:
#          Id                                         Slug  \
# 5527  36070                      gdsc-data-science-track
# 5528  36363  rsna-2022-cervical-spine-fracture-detection
# 5529  36414             google-universal-image-embedding
# 5530  37333                         mayo-clinic-strip-ai
# 5531  37381                               ai-village-ctf
#
#                                             Title  \
# 5527             GDSC_Damnhour Data Science Track
# 5528  RSNA 2022 Cervical Spine Fracture Detection
# 5529             Google Universal Image Embedding
# 5530                       Mayo Clinic - STRIP AI
# 5531         AI Village Capture the Flag @ DEFCON
#
#                                                Subtitle HostSegmentTitle  \
# 5527                                   First ML project          InClass
# 5528             Identify cervical fractures from scans         Featured
# 5529  Create image representations that work across ...         Research
# 5530   Image Classification of Stroke Blood Clot Origin         Research
# 5531  Hack AI! Collect flags by evading, poisoning, ...         Research
#
#         ForumId  OrganizationId  CompetitionTypeId HostName  \
# 5527  2103127.0             NaN                  1      NaN
# 5528  2147844.0          1817.0                  1      NaN
# 5529  2153930.0           855.0                  1      NaN
# 5530  2296551.0          3809.0                  1      NaN
# 5531  2305023.0          3812.0                  1      NaN
#
#               EnabledDate         DeadlineDate  \
# 5527  04/12/2022 15:58:30  04/23/2022 23:59:00
# 5528  07/28/2022 17:49:51  10/27/2022 23:59:00
# 5529  07/11/2022 17:09:06  10/10/2022 23:59:00
# 5530  07/06/2022 20:34:00  10/05/2022 23:59:00
# 5531  08/11/2022 21:33:45  09/12/2022 00:00:00
#
#      ProhibitNewEntrantsDeadlineDate TeamMergerDeadlineDate  \
# 5527                             NaN                    NaN
# 5528             10/20/2022 23:59:00    10/20/2022 23:59:00
# 5529             10/03/2022 23:59:00    10/03/2022 23:59:00
# 5530             09/28/2022 23:59:00    09/28/2022 23:59:00
# 5531             09/12/2022 00:00:00    09/12/2022 00:00:00
#
#      TeamModelDeadlineDate ModelSubmissionDeadlineDate  \
# 5527                   NaN                         NaN
# 5528   11/30/2022 00:00:00                         NaN
# 5529   11/23/2022 00:00:00                         NaN
# 5530   11/05/2022 00:00:00                         NaN
# 5531                   NaN                         NaN
#
#       FinalLeaderboardHasBeenVerified  HasKernels  OnlyAllowKernelSubmissions  \
# 5527                             True        True                       False
# 5528                             True        True                        True
# 5529                             True        True                        True
# 5530                             True        True                        True
# 5531                             True        True                       False
#
#       HasLeaderboard  LeaderboardPercentage  LeaderboardDisplayFormat  \
# 5527            True                      0                       0.0
# 5528            True                     28                       0.0
# 5529            True                     50                       0.0
# 5530            True                      7                       0.0
# 5531            True                    100                       0.0
#
#                  EvaluationAlgorithmAbbreviation  \
# 5527                                         MSE
# 5528               WeightedMeanColumnwiseLogLoss
# 5529                     PostProcessorKernelDesc
# 5530                      WeightedMulticlassLoss
# 5531  NvidiaDefconWeightedCategorizationAccuracy
#
#                 EvaluationAlgorithmName  \
# 5527                 Mean Squared Error
# 5528  Weighted Mean Columnwise Log Loss
# 5529            PostProcessorKernelDesc
# 5530           Weighted Multiclass Loss
# 5531                      Nvidia Defcon
#
#                          EvaluationAlgorithmDescription  \
# 5527                 The average of the squared errors.
# 5528      Mean columnwise log loss with sample weights.
# 5529                  Descending LB order PostProcessor
# 5530  Negative log likelihood divided by the number ...
# 5531                     Custom capture-the-flag metric
#
#      EvaluationAlgorithmIsMax ValidationSetName ValidationSetValue  \
# 5527                    False               NaN                NaN
# 5528                    False               NaN                NaN
# 5529                     True               NaN                NaN
# 5530                    False               NaN                NaN
# 5531                     True               NaN                NaN
#
#       MaxDailySubmissions  NumScoredSubmissions  MaxTeamSize  BanTeamMergers  \
# 5527                    5                     2           10           False
# 5528                    5                     2            5           False
# 5529                    5                     2            5           False
# 5530                    1                     2            5           False
# 5531                  100                   100            1            True
#
#       EnableTeamModels  EnableSubmissionModelHashes  \
# 5527             False                        False
# 5528              True                        False
# 5529              True                        False
# 5530              True                        False
# 5531             False                        False
#
#       EnableSubmissionModelAttachments RewardType  RewardQuantity  NumPrizes  \
# 5527                             False        NaN             NaN          1
# 5528                             False        USD         30000.0          8
# 5529                             False        USD         50000.0          6
# 5530                             False        USD         10000.0          3
# 5531                             False        USD         25000.0          5
#
#       UserRankMultiplier  CanQualifyTiers  TotalTeams  TotalCompetitors  \
# 5527                 0.0            False           1                 1
# 5528                 1.0             True         883              1108
# 5529                 1.0             True        1022              1217
# 5530                 1.0             True         888              1025
# 5531                 0.0            False         668               668
#
#       TotalSubmissions
# 5527                 1
# 5528             12871
# 5529             20984
# 5530              6980
# 5531              4235

# %%
text = ' '.join(df["Title"].values)
print("Text example: ")
text[:3000]
# Out:
# Text example:
# "Forecast Eurovision Voting Predict HIV Progression World Cup 2010 - Take on the Quants INFORMS Data Mining Contest 2010 World Cup 2010 - Confidence Challenge Predict Grant Applications Chess ratings - Elo versus the Rest of the World Tourism Forecasting Part One Tourism Forecasting Part Two R Package Recommendation Engine IJCNN Social Network Challenge RTA Freeway Travel Time Prediction Stay Alert! The Ford Challenge Deloitte/FIDE Chess Rating Challenge Mapping Dark Matter ICDAR 2011 - Arabic Writer Identification Don't Overfit! Heritage Health Prize Wikipedia's Participation Challenge Allstate Claim Prediction Challenge dunnhumby's Shopper Challenge Semi-Supervised Feature Learning Give Me Some Credit UCL CoMPLEX MRes module UCL Applied Machine Learning 2 UW STAT331 Linear Models Contest UMICH SI650 - Sentiment Classification Erasmus University Rotterdam - Econometrie 2  - Prediction Competition Don't Get Kicked! Algorithmic Trading Challenge CHALEARN Gesture Challenge What Do You Know? Photo Quality Prediction First International Competition of Time Series Forecasting The Hewlett Foundation: Automated Essay Scoring Mineria de Datos Uniandes UCI Math77B: Collaborative Filtering Benchmark Bond Trade Price Challenge Eye Movements Verification and Identification Competition KDD Cup 2012, Track 1 KDD Cup 2012, Track 2 Обнаружение веб-спама GigaOM WordPress Challenge: Splunk Innovation Prospect ICFHR 2012 - Arabic Writer Identification Predicting a Biological Response Million Song Dataset Challenge Ecopetrol Online Product Sales Psychopathy Prediction Based on Twitter Usage Raising Money to Fund an Organizational Mission CHALEARN Gesture Challenge 2 EMC Data Science Global Hackathon (Air Quality Prediction) Personality Prediction Based on Twitter Stream CPROD1: Consumer PRODucts contest #1 Practice Fusion Analyze This! 2012 - Prediction Challenge Facebook Recruiting Competition Practice Fusion Analyze This! 2012 - Open Challenge EMC Israel Data Science Challenge The Hewlett Foundation: Short Answer Scoring EMI Music Data Science Hackathon - July 21st - 24 hours Belkin Energy Disaggregation Competition Merck Molecular Activity Challenge Practice Fusion Diabetes Classification Detecting Insults in Social Commentary Predict Closed Questions on Stack Overflow Job Recommendation Challenge Data Mining Hackathon on BIG DATA (7GB) Best Buy mobile web site Global Energy Forecasting Competition 2012 - Load Forecasting Global Energy Forecasting Competition 2012 - Wind Forecasting Data Mining Hackathon on (20 mb) Best Buy mobile web site - ACM SF Bay Area Chapter Observing Dark Worlds Harvard Business Review 'Vision Statement' Prospect U.S. Census Return Rate Challenge Follow the Money: Investigative Reporting Prospect Algorithmic composition Berovingen op straat in Rotterdam - is er een patroon? Photometric Redshift Estimation 2012 Facebook II - Mapping the Internet Galaxy Zoo - The Galaxy Challenge Image Classification: car, motorbike, bicycle Yelp Recruiting "

# %%
#Code by Ihelon https://www.kaggle.com/code/ihelon/ukrainian-descriptions-word-cloud-tutorial

def load_mask(mask_url):
    with urllib.request.urlopen(mask_url) as resp:
        mask = np.asarray(bytearray(resp.read()), dtype="uint8")
        mask = cv2.imdecode(mask, cv2.IMREAD_COLOR)
        mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
        
    return mask


mask = load_mask("https://www.kaggle.com/static/images/site-logo.png")

plt.imshow(mask)
plt.axis("off");

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'white',
                      colormap='GnBu', 
                      height =2000,
                      width = 2000
                     ).generate(str(df["EvaluationAlgorithmAbbreviation"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Kaggle Evaluation Algorithm Abbreviation")
plt.show()

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'darkblue',
                      colormap='cool', 
                      height =2000,
                      width = 2000
                     ).generate(str(df["EvaluationAlgorithmDescription"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Kaggle Evaluation Algorithm Description")
plt.show()

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'white',
                      colormap='GnBu', 
                      height =2000,
                      width = 2000
                     ).generate(str(df["EvaluationAlgorithmName"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Kaggle Evaluation Algorithm Name")
plt.show()

# %%
##Code by Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

from wordcloud import WordCloud
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'black',
                      colormap='GnBu', 
                      height =2000,
                      width = 2000
                     ).generate(str(df["HostSegmentTitle"]))
plt.rcParams['figure.figsize'] = (12,12)
plt.axis("off")
plt.imshow(wordcloud)
plt.title("Host Segment Title")
plt.show()

# %%
#Code by Ihelon https://www.kaggle.com/code/ihelon/ukrainian-descriptions-word-cloud-tutorial

new_mask = load_mask(
    "https://www.kaggle.com/static/images/site-logo.png"
)
new_mask = cv2.resize(
    new_mask, 
    (new_mask.shape[1] * 5, new_mask.shape[0] * 5),
)

plt.imshow(new_mask)
plt.axis("off")
plt.show()

wordcloud = WordCloud(
    background_color="black",
    colormap='Reds',
    mask=new_mask,
    random_state=42,
    max_words=1000,
)
    
wordcloud.generate(text) 

image_colors = ImageColorGenerator(new_mask)

plt.figure(figsize=(16, 8))
plt.imshow(
    wordcloud.recolor(color_func=image_colors)
)
plt.axis("off")
plt.show()

# %% [markdown]
# #Acknowledgements:
#
# Ihelon https://www.kaggle.com/code/ihelon/ukrainian-descriptions-word-cloud-tutorial
#
# Taha07  https://www.kaggle.com/taha07/data-scientists-jobs-analysis-visualization/notebook

# %% [markdown]
# Competition description
#
# Twitter has become an important communication channel in times of emergency. The ubiquitousness of smartphones enables people to announce an emergency they’re observing in real-time. Because of this, more agencies are interested in programatically monitoring Twitter (i.e. disaster relief organizations and news agencies).
#
# But, it’s not always clear whether a person’s words are actually announcing a disaster.
#
# Acknowledgments
#
# This dataset was created by the company figure-eight and originally shared on their ‘Data For Everyone’ website here.

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import re
import string

# %% [markdown]
# Load csv files

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nlp-getting-started/sample_submission.csv
# /kaggle/input/nlp-getting-started/train.csv
# /kaggle/input/nlp-getting-started/test.csv

# %% [markdown]
# Read files

# %%
train  = pd.read_csv('/kaggle/input/nlp-getting-started/train.csv')
test = pd.read_csv('/kaggle/input/nlp-getting-started/test.csv')
submission = pd.read_csv('/kaggle/input/nlp-getting-started/sample_submission.csv')

# %%
train
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
test
# Out:
#          id keyword location  \
# 0         0     NaN      NaN
# 1         2     NaN      NaN
# 2         3     NaN      NaN
# 3         9     NaN      NaN
# 4        11     NaN      NaN
# ...     ...     ...      ...
# 3258  10861     NaN      NaN
# 3259  10865     NaN      NaN
# 3260  10868     NaN      NaN
# 3261  10874     NaN      NaN
# 3262  10875     NaN      NaN
#
#                                                    text
# 0                    Just happened a terrible car crash
# 1     Heard about #earthquake is different cities, s...
# 2     there is a forest fire at spot pond, geese are...
# 3              Apocalypse lighting. #Spokane #wildfires
# 4         Typhoon Soudelor kills 28 in China and Taiwan
# ...                                                 ...
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259  Storm in RI worse than last hurricane. My city...
# 3260  Green Line derailment in Chicago http://t.co/U...
# 3261  MEG issues Hazardous Weather Outlook (HWO) htt...
# 3262  #CityofCalgary has activated its Municipal Eme...
#
# [3263 rows x 4 columns]

# %%
submission
# Out:
#          id  target
# 0         0       0
# 1         2       0
# 2         3       0
# 3         9       0
# 4        11       0
# ...     ...     ...
# 3258  10861       0
# 3259  10865       0
# 3260  10868       0
# 3261  10874       0
# 3262  10875       0
#
# [3263 rows x 2 columns]

# %% [markdown]
# Analyse train

# %%
sns.displot(train['target'], kde=True)

# %%
train['target'].value_counts()
# Out:
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %%
num_classes = train['target'].nunique()
print(num_classes)
# Out:
# 2

# %% [markdown]
# Split dataset

# %%
X = train['text']
y = train['target']

X_test = test['text']

# %%
# Import functions from sklearn library
from sklearn.model_selection import train_test_split

# Splitting the data into training and testing sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1,random_state=42, shuffle=y)
X_train.shape, X_val.shape, y_train.shape, y_val.shape, X_test.shape
# Out:
# ((6851,), (762,), (6851,), (762,), (3263,))

# %% [markdown]
# Tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
import tensorflow_hub as hub
import tensorflow_text as text
from tensorflow import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# 2.11.0

# %%
bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")

# %%
#initialising bert layers
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
preprocessed_text = bert_preprocess(text_input)
outputs = bert_encoder(preprocessed_text)

# %%
#initialising neural network layers
l = tf.keras.layers.Dropout(0.1, name="dropout")(outputs['pooled_output'])
l = tf.keras.layers.Dense(1, activation='sigmoid', name="output")(l)

# %%
#create model
model = tf.keras.Model(inputs=[text_input], outputs = [l])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text (InputLayer)              [(None,)]            0           []
#
#  keras_layer (KerasLayer)       {'input_mask': (Non  0           ['text[0][0]']
#                                 e, 128),
#                                  'input_type_ids':
#                                 (None, 128),
#                                  'input_word_ids':
#                                 (None, 128)}
#
#  keras_layer_1 (KerasLayer)     {'encoder_outputs':  109482241   ['keras_layer[0][0]',
#                                  [(None, 128, 768),               'keras_layer[0][1]',
#                                  (None, 128, 768),                'keras_layer[0][2]']
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768),
#                                  (None, 128, 768)],
#                                  'sequence_output':
#                                  (None, 128, 768),
#                                  'default': (None,
#                                 768),
#                                  'pooled_output': (
#                                 None, 768)}
#
#  dropout (Dropout)              (None, 768)          0           ['keras_layer_1[0][13]']
#
#  output (Dense)                 (None, 1)            769         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 109,483,010
# Trainable params: 769
# Non-trainable params: 109,482,241
# __________________________________________________________________________________________________

# %%
#compile the model
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall')
]

model.compile(optimizer='adam',
 loss='binary_crossentropy',
 metrics=METRICS)

# %%
keras.utils.plot_model(model, "sentiment_classifier.png")

# %%
#fit the model
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=25, verbose=1)
mc = ModelCheckpoint ('best_model.tf', monitor='val_loss', mode='min', save_best_only=True)

model.fit(X_train, y_train, epochs=15, validation_data=(X_val, y_val),verbose=1,callbacks=[early_stopping, mc])
# Out:
# Epoch 1/15
# 215/215 [==============================] - 79s 312ms/step - loss: 0.6176 - accuracy: 0.6628 - precision: 0.6292 - recall: 0.5186 - val_loss: 0.5920 - val_accuracy: 0.7244 - val_precision: 0.7266 - val_recall: 0.6012
# Epoch 2/15
# 215/215 [==============================] - 65s 304ms/step - loss: 0.5808 - accuracy: 0.7030 - precision: 0.6733 - recall: 0.5956 - val_loss: 0.5704 - val_accuracy: 0.7415 - val_precision: 0.7264 - val_recall: 0.6637
# Epoch 3/15
# 215/215 [==============================] - 65s 303ms/step - loss: 0.5736 - accuracy: 0.7139 - precision: 0.6882 - recall: 0.6075 - val_loss: 0.5609 - val_accuracy: 0.7428 - val_precision: 0.7652 - val_recall: 0.6012
# Epoch 4/15
# 215/215 [==============================] - 65s 300ms/step - loss: 0.5573 - accuracy: 0.7270 - precision: 0.7063 - recall: 0.6211 - val_loss: 0.5496 - val_accuracy: 0.7533 - val_precision: 0.7761 - val_recall: 0.6190
# Epoch 5/15
# 215/215 [==============================] - 66s 306ms/step - loss: 0.5511 - accuracy: 0.7235 - precision: 0.7028 - recall: 0.6147 - val_loss: 0.5409 - val_accuracy: 0.7546 - val_precision: 0.7543 - val_recall: 0.6577
# Epoch 6/15
# 215/215 [==============================] - 64s 300ms/step - loss: 0.5461 - accuracy: 0.7317 - precision: 0.7101 - recall: 0.6317 - val_loss: 0.5351 - val_accuracy: 0.7572 - val_precision: 0.7726 - val_recall: 0.6369
# Epoch 7/15
# 215/215 [==============================] - 66s 307ms/step - loss: 0.5385 - accuracy: 0.7405 - precision: 0.7264 - recall: 0.6324 - val_loss: 0.5286 - val_accuracy: 0.7690 - val_precision: 0.7759 - val_recall: 0.6696
# Epoch 8/15
# 215/215 [==============================] - 65s 304ms/step - loss: 0.5375 - accuracy: 0.7411 - precision: 0.7251 - recall: 0.6371 - val_loss: 0.5247 - val_accuracy: 0.7756 - val_precision: 0.7603 - val_recall: 0.7173
# Epoch 9/15
# 215/215 [==============================] - 65s 300ms/step - loss: 0.5306 - accuracy: 0.7481 - precision: 0.7359 - recall: 0.6426 - val_loss: 0.5206 - val_accuracy: 0.7795 - val_precision: 0.7727 - val_recall: 0.7083
# Epoch 10/15
# 215/215 [==============================] - 66s 305ms/step - loss: 0.5328 - accuracy: 0.7447 - precision: 0.7279 - recall: 0.6453 - val_loss: 0.5172 - val_accuracy: 0.7782 - val_precision: 0.7702 - val_recall: 0.7083
# Epoch 11/15
# 215/215 [==============================] - 66s 306ms/step - loss: 0.5259 - accuracy: 0.7513 - precision: 0.7385 - recall: 0.6494 - val_loss: 0.5141 - val_accuracy: 0.7795 - val_precision: 0.7819 - val_recall: 0.6935
# Epoch 12/15
# 215/215 [==============================] - 57s 263ms/step - loss: 0.5233 - accuracy: 0.7529 - precision: 0.7374 - recall: 0.6572 - val_loss: 0.5151 - val_accuracy: 0.7664 - val_precision: 0.8086 - val_recall: 0.6161
# Epoch 13/15
# 215/215 [==============================] - 65s 303ms/step - loss: 0.5234 - accuracy: 0.7567 - precision: 0.7411 - recall: 0.6641 - val_loss: 0.5134 - val_accuracy: 0.7717 - val_precision: 0.8092 - val_recall: 0.6310
# Epoch 14/15
# 215/215 [==============================] - 64s 300ms/step - loss: 0.5220 - accuracy: 0.7524 - precision: 0.7417 - recall: 0.6477 - val_loss: 0.5090 - val_accuracy: 0.7677 - val_precision: 0.7402 - val_recall: 0.7292
# Epoch 15/15
# 215/215 [==============================] - 51s 239ms/step - loss: 0.5160 - accuracy: 0.7542 - precision: 0.7401 - recall: 0.6569 - val_loss: 0.5118 - val_accuracy: 0.7743 - val_precision: 0.8333 - val_recall: 0.6101

# %%
results = model.evaluate(X_val, y_val, batch_size=128)
# Out:
# 6/6 [==============================] - 7s 1s/step - loss: 0.5118 - accuracy: 0.7743 - precision: 0.8333 - recall: 0.6101

# %%
model.save('tweet_model')

# %%
#evaluate the model
predictions = model.predict(X_test)
predictions = predictions.flatten()
predictions
# Out:
# 102/102 [==============================] - 23s 214ms/step
# array([0.45007932, 0.38332865, 0.5764653 , ..., 0.77463245, 0.523532  ,
#        0.6645585 ], dtype=float32)

# %%
cutoff = (predictions.max() - predictions.min()) / 2
predictions = np.where(predictions > 0.5, 1, 0)
predictions
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
sns.displot(predictions, kde=True)

# %%
count_pred = np.unique(predictions, return_counts=True)
count_pred
# Out:
# (array([0, 1]), array([2238, 1025]))

# %% [markdown]
# Prepare submission

# %%
submission['target'] = predictions
submission.to_csv('submission.csv',index=False) # writing data to a CSV file
submission = pd.read_csv("submission.csv")
submission
# Out:
#          id  target
# 0         0       0
# 1         2       0
# 2         3       1
# 3         9       1
# 4        11       1
# ...     ...     ...
# 3258  10861       0
# 3259  10865       1
# 3260  10868       1
# 3261  10874       1
# 3262  10875       1
#
# [3263 rows x 2 columns]

# %% [markdown]
# <p style="background-color:#F1B97B;color:black;font-size:22px;text-align:center;border-radius:10px 10px;font-weight:bold;border:2px solid brown;">Fashion Mnist Classification<span style='font-size:27px; background-color:#F1B97B ;'>🛍</span></p>
#
#
# <center><img src="https://github.com/Isharaneranjana/kaggle_gif/blob/main/fashion%20mnist%20.gif?raw=true"></center>

# %% [markdown]
# ##  <p style="background-color:#F1B97B;color:black;font-size:20px;text-align:center;border-radius:10px 10px;border:2px solid brown;">👔🧥 Introduction </p>
#
# Fashion-MNIST is a dataset of Zalando’s article images consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. It is split in 10,000 as test and 50,000 as train datasets. Although the dataset is relatively simple, it can be used as the basis for learning and practicing how to develop, evaluate, and use deep convolutional neural networks for image classification from scratch.

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import warnings
warnings.filterwarnings("ignore")
# Out:
# /kaggle/input/fashionmnist/t10k-labels-idx1-ubyte
# /kaggle/input/fashionmnist/t10k-images-idx3-ubyte
# /kaggle/input/fashionmnist/fashion-mnist_test.csv
# /kaggle/input/fashionmnist/fashion-mnist_train.csv
# /kaggle/input/fashionmnist/train-labels-idx1-ubyte
# /kaggle/input/fashionmnist/train-images-idx3-ubyte

# %%
train_data = pd.read_csv('/kaggle/input/fashionmnist/fashion-mnist_train.csv')
test_data = pd.read_csv('/kaggle/input/fashionmnist/fashion-mnist_test.csv')

# %%
print("Fashion MNIST train -  rows:",train_data.shape[0]," columns:", train_data.shape[1])
print("Fashion MNIST test -  rows:",test_data.shape[0]," columns:", test_data.shape[1])
# Out:
# Fashion MNIST train -  rows: 60000  columns: 785
# Fashion MNIST test -  rows: 10000  columns: 785

# %%
labels = {0 : "T-shirt/top", 1: "Trouser", 2: "Pullover", 3: "Dress", 4: "Coat",
          5: "Sandal", 6: "Shirt", 7: "Sneaker", 8: "Bag", 9: "Ankle Boot"}
def plot_label_per_class(data):
    f, ax = plt.subplots(1,1, figsize=(12,4))
    g = sns.countplot(data.label, order = data["label"].value_counts().index, palette='YlGn')
    g.set_title("Number of labels for each class")

    for p, label in zip(g.patches, data["label"].value_counts().index):
        g.annotate(labels[label], (p.get_x(), p.get_height()+0.1))
    plt.show()  
    
plot_label_per_class(train_data)

# %%
plot_label_per_class(test_data)

# %%
def sample_images_data(data):
    # An empty list to collect some samples
    sample_images = []
    sample_labels = []

    # Iterate over the keys of the labels dictionary defined in the above cell
    for k in labels.keys():
        # Get four samples for each category
        samples = data[data["label"] == k].head(4)
        # Append the samples to the samples list
        for j, s in enumerate(samples.values):
            # First column contain labels, hence index should start from 1
            img = np.array(samples.iloc[j, 1:]).reshape(28,28)
            sample_images.append(img)
            sample_labels.append(samples.iloc[j, 0])

    print("Total number of sample images to plot: ", len(sample_images))
    return sample_images, sample_labels

train_sample_images, train_sample_labels = sample_images_data(train_data)
# Out:
# Total number of sample images to plot:  40

# %%
def plot_sample_images(data_sample_images,data_sample_labels,cmap="Greys"):
    # Plot the sample images now
    f, ax = plt.subplots(5,8, figsize=(16,10))

    for i, img in enumerate(data_sample_images):
        ax[i//8, i%8].imshow(img, cmap=cmap)
        ax[i//8, i%8].axis('off')
        ax[i//8, i%8].set_title(labels[data_sample_labels[i]])
    plt.show()    
    
plot_sample_images(train_sample_images,train_sample_labels, "Greys")

# %%
test_sample_images, test_sample_labels = sample_images_data(test_data)
plot_sample_images(test_sample_images,test_sample_labels,"Greys")
# Out:
# Total number of sample images to plot:  40

# %%
# data preprocessing
def data_preprocessing(raw):
    out_y = keras.utils.np_utils.to_categorical(raw.label, 10)
    num_images = raw.shape[0]
    x_as_array = raw.values[:,1:]
    x_shaped_array = x_as_array.reshape(num_images, 28, 28, 1)
    out_x = x_shaped_array / 255
    return out_x, out_y

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.python import keras
from keras.utils import np_utils

# prepare the data
X, y = data_preprocessing(train_data)
X_test, y_test = data_preprocessing(test_data)

# %%
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
print("training set size",x_train.shape[0], x_train.shape[1:4])
print("validation set size",x_val.shape[0], x_val.shape[1:4])
print("test set size",X_test.shape[0]," columns:", X_test.shape[1:4])
# Out:
# training set size 48000 (28, 28, 1)
# validation set size 12000 (28, 28, 1)
# test set size 10000  columns: (28, 28, 1)

# %% [markdown]
# ### CNN

# %% [markdown]
# Convolutional neural networks are distinguished from other neural networks by their superior performance with image, speech, or audio signal inputs. They have three main types of layers.
#
#  <p>💎 Convolutional layer </p>
#  <p>💎 Pooling layer </p>
#  <p>💎 Fully-connected (FC) layer</p>

# %% [markdown]
# #### Convolutional layer
#
# The convolutional layer is the core building block of a CNN, and it is where the majority of computation occurs. It requires a few components, which are input data, a filter, and a feature map. Let’s assume that the input will be a color image, which is made up of a matrix of pixels in 3D. This means that the input will have three dimensions a height, width, and depth, which correspond to RGB in an image. We also have a feature detector, also known as a kernel or a filter, which will move across the receptive fields of the image, checking if the feature is present. This process is known as a convolution.
#
# <center><img src="https://github.com/Isharaneranjana/kaggle_gif/blob/main/Convolutional%20operation%20(2).gif?raw=true" style="width:500px;height:300px;"></center>
#
# The feature detector is a two-dimensional (2-D) weighted array that represents a portion of the image. The filter size, which can vary in size, is usually a 3x3 matrix, which also affects the size of the receptive field. After that, the filter is applied to a portion of the image, and a dot product between the input pixels and the filter is calculated. After that, the dot product is loaded into an output array. The filter then shifts by a stride, and the procedure is repeated until the kernel has swept across the entire image. A feature map, activation map, or convolved feature is the ultimate output of a series of dot products from the input and the filter. The feature detector's weights stay fixed as it advances over the image, a technique known as parameter sharing. Backpropagation and gradient descent are used to change some parameters, such as weight values, during training. However, there are three hyperparameters that determine the output volume size that must be established before the neural network training begins.
#
# 1.  The <b>number of filters</b> affects the depth of the output. For example, three distinct filters would yield three different feature maps, creating a depth of three.
#
# 2. <b>Stride </b>is the distance, or number of pixels, that the kernel moves over the input matrix. While stride values of two or greater is rare, a larger stride yields a smaller output.
#
# 3. <b>Padding</b> is usually used when the filters do not fit the input image. This sets all elements that fall outside of the input matrix to zero, producing a larger or equally sized output.
#
# <center><img src="https://github.com/Isharaneranjana/kaggle_gif/blob/main/padding%20(1).gif?raw=true" style="width:500px;height:300px;"></center>

# %% [markdown]
# #### pooling layer
#
# Downsampling, also known as pooling layers, is a dimensionality reduction technique that reduces the number of factors in the input. The pooling process sweeps a filter across the entire input, similar to the convolutional layer, however this filter does not have any weights. Instead, the kernel uses an aggregation function to populate the output array from the values in the receptive field. Pooling can be divided into two categories called max pooling and average pooling.
#
# Max pooling
# <p>As the filter moves across the input, it selects the pixel with the maximum value to send to the output array. As an aside, this approach tends to be used more often compared to average pooling.</p>
#
# Average pooling
# <p>As the filter moves across the input, it calculates the average value within the receptive field to send to the output array.</p>
#
# <center><img src="https://github.com/Isharaneranjana/kaggle_gif/blob/main/pooling.gif?raw=true" style="width:500px;height:300px;"></center>

# %% [markdown]
# #### Fully connected layers
#
# The full-connected layer's name is self-explanatory. In partially linked layers, the pixel values of the input image are not directly connected to the output layer, as previously stated. Each node in the output layer, on the other hand, connects directly to a node in the previous layer in the fully-connected layer.
# This layer performs classification tasks based on the features retrieved by the previous layers and their various filters. While convolutional and pooling layers typically utilize ReLu functions to categorize inputs, FC layers typically use a softmax activation function to provide a probability from 0 to 1.
#
# <p>For more details: </p>
#
# https://towardsdatascience.com/a-comprehensive-guide-to-convolutional-neural-networks-the-eli5-way-3bd2b1164a53
# https://www.ibm.com/cloud/learn/convolutional-neural-networks

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
# Model
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
cnn.add(BatchNormalization())

cnn.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.25))

cnn.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.25))

cnn.add(Flatten())
cnn.add(Dense(512, activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.5))

cnn.add(Dense(128, activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.5))

cnn.add(Dense(10, activation='softmax'))
# Out:
# 2022-11-12 06:18:20.857078: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:20.979638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:20.980561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:20.982590: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-12 06:18:20.984033: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:20.985061: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:20.986128: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:22.991303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:22.992412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:22.993138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-12 06:18:22.993815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
cnn.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 26, 26, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 22, 22, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 22, 22, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               15860224
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 15,958,314
# Trainable params: 15,956,778
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
train_model = cnn.fit(x_train, y_train,
                  batch_size=256,
                  epochs=100,
                  validation_data=(x_val, y_val))
# Out:
# 2022-11-12 06:18:24.473667: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-11-12 06:18:26.509100: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 188/188 [==============================] - 12s 21ms/step - loss: 0.5758 - accuracy: 0.8044 - val_loss: 2.5222 - val_accuracy: 0.1907
# Epoch 2/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.3470 - accuracy: 0.8779 - val_loss: 1.2543 - val_accuracy: 0.6043
# Epoch 3/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.2821 - accuracy: 0.8995 - val_loss: 0.3032 - val_accuracy: 0.8937
# Epoch 4/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.2387 - accuracy: 0.9145 - val_loss: 0.2614 - val_accuracy: 0.9060
# Epoch 5/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.2046 - accuracy: 0.9266 - val_loss: 0.2295 - val_accuracy: 0.9186
# Epoch 6/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.1792 - accuracy: 0.9360 - val_loss: 0.2228 - val_accuracy: 0.9251
# Epoch 7/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.1602 - accuracy: 0.9424 - val_loss: 0.2549 - val_accuracy: 0.9134
# Epoch 8/100
# 188/188 [==============================] - 4s 20ms/step - loss: 0.1422 - accuracy: 0.9494 - val_loss: 0.2442 - val_accuracy: 0.9166
# Epoch 9/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.1265 - accuracy: 0.9538 - val_loss: 0.2459 - val_accuracy: 0.9173
# Epoch 10/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.1137 - accuracy: 0.9593 - val_loss: 0.2513 - val_accuracy: 0.9193
# Epoch 11/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.1058 - accuracy: 0.9618 - val_loss: 0.2472 - val_accuracy: 0.9244
# Epoch 12/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0893 - accuracy: 0.9690 - val_loss: 0.2504 - val_accuracy: 0.9202
# Epoch 13/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0788 - accuracy: 0.9717 - val_loss: 0.2483 - val_accuracy: 0.9267
# Epoch 14/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0768 - accuracy: 0.9728 - val_loss: 0.2528 - val_accuracy: 0.9268
# Epoch 15/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0680 - accuracy: 0.9767 - val_loss: 0.2656 - val_accuracy: 0.9225
# Epoch 16/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0642 - accuracy: 0.9774 - val_loss: 0.2587 - val_accuracy: 0.9256
# Epoch 17/100
# 188/188 [==============================] - 4s 20ms/step - loss: 0.0582 - accuracy: 0.9798 - val_loss: 0.3043 - val_accuracy: 0.9212
# Epoch 18/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0570 - accuracy: 0.9795 - val_loss: 0.2786 - val_accuracy: 0.9293
# Epoch 19/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0527 - accuracy: 0.9817 - val_loss: 0.2909 - val_accuracy: 0.9237
# Epoch 20/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0449 - accuracy: 0.9845 - val_loss: 0.2884 - val_accuracy: 0.9262
# Epoch 21/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0451 - accuracy: 0.9845 - val_loss: 0.2931 - val_accuracy: 0.9237
# Epoch 22/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0435 - accuracy: 0.9848 - val_loss: 0.3066 - val_accuracy: 0.9225
# Epoch 23/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0388 - accuracy: 0.9864 - val_loss: 0.3174 - val_accuracy: 0.9255
# Epoch 24/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0367 - accuracy: 0.9874 - val_loss: 0.2968 - val_accuracy: 0.9279
# Epoch 25/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0367 - accuracy: 0.9876 - val_loss: 0.2934 - val_accuracy: 0.9287
# Epoch 26/100
# 188/188 [==============================] - 4s 20ms/step - loss: 0.0342 - accuracy: 0.9885 - val_loss: 0.3142 - val_accuracy: 0.9266
# Epoch 27/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.3216 - val_accuracy: 0.9239
# Epoch 28/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.0305 - accuracy: 0.9894 - val_loss: 0.3336 - val_accuracy: 0.9227
# Epoch 29/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0282 - accuracy: 0.9906 - val_loss: 0.3201 - val_accuracy: 0.9267
# Epoch 30/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0331 - accuracy: 0.9889 - val_loss: 0.3117 - val_accuracy: 0.9298
# Epoch 31/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0266 - accuracy: 0.9909 - val_loss: 0.3320 - val_accuracy: 0.9277
# Epoch 32/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0288 - accuracy: 0.9900 - val_loss: 0.3203 - val_accuracy: 0.9302
# Epoch 33/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0303 - accuracy: 0.9898 - val_loss: 0.3218 - val_accuracy: 0.9300
# Epoch 34/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0261 - accuracy: 0.9906 - val_loss: 0.3262 - val_accuracy: 0.9270
# Epoch 35/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0260 - accuracy: 0.9909 - val_loss: 0.3329 - val_accuracy: 0.9273
# Epoch 36/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0218 - accuracy: 0.9925 - val_loss: 0.3344 - val_accuracy: 0.9293
# Epoch 37/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0235 - accuracy: 0.9922 - val_loss: 0.3194 - val_accuracy: 0.9287
# Epoch 38/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.3377 - val_accuracy: 0.9280
# Epoch 39/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0199 - accuracy: 0.9932 - val_loss: 0.3380 - val_accuracy: 0.9268
# Epoch 40/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.3466 - val_accuracy: 0.9250
# Epoch 41/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0233 - accuracy: 0.9922 - val_loss: 0.3235 - val_accuracy: 0.9298
# Epoch 42/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 0.3610 - val_accuracy: 0.9247
# Epoch 43/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.0191 - accuracy: 0.9934 - val_loss: 0.3563 - val_accuracy: 0.9272
# Epoch 44/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0198 - accuracy: 0.9932 - val_loss: 0.3384 - val_accuracy: 0.9252
# Epoch 45/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0192 - accuracy: 0.9937 - val_loss: 0.3453 - val_accuracy: 0.9267
# Epoch 46/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.3384 - val_accuracy: 0.9294
# Epoch 47/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.3425 - val_accuracy: 0.9293
# Epoch 48/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.3498 - val_accuracy: 0.9280
# Epoch 49/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.3498 - val_accuracy: 0.9232
# Epoch 50/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.3537 - val_accuracy: 0.9289
# Epoch 51/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.3361 - val_accuracy: 0.9289
# Epoch 52/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0198 - accuracy: 0.9936 - val_loss: 0.3447 - val_accuracy: 0.9254
# Epoch 53/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0176 - accuracy: 0.9939 - val_loss: 0.3491 - val_accuracy: 0.9270
# Epoch 54/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.3488 - val_accuracy: 0.9292
# Epoch 55/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.3467 - val_accuracy: 0.9307
# Epoch 56/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0137 - accuracy: 0.9955 - val_loss: 0.3328 - val_accuracy: 0.9302
# Epoch 57/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.3178 - val_accuracy: 0.9311
# Epoch 58/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.3441 - val_accuracy: 0.9283
# Epoch 59/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.3490 - val_accuracy: 0.9302
# Epoch 60/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0153 - accuracy: 0.9948 - val_loss: 0.3421 - val_accuracy: 0.9332
# Epoch 61/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.3321 - val_accuracy: 0.9312
# Epoch 62/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.3448 - val_accuracy: 0.9284
# Epoch 63/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.3686 - val_accuracy: 0.9268
# Epoch 64/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 0.3663 - val_accuracy: 0.9268
# Epoch 65/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.3559 - val_accuracy: 0.9290
# Epoch 66/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.3634 - val_accuracy: 0.9293
# Epoch 67/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.3584 - val_accuracy: 0.9295
# Epoch 68/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.3671 - val_accuracy: 0.9268
# Epoch 69/100
# 188/188 [==============================] - 3s 18ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.3784 - val_accuracy: 0.9277
# Epoch 70/100
# 188/188 [==============================] - 4s 20ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.4026 - val_accuracy: 0.9261
# Epoch 71/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.3627 - val_accuracy: 0.9298
# Epoch 72/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.3563 - val_accuracy: 0.9308
# Epoch 73/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.3660 - val_accuracy: 0.9299
# Epoch 74/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.3779 - val_accuracy: 0.9314
# Epoch 75/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.3625 - val_accuracy: 0.9323
# Epoch 76/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.3670 - val_accuracy: 0.9307
# Epoch 77/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.3601 - val_accuracy: 0.9271
# Epoch 78/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.3541 - val_accuracy: 0.9285
# Epoch 79/100
# 188/188 [==============================] - 4s 20ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.3619 - val_accuracy: 0.9306
# Epoch 80/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.3532 - val_accuracy: 0.9317
# Epoch 81/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.3568 - val_accuracy: 0.9309
# Epoch 82/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.3482 - val_accuracy: 0.9325
# Epoch 83/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.3739 - val_accuracy: 0.9302
# Epoch 84/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.3600 - val_accuracy: 0.9336
# Epoch 85/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.3916 - val_accuracy: 0.9318
# Epoch 86/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.3670 - val_accuracy: 0.9322
# Epoch 87/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.4035 - val_accuracy: 0.9276
# Epoch 88/100
# 188/188 [==============================] - 4s 20ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.3808 - val_accuracy: 0.9290
# Epoch 89/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.3524 - val_accuracy: 0.9277
# Epoch 90/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.3687 - val_accuracy: 0.9319
# Epoch 91/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.3842 - val_accuracy: 0.9316
# Epoch 92/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.3965 - val_accuracy: 0.9256
# Epoch 93/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 0.3644 - val_accuracy: 0.9330
# Epoch 94/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.3601 - val_accuracy: 0.9327
# Epoch 95/100
# 188/188 [==============================] - 4s 20ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.3474 - val_accuracy: 0.9320
# Epoch 96/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.3546 - val_accuracy: 0.9325
# Epoch 97/100
# 188/188 [==============================] - 4s 20ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.3541 - val_accuracy: 0.9298
# Epoch 98/100
# 188/188 [==============================] - 4s 19ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.3823 - val_accuracy: 0.9293
# Epoch 99/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.3569 - val_accuracy: 0.9307
# Epoch 100/100
# 188/188 [==============================] - 3s 19ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.4125 - val_accuracy: 0.9148

# %%
score = cnn.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.3849482834339142
# Test accuracy: 0.9229999780654907

# %% [markdown]
# ### CNN with 4 convolutional layers

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

cnn1 = Sequential()
cnn1.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
cnn1.add(BatchNormalization())

cnn1.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
cnn1.add(BatchNormalization())
cnn1.add(MaxPooling2D(pool_size=(2, 2)))
cnn1.add(Dropout(0.25))

cnn1.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
cnn1.add(BatchNormalization())
cnn1.add(Dropout(0.25))

cnn1.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
cnn1.add(BatchNormalization())
cnn1.add(MaxPooling2D(pool_size=(2, 2)))
cnn1.add(Dropout(0.25))

cnn1.add(Flatten())

cnn1.add(Dense(512, activation='relu'))
cnn1.add(BatchNormalization())
cnn1.add(Dropout(0.5))

cnn1.add(Dense(128, activation='relu'))
cnn1.add(BatchNormalization())
cnn1.add(Dropout(0.5))

cnn1.add(Dense(10, activation='softmax'))

# %%
cnn1.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
cnn1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 26, 26, 32)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 24, 24, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,221,546
# Trainable params: 1,219,754
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
history = cnn1.fit(x_train, y_train,
          batch_size=256,
          epochs=100,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 188/188 [==============================] - 4s 15ms/step - loss: 0.7634 - accuracy: 0.7356 - val_loss: 2.7514 - val_accuracy: 0.1113
# Epoch 2/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.4460 - accuracy: 0.8390 - val_loss: 1.8789 - val_accuracy: 0.4850
# Epoch 3/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.3791 - accuracy: 0.8646 - val_loss: 0.5504 - val_accuracy: 0.8075
# Epoch 4/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.3372 - accuracy: 0.8812 - val_loss: 0.2850 - val_accuracy: 0.8995
# Epoch 5/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.3117 - accuracy: 0.8904 - val_loss: 0.3002 - val_accuracy: 0.8866
# Epoch 6/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.2900 - accuracy: 0.8973 - val_loss: 0.2377 - val_accuracy: 0.9143
# Epoch 7/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2739 - accuracy: 0.9035 - val_loss: 0.2869 - val_accuracy: 0.8977
# Epoch 8/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2641 - accuracy: 0.9061 - val_loss: 0.2257 - val_accuracy: 0.9191
# Epoch 9/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2515 - accuracy: 0.9100 - val_loss: 0.2408 - val_accuracy: 0.9129
# Epoch 10/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.2377 - accuracy: 0.9153 - val_loss: 0.2371 - val_accuracy: 0.9176
# Epoch 11/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2259 - accuracy: 0.9196 - val_loss: 0.2185 - val_accuracy: 0.9231
# Epoch 12/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2234 - accuracy: 0.9190 - val_loss: 0.2351 - val_accuracy: 0.9207
# Epoch 13/100
# 188/188 [==============================] - 3s 14ms/step - loss: 0.2141 - accuracy: 0.9231 - val_loss: 0.2210 - val_accuracy: 0.9233
# Epoch 14/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.2045 - accuracy: 0.9269 - val_loss: 0.2640 - val_accuracy: 0.9106
# Epoch 15/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.2061 - accuracy: 0.9261 - val_loss: 0.2437 - val_accuracy: 0.9158
# Epoch 16/100
# 188/188 [==============================] - 3s 13ms/step - loss: 0.1928 - accuracy: 0.9307 - val_loss: 0.1945 - val_accuracy: 0.9320
# Epoch 17/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1934 - accuracy: 0.9304 - val_loss: 0.2013 - val_accuracy: 0.9314
# Epoch 18/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1839 - accuracy: 0.9340 - val_loss: 0.2215 - val_accuracy: 0.9260
# Epoch 19/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.1828 - accuracy: 0.9339 - val_loss: 0.2110 - val_accuracy: 0.9287
# Epoch 20/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1740 - accuracy: 0.9382 - val_loss: 0.1895 - val_accuracy: 0.9355
# Epoch 21/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1735 - accuracy: 0.9383 - val_loss: 0.1957 - val_accuracy: 0.9349
# Epoch 22/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1657 - accuracy: 0.9395 - val_loss: 0.1966 - val_accuracy: 0.9353
# Epoch 23/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1638 - accuracy: 0.9409 - val_loss: 0.1992 - val_accuracy: 0.9331
# Epoch 24/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.1605 - accuracy: 0.9421 - val_loss: 0.2094 - val_accuracy: 0.9281
# Epoch 25/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1594 - accuracy: 0.9421 - val_loss: 0.2088 - val_accuracy: 0.9301
# Epoch 26/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1498 - accuracy: 0.9459 - val_loss: 0.2301 - val_accuracy: 0.9248
# Epoch 27/100
# 188/188 [==============================] - 3s 13ms/step - loss: 0.1487 - accuracy: 0.9465 - val_loss: 0.2061 - val_accuracy: 0.9306
# Epoch 28/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.1458 - accuracy: 0.9475 - val_loss: 0.2162 - val_accuracy: 0.9308
# Epoch 29/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.1440 - accuracy: 0.9475 - val_loss: 0.2004 - val_accuracy: 0.9347
# Epoch 30/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.1371 - accuracy: 0.9508 - val_loss: 0.2152 - val_accuracy: 0.9329
# Epoch 31/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1357 - accuracy: 0.9509 - val_loss: 0.1999 - val_accuracy: 0.9348
# Epoch 32/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1341 - accuracy: 0.9512 - val_loss: 0.2162 - val_accuracy: 0.9298
# Epoch 33/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1302 - accuracy: 0.9525 - val_loss: 0.2039 - val_accuracy: 0.9338
# Epoch 34/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.1307 - accuracy: 0.9531 - val_loss: 0.2151 - val_accuracy: 0.9333
# Epoch 35/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1249 - accuracy: 0.9549 - val_loss: 0.2052 - val_accuracy: 0.9338
# Epoch 36/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1250 - accuracy: 0.9539 - val_loss: 0.1991 - val_accuracy: 0.9369
# Epoch 37/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1161 - accuracy: 0.9575 - val_loss: 0.2026 - val_accuracy: 0.9380
# Epoch 38/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.1191 - accuracy: 0.9563 - val_loss: 0.2170 - val_accuracy: 0.9320
# Epoch 39/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1183 - accuracy: 0.9562 - val_loss: 0.2280 - val_accuracy: 0.9290
# Epoch 40/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1145 - accuracy: 0.9580 - val_loss: 0.2169 - val_accuracy: 0.9317
# Epoch 41/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.1101 - accuracy: 0.9607 - val_loss: 0.2094 - val_accuracy: 0.9367
# Epoch 42/100
# 188/188 [==============================] - 3s 14ms/step - loss: 0.1106 - accuracy: 0.9596 - val_loss: 0.2109 - val_accuracy: 0.9350
# Epoch 43/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.1067 - accuracy: 0.9607 - val_loss: 0.2086 - val_accuracy: 0.9371
# Epoch 44/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1056 - accuracy: 0.9614 - val_loss: 0.2303 - val_accuracy: 0.9352
# Epoch 45/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1017 - accuracy: 0.9628 - val_loss: 0.2106 - val_accuracy: 0.9360
# Epoch 46/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1018 - accuracy: 0.9630 - val_loss: 0.2147 - val_accuracy: 0.9379
# Epoch 47/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.1007 - accuracy: 0.9638 - val_loss: 0.2162 - val_accuracy: 0.9360
# Epoch 48/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0968 - accuracy: 0.9657 - val_loss: 0.2122 - val_accuracy: 0.9349
# Epoch 49/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0976 - accuracy: 0.9651 - val_loss: 0.2251 - val_accuracy: 0.9354
# Epoch 50/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0963 - accuracy: 0.9654 - val_loss: 0.2201 - val_accuracy: 0.9350
# Epoch 51/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0965 - accuracy: 0.9654 - val_loss: 0.2430 - val_accuracy: 0.9322
# Epoch 52/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0919 - accuracy: 0.9669 - val_loss: 0.2275 - val_accuracy: 0.9338
# Epoch 53/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0924 - accuracy: 0.9672 - val_loss: 0.2209 - val_accuracy: 0.9377
# Epoch 54/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0887 - accuracy: 0.9682 - val_loss: 0.2311 - val_accuracy: 0.9375
# Epoch 55/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0883 - accuracy: 0.9681 - val_loss: 0.2238 - val_accuracy: 0.9379
# Epoch 56/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0886 - accuracy: 0.9682 - val_loss: 0.2274 - val_accuracy: 0.9366
# Epoch 57/100
# 188/188 [==============================] - 3s 15ms/step - loss: 0.0866 - accuracy: 0.9693 - val_loss: 0.2375 - val_accuracy: 0.9358
# Epoch 58/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0885 - accuracy: 0.9676 - val_loss: 0.2240 - val_accuracy: 0.9402
# Epoch 59/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0804 - accuracy: 0.9704 - val_loss: 0.2417 - val_accuracy: 0.9351
# Epoch 60/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0833 - accuracy: 0.9693 - val_loss: 0.2365 - val_accuracy: 0.9372
# Epoch 61/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0814 - accuracy: 0.9712 - val_loss: 0.2295 - val_accuracy: 0.9383
# Epoch 62/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0806 - accuracy: 0.9706 - val_loss: 0.2394 - val_accuracy: 0.9371
# Epoch 63/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0785 - accuracy: 0.9711 - val_loss: 0.2409 - val_accuracy: 0.9361
# Epoch 64/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0791 - accuracy: 0.9717 - val_loss: 0.2364 - val_accuracy: 0.9375
# Epoch 65/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0772 - accuracy: 0.9722 - val_loss: 0.2335 - val_accuracy: 0.9369
# Epoch 66/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0764 - accuracy: 0.9720 - val_loss: 0.2375 - val_accuracy: 0.9371
# Epoch 67/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0728 - accuracy: 0.9736 - val_loss: 0.2301 - val_accuracy: 0.9391
# Epoch 68/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0758 - accuracy: 0.9722 - val_loss: 0.2240 - val_accuracy: 0.9400
# Epoch 69/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0710 - accuracy: 0.9741 - val_loss: 0.2297 - val_accuracy: 0.9405
# Epoch 70/100
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0718 - accuracy: 0.9747 - val_loss: 0.2476 - val_accuracy: 0.9380
# Epoch 71/100
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0752 - accuracy: 0.9724 - val_loss: 0.2325 - val_accuracy: 0.9407
# Epoch 72/100
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0751 - accuracy: 0.9737 - val_loss: 0.2303 - val_accuracy: 0.9392
# Epoch 73/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0711 - accuracy: 0.9745 - val_loss: 0.2339 - val_accuracy: 0.9398
# Epoch 74/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0684 - accuracy: 0.9754 - val_loss: 0.2436 - val_accuracy: 0.9395
# Epoch 75/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0691 - accuracy: 0.9751 - val_loss: 0.2375 - val_accuracy: 0.9388
# Epoch 76/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0680 - accuracy: 0.9755 - val_loss: 0.2396 - val_accuracy: 0.9403
# Epoch 77/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0642 - accuracy: 0.9771 - val_loss: 0.2422 - val_accuracy: 0.9387
# Epoch 78/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0652 - accuracy: 0.9770 - val_loss: 0.2318 - val_accuracy: 0.9418
# Epoch 79/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0676 - accuracy: 0.9761 - val_loss: 0.2463 - val_accuracy: 0.9402
# Epoch 80/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0672 - accuracy: 0.9754 - val_loss: 0.2478 - val_accuracy: 0.9388
# Epoch 81/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0643 - accuracy: 0.9769 - val_loss: 0.2420 - val_accuracy: 0.9399
# Epoch 82/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0675 - accuracy: 0.9749 - val_loss: 0.2496 - val_accuracy: 0.9383
# Epoch 83/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0633 - accuracy: 0.9778 - val_loss: 0.2454 - val_accuracy: 0.9398
# Epoch 84/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0670 - accuracy: 0.9759 - val_loss: 0.2405 - val_accuracy: 0.9400
# Epoch 85/100
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0640 - accuracy: 0.9770 - val_loss: 0.2621 - val_accuracy: 0.9354
# Epoch 86/100
# 188/188 [==============================] - 3s 14ms/step - loss: 0.0654 - accuracy: 0.9768 - val_loss: 0.2373 - val_accuracy: 0.9412
# Epoch 87/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0671 - accuracy: 0.9758 - val_loss: 0.2501 - val_accuracy: 0.9392
# Epoch 88/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0624 - accuracy: 0.9783 - val_loss: 0.2446 - val_accuracy: 0.9401
# Epoch 89/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0565 - accuracy: 0.9796 - val_loss: 0.2441 - val_accuracy: 0.9412
# Epoch 90/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0623 - accuracy: 0.9782 - val_loss: 0.2575 - val_accuracy: 0.9358
# Epoch 91/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0565 - accuracy: 0.9795 - val_loss: 0.2442 - val_accuracy: 0.9411
# Epoch 92/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0592 - accuracy: 0.9783 - val_loss: 0.2513 - val_accuracy: 0.9389
# Epoch 93/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0598 - accuracy: 0.9783 - val_loss: 0.2421 - val_accuracy: 0.9392
# Epoch 94/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0582 - accuracy: 0.9785 - val_loss: 0.2615 - val_accuracy: 0.9383
# Epoch 95/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0558 - accuracy: 0.9811 - val_loss: 0.2502 - val_accuracy: 0.9398
# Epoch 96/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0591 - accuracy: 0.9786 - val_loss: 0.2456 - val_accuracy: 0.9392
# Epoch 97/100
# 188/188 [==============================] - 3s 13ms/step - loss: 0.0561 - accuracy: 0.9800 - val_loss: 0.2509 - val_accuracy: 0.9406
# Epoch 98/100
# 188/188 [==============================] - 2s 12ms/step - loss: 0.0579 - accuracy: 0.9795 - val_loss: 0.2538 - val_accuracy: 0.9394
# Epoch 99/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0528 - accuracy: 0.9812 - val_loss: 0.2531 - val_accuracy: 0.9388
# Epoch 100/100
# 188/188 [==============================] - 2s 13ms/step - loss: 0.0518 - accuracy: 0.9818 - val_loss: 0.2540 - val_accuracy: 0.9416

# %%
score = cnn1.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.23831906914710999
# Test accuracy: 0.9437000155448914

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'r', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Predictions for the test data
predicted_classes = (cnn1.predict(X_test) > 0.5).astype("int32")

# Indices to be plotted
y_true = y_test
correct = np.nonzero(predicted_classes==y_true)[0]
incorrect = np.nonzero(predicted_classes!=y_true)[0]

from sklearn.metrics import classification_report
target_names = ["Class {}".format(i) for i in range(10)]
print(classification_report(y_true, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.92      0.89      0.91      1000
#      Class 1       1.00      1.00      1.00      1000
#      Class 2       0.94      0.89      0.91      1000
#      Class 3       0.95      0.96      0.95      1000
#      Class 4       0.92      0.92      0.92      1000
#      Class 5       0.99      0.98      0.99      1000
#      Class 6       0.82      0.85      0.83      1000
#      Class 7       0.97      0.97      0.97      1000
#      Class 8       0.99      0.99      0.99      1000
#      Class 9       0.97      0.98      0.97      1000
#
#    micro avg       0.95      0.94      0.94     10000
#    macro avg       0.95      0.94      0.94     10000
# weighted avg       0.95      0.94      0.94     10000
#  samples avg       0.94      0.94      0.94     10000

# %% [markdown]
# <center><p style="color:#236D46;font-size:17px;border:2px solid #236D46;border-radius:12px 10px;text-align:center;">
# <b>Highly appreciate your questions or feedback related to this notebook.If you liked this Notebook, please do <span style="color:gold;">upvote</span>. THANK YOU <span style='font-size:22px;'>&#128522;</span></b> </p></center>

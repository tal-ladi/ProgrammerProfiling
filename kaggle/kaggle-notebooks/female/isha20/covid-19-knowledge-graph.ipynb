# %% [markdown]
# # COVID-19 knowledge graph

# %% [markdown]
# ## Abstract
#
# This work focuses on extracting relations between chemicals, genes and disease from research articles to build a biomedical knowledge graph related to COVID-19. Entities are collected from [BioSNAP](http://snap.stanford.edu/biodata/index.html) to identify instances of chemical, gene and disease names in abstracts.
#
# To understand what relationship types are possible and map unstructured natural language descriptions onto these structured classes, labeled sentences in [Percha B 2018](https://academic.oup.com/bioinformatics/article/34/15/2614/4911883) are used to classify relations between entities.
# The source code for classification model can be seen [here](https://github.com/jxzly/Biomedical-Relation-Classification).

# %%
# !pip install pyecharts
# Out:
# Collecting pyecharts
#   Downloading pyecharts-1.8.1-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 2.8 MB/s
# Collecting simplejson
#   Downloading simplejson-3.17.0.tar.gz (83 kB)
#      |████████████████████████████████| 83 kB 951 kB/s
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from pyecharts) (2.11.1)
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.6/site-packages (from pyecharts) (0.7.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->pyecharts) (1.1.1)
# Building wheels for collected packages: simplejson
# done
#   Created wheel for simplejson: filename=simplejson-3.17.0-cp36-cp36m-linux_x86_64.whl size=121380 sha256=ece1fbce318ce76225e48d29369d0bbe537b57cd9e0d1e92cc82772a11270635
#   Stored in directory: /root/.cache/pip/wheels/c2/95/a2/477b46cfe980061fddc4cb76ed4657eceec35d2b2090355e41
# Successfully built simplejson
# Installing collected packages: simplejson, pyecharts
# Successfully installed pyecharts-1.8.1 simplejson-3.17.0

# %%
import numpy as np 
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from pyecharts import options as opts
from pyecharts.charts import Graph
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset,TensorDataset,DataLoader
from keras.preprocessing import sequence
from transformers import BertTokenizer, BertForSequenceClassification

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load marked sentences
#
# These sentences containing more than two biomedical entities were extracted from abstracts. We combined the pairwise entities in each sentence to build relations.

# %% [markdown]
# First,a vocabulary is created which includes drugs, genes, diseases name from SNAP and then some entities related to COVID-19 are added manually. Then we check for those sentences in abstract which contain more than two entities and mark them.
#
# > example:
# > vocab: [A,B,C...]
# > sentence: A and C are effective for B.
# > marked_sentence:
# > 1. start_entity and end_entity are effective for B.
# > 2. start_entity and C are effective for end_entity.
# > 3. A and start_entity are effective for end_entity .

# %%
marked_sentence_df = pd.read_csv('/kaggle/input/covid19-knowledge-graph/marked_sentence.csv')

# %%
marked_sentence_df.sample(5)
# Out:
#       start_entity end_entity start_entity_type end_entity_type  \
# 25859      EIF2AK2        TNF              Gene            Gene
# 34684         CD44   COVID-19              Gene         Disease
# 37957      CAPRIN1        MYC              Gene            Gene
# 20882       EEF1A1      RPS23              Gene            Gene
# 31824         CCL3       CCL5              Gene            Gene
#
#                                          marked_sentence
# 25859  Downregulation of double-stranded RNA dsRNA-de...
# 34684  Sequential serum samples, collected during the...
# 37957  Tylophorine directly binds to start_entity and...
# 20882  From the most stable to the least stable, gene...
# 31824  Compared to uninfected control patients, PIV-i...

# %%
marked_sentence_df["marked_sentence"][1]
# Out:
# 'Middle-aged female identical twins, one of whom had systemic lupus erythematosus end_entity, were evaluated for immunologic reactivity to previous antigenic challenges, including primary immunization with a foreign antigen, start_entity KLH'

# %%
marked_sentence_df.head(5)
# Out:
#                 start_entity                     end_entity start_entity_type  \
# 0                    IGKV4-1                            TAZ              Gene
# 1  keyhole limpet hemocyanin  Lupus Erythematosus, Systemic          Chemical
# 2                   COVID-19                    Pharyngitis           Disease
# 3                      cough                         sputum           Disease
# 4                     B3GAT1                           GLS2              Gene
#
#   end_entity_type                                    marked_sentence
# 0            Gene  In addition to rubella there is suggestive, bu...
# 1         Disease  Middle-aged female identical twins, one of who...
# 2         Disease  end_entity, bronchitis, and start_entity repre...
# 3         Disease  It is characterized by persistent start_entity...
# 4            Gene  While the perikarya of all cells contained ele...

# %%
def Build_graph(df,relation=False,repulsion=40,title='COVID-19 knowledge graph',labelShow=False):
    entity_type_dic = dict(df.drop_duplicates(['start_entity']).set_index(['start_entity'])['start_entity_type'])
    entity_type_dic.update(dict(df.drop_duplicates(['end_entity']).set_index(['end_entity'])['end_entity_type']))
    color = {'Disease':'#FF7F50','Gene':'#48D1CC','Chemical':'#B3EE3A'}
    cate =  {'Disease':0,'Gene':1,'Chemical':2}
    categories = [{'name':'Disease','itemStyle': {'normal': {'color': color['Disease']}}},{'name':'Gene','itemStyle': {'normal': {'color': color['Gene']}}},{'name':'Chemical','itemStyle': {'normal': {'color': color['Chemical']}}}]
    nodes = []
    for entity in list(set(df['start_entity'])|set(df['end_entity'])):
        nodes.append({'name': entity, 'symbolSize': max(10,np.log1p(df.loc[(df['start_entity']==entity)|(df['end_entity']==entity)].shape[0])*10//1),
                     'category':cate[entity_type_dic[entity]]})
    links = []
    for i in df.index:
        if not relation:
            links.append({'source': df.loc[i,'start_entity'], 'target': df.loc[i,'end_entity']})
        else:
            links.append({'source': df.loc[i,'start_entity'], 'target': df.loc[i,'end_entity'], 'value':df.loc[i,'pred']})
    g = (
        Graph()
        .add('', nodes, links,categories, repulsion=repulsion,label_opts=opts.LabelOpts(is_show=labelShow))
        .set_global_opts(title_opts=opts.TitleOpts(title=title),legend_opts=opts.LegendOpts(orient='vertical', pos_left='2%', pos_top='40%',legend_icon='circle'))
        .render_notebook()
        )
    return g

# %%
g = Build_graph(marked_sentence_df.sample(100),title='subsample of topology graph')
g
# Out:
# /opt/conda/lib/python3.6/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="42a9178eaa434ba9aba277919949e1da" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_42a9178eaa434ba9aba277919949e1da = echarts.init(
#                     document.getElementById('42a9178eaa434ba9aba277919949e1da'), 'white', {renderer: 'canvas'});
#                 var option_42a9178eaa434ba9aba277919949e1da = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 40,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "SFTPA1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Stevens-Johnson Syndrome",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Liver Cirrhosis, Biliary",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "VHLL",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "DPP4",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Dermatitis",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "IRF9",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Eczema",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "E2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PPIP5K1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PAFAH1B1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "S4",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "TRIM55",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CTSG",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CXCL10",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "OTOF",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "DDX56",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Polycythemia Vera",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "IGKV6-21",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "COVID-19",
#                     "symbolSize": 23.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Rhinitis, Allergic",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "MCC",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "FPR3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MERS",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "MBP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Severe Acute Respiratory Syndrome",
#                     "symbolSize": 19.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Pneumonia",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "sputum",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Diclofenac",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "MCD",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Feline Infectious Peritonitis",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Carcinoma, Hepatocellular",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "S2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Coronavirus Infections",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "CD4",
#                     "symbolSize": 17.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "AP-1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Hamartoma Syndrome, Multiple",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Leukemia, Myeloid",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "CASP9",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "M

# %% [markdown]
# # Classify relations
#
# [Percha B 2018](https://academic.oup.com/bioinformatics/article/34/15/2614/4911883) revealed 10 broad themes for chemical-gene relations, 7 for chemical-disease, 10 for gene-disease and 9 for gene–gene in Medline abstracts. These labeled sentences were used to train a model to classify sentences in this work. As order of entities cannot be confirmed, two possibilities(init_pred and reverse_pred) were predicted while retrieving the higher one. The details can be seen [here](https://github.com/jxzly/Biomedical-Relation-Classification)

# %%
class Args:
    task_type = 'chemical-disease'
    max_seq_len = 64
    bs = 64

class Conf:
    # some information can be found in:
    # Percha B, Altman R B. A global network of biomedical relationships derived from text[J]. Bioinformatics, 2018, 34(15): 2614-2624.
    relation_type = {'chemical-disease':['T', 'C', 'Sa', 'Pr', 'Pa', 'J'],
                     'disease-chemical':['Mp'],
                     'chemical-gene':['A+', 'A-', 'B', 'E+', 'E-', 'E', 'N'],
                     'gene-chemical':['O', 'K', 'Z'],
                     'gene-disease':['U', 'Ud', 'D', 'J', 'Te', 'Y', 'G'],
                     'disease-gene':['Md', 'X', 'L'],
                     'gene-gene':['B', 'W', 'V+', 'E+', 'E', 'I', 'H', 'Rg', 'Q'],
                     }

args = Args()
conf = Conf()
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
# load pretrained Bert model
def Bert_model(taskType,bertPath):
    label_df = pd.read_csv('/kaggle/input/covid19-knowledge-graph/%s_label.csv'%taskType)
    tokenizer = BertTokenizer.from_pretrained(bertPath,do_lower_case=False)
    model = BertForSequenceClassification.from_pretrained(bertPath, num_labels=label_df['label'].nunique())
    return label_df,tokenizer,model

# bulid data loader
def Data_loader(x,y=None,bs=128,shuffle=False,numWorkers=0):
    if y is not None:
        data = TensorDataset(x,y)
    else:
        data = TensorDataset(x)
    data_loader = DataLoader(dataset=data,batch_size=bs,shuffle=shuffle,num_workers=numWorkers)
    return data_loader

def Prepare_predict_data(tokenizer,bs):
    marked_sentences = marked_sentence_df.loc[(marked_sentence_df['start_entity_type'].apply(lambda x:x.lower())==args.task_type.split('-')[0])&\
                                              (marked_sentence_df['end_entity_type'].apply(lambda x:x.lower())==args.task_type.split('-')[1]),'marked_sentence']
    # convert tokens to ids
    ids = marked_sentences.apply(lambda x:tokenizer.convert_tokens_to_ids(tokenizer.tokenize(x))).tolist()
    # padding ids
    ids = sequence.pad_sequences(ids,args.max_seq_len, truncating='post', padding='post')
    # we cannot confirm order of entities, so predict two possibilities
    reverse_marked_sentences = marked_sentence_df.loc[(marked_sentence_df['start_entity_type'].apply(lambda x:x.lower())==args.task_type.split('-')[0])&\
                                              (marked_sentence_df['end_entity_type'].apply(lambda x:x.lower())==args.task_type.split('-')[1]),'marked_sentence']\
                                              .apply(lambda x:x.replace('start_entity','init_start_entity').replace('end_entity','start_entity').replace('init_start_entity','end_entity'))
    reverse_ids = reverse_marked_sentences.apply(lambda x:tokenizer.convert_tokens_to_ids(tokenizer.tokenize(x))).tolist()
    reverse_ids = sequence.pad_sequences(reverse_ids,args.max_seq_len, truncating='post', padding='post')
    predict_data_loader = Data_loader(torch.LongTensor(ids),torch.LongTensor(reverse_ids),bs=bs)
    return marked_sentences.values,predict_data_loader

def Predict():
    reverse_task_type = args.task_type.split('-')[1] + '-' + args.task_type.split('-')[0]
    def Filter(x):
        if x['init_pred'] in conf.relation_type[args.task_type]:
            if x['reverse_pred'] not in conf.relation_type[reverse_task_type]:
                # init_pred is a correct relation but reverse_pred not
                return 'init_pred'
            else:
                # init_pred and reverse_pred both are correct relations
                if x['init_pred_prob'] >= x['reverse_pred_prob']:
                    # init_pred_prob greater than or equal to reverse_pred_prob
                    return 'init_pred'
                else:
                    return 'reverse_pred'
        else:
            if x['reverse_pred'] not in conf.relation_type[reverse_task_type]:
                # init_pred and reverse_pred both are uncorrect relations
                return 'uncorrect'
            else:
                # reverse_pred is a correct relation but init_pred not
                return 'reverse_pred'
    label_df,tokenizer,model = Bert_model(args.task_type,'/kaggle/input/covid19-knowledge-graph/%s/'%args.task_type)
    marked_sentences,predict_data_loader = Prepare_predict_data(tokenizer,args.bs)
    model = model.to(device)
    preds = []
    preds_prob = []
    reverse_preds = []
    reverse_preds_prob = []
    for data in tqdm(predict_data_loader):
        ids,reverse_ids = [t.to(device) for t in data]
        outputs = model(input_ids=ids)
        logits = outputs[0]
        pred_prob, pred = torch.max(F.softmax(logits.data,1), 1)
        preds.extend(list(pred.cpu().detach().numpy()))
        preds_prob.extend(list(pred_prob.cpu().detach().numpy()))
        reverse_outputs = model(input_ids=reverse_ids)
        reverse_logits = reverse_outputs[0]
        reverse_pred_prob, reverse_pred = torch.max(F.softmax(reverse_logits.data,1), 1)
        reverse_preds.extend(list(reverse_pred.cpu().detach().numpy()))
        reverse_preds_prob.extend(list(reverse_pred_prob.cpu().detach().numpy()))

    pred_df = pd.DataFrame({'marked_sentence':marked_sentences,'init_pred':preds,'init_pred_prob':preds_prob,'reverse_pred':reverse_preds,'reverse_pred_prob':reverse_preds_prob})
    # map label(0, 1, 2...) to raw label(T, C, Sa...) 
    pred_df['init_pred'] = pred_df['init_pred'].replace(dict(label_df.set_index(['label'])['label_raw']))
    pred_df['reverse_pred'] = pred_df['reverse_pred'].replace(dict(label_df.set_index(['label'])['label_raw']))
    # judge the order of a pair of entities
    pred_df['filter'] = pred_df.apply(lambda x:Filter(x), axis=1)
    pred_df['pred'] = pred_df['init_pred']
    pred_df['pred_prob'] = pred_df['init_pred_prob']
    pred_df.loc[pred_df['filter']=='reverse_pred','pred'] = pred_df.loc[pred_df['filter']=='reverse_pred','reverse_pred']
    pred_df.loc[pred_df['filter']=='reverse_pred','pred_prob'] = pred_df.loc[pred_df['filter']=='reverse_pred','reverse_pred_prob']
    pred_df = pred_df.loc[pred_df['filter']!='uncorrect']
    pred_df = marked_sentence_df.merge(pred_df,how='inner',on='marked_sentence')
    pred_df['init_start_entity'] = pred_df['start_entity']
    pred_df['init_start_entity_type'] = pred_df['start_entity_type']
    pred_df.loc[pred_df['filter']=='reverse_pred','start_entity'] = pred_df.loc[pred_df['filter']=='reverse_pred','end_entity']
    pred_df.loc[pred_df['filter']=='reverse_pred','start_entity_type'] = pred_df.loc[pred_df['filter']=='reverse_pred','end_entity_type']
    pred_df.loc[pred_df['filter']=='reverse_pred','end_entity'] = pred_df.loc[pred_df['filter']=='reverse_pred','init_start_entity']
    pred_df.loc[pred_df['filter']=='reverse_pred','end_entity_type'] = pred_df.loc[pred_df['filter']=='reverse_pred','init_start_entity_type']
    pred_df.drop(['init_start_entity','init_start_entity_type'],axis=1,inplace=True)
    torch.cuda.empty_cache()
    return label_df,pred_df

# %%
# chemical-disease relation prediction
args.task_type = 'chemical-disease'
c_d_label_df,c_d_pred_df = Predict()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:61: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))

# %%
# chemical-disease relation theme
c_d_label_df
# Out:
#   label_raw  label                                    theme
# 0         C      0      Inhibits cell growth (esp. cancers)
# 1         J      1                     Role in pathogenesis
# 2        Mp      2                 Biomarkers (progression)
# 3        Pa      3                      Alleviates, reduces
# 4        Pr      4                     Prevents, suppresses
# 5        Sa      5                Side effect/adverse event
# 6         T      6  Treatment/therapy (incl. investigatory)

# %%
# chemical-disease classification results
c_d_pred_df.sample(5)
# Out:
#     start_entity                            end_entity start_entity_type  \
# 875  ventilation                              COVID-19          Chemical
# 82   ventilation  Respiratory Distress Syndrome, Adult          Chemical
# 550    Infection                          Methotrexate           Disease
# 381   Pranlukast                            Recurrence          Chemical
# 133  ventilation     Severe Acute Respiratory Syndrome          Chemical
#
#     end_entity_type                                    marked_sentence  \
# 875         Disease  Middle East respiratory syndrome end_entity ME...
# 82          Disease  While effective treatments for acute respirato...
# 550        Chemical  Akio Tanaka, Satoshi Morioke, Yukihiro Ohya, N...
# 381         Disease  Pieters A245 How to Define Chronic Cough: Base...
# 133         Disease  CONCLUSION: Some measures, particularly good a...
#
#     init_pred  init_pred_prob reverse_pred  reverse_pred_prob        filter  \
# 875         T        0.999833           Sa           0.999952     init_pred
# 82          T        0.999969           Sa           0.986141     init_pred
# 550        Mp        0.586788           Mp           0.586788  reverse_pred
# 381         C        0.527138            C           0.527138     init_pred
# 133        Pr        0.912145           Sa           0.995642     init_pred
#
#     pred  pred_prob
# 875    T   0.999833
# 82     T   0.999969
# 550   Mp   0.586788
# 381    C   0.527138
# 133   Pr   0.912145

# %%
# chemical-gene relation prediction
args.task_type = 'chemical-gene'
c_g_label_df,c_g_pred_df = Predict()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:61: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
# chemical-gene relation theme
c_g_label_df
# Out:
#   label_raw  label                                    theme
# 0        A+      0                      Agonism, activation
# 1        A-      1                     Antagonism, blocking
# 2         B      2         Binding, ligand (esp. receptors)
# 3         E      3  Affects expression/production (neutral)
# 4        E-      4          Decreases expression/production
# 5         K      5             Metabolism, pharmacokinetics
# 6         N      6                                 Inhibits
# 7         O      7                      Transport, channels
# 8         Z      8                          Enzyme activity

# %%
# chemical-gene classification results
c_g_pred_df.sample(5)
# Out:
#      start_entity end_entity start_entity_type end_entity_type  \
# 272    Omalizumab      MAPK8          Chemical            Gene
# 240  Methotrexate      PSME3          Chemical            Gene
# 339   Alprostadil      MAPK8          Chemical            Gene
# 48    Cholesterol        MCD          Chemical            Gene
# 177       Toluene       PTX3          Chemical            Gene
#
#                                        marked_sentence init_pred  \
# 272  Ehlayel, Abdul Bari Bener A607 Strong Associat...         E
# 240  Akio Tanaka, Satoshi Morioke, Yukihiro Ohya, N...         N
# 339  Furthermore, we found that start_entity had an...         N
# 48   start_entity depletion by pretreatment of Madi...         E
# 177  Leung, Ka Hou Chu A67 The relationship between...         E
#
#      init_pred_prob reverse_pred  reverse_pred_prob     filter pred  pred_prob
# 272        0.987748            E           0.987748  init_pred    E   0.987748
# 240        0.991007            N           0.991007  init_pred    N   0.991007
# 339        0.995382            K           0.922250  init_pred    N   0.995382
# 48         0.985393            E           0.754519  init_pred    E   0.985393
# 177        0.998353            O           0.968128  init_pred    E   0.998353

# %%
# gene-disease relation prediction
args.task_type = 'gene-disease'
g_d_label_df,g_d_pred_df = Predict()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:61: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=142.0), HTML(value='')))

# %%
# gene-disease relation theme
g_d_label_df
# Out:
#   label_raw  label                                  theme
# 0         D      0                           Drug targets
# 1         G      1                   Promotes progression
# 2         J      2                   Role in pathogenesis
# 3         L      3  Improper regulation linked to disease
# 4        Md      4                Biomarkers (diagnostic)
# 5        Te      5            Possible therapeutic effect
# 6         U      6                       Causal mutations
# 7        Ud      7        Mutations affect disease course
# 8         X      8              Overexpression in disease
# 9         Y      9               Polymorphisms alter risk

# %%
# gene-disease classification results
g_d_pred_df.sample(5)
# Out:
#      start_entity                    end_entity start_entity_type  \
# 5890         TIA1             Polycythemia Vera              Gene
# 4428           SS            Sjogren's Syndrome              Gene
# 1414           S2                          MERS              Gene
# 1967          KAP  Popliteal Pterygium Syndrome              Gene
# 7455         DPP4                          MERS              Gene
#
#      end_entity_type                                    marked_sentence  \
# 5890         Disease  Here, we report that cells infected with polio...
# 4428         Disease  INTRODUCTION: Understanding the mechanisms und...
# 1414         Disease  The global distance test and contact area diff...
# 1967         Disease  METHODS: A close-ended questionnaire developed...
# 7455         Disease  We speculate that the preferential TBATA local...
#
#      init_pred  init_pred_prob reverse_pred  reverse_pred_prob     filter  \
# 5890         J        0.912460            J           0.985812  init_pred
# 4428         U        0.660757            U           0.867015  init_pred
# 1414         U        0.997497            U           0.704636  init_pred
# 1967         U        0.948552            U           0.981927  init_pred
# 7455         U        0.950060           Te           0.641737  init_pred
#
#      pred  pred_prob
# 5890    J   0.912460
# 4428    U   0.660757
# 1414    U   0.997497
# 1967    U   0.948552
# 7455    U   0.950060

# %%
# gene-gene relation prediction
args.task_type = 'gene-gene'
g_g_label_df,g_g_pred_df = Predict()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:61: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=340.0), HTML(value='')))

# %%
# gene-gene relation theme
g_g_label_df
# Out:
#   label_raw  label                                    theme
# 0         B      0         Binding, ligand (esp. receptors)
# 1         E      1  Affects expression/production (neutral)
# 2        E+      2          Increases expression/production
# 3         H      3                  Same protein or complex
# 4         I      4                        Signaling pathway
# 5         Q      5            Production by cell population
# 6        Rg      6                               Regulation
# 7        V+      7                    Activates, stimulates
# 8         W      8                        Enhances response

# %%
# gene-gene classification results
g_g_pred_df.sample(5)
# Out:
#       start_entity end_entity start_entity_type end_entity_type  \
# 17959        GCNT2     CLEC4M              Gene            Gene
# 3386        TMBIM6      SOCS3              Gene            Gene
# 18746           GC         G2              Gene            Gene
# 10224          CD7        GP2              Gene            Gene
# 2028          GLS2         GL              Gene            Gene
#
#                                          marked_sentence init_pred  \
# 17959  Immunohistochemistry showed that start_entity ...         B
# 3386   BIK, end_entity, start_entity, hypoxia-inducib...        V+
# 18746  The membrane glycoproteins G1 and start_entity...         B
# 10224  Ebola end_entity plays a critical role in viru...         B
# 2028   The metabolic product of start_entity, 18-glyc...         B
#
#        init_pred_prob reverse_pred  reverse_pred_prob        filter pred  \
# 17959        0.647625           E+           0.930488  reverse_pred   E+
# 3386         0.389700           V+           0.476143  reverse_pred   V+
# 18746        0.999416            B           0.999859  reverse_pred    B
# 10224        0.932301            B           0.627924     init_pred    B
# 2028         0.454434           V+           0.850830  reverse_pred   V+
#
#        pred_prob
# 17959   0.930488
# 3386    0.476143
# 18746   0.999859
# 10224   0.932301
# 2028    0.850830

# %% [markdown]
# # Show relation between covid-19 and other entities
#
# Pyecharts cannot show multiple relations between two entities, so the graph is incomplete. Complete relations can be seen in ***pred_df***.

# %%
# chemicl-COVID-19 relations
g = Build_graph(c_d_pred_df.loc[(c_d_pred_df['start_entity']=='COVID-19')|(c_d_pred_df['end_entity']=='COVID-19')],relation=True,repulsion=800,title='Chemical-COVID-19 knowledge graph',labelShow=True)
g
# Out:
# /opt/conda/lib/python3.6/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1d26e7746c55424cad66ad1dec37a19c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1d26e7746c55424cad66ad1dec37a19c = echarts.init(
#                     document.getElementById('1d26e7746c55424cad66ad1dec37a19c'), 'white', {renderer: 'canvas'});
#                 var option_1d26e7746c55424cad66ad1dec37a19c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 800,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "Amantadine",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "PX-12",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Doxycycline",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "membrane oxygenation",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "ventilation",
#                     "symbolSize": 34.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Ganciclovir",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": " oxygen therapy ",
#                     "symbolSize": 13.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Hydroxychloroquine",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Vitamin C",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Daptomycin",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Toluene",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "COVID-19",
#                     "symbolSize": 43.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Zinc",
#                     "symbolSize": 13.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Hexamethylene amiloride",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Oseltamivir",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "mesenchymal stem cells",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "Nitazoxanide",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "remdesivir",
#                     "symbolSize": 23.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Chloroquine",
#                     "symbolSize": 13.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "glucocorticoids",
#                     "symbolSize": 13.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Lopinavir/Ritonavir",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "oseltamivir",
#                     "symbolSize": 16.0,
#                     "category": 2
#                 },
#                 {
#                     "name": "Lopinavir",
#                     "symbolSize": 10,
#                     "category": 2
#                 },
#                 {
#                     "name": "SSYA10-001",
#                     "symbolSize": 10,
#                     "category": 2
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "Disease",
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#FF7F50"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Gene",
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#48D1CC"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chemical",
#                     "itemStyle": {
#                         "normal": {
#                             "color": "#B3EE3A"
#                         }
#                     }
#                 }
#             ],
#             "edgeLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "Daptomycin",
#                     "target": "COVID-19",
#                     "value": "T"
#                 },
#                 {
#                     "source": "ventilation",
#                     "target": "COVID-19",
#                     "value": "T"
#                 },
#                 {
#                     "source": "Nitazoxanide",
#                     "target": "COVID-19",
#                     "value": "C"
#                 },
#                 {
#                     "source": "ventilation",
#                     "target": "COVID-19",
#                     "value": "Sa"
#                 },
#                 {
#                     "source": "oseltamivir",
#                     "target": "COVID-19",
#                     "value": "T"
#                 },
#                 {
#                     "source": "ventilation",
#                     "target": "COVID-19",
#                     "value": "Pr"
#                 },
#                 {
#                     "source": "Ganciclovir",
#                     "target": "COVID-19",
#                     "value": "T"
#                 },
#                 {
#                     "source": "ventilation",
#                     "tar

# %%
# gene-COVID-19 relations
g = Build_graph(g_d_pred_df.loc[(g_d_pred_df['start_entity']=='COVID-19')|(g_d_pred_df['end_entity']=='COVID-19')],relation=True,repulsion=60,title='Gene-COVID-19 knowledge graph',labelShow=False)
g
# Out:
# /opt/conda/lib/python3.6/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cf6a8aea3d994540b1b07312a1f4433d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cf6a8aea3d994540b1b07312a1f4433d = echarts.init(
#                     document.getElementById('cf6a8aea3d994540b1b07312a1f4433d'), 'white', {renderer: 'canvas'});
#                 var option_cf6a8aea3d994540b1b07312a1f4433d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 60,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "IRF3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "NDUFB6",
#                     "symbolSize": 27.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "d-dimer",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "RHO",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "alanine ",
#                     "symbolSize": 19.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "CAV",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "GALT",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "NLRP3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "P1",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "CAP",
#                     "symbolSize": 48.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "CPE",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PRH1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "KIR3DL1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "RPLP2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "EGFR",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "B29",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "SEC14L2",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "IL18",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "HR",
#                     "symbolSize": 17.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "SCAP",
#                     "symbolSize": 16.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "CCL3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "GAD1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "NSP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ALB",
#                     "symbolSize": 21.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "B1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "RCP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MB",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "HHAT",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "F2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CBLB",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IGKV4-1",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "PDCD1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "APOBEC3G",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "PRDX2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "LTA",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "ZNF79",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "DDX1",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "CDKN2A",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "CD82",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "UCN",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ATP1A1",
#                     "symbolSize": 10,

# %%
# gene-COVID-19 relations
g = Build_graph(marked_sentence_df.loc[(marked_sentence_df['start_entity']=='COVID-19')&(marked_sentence_df['end_entity_type']=='Disease')|(marked_sentence_df['start_entity_type']=='Disease')&(marked_sentence_df['end_entity']=='COVID-19')],relation=False,repulsion=60,title='Disease-COVID-19 topology graph',labelShow=False)
g
# Out:
# /opt/conda/lib/python3.6/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="052869b699c648c3a4d4c79a29c9f2a3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_052869b699c648c3a4d4c79a29c9f2a3 = echarts.init(
#                     document.getElementById('052869b699c648c3a4d4c79a29c9f2a3'), 'white', {renderer: 'canvas'});
#                 var option_052869b699c648c3a4d4c79a29c9f2a3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 60,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "Stickler syndrome, type 1",
#                     "symbolSize": 17.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Pulmonary Disease, Chronic Obstructive",
#                     "symbolSize": 33.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Hyponatremia",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Porcine Reproductive and Respiratory Syndrome",
#                     "symbolSize": 13.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Achondroplasia",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Robinow syndrome, autosomal recessive",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Hemorrhagic Fever, Ebola",
#                     "symbolSize": 16.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Enteritis",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Nance-Horan syndrome",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Autoimmune polyendocrinopathy syndrome, type 1",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Pneumonia, Mycoplasma",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "vomiting",
#                     "symbolSize": 30.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Lassa Fever",
#                     "symbolSize": 17.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Hantavirus Pulmonary Syndrome",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Encephalitis, Japanese",
#                     "symbolSize": 16.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Hypokalemia",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Transplantation",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Polycythemia Vera",
#                     "symbolSize": 13.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Severe Combined Immunodeficiency",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "heart rate",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "COVID-19",
#                     "symbolSize": 79.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "MERS",
#                     "symbolSize": 55.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Severe Acute Respiratory Syndrome",
#                     "symbolSize": 70.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "sputum",
#                     "symbolSize": 34.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Paramyxoviridae Infections",
#                     "symbolSize": 13.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Sarcoma, Ewing",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Yellow Fever",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Coronavirus Infections",
#                     "symbolSize": 46.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Hepatitis",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Hamartoma Syndrome, Multiple",
#                     "symbolSize": 21.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "TS",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Chondrosarcoma, Extraskeletal Myxoid",
#                     "symbolSize": 17.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Peanut Hypersensitivity",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Ataxia Telangiectasia",
#                     "symbolSize": 13.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "Blindness",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Respiratory Tract Infections",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "Emergencies",
#                     "symbolSize": 33.0,

# %% [markdown]
# # Results

# %%
# merge all relation prediction and save results
cols = ['start_entity','end_entity','start_entity_type','end_entity_type','marked_sentence','pred','pred_prob']
relation_df = pd.concat([c_d_pred_df[cols],c_g_pred_df[cols],g_d_pred_df[cols],g_g_pred_df[cols]]).append(marked_sentence_df.loc[(marked_sentence_df['start_entity_type'].isin(['Chemical','Disease'])&(marked_sentence_df['start_entity_type']==marked_sentence_df['end_entity_type']))]).reset_index(drop=True)
relation_df.loc[(relation_df['pred'].isna())&(relation_df['start_entity_type']=='Chemical'),'pred'] = 'CC'
relation_df.loc[(relation_df['pred'].isna())&(relation_df['start_entity_type']=='Disease'),'pred'] = 'DD'
relation_df = relation_df[cols]
relation_df.to_csv('relation.csv',index=False)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
relation_df
# Out:
#                             start_entity                         end_entity  \
# 0              keyhole limpet hemocyanin      Lupus Erythematosus, Systemic
# 1                                Cocaine             Incontinentia Pigmenti
# 2                             Daptomycin                           COVID-19
# 3                                   Zinc                           diarrhea
# 4                                   Zinc   Glycogen Storage Disease Type II
# ...                                  ...                                ...
# 39577             Coronavirus Infections  Severe Acute Respiratory Syndrome
# 39578             Coronavirus Infections                           Syndrome
# 39579                               MERS  Severe Acute Respiratory Syndrome
# 39580                               MERS                           Syndrome
# 39581  Severe Acute Respiratory Syndrome                           Syndrome
#
#       start_entity_type end_entity_type  \
# 0              Chemical         Disease
# 1              Chemical         Disease
# 2              Chemical         Disease
# 3              Chemical         Disease
# 4              Chemical         Disease
# ...                 ...             ...
# 39577           Disease         Disease
# 39578           Disease         Disease
# 39579           Disease         Disease
# 39580           Disease         Disease
# 39581           Disease         Disease
#
#                                          marked_sentence pred  pred_prob
# 0      Middle-aged female identical twins, one of who...   Pa   0.969853
# 1      start_entity 10 mgkg, administered intraperito...   Pa   0.832485
# 2      start_entity is not indicated for end_entity, ...    T   0.999757
# 3      start_entity is being used for the treatment o...   Pa   0.769986
# 4      start_entity was effective in decreasing the i...   Pa   0.423429
# ...                                                  ...  ...        ...
# 39577  In a recent review on the persistence of human...   DD        NaN
# 39578  In a recent review on the persistence of human...   DD        NaN
# 39579  In a recent review on the persistence of human...   DD        NaN
# 39580  In a recent review on the persistence of human...   DD        NaN
# 39581  In a recent review on the persistence of human...   DD        NaN
#
# [39582 rows x 7 columns]

# %%
# subsample of knowledge graph
g = Build_graph(relation_df.sample(1000),relation=True,repulsion=15,title='subsample of COVID-19 knowledge graph',labelShow=False)
g
# Out:
# /opt/conda/lib/python3.6/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b68e1fadff0d4413b5376aee47919b8f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b68e1fadff0d4413b5376aee47919b8f = echarts.init(
#                     document.getElementById('b68e1fadff0d4413b5376aee47919b8f'), 'white', {renderer: 'canvas'});
#                 var option_b68e1fadff0d4413b5376aee47919b8f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 15,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "IRF3",
#                     "symbolSize": 21.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "ATF5",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "THBS1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "alanine ",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "F11",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "FOS",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "vomiting",
#                     "symbolSize": 21.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "ATG3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "P1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "UBA7",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ATG5",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ANXA3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "NOD2",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "SLC2A5",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Severe Acute Respiratory Syndrome",
#                     "symbolSize": 41.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "RNPEP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "EGFR",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CD36",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MTHFR",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "YOD1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Hepatitis",
#                     "symbolSize": 16.0,
#                     "category": 0
#                 },
#                 {
#                     "name": "PSME1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "TICAM1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "MITF",
#                     "symbolSize": 13.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "SCAP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CCL3",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "CAM",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "TUBA4A",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "B1",
#                     "symbolSize": 17.0,
#                     "category": 1
#                 },
#                 {
#                     "name": "RCP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "FPGS",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "HHAT",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "ABCA1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Attention Deficit Disorder with Hyperactivity",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "CLP",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "IGKV4-1",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "FCER1G",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Pleuropulmonary blastoma",
#                     "symbolSize": 10,
#                     "category": 0
#                 },
#                 {
#                     "name": "EPO",
#                     "symbolSize": 10,
#                     "category": 1
#                 },
#                 {
#                     "name": "Emergencies",
#                     "symbolSize": 17.0,
#                     "category": 0
#                 },

# %% [markdown]
# ## 1. What genes have U(Causal mutations), Ud(Mutations affect disease course), Y(Polymorphisms alter risk) to COVID-19?

# %%
# 1. What genes have U(Causal mutations), Ud(Mutations affect disease course), Y(Polymorphisms alter risk) to COVID-19?


g_d_pred_df.loc[(g_d_pred_df['end_entity']=='COVID-19')&(g_d_pred_df['pred'].isin(['U','Ud','Y']))]
# Out:
#      start_entity end_entity start_entity_type end_entity_type  \
# 1             p28   COVID-19              Gene         Disease
# 4              E1   COVID-19              Gene         Disease
# 5              E2   COVID-19              Gene         Disease
# 9          ERVW-1   COVID-19              Gene         Disease
# 11             E1   COVID-19              Gene         Disease
# ...           ...        ...               ...             ...
# 7807           S2   COVID-19              Gene         Disease
# 7819         ACE2   COVID-19              Gene         Disease
# 7835         ACE2   COVID-19              Gene         Disease
# 7862        MERTK   COVID-19              Gene         Disease
# 7868        PLpro   COVID-19              Gene         Disease
#
#                                         marked_sentence init_pred  \
# 1     A high level of similarity was detected betwee...        Ud
# 4     The carbohydrate contents of end_entity glycop...         U
# 5     The carbohydrate contents of end_entity glycop...         U
# 9     Tunicamycin has different effects on the glyco...        Ud
# 11    The end_entity envelope ERVW-1 start_entity ap...        Ud
# ...                                                 ...       ...
# 7807  The severe acute respiratory syndrome end_enti...         Y
# 7819  Molecular modeling revealed that end_entity RB...         U
# 7835  Infection by severe acute respiratory syndrome...         U
# 7862  A 12 start_entity peptide derived from end_ent...        Ud
# 7868  Severe_Acute_Respiratory_Syndrome end_entity S...         U
#
#       init_pred_prob reverse_pred  reverse_pred_prob     filter pred  \
# 1           0.932619            U           0.975709  init_pred   Ud
# 4           0.959630            U           0.977801  init_pred    U
# 5           0.935260            J           0.610730  init_pred    U
# 9           0.687815            Y           0.812220  init_pred   Ud
# 11          0.989257            L           0.718455  init_pred   Ud
# ...              ...          ...                ...        ...  ...
# 7807        0.676709            U           0.480307  init_pred    Y
# 7819        0.607001            Y           0.998896  init_pred    U
# 7835        0.928479            U           0.836396  init_pred    U
# 7862        0.558342            J           0.512183  init_pred   Ud
# 7868        0.695120            J           0.999687  init_pred    U
#
#       pred_prob
# 1      0.932619
# 4      0.959630
# 5      0.935260
# 9      0.687815
# 11     0.989257
# ...         ...
# 7807   0.676709
# 7819   0.607001
# 7835   0.928479
# 7862   0.558342
# 7868   0.695120
#
# [547 rows x 12 columns]

# %% [markdown]
# ## 2. What diseases are associated to COVID-19 (like complication)

# %%
# 2. What diseases are associated to COVID-19 (like complication)
d_d_df = relation_df.loc[((relation_df['start_entity']=='COVID-19')&(relation_df['end_entity_type']=='Disease'))|((relation_df['start_entity_type']=='Disease')&(relation_df['end_entity']=='COVID-19'))]
value_counts_dic = dict(d_d_df['start_entity'].value_counts())
end_entity_value_counts_dic = dict(d_d_df['end_entity'].value_counts())
for key in end_entity_value_counts_dic:
    if key in value_counts_dic:
        value_counts_dic[key] += end_entity_value_counts_dic[key]
    else:
        value_counts_dic[key] = end_entity_value_counts_dic[key]
most_relevant_disease = []
for key in value_counts_dic:
    if value_counts_dic[key] > 10:
        most_relevant_disease.append(key)
relation_df.loc[((relation_df['start_entity'].isin(most_relevant_disease))&(relation_df['end_entity']=='COVID-19'))|((relation_df['start_entity']=='COVID-19')&(relation_df['end_entity'].isin(most_relevant_disease)))]
# Out:
#       start_entity                         end_entity start_entity_type  \
# 30951     COVID-19  Cataract congenital Volkmann type           Disease
# 30956     COVID-19  Cataract congenital Volkmann type           Disease
# 30961     COVID-19                   Influenza, Human           Disease
# 30964     COVID-19  Cataract congenital Volkmann type           Disease
# 30971     COVID-19                          Infection           Disease
# ...            ...                                ...               ...
# 39569     COVID-19  Severe Acute Respiratory Syndrome           Disease
# 39572     COVID-19             Coronavirus Infections           Disease
# 39573     COVID-19                               MERS           Disease
# 39574     COVID-19  Severe Acute Respiratory Syndrome           Disease
# 39575     COVID-19                           Syndrome           Disease
#
#       end_entity_type                                    marked_sentence pred  \
# 30951         Disease  The pathogenesis of canine start_entity end_en...   DD
# 30956         Disease  The genomic organization at the 3 end of canin...   DD
# 30961         Disease  Blood was taken from the sows at the beginning...   DD
# 30964         Disease  From the reasons that canine start_entity end_...   DD
# 30971         Disease  end_entity of cell monolayers by murine start_...   DD
# ...               ...                                                ...  ...
# 39569         Disease  end_entity start_entity end_entity-CoV papain-...   DD
# 39572         Disease  In a recent review on the persistence of human...   DD
# 39573         Disease  In a recent review on the persistence of human...   DD
# 39574         Disease  In a recent review on the persistence of human...   DD
# 39575         Disease  In a recent review on the persistence of human...   DD
#
#        pred_prob
# 30951        NaN
# 30956        NaN
# 30961        NaN
# 30964        NaN
# 30971        NaN
# ...          ...
# 39569        NaN
# 39572        NaN
# 39573        NaN
# 39574        NaN
# 39575        NaN
#
# [2450 rows x 7 columns]

# %% [markdown]
# ## What do we know about vaccines and therapeutics?

# %%
# 1. What chemicals have Pa(Alleviates, reduces), Pr(Prevents, suppresses), T(Treatment/therapy (incl. investigatory)) to COVID-19 and revelant disease?

c_d_pred_df.loc[(c_d_pred_df['end_entity']=='COVID-19')&(c_d_pred_df['pred'].isin(['Pa','Pr','T']))]
# Out:
#                start_entity end_entity start_entity_type end_entity_type  \
# 2                Daptomycin   COVID-19          Chemical         Disease
# 15              ventilation   COVID-19          Chemical         Disease
# 47              oseltamivir   COVID-19          Chemical         Disease
# 55              ventilation   COVID-19          Chemical         Disease
# 57              Ganciclovir   COVID-19          Chemical         Disease
# 59              ventilation   COVID-19          Chemical         Disease
# 67              Chloroquine   COVID-19          Chemical         Disease
# 69              ventilation   COVID-19          Chemical         Disease
# 78              ventilation   COVID-19          Chemical         Disease
# 79              ventilation   COVID-19          Chemical         Disease
# 90              ventilation   COVID-19          Chemical         Disease
# 95               remdesivir   COVID-19          Chemical         Disease
# 97          glucocorticoids   COVID-19          Chemical         Disease
# 98              ventilation   COVID-19          Chemical         Disease
# 99              ventilation   COVID-19          Chemical         Disease
# 100              remdesivir   COVID-19          Chemical         Disease
# 102              remdesivir   COVID-19          Chemical         Disease
# 104             Chloroquine   COVID-19          Chemical         Disease
# 105      Hydroxychloroquine   COVID-19          Chemical         Disease
# 106                   PX-12   COVID-19          Chemical         Disease
# 107             ventilation   COVID-19          Chemical         Disease
# 111              remdesivir   COVID-19          Chemical         Disease
# 112    membrane oxygenation   COVID-19          Chemical         Disease
# 116     Lopinavir/Ritonavir   COVID-19          Chemical         Disease
# 120              remdesivir   COVID-19          Chemical         Disease
# 122              remdesivir   COVID-19          Chemical         Disease
# 123         glucocorticoids   COVID-19          Chemical         Disease
# 125         oxygen therapy    COVID-19          Chemical         Disease
# 126             ventilation   COVID-19          Chemical         Disease
# 135             ventilation   COVID-19          Chemical         Disease
# 787              remdesivir   COVID-19          Chemical         Disease
# 794             Oseltamivir   COVID-19          Chemical         Disease
# 799             ventilation   COVID-19          Chemical         Disease
# 804               Vitamin C   COVID-19          Chemical         Disease
# 805             ventilation   COVID-19          Chemical         Disease
# 806             ventilation   COVID-19          Chemical         Disease
# 812             ventilation   COVID-19          Chemical         Disease
# 823             ventilation   COVID-19          Chemical         Disease
# 830              SSYA10-001   COVID-19          Chemical         Disease
# 833             oseltamivir   COVID-19          Chemical         Disease
# 836             oseltamivir   COVID-19          Chemical         Disease
# 857              Amantadine   COVID-19          Chemical         Disease
# 859             ventilation   COVID-19          Chemical         Disease
# 868                    Zinc   COVID-19          Chemical         Disease
# 872              remdesivir   COVID-19          Chemical         Disease
# 875             ventilation   COVID-19          Chemical         Disease
# 876  mesenchymal stem cells   COVID-19          Chemical         Disease
# 887         oxygen therapy    COVID-19          Chemical         Disease
# 888             ventilation   COVID-19          Chemical         Disease
# 889         glucocorticoids   COVID-19          Chemical         Disease
# 890             oseltamivir   COVID-19          Chemical         Disease
#
#                                        marked_sentence init_pred  \
# 2    start_entity is not indicated for end_entity, ...         T
# 15   Study objectives: To report on our experience ...         T
# 47   During the pandemic H1N1 2009 influenza A viru...         T
# 55   Bad housing, particularly bad start_entity, wi...        Pr
# 57   start_entity can be considered for patients wi...         T
# 59   Case report We report a case of acute respirat...         T
# 67   start_entity, remdesivir, lopinavir, ribavirin...         T
# 69   Three clinical cases of patients presenting se...         T
# 78   The populations of patients with community-acq...         T
# 79   By contrast, the use of non-invasive start_ent...         T
# 90   Methods In this retrospective cohort study, we...         T
# 95   Herein, we suggest four potential drug candida...         T
# 97   With more and more patients diagnosed, China h...         T
# 98   Another series10 of nine pregnant women with e...         T
# 99   About 1520 of suspected and confirmed patients...         T
# 100  Gengfu Xiao, Wu Zhong and Zhihong Hu, the anti...         T
# 102  25, the US National Institutes of Health NIH s...         T
# 104  start_entity has been sporadically used in tre...         T
# 105  CONCLUSIONS: start_entity was found to be more...        Pa
# 106  Molecular docking against the two thiol protea...        Pa
# 107  For end_entity patients with mechanical start_...         T
# 111  Drugs are possibly effective for end_entity in...         T
# 112  long with the sharp increase of confirmed case...         T
# 116  Combination of Ribavirin and Interferon- is re...         T
# 120  Several drugs such as chloroquine, arbidol, st...         T
# 122  Recently, the RNA polymerase start_entity had ...         T
# 123  Because of the delayed clearance of viral RNA ...         T
# 125  The treatment experience in severe cases of 20...         T
# 126  The treatment experience in severe cases of 20...        Pr
# 135  CONCLUSIONS: Community-acquired adenovirus end...         T
# 787  We recently reported that the nucleoside analo...        Pa
# 794  Intranasal administration of PA markedly impro...        Pa
# 799  Compared with continuous invasive start_entity...        Pa
# 804  Therefore, we tested a set of Strepsils lozeng...        Pr
# 805  INTRODUCTION: Non-invasive start_entity NIV is...         T
# 806  CONCLUSION: Special attention should be given ...         T
# 812  Twenty-seven articles were grouped into the fo...        Pa
# 823  PURPOSE: To compare the outcomes of patients h...         T
# 830  Here, we show that start_entity also inhibits ...         T
# 833  No start_entity treatment studies reported eff...         T
# 836  Treatment trials with start_entity or zanamivi...        Pa
# 857  However, three drugs approved for human use ma...        Pa
# 859  Conclusions: Room start_entity, open space, pr...        Pa
# 868  Conclusions: start_entity supplementation impr...         T
# 872  The one case of end_entity end_entity in the U...         T
# 875  Middle East respiratory syndrome end_entity ME...         T
# 876  Transplantation of start_entity MSCs is a prom...         T
# 887  Supporting the recommendation of the authors, ...         T
# 888  Supporting the recommendation of the authors, ...        Pa
# 889  8 Fifth, WHO has made it clear that there are ...         T
# 890  Despite this, there have been reports of the u...         T
#
#      init_pred_prob reverse_pred  reverse_pred_prob     filter pred  pred_prob
# 2          0.999757            T           0.597799  init_pred    T   0.999757
# 15         0.999976           Sa           0.998793  init_pred    T   0.999976
# 47         0.584094            T           0.932823  init_pred    T   0.584094
# 55         0.759886           Sa           0.961628  init_pred   Pr   0.759886
# 57         0.999927            T           0.999898  init_pred    T   0.999927
# 59         0.848494           Sa           0.999983  init_pred    T   0.848494
# 67         0.948416           Pr           0.833724  init_pred    T   0.948416
# 69         0.946440            T           0.936319  init_pred    T   0.946440
# 78         0.999792            C           0.627967  init_pred    T   0.999792
# 79         0.998000            T           0.521081  init_pred    T   0.998000
# 90         0.999998            T           0.999974  init_pred    T   0.999998
# 95         0.824200            T           0.988221  init_pred    T   0.824200
# 97         0.977593           Sa           0.791993  init_pred    T   0.977593
# 98         0.999441           Sa           0.931194  init_pred    T   0.999441
# 99         0.998170           Sa           0.994765  init_pred    T   0.998170
# 100        0.753332            T           0.753332  init_pred    T   0.753332
# 102        0.672607           Sa           0.957551  init_pred    T   0.672607
# 104        0.999489            T           0.996359  init_pred    T   0.999489
# 105        0.996757           Pa           0.701936  init_pred   Pa   0.996757
# 106        0.821953            J           0.999817  init_pred   Pa   0.821953
# 107        0.999752            T           0.997911  init_pred    T   0.999752
# 111        0.998933           Pr           0.989574  init_pred    T   0.998933
# 112        0.998529            T           0.999905  init_pred    T   0.998529
# 116        0.999992            T           0.999994  init_pred    T   0.999992
# 120        0.999784           Sa           0.993309  init_pred    T   0.999784
# 122        0.992526           Pa           0.570598  init_pred    T   0.992526
# 123        0.992699            T           0.487099  init_pred    T   0.992699
# 125        0.928400            T           0.948041  init_pred    T   0.928400
# 126        0.913141            T           0.991021  init_pred   Pr   0.913141
# 135        0.999564           Sa           0.999994  init_pred    T   0.999564
# 787        0.999938            C           0.931957  init_pred   Pa   0.999938
# 794        0.999786           Sa           0.983384  init_pred   Pa   0.999786
# 799        0.984847            J           0.951272  init_pred   Pa   0.984847
# 804        0.987307           Pr           0.999992  init_pred   Pr   0.987307
# 805        0.983459            C           0.781648  init_pred    T   0.983459
# 806        0.651040           Sa           0.920122  init_pred    T   0.651040
# 812        0.999425           Pa           0.890730  init_pred   Pa   0.999425
# 823        0.999985            C           0.998503  init_pred    T   0.999985
# 830        0.997492           Sa           0.856657  init_pred    T   0.997492
# 833        0.987213            T           0.867692  init_pred    T   0.987213
# 836        0.722925           Sa           0.997325  init_pred   Pa   0.722925
# 857        0.994300           Sa           0.853902  init_pred   Pa   0.994300
# 859        0.954351           Pr           0.794338  init_pred   Pa   0.954351
# 868        0.948984            T           0.663313  init_pred    T   0.948984
# 872        0.999963            T           0.999805  init_pred    T   0.999963
# 875        0.999833           Sa           0.999952  init_pred    T   0.999833
# 876        0.999805            T           0.855525  init_pred    T   0.999805
# 887        0.940325           Sa           0.989545  init_pred    T   0.940325
# 888        0.943463           Sa           0.998464  init_pred   Pa   0.943463
# 889        0.997896           Pr           0.703673  init_pred    T   0.997896
# 890        0.999295            T           0.758861  init_pred    T   0.999295

# %%
# 2. What genes have D(Drug targets), G(Promotes progression), J(Role in pathogenesis), Te(Possible therapeutic effect), X(Overexpression in disease) to COVID-19 and revelant disease?

g_d_pred_df.loc[(g_d_pred_df['end_entity']=='COVID-19')&(g_d_pred_df['pred'].isin(['D','G','J','Te','X']))]
# Out:
#      start_entity end_entity start_entity_type end_entity_type  \
# 8           GCNT2   COVID-19              Gene         Disease
# 18          PSMD1   COVID-19              Gene         Disease
# 24          CYTIP   COVID-19              Gene         Disease
# 27             S2   COVID-19              Gene         Disease
# 33          CYTIP   COVID-19              Gene         Disease
# ...           ...        ...               ...             ...
# 7805        PSMD1   COVID-19              Gene         Disease
# 7808       NDUFB6   COVID-19              Gene         Disease
# 7810        IFNA1   COVID-19              Gene         Disease
# 7834        ARIH1   COVID-19              Gene         Disease
# 7870         BRD2   COVID-19              Gene         Disease
#
#                                         marked_sentence init_pred  \
# 8     This end_entity, like influenza virus, can rep...         J
# 18    The sequences of the peplomeric start_entity p...         J
# 24    The hemagglutininesterase start_entity, spike ...         D
# 27    These observations may reflect the biological ...        Te
# 33    In contrast to bovine end_entity, which appare...         J
# ...                                                 ...       ...
# 7805  We investigated the kinetics of serologic resp...        Te
# 7808  We fitted a log-normal distribution to pooled ...         D
# 7810  Poxvirus and end_entity mutants that lacked 2-...        Te
# 7834  The Human respiratory syncytial virus RSV is o...        Te
# 7870  Conclusions Therefore, we concluded that viral...        Te
#
#       init_pred_prob reverse_pred  reverse_pred_prob     filter pred  \
# 8           0.999964           Ud           0.578843  init_pred    J
# 18          0.958232            U           0.994972  init_pred    J
# 24          0.480010           Te           0.834432  init_pred    D
# 27          0.731474            J           0.999688  init_pred   Te
# 33          0.993721            L           0.988948  init_pred    J
# ...              ...          ...                ...        ...  ...
# 7805        0.744864            J           0.997138  init_pred   Te
# 7808        0.962256           Te           0.909174  init_pred    D
# 7810        0.784429            J           0.973894  init_pred   Te
# 7834        0.914881            J           0.916928  init_pred   Te
# 7870        0.999843            J           0.969410  init_pred   Te
#
#       pred_prob
# 8      0.999964
# 18     0.958232
# 24     0.480010
# 27     0.731474
# 33     0.993721
# ...         ...
# 7805   0.744864
# 7808   0.962256
# 7810   0.784429
# 7834   0.914881
# 7870   0.999843
#
# [680 rows x 12 columns]

# %% [markdown]
# # Problem
# This competition puts us through this painful one-trade-at-a-time loop:
#
# **for (test_df, sample_prediction_df) in iter_test:**

# %% [markdown]
# # Solution
# * **test.csv** is here for your downloading comfort;
# * the code is also here for your forking comfort.
#
# This is a stripped-down, minimalist code to save the test dataset for repeated use without having to
#
# * Add data > janestreet
# * import janestreet
# * env = janestreet.make_env()
# * iter_test = env.iter_test()
# * for (test_df, sample_prediction_df) in iter_test:
#
# until we are really, really ready to submit.

# %%
import janestreet
import pandas as pd
from datetime import datetime
from pytz import timezone
print('HEY', datetime.now(timezone('Canada/Pacific')).isoformat(timespec='minutes'))
# Out:
# HEY 2021-02-03T22:10-08:00

# %%
env = janestreet.make_env()
iter_test = env.iter_test()
test = pd.DataFrame()
for (test_df, sample_prediction_df) in iter_test:
    test = pd.concat([test, test_df])
    sample_prediction_df.action = 0 
    env.predict(sample_prediction_df)
test.to_csv('test.csv', index=False)
test
# Out:
#           weight  feature_0  feature_1  feature_2  feature_3  feature_4  \
# 0       0.000000        1.0  -1.872746  -2.191242  -0.474163  -0.323046
# 1      16.673515       -1.0  -1.349537  -1.704709   0.068058   0.028432
# 2       0.000000       -1.0   0.812780  -0.256156   0.806463   0.400221
# 3       0.000000       -1.0   1.174378   0.344640   0.066872   0.009357
# 4       0.138531        1.0  -3.172026  -3.093182  -0.161518  -0.128149
# ...          ...        ...        ...        ...        ...        ...
# 15214   0.000000        1.0  -1.213240  -1.557117   0.530793   0.382429
# 15215   0.000000        1.0  -0.413328  -0.642504   0.429951   0.333967
# 15216   0.000000        1.0  -1.378947  -1.702976   0.548763   0.396754
# 15217   0.000000        1.0  -0.324708  -1.089962  -0.873900  -0.544143
# 15218   0.000000        1.0  -1.652183  -1.857245   0.451629   0.352413
#
#        feature_5  feature_6  feature_7  feature_8  ...  feature_121  \
# 0       0.014688  -0.002484        NaN        NaN  ...          NaN
# 1       0.193794   0.138212        NaN        NaN  ...          NaN
# 2      -0.614188  -0.354800        NaN        NaN  ...          NaN
# 3      -1.006373  -0.676458        NaN        NaN  ...          NaN
# 4      -0.195006  -0.143780        NaN        NaN  ...          NaN
# ...          ...        ...        ...        ...  ...          ...
# 15214   0.316811   0.240976   0.741902   0.680989  ...     0.200094
# 15215  -0.728263  -0.637617   0.204294   0.138052  ...     2.070960
# 15216   0.328203   0.249898   0.784458   0.730435  ...     0.200728
# 15217  -1.265208  -0.844335   2.302628   1.978776  ...     0.300244
# 15218  -0.716532  -0.626735   0.268371   0.208574  ...     2.073743
#
#        feature_122  feature_123  feature_124  feature_125  feature_126  \
# 0         1.168391     8.313583     1.782433    14.018213     2.653056
# 1        -1.178850     1.777472    -0.915458     2.831612    -1.417010
# 2         6.115747     9.667908     5.542871    11.671595     7.281757
# 3         2.838853     0.499251     3.033732     1.513488     4.397532
# 4         0.344850     4.101145     0.614252     6.623456     0.800129
# ...            ...          ...          ...          ...          ...
# 15214     1.655182     2.551488     0.525934     1.242721     1.977483
# 15215     6.393191    22.159397    -0.101824     3.804838     1.780150
# 15216     1.740141     2.685696     0.527251     1.245219     1.981606
# 15217     5.243907    11.789678     0.310616     2.660067     3.052869
# 15218     6.423787    22.254007    -0.098530     3.816995     1.793470
#
#        feature_127  feature_128  feature_129  date
# 0        12.600292     2.301488    11.445807   0.0
# 1         2.297459    -1.304614     1.898684   0.0
# 2        10.060014     6.638248     9.427299   0.0
# 3         1.266037     3.856384     1.013469   0.0
# 4         5.233243     0.362636     3.926633   0.0
# ...            ...          ...          ...   ...
# 15214     2.563083     1.857149     2.424928   2.0
# 15215     7.504901     4.702145    15.376130   2.0
# 15216     2.567519     1.876328     2.450874   2.0
# 15217     6.399390     5.396259    10.972647   2.0
# 15218     7.534632     4.730957    15.457871   2.0
#
# [15219 rows x 132 columns]

# %%
print('BYE', datetime.now(timezone('Canada/Pacific')).isoformat(timespec='minutes') )
# Out:
# BYE 2021-02-03T22:14-08:00

# %% [markdown]
# # Cheers, Kaggle and Kagglers!
# for democratising learning and skills

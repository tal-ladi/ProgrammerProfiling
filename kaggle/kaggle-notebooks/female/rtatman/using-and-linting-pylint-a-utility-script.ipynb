# %%
# import in our custom functions
import join_forum_post_info as jfpi
import pylint

# %% [markdown]
# # First, let's make sure all our functions work the way we think they should...

# %%
# read in the three tables we want from metakaggle
forums_info_df, forum_posts_df, forum_topics_df = jfpi.read_in_forum_tables()

# %%
# check column names; if all's well you should have no output
jfpi.check_column_names_forum_forums(forums_info_df)
jfpi.check_column_names_forum_posts(forum_posts_df)
jfpi.check_column_names_forum_topics(forum_topics_df)

# join tablesforums_info_df
posts_and_topics_df = jfpi.join_posts_and_topics(forum_posts_df, forum_topics_df)
forum_posts = jfpi.join_posts_with_forum_title(posts_and_topics_df, forums_info_df)

# %%
# check joined file
forum_posts.head()
# Out:
#               PostDate                                            Message  \
# 0  07/18/2015 10:32:20  <p>In 'coupon_list_train.csv' what do the valu...
# 1  07/19/2015 00:29:55  <p>I'm guessing it means whether the coupon ca...
# 2  07/19/2015 05:35:43  <p>Ok. Let's say '0' means it cannot be used o...
# 3  07/20/2015 01:36:12  <p>You've got me there. I wonder if it's the n...
# 4  07/28/2015 10:40:11  <p>I am wondering too about this magical numbe...
#
#    ForumPostId                TopicTitle                  ForumTitle
# 0        85929  USABLE_DATE_XXX question  Coupon Purchase Prediction
# 1        85994  USABLE_DATE_XXX question  Coupon Purchase Prediction
# 2        86028  USABLE_DATE_XXX question  Coupon Purchase Prediction
# 3        86112  USABLE_DATE_XXX question  Coupon Purchase Prediction
# 4        87291  USABLE_DATE_XXX question  Coupon Purchase Prediction

# %% [markdown]
# ## Now let's use a linter to check our code against a style guide

# %%
# !pylint join_forum_post_info
# Out:
# ************* Module join_forum_post_info
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:7:0: C0301: Line too long (107/100) (line-too-long)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:8:0: C0301: Line too long (112/100) (line-too-long)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:9:0: C0301: Line too long (113/100) (line-too-long)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:15:36: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:21:0: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:26:0: C0330: Wrong continued indentation (add 1 space).
#                       column_names=forum_posts_columns)
#                       ^| (bad-continuation)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:32:0: C0330: Wrong continued indentation (add 1 space).
#                       column_names=forum_topics_columns)
#                       ^| (bad-continuation)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:33:0: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:38:0: C0330: Wrong continued indentation (add 1 space).
#                       column_names=forum_info_columns)
#                       ^| (bad-continuation)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:45:106: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:45:0: C0301: Line too long (106/100) (line-too-long)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:46:0: C0330: Wrong continued indentation (add 16 spaces).
#                    forum_topics_df[['Id', 'ForumId', 'TopicTitle']],
#                    ^               | (bad-continuation)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:46:68: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:47:0: C0330: Wrong continued indentation (add 16 spaces).
#                    left_on='ForumTopicId', right_on='Id')
#                    ^               | (bad-continuation)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:49:0: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:50:0: C0325: Unnecessary parens after 'return' keyword (superfluous-parens)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:55:47: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:56:63: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:59:0: C0303: Trailing whitespace (trailing-whitespace)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:60:0: C0325: Unnecessary parens after 'return' keyword (superfluous-parens)
# /kaggle/usr/lib/join_forum_post_info/join_forum_post_info.py:1:0: C0111: Missing module docstring (missing-docstring)
#
# -----------------------------------
# Your code has been rated at 1.54/10

# %%
## Imports (code & data)
import re
import pandas as pd
#import yake_helper_funcs as yhf
from datetime import datetime, timedelta
from math import sqrt, floor
from sklearn.cluster import SpectralClustering
import numpy as np
import itertools
from flashtext.keyword import KeywordProcessor
import string
import nltk
import math
import join_forum_post_info as jfpi
import kaggle_specific_embed_cluster as embed_cluster
import get_surprising_words as surprising_words

# forum-wide frequency info for identifying surprising words
frequency_table = pd.read_csv("../input/kaggle-forum-term-frequency-unstemmed/kaggle_lex_freq.csv",
                             error_bad_lines=False)
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# b'Skipping line 2532: expected 4 fields, saw 5\nSkipping line 2652: expected 4 fields, saw 5\nSkipping line 3490: expected 4 fields, saw 5\nSkipping line 4018: expected 4 fields, saw 5\nSkipping line 4431: expected 4 fields, saw 5\nSkipping line 4857: expected 4 fields, saw 5\nSkipping line 4932: expected 4 fields, saw 5\nSkipping line 5253: expected 4 fields, saw 5\nSkipping line 5390: expected 4 fields, saw 5\nSkipping line 5555: expected 4 fields, saw 6\nSkipping line 5668: expected 4 fields, saw 5\nSkipping line 6678: expected 4 fields, saw 5\nSkipping line 7002: expected 4 fields, saw 5\nSkipping line 7506: expected 4 fields, saw 5\nSkipping line 7533: expected 4 fields, saw 5\nSkipping line 7657: expected 4 fields, saw 5\nSkipping line 7856: expected 4 fields, saw 5\nSkipping line 8253: expected 4 fields, saw 5\nSkipping line 8454: expected 4 fields, saw 5\nSkipping line 8634: expected 4 fields, saw 5\nSkipping line 9229: expected 4 fields, saw 5\nSkipping line 9302: expected 4 fields, saw 6\nSkipping line 9937: expected 4 fields, saw 7\nSkipping line 10236: expected 4 fields, saw 5\nSkipping line 10240: expected 4 fields, saw 5\nSkipping line 10321: expected 4 fields, saw 5\nSkipping line 10363: expected 4 fields, saw 8\nSkipping line 10773: expected 4 fields, saw 6\nSkipping line 10862: expected 4 fields, saw 6\nSkipping line 10914: expected 4 fields, saw 5\nSkipping line 11105: expected 4 fields, saw 5\nSkipping line 11172: expected 4 fields, saw 5\nSkipping line 11294: expected 4 fields, saw 5\nSkipping line 11650: expected 4 fields, saw 5\nSkipping line 12550: expected 4 fields, saw 6\nSkipping line 13087: expected 4 fields, saw 5\nSkipping line 13094: expected 4 fields, saw 5\nSkipping line 13362: expected 4 fields, saw 7\nSkipping line 13580: expected 4 fields, saw 5\nSkipping line 13660: expected 4 fields, saw 5\nSkipping line 14195: expected 4 fields, saw 5\nSkipping line 14204: expected 4 fields, saw 5\nSkipping line 14227: expected 4 fields, saw 5\nSkipping line 14304: expected 4 fields, saw 5\nSkipping line 14456: expected 4 fields, saw 6\nSkipping line 14857: expected 4 fields, saw 5\nSkipping line 14978: expected 4 fields, saw 7\nSkipping line 14990: expected 4 fields, saw 7\nSkipping line 15185: expected 4 fields, saw 6\nSkipping line 15347: expected 4 fields, saw 5\nSkipping line 15393: expected 4 fields, saw 5\nSkipping line 15768: expected 4 fields, saw 5\nSkipping line 15971: expected 4 fields, saw 8\nSkipping line 16245: expected 4 fields, saw 5\nSkipping line 16518: expected 4 fields, saw 5\nSkipping line 16550: expected 4 fields, saw 6\nSkipping line 16584
ected 4 fields, saw 5\nSkipping line 10240: expected 4 fields, saw 5\nSkipping line 10321: expected 4 fields, saw 5\nSkipping line 10363: expected 4 fields, saw 8\nSkipping line 10773: expected 4 fields, saw 6\nSkipping line 10862: expected 4 fields, saw 6\nSkipping line 10914: expected 4 fields, saw 5\nSkipping line 11105: expected 4 fields, saw 5\nSkipping line 11172: expected 4 fields, saw 5\nSkipping line 11294: expected 4 fields, saw 5\nSkipping line 11650: expected 4 fields, saw 5\nSkipping line 12550: expected 4 fields, saw 6\nSkipping line 13087: expected 4 fields, saw 5\nSkipping line 13094: expected 4 fields, saw 5\nSkipping line 13362: expected 4 fields, saw 7\nSkipping line 13580: expected 4 fields, saw 5\nSkipping line 13660: expected 4 fields, saw 5\nSkipping line 14195: expected 4 fields, saw 5\nSkipping line 14204: expected 4 fields, saw 5\nSkipping line 14227: expected 4 fields, saw 5\nSkipping line 14304: expected 4 fields, saw 5\nSkipping line 14456: expected 4 fields, saw 6\nSkipping line 14857: expected 4 fields, saw 5\nSkipping line 14978: expected 4 fields, saw 7\nSkipping line 14990: expected 4 fields, saw 7\nSkipping line 15185: expected 4 fields, saw 6\nSkipping line 15347: expected 4 fields, saw 5\nSkipping line 15393: expected 4 fields, saw 5\nSkipping line 15768: expected 4 fields, saw 5\nSkipping line 15971: expected 4 fields, saw 8\nSkipping line 16245: expected 4 fields, saw 5\nSkipping line 16518: expected 4 fields, saw 5\nSkipping line 16550: expected 4 fields, saw 6\nSkipping line 16584: expected 4 fields, saw 5\nSkipping line 16787: expected 4 fields, saw 5\nSkipping line 16932: expected 4 fields, saw 6\nSkipping line 16950: expected 4 fields, saw 5\nSkipping line 16978: expected 4 fields, saw 7\nSkipping line 17350: expected 4 fields, saw 5\nSkipping line 18066: expected 4 fields, saw 5\nSkipping line 18419: expected 4 fields, saw 5\nSkipping line 18429: expected 4 fields, saw 5\nSkipping line 19042: expected 4 fields, saw 5\nSkipping line 19165: expected 4 fields, saw 5\nSkipping line 19225: expected 4 fields, saw 7\nSkipping line 19481: expected 4 fields, saw 7\nSkipping line 19895: expected 4 fields, saw 6\nSkipping line 20305: expected 4 fields, saw 5\nSkipping line 20467: expected 4 fields, saw 5\nSkipping line 20561: expected 4 fields, saw 5\nSkipping line 20601: expected 4 fields, saw 5\nSkipping line 20627: expected 4 fields, saw 5\nSkipping line 20657: expected 4 fields, saw 6\nSkipping line 21097: expected 4 fields, saw 6\nSkipping line 21310: expected 4 fields, saw 5\nSkipping line 21367: expected 4 fields, saw 5\nSkipping line 21375: expected 4 fields, saw 5\nSkipping line 21573: expected 4 fields, saw 5\nSkipping line 21661: expected 4 fields, saw 5\nSkipping line 21762: expected 4 fields, saw 5\nSkipping line 21810: expected 4 fields, saw 5\nSkipping line 22762: expected 4 fields, saw 5\nSkipping line 22825: expec ...
Skipping line 136204: expected 4 fields, saw 5\nSkipping line 136334: expected 4 fields, saw 5\nSkipping line 136345: expected 4 fields, saw 5\nSkipping line 136396: expected 4 fields, saw 5\nSkipping line 136433: expected 4 fields, saw 5\nSkipping line 136443: expected 4 fields, saw 6\nSkipping line 136510: expected 4 fields, saw 9\nSkipping line 136529: expected 4 fields, saw 5\nSkipping line 136530: expected 4 fields, saw 5\nSkipping l ...

# %%
## Utility functions

# get sample post info by #
def get_post_info_by_cluster(number, 
                             data,
                             cluster):
    return(data[cluster.labels_ == number])

# remove HTML stuff
# https://medium.com/@jorlugaqui/how-to-strip-html-tags-from-a-string-in-python-7cb81a2bbf44
def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return(re.sub(clean, '', text))


def polite_post_index(forum_posts):
    '''Pass in a list of fourm posts, get
    back the indexes of short, polite ones.'''
    
    polite_indexes = []
    
    # create  custom stop word list to identify polite forum posts
    stop_word_list = ["no problem", "thanks", "thx", "thank", "great",
                      "nice", "interesting", "awesome", "perfect", 
                      "amazing", "well done", "good job", "good work",
                      "congrats", "+1", "you're welcome", "good one",
                      "you are welcome", "good", "wow", "congrats",
                      "thnx", "my pleasure", "congratulations", "welcome",
                      "brilliant"
                     ]

    # create a KeywordProcess
    keyword_processor = KeywordProcessor()
    keyword_processor.add_keywords_from_list(stop_word_list)

    # test our keyword processor
    for i,post in enumerate(forum_posts):
        post = post.lower().translate(str.maketrans({a:None for a in string.punctuation}))
        
        if len(post) < 100:
            keywords_found = keyword_processor.extract_keywords(post.lower(), span_info=True)
            if keywords_found:
                polite_indexes.append(i)

    return(polite_indexes)

# %%
## Hyperprameters

# number of clusters currently based on the square root of the # of posts
days_of_posts = 4

# do you want to inclue comments on notebooks/scripts?
include_kernel_comments = False

# %% [markdown]
# # Preprocessing posts

# %%
# read in and join forum post info
forums_info_df, forum_posts_df, forum_topics_df = jfpi.read_in_forum_tables()

# data validation
jfpi.check_column_names_forum_posts(forum_posts_df)
jfpi.check_column_names_forum_forums(forums_info_df)
jfpi.check_column_names_forum_topics(forum_topics_df)

# join info from different tables
posts_and_topics_df = jfpi.join_posts_and_topics(forum_posts_df, forum_topics_df)
forum_posts = jfpi.join_posts_with_forum_title(posts_and_topics_df, forums_info_df)

# %%
# remove kernel comments if desired
if include_kernel_comments == False:
    forum_posts = forum_posts[forum_posts["ForumTitle"] != "Kernels"]

# parse dates
forum_posts['Date'] = pd.to_datetime(forum_posts.PostDate, format="%m/%d/%Y %H:%M:%S")

# posts from the last X days
start_time = datetime.now() + timedelta(days=-days_of_posts)  

# forum posts from last week (remember to convert to str)
sample_post_info = forum_posts.loc[forum_posts.Date > start_time]
sample_posts = sample_post_info.Message.astype(str)

# reindex from 0
sample_posts.reset_index(drop=True)
sample_post_info.reset_index(drop=True)

# remove html tags
sample_post_info.Message = sample_post_info.Message\
    .astype(str)\
    .apply(remove_html_tags)
sample_posts = sample_posts.apply(remove_html_tags)

# remove polite posts (make sure you remove HTML tags first)
polite_posts = sample_posts.index[polite_post_index(sample_posts)]
sample_posts = sample_posts.drop(polite_posts)
sample_post_info = sample_post_info.drop(polite_posts)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# add URLs of each post to info

# add column for URLS
sample_post_info["url"] = ""

# info w/ forum titles and URL abbreviations
forum_titles = ["Kaggle Forum","Getting Started", "Product Feedback", 
                "Questions & Answers", "Datasets", "Learn"]
forum_title_abbrvs = {"Kaggle Forum":"general",
                "Getting Started":"getting-started",
                "Product Feedback":"product-feedback",
                "Questions & Answers":"questions-and-answers",
                "Datasets":"data",
                "Learn":"learn-forum"}

# add URLs to posts in main forums
for index, row in sample_post_info.iterrows():
   if row["ForumTitle"] in forum_titles:
        forum_name = row["ForumTitle"]
        forum_abbrv = forum_title_abbrvs[forum_name]
        post_id = row["ForumPostId"]
        topic_id = row["ForumTopicId"]
        
        post_url = (f'<a href="https://www.kaggle.com/{forum_abbrv}/{topic_id}#{post_id}">kaggle.com/{forum_abbrv}/{topic_id}#{post_id}</a>')
                
        sample_post_info.at[index,'url'] = post_url

# %%
# number of posts
num_of_posts = sample_posts.shape[0]

# number of clusters is square root of the # of posts (rounded down)
number_clusters = floor(sqrt(num_of_posts))

# how many posts are we clustering?
print(f"You're looking at {num_of_posts} posts.")
# Out:
# You're looking at 521 posts.

# %%
# check out the first few rows:
sample_post_info.head()
# Out:
#        ForumTopicId             PostDate  \
# 15716         97876  10/10/2019 13:55:37
# 19198        110829  10/10/2019 14:18:11
# 19199        110829  10/10/2019 15:50:53
# 19200        110829  10/10/2019 17:12:06
# 19961        102365  10/09/2019 06:17:50
#
#                                                  Message  ForumPostId  \
# 15716  Great resource to refer. Please provide links ...       645804
# 19198                                               Cool       645827
# 19199                                                yep       645908
# 19200  That is at this moment we notice our dependenc...       645966
# 19961                               likewise @adldotori        644652
#
#        ForumId                                         TopicTitle  \
# 15716      208  Many free books on data science machine learni...
# 19198      208                           TensorFlow 2.0 is here!!
# 19199      208                           TensorFlow 2.0 is here!!
# 19200      208                           TensorFlow 2.0 is here!!
# 19961      208  Andrew NG's Notes! 100 Pages pdf + Visual Note...
#
#             ForumTitle                Date  \
# 15716  Getting Started 2019-10-10 13:55:37
# 19198  Getting Started 2019-10-10 14:18:11
# 19199  Getting Started 2019-10-10 15:50:53
# 19200  Getting Started 2019-10-10 17:12:06
# 19961  Getting Started 2019-10-09 06:17:50
#
#                                                      url
# 15716  <a href="https://www.kaggle.com/getting-starte...
# 19198  <a href="https://www.kaggle.com/getting-starte...
# 19199  <a href="https://www.kaggle.com/getting-starte...
# 19200  <a href="https://www.kaggle.com/getting-starte...
# 19961  <a href="https://www.kaggle.com/getting-starte...

# %% [markdown]
# # Embed & cluster forum posts

# %%
clustering = embed_cluster.get_spectral_clusters(sample_posts=sample_posts)

# %% [markdown]
# # Generate HTML report of clusters

# %%
# count of posts/cluster
cluster_counts = pd.Series(clustering.labels_).value_counts()

# %%
# look at distrobution of cluster labels
size_df = pd.Series(clustering.labels_).value_counts().to_frame()

size_df = size_df.rename(columns={0: "size"})

size_df['characteristic_words'] = 0
size_df['characteristic_words'] = size_df['characteristic_words'].astype(object)

size_df["cluster_label"] = size_df.index

size_df['link_to_posts'] = ""

for index, row in size_df.iterrows():
    current_cluster_label = row["cluster_label"]
    link_to_posts = (f'<a href="#anchor_{current_cluster_label}">Link to posts</a>')
    size_df.at[index,'link_to_posts'] = link_to_posts

for i in size_df.index:
    words = surprising_words.get_surprising_words(cluster_index=i,
                                 post_data=sample_post_info, 
                                 cluster_object=clustering).tolist()
    size_df.at[i,'characteristic_words'] = words

# %%
size_df
# Out:
#     size                               characteristic_words  cluster_label  \
# 0    212  [https, streamlit, //nbviewer.jupyter.org/gith...              0
# 15   181  [uid, 4.756338e+06, 0.000000e+00, 1.000000e+00...             15
# 17    29  [bob, alice, eve, decrypt, cryptosystem, crypt...             17
# 14    22  [ec, eb, b8, b4, b9, a7, 9d, b0, b2, a1, 9e, /...             14
# 16    12               [as, step, here, stopwords, heipful]             16
# 13     9  [lb, public, private, our, stack, 0.9668, 0.94...             13
# 3      9  [very, found, helpful, an, upvote, much, appre...              3
# 1      7                         [you, can, https, helpful]              1
# 11     7                     [to, install, pip, previuosly]             11
# 6      7                                [is, houses, built]              6
# 4      6                                         [to, file]              4
# 10     4     [in, it, 's, see, interesting, silver, bronze]             10
# 2      3                                             [cool]              2
# 21     3                                              [and]             21
# 5      2  [following, up, here, we, just, launched, new,...              5
# 7      2                  [this, should, now, be, resolved]              7
# 8      2  [do, 2.0, offline, //github.com/tensorflow/ten...              8
# 12     2  [to, or, use, can, audio, person, factor, voic...             12
# 9      2                      [cv_results, 'test-rmse-mean]              9
#
#                              link_to_posts
# 0    <a href="#anchor_0">Link to posts</a>
# 15  <a href="#anchor_15">Link to posts</a>
# 17  <a href="#anchor_17">Link to posts</a>
# 14  <a href="#anchor_14">Link to posts</a>
# 16  <a href="#anchor_16">Link to posts</a>
# 13  <a href="#anchor_13">Link to posts</a>
# 3    <a href="#anchor_3">Link to posts</a>
# 1    <a href="#anchor_1">Link to posts</a>
# 11  <a href="#anchor_11">Link to posts</a>
# 6    <a href="#anchor_6">Link to posts</a>
# 4    <a href="#anchor_4">Link to posts</a>
# 10  <a href="#anchor_10">Link to posts</a>
# 2    <a href="#anchor_2">Link to posts</a>
# 21  <a href="#anchor_21">Link to posts</a>
# 5    <a href="#anchor_5">Link to posts</a>
# 7    <a href="#anchor_7">Link to posts</a>
# 8    <a href="#anchor_8">Link to posts</a>
# 12  <a href="#anchor_12">Link to posts</a>
# 9    <a href="#anchor_9">Link to posts</a>

# %%
# write suprising words & contents of cluster in file
with open("cluster_report.html", 'w', encoding="utf-8") as file:
    # file header
    file.writelines('<meta charset="UTF-8">\n')
    
    # add cluster info
    file.write(size_df.drop(["cluster_label"], axis=1).to_html(escape=False))
    file.write("\n")
                    
    for i in range(number_clusters):
        if i in size_df.index:
            file.write(f'\n<h2 id="anchor_{i}">Cluster {i}:</h2>\n')

            cluster_info = get_post_info_by_cluster(i,
                                                    data = sample_post_info,
                                                    cluster = clustering)

            cluster_info = cluster_info.drop(['ForumTopicId','PostDate','ForumPostId',
                                              'ForumId', 'Date'], axis=1)

            # truncate posts
            cluster_info.Message = cluster_info.Message.apply(lambda x: x[:100])

            file.write(cluster_info.to_html(escape=False))

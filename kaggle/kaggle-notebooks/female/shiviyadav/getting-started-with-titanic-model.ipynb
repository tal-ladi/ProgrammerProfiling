# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix, precision_score, recall_score

from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
#importing input data
train = pd.read_csv('../input/titanic/train.csv')

test = pd.read_csv('../input/titanic/test.csv') 

val = pd.read_csv('../input/titanic/gender_submission.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test['Survived'] = val['Survived']

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
#DATA PREP
train.isnull().sum()#finding the missing values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train= train.dropna(axis=0, subset=['Embarked']) #dropped the whole row as the percent of its low, so dropping them

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
train['Age'] = train['Age'].fillna(train['Age'].median()) #taking the median values of age
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
train=train.drop(['Cabin'], axis=1)

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# As we see no missing value is left

# %%
train.drop(['Name','Ticket'], axis = 1, inplace=True) #As Name and ticket are useless

# %%
train
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
#Test data Preprocessing
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Survived         0
# dtype: int64

# %%
test['Fare'] = test['Fare'].fillna(test['Fare'].median()) #as for the test we can not drop any

# %%
test['Age'] =test['Age'].fillna(test['Age'].median())

# %%
test=test.drop(['Cabin'], axis=1) # as for the train we have done it, and we want to do the same for the test

# %%
test.drop(['Name','Ticket'], axis = 1, inplace=True) #As Name and ticket are useless
test
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked  \
# 0            892       3    male  34.5      0      0    7.8292        Q
# 1            893       3  female  47.0      1      0    7.0000        S
# 2            894       2    male  62.0      0      0    9.6875        Q
# 3            895       3    male  27.0      0      0    8.6625        S
# 4            896       3  female  22.0      1      1   12.2875        S
# ..           ...     ...     ...   ...    ...    ...       ...      ...
# 413         1305       3    male  27.0      0      0    8.0500        S
# 414         1306       1  female  39.0      0      0  108.9000        C
# 415         1307       3    male  38.5      0      0    7.2500        S
# 416         1308       3    male  27.0      0      0    8.0500        S
# 417         1309       3    male  27.0      1      1   22.3583        C
#
#      Survived
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Sex          889 non-null    object
#  4   Age          889 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Fare         889 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 69.5+ KB

# %%
#Preparing for dummy variable
train["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
train['Survived'] = train['Survived'].apply(str)

# %%
train['Pclass'] = train['Pclass'].apply(str)

# %%
train
# Out:
#      PassengerId Survived Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0              1        0      3    male  22.0      1      0   7.2500        S
# 1              2        1      1  female  38.0      1      0  71.2833        C
# 2              3        1      3  female  26.0      0      0   7.9250        S
# 3              4        1      1  female  35.0      1      0  53.1000        S
# 4              5        0      3    male  35.0      0      0   8.0500        S
# ..           ...      ...    ...     ...   ...    ...    ...      ...      ...
# 886          887        0      2    male  27.0      0      0  13.0000        S
# 887          888        1      1  female  19.0      0      0  30.0000        S
# 888          889        0      3  female  28.0      1      2  23.4500        S
# 889          890        1      1    male  26.0      0      0  30.0000        C
# 890          891        0      3    male  32.0      0      0   7.7500        Q
#
# [889 rows x 9 columns]

# %%
final_train = pd.get_dummies(train,columns=["Sex"])
final_train.drop('Sex_female', axis = 1, inplace=True)
final_train
# Out:
#      PassengerId Survived Pclass   Age  SibSp  Parch     Fare Embarked  \
# 0              1        0      3  22.0      1      0   7.2500        S
# 1              2        1      1  38.0      1      0  71.2833        C
# 2              3        1      3  26.0      0      0   7.9250        S
# 3              4        1      1  35.0      1      0  53.1000        S
# 4              5        0      3  35.0      0      0   8.0500        S
# ..           ...      ...    ...   ...    ...    ...      ...      ...
# 886          887        0      2  27.0      0      0  13.0000        S
# 887          888        1      1  19.0      0      0  30.0000        S
# 888          889        0      3  28.0      1      2  23.4500        S
# 889          890        1      1  26.0      0      0  30.0000        C
# 890          891        0      3  32.0      0      0   7.7500        Q
#
#      Sex_male
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# ..        ...
# ...

# %%
final_train = pd.get_dummies(final_train,columns=["Pclass"])
final_train.drop('Pclass_1', axis = 1, inplace=True)
final_train
# Out:
#      PassengerId Survived   Age  SibSp  Parch     Fare Embarked  Sex_male  \
# 0              1        0  22.0      1      0   7.2500        S         1
# 1              2        1  38.0      1      0  71.2833        C         0
# 2              3        1  26.0      0      0   7.9250        S         0
# 3              4        1  35.0      1      0  53.1000        S         0
# 4              5        0  35.0      0      0   8.0500        S         1
# ..           ...      ...   ...    ...    ...      ...      ...       ...
# 886          887        0  27.0      0      0  13.0000        S         1
# 887          888        1  19.0      0      0  30.0000        S         0
# 888          889        0  28.0      1      2  23.4500        S         0
# 889          890        1  26.0      0      0  30.0000        C         1
# 890          891        0  32.0      0      0   7.7500        Q         1
#
#      Pclass_2  Pclass_3
# 0           0         1
# 1           0         0
# ...

# %%
final_train = pd.get_dummies(final_train,columns=["Embarked"])
final_train.drop('Embarked_C', axis = 1, inplace=True)
final_train
# Out:
#      PassengerId Survived   Age  SibSp  Parch     Fare  Sex_male  Pclass_2  \
# 0              1        0  22.0      1      0   7.2500         1         0
# 1              2        1  38.0      1      0  71.2833         0         0
# 2              3        1  26.0      0      0   7.9250         0         0
# 3              4        1  35.0      1      0  53.1000         0         0
# 4              5        0  35.0      0      0   8.0500         1         0
# ..           ...      ...   ...    ...    ...      ...       ...       ...
# 886          887        0  27.0      0      0  13.0000         1         1
# 887          888        1  19.0      0      0  30.0000         0         0
# 888          889        0  28.0      1      2  23.4500         0         0
# 889          890        1  26.0      0      0  30.0000         1         0
# 890          891        0  32.0      0      0   7.7500         1         0
#
#      Pclass_3  Embarked_Q  Embarked_S
# ...

# %%
k = final_train.pop("Survived")

# %%
y_train = k
print(y_train)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 889, dtype: object

# %%
final_train.shape
# Out:
# (889, 10)

# %%
test
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked  \
# 0            892       3    male  34.5      0      0    7.8292        Q
# 1            893       3  female  47.0      1      0    7.0000        S
# 2            894       2    male  62.0      0      0    9.6875        Q
# 3            895       3    male  27.0      0      0    8.6625        S
# 4            896       3  female  22.0      1      1   12.2875        S
# ..           ...     ...     ...   ...    ...    ...       ...      ...
# 413         1305       3    male  27.0      0      0    8.0500        S
# 414         1306       1  female  39.0      0      0  108.9000        C
# 415         1307       3    male  38.5      0      0    7.2500        S
# 416         1308       3    male  27.0      0      0    8.0500        S
# 417         1309       3    male  27.0      1      1   22.3583        C
#
#      Survived
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ...

# %%
test['Survived'] = test['Survived'].apply(str)

# %%
test['Pclass'] = test['Pclass'].apply(str)

# %%
final_test = pd.get_dummies(test,columns=["Sex"])
final_test.drop('Sex_female', axis = 1, inplace=True)
final_test
# Out:
#      PassengerId Pclass   Age  SibSp  Parch      Fare Embarked Survived  \
# 0            892      3  34.5      0      0    7.8292        Q        0
# 1            893      3  47.0      1      0    7.0000        S        1
# 2            894      2  62.0      0      0    9.6875        Q        0
# 3            895      3  27.0      0      0    8.6625        S        0
# 4            896      3  22.0      1      1   12.2875        S        1
# ..           ...    ...   ...    ...    ...       ...      ...      ...
# 413         1305      3  27.0      0      0    8.0500        S        0
# 414         1306      1  39.0      0      0  108.9000        C        1
# 415         1307      3  38.5      0      0    7.2500        S        0
# 416         1308      3  27.0      0      0    8.0500        S        0
# 417         1309      3  27.0      1      1   22.3583        C        0
#
#      Sex_male
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0
# ...

# %%
final_test = pd.get_dummies(final_test,columns=["Pclass"])
final_test.drop('Pclass_1', axis = 1, inplace=True)
final_test
# Out:
#      PassengerId   Age  SibSp  Parch      Fare Embarked Survived  Sex_male  \
# 0            892  34.5      0      0    7.8292        Q        0         1
# 1            893  47.0      1      0    7.0000        S        1         0
# 2            894  62.0      0      0    9.6875        Q        0         1
# 3            895  27.0      0      0    8.6625        S        0         1
# 4            896  22.0      1      1   12.2875        S        1         0
# ..           ...   ...    ...    ...       ...      ...      ...       ...
# 413         1305  27.0      0      0    8.0500        S        0         1
# 414         1306  39.0      0      0  108.9000        C        1         0
# 415         1307  38.5      0      0    7.2500        S        0         1
# 416         1308  27.0      0      0    8.0500        S        0         1
# 417         1309  27.0      1      1   22.3583        C        0         1
#
#      Pclass_2  Pclass_3
# 0           0         1
# ...

# %%
final_test = pd.get_dummies(final_test,columns=["Embarked"])
final_test.drop('Embarked_C', axis = 1, inplace=True)
final_test
# Out:
#      PassengerId   Age  SibSp  Parch      Fare Survived  Sex_male  Pclass_2  \
# 0            892  34.5      0      0    7.8292        0         1         0
# 1            893  47.0      1      0    7.0000        1         0         0
# 2            894  62.0      0      0    9.6875        0         1         1
# 3            895  27.0      0      0    8.6625        0         1         0
# 4            896  22.0      1      1   12.2875        1         0         0
# ..           ...   ...    ...    ...       ...      ...       ...       ...
# 413         1305  27.0      0      0    8.0500        0         1         0
# 414         1306  39.0      0      0  108.9000        1         0         0
# 415         1307  38.5      0      0    7.2500        0         1         0
# 416         1308  27.0      0      0    8.0500        0         1         0
# 417         1309  27.0      1      1   22.3583        0         1         0
#
#      Pclass_3  Embarked_Q  Embarked_S
# ...

# %%
y_test = final_test.pop("Survived")

# %%
print(y_test)
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: object

# %%
final_train
# Out:
#      PassengerId   Age  SibSp  Parch     Fare  Sex_male  Pclass_2  Pclass_3  \
# 0              1  22.0      1      0   7.2500         1         0         1
# 1              2  38.0      1      0  71.2833         0         0         0
# 2              3  26.0      0      0   7.9250         0         0         1
# 3              4  35.0      1      0  53.1000         0         0         0
# 4              5  35.0      0      0   8.0500         1         0         1
# ..           ...   ...    ...    ...      ...       ...       ...       ...
# 886          887  27.0      0      0  13.0000         1         1         0
# 887          888  19.0      0      0  30.0000         0         0         0
# 888          889  28.0      1      2  23.4500         0         0         1
# 889          890  26.0      0      0  30.0000         1         0         0
# 890          891  32.0      0      0   7.7500         1         0         1
#
#      Embarked_Q  Embarked_S
# ...

# %%
final_test
# Out:
#      PassengerId   Age  SibSp  Parch      Fare  Sex_male  Pclass_2  Pclass_3  \
# 0            892  34.5      0      0    7.8292         1         0         1
# 1            893  47.0      1      0    7.0000         0         0         1
# 2            894  62.0      0      0    9.6875         1         1         0
# 3            895  27.0      0      0    8.6625         1         0         1
# 4            896  22.0      1      1   12.2875         0         0         1
# ..           ...   ...    ...    ...       ...       ...       ...       ...
# 413         1305  27.0      0      0    8.0500         1         0         1
# 414         1306  39.0      0      0  108.9000         0         0         0
# 415         1307  38.5      0      0    7.2500         1         0         1
# 416         1308  27.0      0      0    8.0500         1         0         1
# 417         1309  27.0      1      1   22.3583         1         0         1
#
#      Embarked_Q  Embarked_S
# ...

# %%
scaler= StandardScaler()

scaler.fit(final_train)
# Out:
# StandardScaler()

# %%
Logistic_model = LogisticRegression(max_iter=4000)

Logistic_model.fit(final_train,y_train)
# Out:
# LogisticRegression(max_iter=4000)

# %%
y_pred =  Logistic_model.predict(final_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9497607655502392

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=2, random_state=0)
rf.fit(final_train, y_train)
RF_pred = rf.predict(final_test)

# %%
accuracy_score(y_test,RF_pred)
# Out:
# 0.7703349282296651

# %%
submission = pd.DataFrame()
submission['PassengerId'] = test['PassengerId']
submission['Survived'] = y_pred
submission.to_csv('GettingStartedWithtitanicmodel.csv',index=False)
print("Submission was successfully saved!")
# Out:
# Submission was successfully saved!

# %% [markdown]
# # Melanoma Prediction Using Tabular Data
# In this solely based on feature engineering and using Machine learning Model to detect Skin Cancer. No Deep Learning Model has been used here.
#
# **Special Thank to [oliver](https://www.kaggle.com/ogrellier) for sharing some key features in the data**

# %%
import numpy as np 
import pandas as pd 
import os
from glob import glob
from tqdm import tqdm
import seaborn as sns
sns.set(style = 'dark')
import matplotlib.pyplot as plt

# %%
train_files_dir = glob('/kaggle/input/siim-isic-melanoma-classification/jpeg/train/*')
test_files_dir = glob('/kaggle/input/siim-isic-melanoma-classification/jpeg/test/*')

# %%
train_df = pd.read_csv('/kaggle/input/siim-isic-melanoma-classification/train.csv')
test_df = pd.read_csv('/kaggle/input/siim-isic-melanoma-classification/test.csv')

# %%
train_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0

# %%
test_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity

# %% [markdown]
# # Label Encoding

# %% [markdown]
# ## Sex

# %%
train_df['sex'].fillna('unkown',inplace = True) # missing value

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
train_df['sex_enc'] = enc.fit_transform(train_df.sex.astype('str'))
test_df['sex_enc'] = enc.transform(test_df.sex.astype('str'))

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'sex', hue = 'target', data = train_df)

# %%
train_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  sex_enc
# 0   unknown           benign       0        1
# 1   unknown           benign       0        0
# 2     nevus           benign       0        0
# 3   unknown           benign       0        0
# 4   unknown           benign       0        0

# %%
test_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_0052060  IP_3579794    male        70.0                           NaN
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity
#
#    sex_enc
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ## Anatom_site_general_challenge

# %%
test_df.anatom_site_general_challenge = test_df.anatom_site_general_challenge.fillna('unknown')
train_df.anatom_site_general_challenge = train_df.anatom_site_general_challenge.fillna('unknown')

# %%
train_df['anatom_enc']= enc.fit_transform(train_df.anatom_site_general_challenge.astype('str'))
test_df['anatom_enc']= enc.transform(test_df.anatom_site_general_challenge.astype('str'))

# %%
train_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  sex_enc  anatom_enc
# 0   unknown           benign       0        1           0
# 1   unknown           benign       0        0           6
# 2     nevus           benign       0        0           1
# 3   unknown           benign       0        0           0
# 4   unknown           benign       0        0           6

# %%
test_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_0052060  IP_3579794    male        70.0                       unknown
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity
#
#    sex_enc  anatom_enc
# 0        1           5
# 1        1           1
# 2        0           4
# 3        0           4
# 4        0           1

# %% [markdown]
# # Age

# %%
train_df['age_approx'] = train_df['age_approx'].fillna(train_df['age_approx'].mode().values[0])
test_df['age_approx']  = test_df['age_approx'].fillna(test_df['age_approx'].mode().values[0]) # Test data doesn't have any NaN in age_approx

# %%
train_df['age_enc']= enc.fit_transform(train_df['age_approx'].astype('str'))
test_df['age_enc']= enc.transform(test_df['age_approx'].astype('str'))

# %%
plt.figure(figsize = (20,6))
sns.countplot(x = 'age_approx', hue = 'target', data = train_df)

# %%
train_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  sex_enc  anatom_enc  age_enc
# 0   unknown           benign       0        1           0        8
# 1   unknown           benign       0        0           6        8
# 2     nevus           benign       0        0           1        9
# 3   unknown           benign       0        0           0        8
# 4   unknown           benign       0        0           6       10

# %%
test_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_0052060  IP_3579794    male        70.0                       unknown
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity
#
#    sex_enc  anatom_enc  age_enc
# 0        1           5       13
# 1        1           1        7
# 2        0           4       10
# 3        0           4        9
# 4        0           1        8

# %% [markdown]
# # Images Per Patient

# %%
train_df['n_images'] = train_df.patient_id.map(train_df.groupby(['patient_id']).image_name.count())
test_df['n_images'] = test_df.patient_id.map(test_df.groupby(['patient_id']).image_name.count())

# %% [markdown]
# # Categorize Number of Images Per Patient

# %%
from sklearn.preprocessing import KBinsDiscretizer
categorize = KBinsDiscretizer(n_bins = 10, encode = 'ordinal', strategy = 'uniform')
train_df['n_images_enc'] = categorize.fit_transform(train_df['n_images'].values.reshape(-1, 1)).astype(int).squeeze()
test_df['n_images_enc'] = categorize.transform(test_df['n_images'].values.reshape(-1, 1)).astype(int).squeeze()

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'n_images_enc', hue = 'target', data = train_df)

# %%
train_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  sex_enc  anatom_enc  age_enc  n_images  \
# 0   unknown           benign       0        1           0        8       115
# 1   unknown           benign       0        0           6        8        24
# 2     nevus           benign       0        0           1        9         5
# 3   unknown           benign       0        0           0        8        22
# 4   unknown           benign       0        0           6       10        20
#
#    n_images_enc
# 0             9
# 1             1
# 2             0
# 3             1
# 4             1

# %%
test_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_0052060  IP_3579794    male        70.0                       unknown
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity
#
#    sex_enc  anatom_enc  age_enc  n_images  n_images_enc
# 0        1           5       13       240             9
# 1        1           1        7        46             3
# 2        0           4       10        28             2
# 3        0           4        9        38             3
# 4        0           1        8        29             2

# %% [markdown]
# # Image Size

# %%
train_images = train_df['image_name'].values
train_sizes = np.zeros(train_images.shape[0])
for i, img_path in enumerate(tqdm(train_images)):
    train_sizes[i] = os.path.getsize(os.path.join('/kaggle/input/siim-isic-melanoma-classification/jpeg/train/', f'{img_path}.jpg'))
    
train_df['image_size'] = train_sizes


test_images = test_df['image_name'].values
test_sizes = np.zeros(test_images.shape[0])
for i, img_path in enumerate(tqdm(test_images)):
    test_sizes[i] = os.path.getsize(os.path.join('/kaggle/input/siim-isic-melanoma-classification/jpeg/test/', f'{img_path}.jpg'))
    
test_df['image_size'] = test_sizes
# Out:
# 100%|██████████| 33126/33126 [00:11<00:00, 2904.46it/s]
# 100%|██████████| 10982/10982 [00:03<00:00, 3306.15it/s]

# %% [markdown]
# # Scaling Image Size

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scale = MinMaxScaler()
train_df['image_size_scaled'] = scale.fit_transform(train_df['image_size'].values.reshape(-1, 1))
test_df['image_size_scaled'] = scale.transform(test_df['image_size'].values.reshape(-1, 1))

# %% [markdown]
# # Categorize Image Size

# %%
from sklearn.preprocessing import KBinsDiscretizer
categorize = KBinsDiscretizer(n_bins = 10, encode = 'ordinal', strategy = 'uniform')
train_df['image_size_enc'] = categorize.fit_transform(train_df.image_size_scaled.values.reshape(-1, 1)).astype(int).squeeze()
test_df['image_size_enc'] = categorize.transform(test_df.image_size_scaled.values.reshape(-1, 1)).astype(int).squeeze()

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'image_size_enc', hue = 'target', data = train_df)

# %%
train_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  sex_enc  anatom_enc  age_enc  n_images  \
# 0   unknown           benign       0        1           0        8       115
# 1   unknown           benign       0        0           6        8        24
# 2     nevus           benign       0        0           1        9         5
# 3   unknown           benign       0        0           0        8        22
# 4   unknown           benign       0        0           6       10        20
#
#    n_images_enc  image_size  image_size_scaled  image_size_enc
# 0             9   1840868.0           0.525522               5
# 1             1   1911615.0           0.545893               5
# 2             0    138515.0           0.035336               0
# 3             1    215755.0           0.057577               0
# 4             1   1649943.0           0.470546               4

# %%
test_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_0052060  IP_3579794    male        70.0                       unknown
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity
#
#    sex_enc  anatom_enc  age_enc  n_images  n_images_enc  image_size  \
# 0        1           5       13       240             9   2097525.0
# 1        1           1        7        46             3   1167934.0
# 2        0           4       10        28             2   1148771.0
# 3        0           4        9        38             3   1190077.0
# 4        0           1        8        29             2    154448.0
#
#    image_size_scaled  image_size_enc
# 0           0.599425               5
# 1           0.331753               3
# 2           0.326235               3
# 3           0.338129               3
# 4           0.039924               0

# %% [markdown]
# # Mean Color(Used previously saved data)

# %%
train_mean_color = pd.read_csv('/kaggle/input/mean-color-isic2020/train_color.csv')
test_mean_color = pd.read_csv('/kaggle/input/mean-color-isic2020/test_color.csv')

# %%
train_df['mean_color'] = train_mean_color.values
test_df['mean_color'] = test_mean_color.values

# %% [markdown]
# # Categorize Mean Color

# %%
from sklearn.preprocessing import KBinsDiscretizer
categorize = KBinsDiscretizer(n_bins = 10, encode = 'ordinal', strategy = 'uniform')
train_df['mean_color_enc'] = categorize.fit_transform(train_df['mean_color'].values.reshape(-1, 1)).astype(int).squeeze()
test_df['mean_color_enc'] = categorize.transform(test_df['mean_color'].values.reshape(-1, 1)).astype(int).squeeze()

# %%
plt.figure(figsize = (12,6))
sns.countplot(x = 'mean_color_enc', hue = 'target', data = train_df)

# %% [markdown]
# # Min-Max age of Patient

# %%
train_df['age_id_min']  = train_df['patient_id'].map(train_df.groupby(['patient_id']).age_approx.min())
train_df['age_id_max']  = train_df['patient_id'].map(train_df.groupby(['patient_id']).age_approx.max())

test_df['age_id_min']  = test_df['patient_id'].map(test_df.groupby(['patient_id']).age_approx.min())
test_df['age_id_max']  = test_df['patient_id'].map(test_df.groupby(['patient_id']).age_approx.max())

# %% [markdown]
# # Mean Encoding

# %% [markdown]
# ## Plotting Barplot with number

# %%
def show_bar_plot(df, figsize = (12,6)):
 
    import seaborn as sns
    import matplotlib.pyplot as plt
    import numpy as np
    
    def show_values_on_bars(axs, h_v="v", space=0.4, v_space = 0.02, figsize = (12,6)):
        def _show_on_single_plot(ax):
            if h_v == "v":
                for p in ax.patches:
                    _x = p.get_x() + p.get_width() / 2
                    _y = p.get_y() + p.get_height()+ v_space
                    value = float(p.get_height())
                    ax.text(_x, _y, f'{value:.1f}', ha="center") 
            elif h_v == "h":
                for p in ax.patches:
                    _x = p.get_x() + p.get_width() + float(space)
                    _y = p.get_y() + p.get_height()+ v_space
                    value = int(p.get_width())
                    ax.text(_x, _y, value, ha="left")

        if isinstance(axs, np.ndarray):
            for idx, ax in np.ndenumerate(axs):
                _show_on_single_plot(ax)
        else:
            _show_on_single_plot(axs)
            

#     fig = plt.gcf()
#     fig.set_size_inches(12, 8)
    plt.figure(figsize = figsize)
    sns.set()
    plt.title('Probability')

    prob = df*100
    pal = sns.color_palette(palette='Blues_r', n_colors=len(prob))
    rank = prob.values.argsort().argsort() 
    #g=sns.barplot(x='day',y='tip',data=groupedvalues, palette=np.array(pal[::-1])[rank])
    br = sns.barplot(prob.index, prob.values, palette=np.array(pal[::-1])[rank])
    show_values_on_bars(br, "v", .50)
    plt.show()

# %%
def kdeplot( df,col_name, figsize = (12,6)):

    plt.figure(figsize = figsize)
    sns.kdeplot(df[col_name][df.target==0], shade = True, color = 'b', label = '0')
    sns.kdeplot(df[col_name][df.target==1], shade = True, color = 'r', label = '1')
    plt.show()

# %% [markdown]
# ## Age

# %%
train_df['age_approx_mean_enc'] = train_df['age_approx'].map(train_df.groupby(['age_approx'])['target'].mean())
test_df['age_approx_mean_enc'] = test_df['age_approx'].map(train_df.groupby(['age_approx'])['target'].mean())

# %% [markdown]
# ## Probability of melanoma with respect to Age

# %%
show_bar_plot(train_df.groupby(['age_approx'])['target'].mean(), (20,10))

# %% [markdown]
# ## Before Mean Encoding

# %%
col_name = 'age_approx'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## After Mean Encoding

# %%
col_name = 'age_approx_mean_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %%
train_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  sex_enc  anatom_enc  ...  n_images  \
# 0   unknown           benign       0        1           0  ...       115
# 1   unknown           benign       0        0           6  ...        24
# 2     nevus           benign       0        0           1  ...         5
# 3   unknown           benign       0        0           0  ...        22
# 4   unknown           benign       0        0           6  ...        20
#
#    n_images_enc  image_size  image_size_scaled  image_size_enc  mean_color  \
# 0             9   1840868.0           0.525522               5  169.862452
# 1             1   1911615.0           0.545893               5  171.084778
# 2             0    138515.0           0.035336               0  158.691048
# 3             1    215755.0           0.057577               0   80.342856
# 4             1   1649943.0           0.470546               4  183.955453
#
#    mean_color_enc  age_id_min  age_id_max  age_approx_mean_enc
# 0               6        45.0        45.0             0.011910
# 1               6        45.0        45.0             0.011910
# 2               6        50.0        55.0             0.012412
# 3               2        40.0        45.0             0.011910
# 4               7        55.0        55.0             0.016736
#
# [5 rows x 21 columns]

# %%
test_df.head()
# Out:
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_0052060  IP_3579794    male        70.0                       unknown
# 1  ISIC_0052349  IP_7782715    male        40.0               lower extremity
# 2  ISIC_0058510  IP_7960270  female        55.0                         torso
# 3  ISIC_0073313  IP_6375035  female        50.0                         torso
# 4  ISIC_0073502  IP_0589375  female        45.0               lower extremity
#
#    sex_enc  anatom_enc  age_enc  n_images  n_images_enc  image_size  \
# 0        1           5       13       240             9   2097525.0
# 1        1           1        7        46             3   1167934.0
# 2        0           4       10        28             2   1148771.0
# 3        0           4        9        38             3   1190077.0
# 4        0           1        8        29             2    154448.0
#
#    image_size_scaled  image_size_enc  mean_color  mean_color_enc  age_id_min  \
# 0           0.599425               5  189.424321               7        70.0
# 1           0.331753               3  206.967936               8        40.0
# 2           0.326235               3  218.997725               8        55.0
# 3           0.338129               3  216.520168               8        50.0
# 4           0.039924               0  146.340647               5        40.0
#
#    age_id_max  age_approx_mean_enc
# 0        70.0             0.029472
# 1        40.0             0.006711
# 2        55.0             0.016736
# 3        50.0             0.012412
# 4        65.0             0.011910

# %% [markdown]
# ## Sex

# %%
train_df['sex_mean_enc'] = train_df.sex_enc.map(train_df.groupby(['sex_enc'])['target'].mean())
test_df['sex_mean_enc'] = test_df.sex_enc.map(train_df.groupby(['sex_enc'])['target'].mean())

# %% [markdown]
# ## Probability of melanoma with respect to Sex

# %%
show_bar_plot(train_df.groupby(['sex'])['target'].mean())

# %% [markdown]
# ## Before Mean Encoding

# %%
col_name = 'sex_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## After Mean Encoding

# %%
col_name = 'sex_mean_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## n_images

# %%
train_df['n_images_mean_enc'] = train_df['n_images_enc'].map(train_df.groupby(['n_images_enc'])['target'].mean())
test_df['n_images_mean_enc'] = test_df['n_images_enc'].map(train_df.groupby(['n_images_enc'])['target'].mean())

# %% [markdown]
# ## Probability of melanoma with respect to Number of Image per Patient

# %%
show_bar_plot(train_df.groupby(['n_images_enc'])['target'].mean())

# %%
col_name = 'n_images'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## After Encoding

# %%
col_name = 'n_images_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## After Mean Encoding

# %%
col_name = 'n_images_mean_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## Image Size

# %%
train_df['image_size_mean_enc'] = train_df['image_size_enc'].map(train_df.groupby(['image_size_enc'])['target'].mean())
test_df['image_size_mean_enc'] = test_df['image_size_enc'].map(train_df.groupby(['image_size_enc'])['target'].mean())

# %% [markdown]
# ## Probability of melanoma with respect to Image Size

# %%
show_bar_plot(train_df.groupby(['image_size_enc'])['target'].mean())

# %% [markdown]
# ## After Encoding

# %%
col_name = 'image_size'
kdeplot(train_df,col_name, figsize = (16,8))

# %%
col_name = 'image_size_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %%
col_name = 'image_size_mean_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## Anatom General Challenge

# %%
train_df['anatom_mean_enc'] = train_df['anatom_enc'].map(train_df.groupby(['anatom_enc'])['target'].mean())
test_df['anatom_mean_enc'] = test_df['anatom_enc'].map(train_df.groupby(['anatom_enc'])['target'].mean())

# %% [markdown]
# ## Probability of melanoma with respect to Anatom General Challege

# %%
show_bar_plot(train_df.groupby(['anatom_enc'])['target'].mean())

# %%
col_name = 'anatom_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %%
col_name = 'anatom_mean_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# # Mean Color

# %%
train_df['mean_color_mean_enc'] = train_df['mean_color_enc'].map(train_df.groupby(['mean_color_enc'])['target'].mean())
test_df['mean_color_mean_enc'] = test_df['mean_color_enc'].map(train_df.groupby(['mean_color_enc'])['target'].mean())

# %% [markdown]
# ## Probability of melanoma with respect to Mean Color

# %%
show_bar_plot(train_df.groupby(['mean_color_enc'])['target'].mean())

# %% [markdown]
# ## Before encoding

# %%
col_name = 'mean_color'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## After encoding

# %%
col_name = 'mean_color_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# ## After Mean Encoding

# %%
col_name = 'mean_color_mean_enc'
kdeplot(train_df,col_name, figsize = (16,8))

# %% [markdown]
# # Mean Encoding is Angel or Devil?
#
# As you can see mean encoding has some interesting effect on data. But there is a good chnace we will end up overfitting because we're depending on target of train data. What if train and test data have different distribution???

# %% [markdown]
# # Correlation Matrix
# We can extract some interesting features from Corr Matrix. I leave that to the reader to find out some tricky features from Corr Matrix. Let me know you find one.
#
# **Spoiler Alert:** You can easily get **.80** just playing with these features

# %%
corr = train_df.corr(method = 'pearson')
corr = corr.abs()
corr.style.background_gradient(cmap='inferno')
# Out:
# <style  type="text/css" >
#     #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col0 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col1 {
#             background-color:  #10092d;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col2 {
#             background-color:  #190c3e;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col3 {
#             background-color:  #040314;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col4 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col5 {
#             background-color:  #210c4a;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col6 {
#             background-color:  #230c4c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col7 {
#             background-color:  #1c0c43;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col8 {
#             background-color:  #1c0c43;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col9 {
#             background-color:  #190c3e;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col10 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col11 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col12 {
#             background-color:  #f1f179;
#             color:  #000000;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col13 {
#             background-color:  #f2f27d;
#             color:  #000000;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col14 {
#             background-color:  #f2741c;
#             color:  #000000;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col15 {
#             background-color:  #190c3e;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col16 {
#             background-color:  #2d0b59;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col17 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col18 {
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row0_col19 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col0 {
#             background-color:  #0b0724;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col1 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col2 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col3 {
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col4 {
#             background-color:  #0b0724;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col5 {
#             background-color:  #0a0722;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col6 {
#             background-color:  #0a0722;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col7 {
#             background-color:  #0d0829;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col8 {
#             background-color:  #0d0829;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col9 {
#             background-color:  #0e092b;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col10 {
#             background-color:  #07051b;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col11 {
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col12 {
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col13 {
#             background-color:  #0d0829;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col14 {
#             background-color:  #150b37;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col15 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col16 {
#             background-color:  #180c3c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col17 {
#             background-color:  #210c4a;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col18 {
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row1_col19 {
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col0 {
#             background-color:  #110a30;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col1 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col2 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col3 {
#             background-color:  #010106;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col4 {
#             background-color:  #110a30;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col5 {
#             background-color:  #010005;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col6 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col7 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col8 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col9 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col10 {
#             background-color:  #030210;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col11 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col12 {
#             background-color:  #0b0724;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col13 {
#             background-color:  #160b39;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col14 {
#             background-color:  #040312;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col15 {
#             background-color:  #f1ec6d;
#             color:  #000000;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col16 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col17 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col18 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01a2fa84_c080_11ea_9185_0242ac130202row2_col19 {
#             background-color:  #040312;

# %%
# plt.figure(figsize = (20,20))
# sns.heatmap(corr, annot = True)

# %%
corr = test_df.corr(method = 'pearson')
corr = corr.abs()
corr.style.background_gradient(cmap='inferno')
# Out:
# <style  type="text/css" >
#     #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col0 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col1 {
#             background-color:  #190c3e;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col2 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col3 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col4 {
#             background-color:  #310a5c;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col5 {
#             background-color:  #160b39;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col6 {
#             background-color:  #490b6a;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col7 {
#             background-color:  #490b6a;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col8 {
#             background-color:  #420a68;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col9 {
#             background-color:  #07051b;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col10 {
#             background-color:  #08051d;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col11 {
#             background-color:  #f1f179;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col12 {
#             background-color:  #f2f482;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col13 {
#             background-color:  #f98c0a;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col14 {
#             background-color:  #190c3e;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col15 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col16 {
#             background-color:  #040312;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col17 {
#             background-color:  #040314;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row0_col18 {
#             background-color:  #050417;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col0 {
#             background-color:  #180c3c;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col1 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col2 {
#             background-color:  #030210;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col3 {
#             background-color:  #180c3c;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col4 {
#             background-color:  #180c3c;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col5 {
#             background-color:  #0d0829;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col6 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col7 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col8 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col9 {
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col10 {
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col11 {
#             background-color:  #0e092b;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col12 {
#             background-color:  #1e0c45;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col13 {
#             background-color:  #160b39;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col14 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col15 {
#             background-color:  #110a30;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col16 {
#             background-color:  #040312;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col17 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row1_col18 {
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col0 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col1 {
#             background-color:  #040314;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col2 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col3 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col4 {
#             background-color:  #0e092b;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col5 {
#             background-color:  #050417;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col6 {
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col7 {
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col8 {
#             background-color:  #02020c;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col9 {
#             background-color:  #07051b;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col10 {
#             background-color:  #050417;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col11 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col12 {
#             background-color:  #040314;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col13 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col14 {
#             background-color:  #040314;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col15 {
#             background-color:  #010108;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col16 {
#             background-color:  #010106;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col17 {
#             background-color:  #260c51;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row2_col18 {
#             background-color:  #02020e;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row3_col0 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row3_col1 {
#             background-color:  #190c3e;
#             color:  #f1f1f1;
#         }    #T_01c8d81c_c080_11ea_9185_0242ac130202row3_col2 {
#             background-color:  #02020c;

# %% [markdown]
# # Selecting Features

# %%
test_df.columns
# Out:
# Index(['image_name', 'patient_id', 'sex', 'age_approx',
#        'anatom_site_general_challenge', 'sex_enc', 'anatom_enc', 'age_enc',
#        'n_images', 'n_images_enc', 'image_size', 'image_size_scaled',
#        'image_size_enc', 'mean_color', 'mean_color_enc', 'age_id_min',
#        'age_id_max', 'age_approx_mean_enc', 'sex_mean_enc',
#        'n_images_mean_enc', 'image_size_mean_enc', 'anatom_mean_enc',
#        'mean_color_mean_enc'],
#       dtype='object')

# %% [markdown]
# # I get rid of some features for best LB score

# %%
features = [
            'age_approx',
#             'age_enc',
#             'age_approx_mean_enc',
            'age_id_min',
            'age_id_max',
            'sex_enc',
#             'sex_mean_enc',
            'anatom_enc',
#             'anatom_mean_enc',
            'n_images',
#             'n_images_mean_enc',
#             'n_images_enc',
            'image_size_scaled',
#             'image_size_enc',
#             'image_size_mean_enc',
            'mean_color',
#             'mean_color_enc', 
#             'mean_color_mean_enc'
           ]

# %%
trlm_df = pd.read_csv('../input/landscape/train40Features.csv')
telm_df = pd.read_csv('../input/landscape/test40Features.csv')

X = pd.concat([train_df[features], trlm_df.iloc[:,3:]], axis=1)
y = train_df['target']

X_test = pd.concat([test_df[features],telm_df.iloc[:,3:]], axis=1)

# %%
# Load libraries
from pandas import read_csv
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR, SVC
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from xgboost import XGBClassifier, XGBRegressor
from sklearn.linear_model import SGDRegressor, BayesianRidge
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# # Training Xgboost
# ## Parameters were tunned using Gridsearch

# %%
model = XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=0.8, gamma=1, gpu_id=-1,
             importance_type='gain', interaction_constraints=None,
             learning_rate=0.002, max_delta_step=0, max_depth=10,
             min_child_weight=1, missing=None, monotone_constraints=None,
             n_estimators=700, n_jobs=-1, nthread=-1, num_parallel_tree=1,
             objective='binary:logistic', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, silent=True, subsample=0.8,
             tree_method=None, validate_parameters=False, verbosity=None)

kfold = StratifiedKFold(n_splits=5, random_state=1001, shuffle=True)
cv_results = cross_val_score(model, X, y, cv=kfold, scoring='roc_auc', verbose = 3)
cv_results.mean()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  ................................................................
# [CV] .................................... , score=0.855, total= 1.7min
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.7min remaining:    0.0s
# [CV] .................................... , score=0.836, total= 1.7min
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  3.3min remaining:    0.0s
# [CV] .................................... , score=0.863, total= 1.7min
# [CV]  ................................................................
# [CV] .................................... , score=0.881, total= 1.7min
# [CV]  ................................................................
# [CV] .................................... , score=0.855, total= 1.7min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  8.4min finished
# 0.8579544716201335

# %%
xgb = XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=0.8, gamma=1, gpu_id=-1,
             importance_type='gain', interaction_constraints=None,
             learning_rate=0.002, max_delta_step=0, max_depth=10,
             min_child_weight=1, missing=None, monotone_constraints=None,
             n_estimators=700, n_jobs=-1, nthread=-1, num_parallel_tree=1,
             objective='binary:logistic', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, silent=True, subsample=0.8,
             tree_method=None, validate_parameters=False, verbosity=None)

xgb.fit(X,y)
pred_xgb = xgb.predict(X_test)

# %% [markdown]
# # Plot: Feature Importance

# %%
feature_important = xgb.get_booster().get_score(importance_type='weight')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
plt.figure(figsize= (12,10))
sns.barplot(x = data.score , y = data.index, orient = 'h', palette = 'Blues_r')

# %% [markdown]
# # Dimension Reduction (PCA)

# %%
from sklearn.decomposition import PCA

n_components = 2
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)

pca_df = pd.DataFrame({'x_pca_0':X_pca[:,0],
             'x_pca_1':X_pca[:,1],
             'y':y})

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(
    x="x_pca_0", y="x_pca_1",
    hue="y",
    data=pca_df,
    legend="full",
    alpha=0.9
)

# %% [markdown]
# # Prediction

# %%
sub = pd.DataFrame({'image_name':test_df.image_name.values,
                    'target':pred_xgb})
sub.to_csv('submission.csv',index = False)

# %% [markdown]
# Though it is difficult to predict location of melanoma class from  plot but we look carefully we'll be able to notice that there are some regions where there is no melanoma class at all.

# %% [markdown]
# There might be two possible reasons behind LB score differing from the CV score .
# 1. Only 30% test data is used in Public LB
# 2. Our Model has been ovefitted
#
# Please let me know if I can improve my results.
# ## Thank You Very Much

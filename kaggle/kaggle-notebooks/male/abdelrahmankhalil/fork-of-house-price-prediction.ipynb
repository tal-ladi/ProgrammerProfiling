# %%
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # **** read data

# %%
## read data
train_data = pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
test_data = pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')
sample_submission = pd.read_csv('../input/house-prices-advanced-regression-techniques/sample_submission.csv')

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
y = train_data['SalePrice']
y.shape
# Out:
# (1460,)

# %%
describe_data = train_data.describe()
describe_data
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
##show data
train_data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %%
##histogram
##draw the oytput "y" 

sns.distplot(y);

# %%
train_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
test_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %% [markdown]
# # 1.**Draw the Relationship between the numerical variable input and autput

# %%
##Draw the relationship between "LotArea" and the output
z = train_data['LotArea']
print(z.shape)
plt.scatter(z,y)
# Out:
# (1460,)

# %%
##Draw the relationship between "TotalBsmtSF" and the output
p = train_data['TotalBsmtSF']
print(z.shape)
plt.scatter(p,y)
# Out:
# (1460,)

# %%
##Draw the relationship between "1stFlrSF" and the output
c = train_data['1stFlrSF']
print(z.shape)
plt.scatter(c,y)
# Out:
# (1460,)

# %%
##Draw the relationship between "GarageArea" and the output
u = train_data['GarageArea']
print(z.shape)
plt.scatter(u,y)
# Out:
# (1460,)

# %%
categorical_features = train_data.select_dtypes([object]).columns
numerical_features = train_data.select_dtypes([int, float]).columns

# %%
fig = plt.figure(figsize=(25,40)) #figure size
o = 13  # number of rows
q = 3  # number of columns
w = 1  # initialize plot counter

for feat in numerical_features:
    plt.subplot(o, q, w)
    sns.kdeplot(x=train_data[feat])
    w+=1
    
plt.tight_layout()
plt.show()

# %%
#histogram and normal probability plot
sns.distplot(y, fit=norm);
fig = plt.figure()
res = stats.probplot(y, plot=plt)

# %%
y  = np.log(y)

# %%
##transformed histogram and normal probability plot
sns.distplot(y, fit=norm);
fig = plt.figure()
res = stats.probplot(y, plot=plt)

# %% [markdown]
#  # ********missing data

# %%
## delaing measing data in train_data
train_data.isna().sum()[train_data.isna().sum()>0]
train_data.fillna('Unknown',inplace=True)
print(train_data.shape)
# Out:
# (1460, 81)

# %%
train_data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
## delaing measing data in test_data
test_data.isna().sum()[test_data.isna().sum()>0]
test_data.fillna('Unknown',inplace=True)
print(test_data.shape)
# Out:
# (1459, 80)

# %%
test_data.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 80, dtype: int64

# %% [markdown]
# # ****convert data from string to number

# %%
oe=OrdinalEncoder()
for col in train_data:
    train_data[col]=oe.fit_transform(np.asarray(train_data[col].astype('str')).reshape(-1,1))
for col in test_data:
    test_data[col]=oe.fit_transform(np.asarray(test_data[col].astype('str')).reshape(-1,1))

# %%
print(train_data.shape)
print(test_data.shape)
print(y.shape)
# Out:
# (1460, 81)
# (1459, 80)
# (1460,)

# %%
test_data.head(10)
# Out:
#     Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 
iscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0          4.0      0.0     4.0     2.0       8.0            4.0      343.0
# 1          4.0      0.0     7.0     1.0       8.0            4.0      270.0
# 2          4.0      0.0    11.0     2.0       8.0            4.0      373.0
# 3          4.0      0.0     4.0     0.0       8.0            0.0      125.0
# 4          4.0      0.0     3.0     2.0       8.0            4.0      425.0
# 5          2.0     18.0     1.0     3.0       8.0            4.0      134.0
# 6          4.0      0.0    10.0     1.0       8.0            4.0      504.0
# 7          2.0      8.0     2.0     3.0       8.0            4.0      321.0
# 8          4.0      0.0     6.0     2.0       8.0            0.0       82.0
# 9          4.0      0.0     0.0     2.0       8.0            4.0       44.0
#
# [10 rows x 81 columns]

# %%
## spliting data to X and y


X = train_data.drop(columns = "SalePrice")
print(X.shape)
print(y.shape)
print(test_data.shape)
# Out:
# (1460, 80)
# (1460,)
# (1459, 80)

# %% [markdown]
# # ****Scaling data

# %%
## Scaling Model 
## scale to train_data
scaler = StandardScaler()
X = scaler.fit_transform(X)
print(X.shape)
# Out:
# (1460, 80)

# %% [markdown]
# # *****Spliting data to X_train, y_train,X_test and y_test

# %%
## spliting data into X_train , y_train,X_test,y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (978, 80)
# (978,)
# (482, 80)
# (482,)

# %% [markdown]
# # ****apply the RandomForestRegressor Algorithm

# %%
RandomForestRegressorModel = RandomForestRegressor(n_estimators=100,max_depth=5, random_state=44,min_samples_split=5,min_samples_leaf=5
                                                ,n_jobs=-1 )
                                                  
RandomForestRegressorModel.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, min_samples_leaf=5, min_samples_split=5,
#                       n_jobs=-1, random_state=44)

# %%
#Calculating Details
print('Random Forest Regressor Train Score is : ' , RandomForestRegressorModel.score(X_train, y_train))
print('Random Forest Regressor Test Score is : ' , RandomForestRegressorModel.score(X_test, y_test))
# Out:
# Random Forest Regressor Train Score is :  0.8842644546750896
# Random Forest Regressor Test Score is :  0.8004118839671199

# %%
#Calculating Prediction
y_pred =  RandomForestRegressorModel.predict(X_test)

print('Predicted Value for RandomForestRegressorModelis : ' , y_pred)

print(y_pred.shape)
# Out:
# Predicted Value for RandomForestRegressorModelis :  [11.68516114 11.83619081 12.51015716 11.75597977 12.03590491 11.86517544
#  11.98991343 12.13344428 11.92297545 12.23172537 12.60901533 11.80197418
#  11.70976815 11.96417425 11.72991682 12.61870303 11.62332729 11.80267573
#  11.91837249 12.10469676 11.98189249 11.54801242 11.80537651 11.72009976
#  11.56476121 11.84796848 11.76440638 12.46665902 11.73280865 11.74353729
#  12.12558697 11.98449486 12.05210718 11.52469343 11.99804672 11.90176454
#  12.08808681 11.84991072 11.87626078 12.54039679 12.10477676 12.0711267
#  11.86399882 11.83749466 12.12044468 12.02559367 11.72258204 12.25166913
#  11.95579041 12.29636105 12.15640224 11.89834265 12.58302763 12.18653327
#  11.98357196 12.23729455 11.57221335 12.06280651 12.13625823 11.80058249
#  12.09441395 12.02725742 12.18590064 12.095824   12.30031134 12.10261816
#  12.17364516 11.6297225  11.99207875 11.79969467 12.45484716 11.85717994
#  12.0386436  11.65208816 12.44115022 11.61850007 12.81660428 12.28043322
#  12.47952081 11.68380243 12.0638832  12.52783408 12.3622152  12.44918445
#  12.29428867 12.36882761 11.56557104 11.83160303 11.75678196 11.68837792
#  12.59000221 12.49558963 11.92925412 11.51888559 11.97455327 11.98242597
#  11.78000553 12.04386878 11.61664193 11.77433046 12.17734001 11.86153279
#  12.13349361 12.09689688 11.82927843 11.55803763 11.87610501 12.10963838
#  12.73105582 12.23831807 11.81029753 12.17240765 12.71313714 11.97648283
#  11.89785013 11.76633856 12.33593497 11.50017836 11.83492741 12.14857835
#  11.73491033 11.82347839 11.83106551 11.71678298 12.32280961 12.13670616
#  12.77236786 11.80889496 11.95444522 11.84835004 11.79653857 12.47415837
#  11.81608121 11.78106356 12.00152677 12.03160705 12.01121309 11.95094466
#  11.78509305 12.09357099 12.15889964 12.39570358 12.10089356 11.63211899
#  11.85208589 12.42681036 12.20921924 12.20378647 11.6052554  11.95017487
#  11.655145   11.75830941 12.55242497 12.1210506  11.24005679 11.87955196
#  11.85635646 12.07098577 12.20717732 12.24682949 12.57432153 12.380592
#  11.77498726 12.2263216  12.03995247 12.08213333 11.68265401 12.44815553
#  11.81257583 12.26345239 12.43301764 11.50436142 11.85433054 11.90132506
#  11.728858   13.12207316 12.20153615 12.45275481 12.02526628 11.44826144
#  11.69586156 12.62543072 12.0782366  12.32064081 11.66861495 12.08249409
#  12.05476922 11.79557393 11.79374271 12.09936601 11.80554424 11.74521812
#  11.98911444 12.03825619 11.8699543  11.99367336 12.20069792 11.68979507
#  12.78444988 12.31549497 12.02665618 11.99206645 12.07979069 12.04176953
#  12.31175358 12.13174752 11.90607458 12.04292213 11.95413161 12.14041891
#  11.99806015 12.45596252 13.08291165 12.31402885 12.02548734 11.96343512
#  11.97460196 11.28416057 11.95094466 12.14513751 12.02654455 12.21182092
#  11.4331451  12.30307718]
# (482,)

# %%
MAEValue = mean_absolute_error(y_test, y_pred, multioutput='uniform_average')
print("MAEValue is :" ,MAEValue)
# Out:
# MAEValue is : 0.1205052798384161

# %%
MSEValue= mean_squared_error(y_test, y_pred, multioutput='raw_values')
print("MSEValue is : " , MSEValue)
# Out:
# MSEValue is :  [0.03238445]

# %% [markdown]
# # ****knowing the best features

# %%
## Knowing the best features 
sel = SelectFromModel(RandomForestRegressor( )) 
sel.fit(X,y)
selected_features = sel.transform(X)
sel.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False,  True, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True, False, False,  True, False, False, False, False,
#        False, False,  True,  True,  True, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
feature_importance =  RandomForestRegressorModel.feature_importances_
feature_importance
# Out:
# array([2.58744373e-04, 1.56284368e-03, 3.29554506e-03, 5.87939421e-03,
#        2.11115620e-03, 0.00000000e+00, 0.00000000e+00, 1.76844032e-03,
#        6.37726901e-05, 0.00000000e+00, 1.90243828e-04, 7.91119606e-04,
#        2.25841272e-03, 0.00000000e+00, 0.00000000e+00, 6.33073615e-04,
#        2.99459836e-04, 3.50552244e-01, 3.24285865e-03, 1.78963213e-01,
#        2.40529101e-02, 1.66968542e-04, 0.00000000e+00, 5.66188051e-04,
#        1.06252162e-04, 2.64731982e-04, 7.63103621e-04, 7.20259864e-02,
#        3.25577931e-03, 9.10830149e-04, 1.60214536e-02, 1.94505218e-04,
#        7.09128166e-04, 1.27967153e-03, 3.29900541e-03, 0.00000000e+00,
#        0.00000000e+00, 1.20808154e-03, 6.63089961e-03, 8.98476062e-05,
#        3.70537201e-04, 8.80886853e-03, 3.43464274e-05, 9.03930319e-03,
#        4.43406001e-03, 0.00000000e+00, 5.97806845e-02, 4.13170171e-04,
#        0.00000000e+00, 9.55470721e-03, 1.05264464e-03, 5.95276150e-03,
#        2.63239225e-04, 1.18000045e-02, 6.15189401e-03, 0.00000000e+00,
#        2.82597450e-02, 3.32163904e-02, 1.30481666e-02, 1.45915551e-03,
#        9.49551617e-03, 8.48798089e-02, 2.43103828e-02, 8.25067569e-05,
#        4.56304020e-05, 1.44411892e-03, 7.76332876e-04, 7.34189606e-04,
#        4.63745169e-05, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.47081796e-04, 1.31038302e-04, 1.25121213e-04, 5.26354863e-04])

# %% [markdown]
# # ****Make Predictions

# %%
test_preds = RandomForestRegressorModel.predict(test_data)

# %%
print(test_preds.shape)
# Out:
# (1459,)

# %%
print(test_data)
# Out:
#           Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        0.0         5.0       2.0         95.0    187.0     1.0    2.0
# 1        1.0         5.0       3.0         96.0    374.0     1.0    2.0
# 2        2.0        10.0       3.0         89.0    357.0     1.0    2.0
# 3        3.0        10.0       3.0         93.0   1103.0     1.0    2.0
# 4        4.0         0.0       3.0         58.0    631.0     1.0    2.0
# ...      ...         ...       ...          ...      ...     ...    ...
# 1454  1454.0         2.0       4.0         39.0    491.0     1.0    2.0
# 1455  1455.0         2.0       4.0         39.0    488.0     1.0    2.0
# 1456  1456.0         5.0       3.0         36.0    500.0     1.0    2.0
# 1457  1457.0        14.0       3.0         77.0     57.0     1.0    2.0
# 1458  1458.0        10.0       3.0         89.0   1052.0     1.0    2.0
#
#       LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# 0          3.0          3.0        0.0  ...         12.0       0.0     2.0
# 1          0.0          3.0        0.0  ...          0.0       0.0     2.0
# 2          0.0          3.0        0.0  ...          0.0       0.0     2.0
# 3          0.0          3.0        0.0  ...          0.0       0.0     2.0
# 4          0.0          1.0        0.0  ...         21.0       0.0     2.0
# ...        ...          ...        ...  ...          ...       ...     ...
# 1454       3.0          3.0        0.0  ...          0.0       0.0     2.0
# 1455       3.0          3.0        0.0  ...          0.0       0.0     2.0
# 1456       3.0          3.0        0.0  ...          0.0       0.0     2.0
# 1457       3.0          3.0        0.0  ...          0.0       0.0     2.0
# 1458       3.0          3.0        0.0  ...          0.0       0.0     2.0
#
#       Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0       2.0          3.0      0.0     8.0     4.0       9.0            4.0
# 1       4.0          0.0      3.0     8.0     4.0       9.0            4.0
# 2       2.0          3.0      0.0     5.0     4.0       9.0            4.0
# 3       4.0          3.0      0.0     8.0     4.0       9.0            4.0
# 4       4.0          3.0      0.0     0.0     4.0       9.0            4.0
# ...     ...          ...      ...     ...     ...       ...            ...
# 1454    4.0          3.0      0.0     8.0     0.0       9.0            4.0
# 1455    4.0          3.0      0.0     6.0     0.0       9.0            0.0
# 1456    4.0          3.0      0.0    11.0     0.0       9.0            0.0
# 1457    2.0          2.0     22.0     9.0     0.0       9.0            4.0
# 1458    4.0          3.0      0.0     2.0     0.0       9.0            4.0
#
# [1459 rows x 80 columns]

# %% [markdown]
# # ****Submission

# %%
y_pred = np.floor(np.expm1(RandomForestRegressorModel.predict(test_data)))
y_pred
# Out:
# array([343411., 342778., 341460., ..., 338274., 259980., 338243.])

# %%
test_id = test_data['Id']
sub = pd.DataFrame()
sub['Id'] = test_id
sub.to_csv('mysubmission.csv',index=False)

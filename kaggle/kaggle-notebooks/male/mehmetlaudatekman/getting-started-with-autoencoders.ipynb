# %% [markdown]
# # Introduction
# Hello people, welcome to this kernel. In this kernel I am going to explain what is Autoencoders, when do we use them. And after that I will train a Autoencoder using Fashion MNIST data.
#
# Before starting, let's take a look at the content of this kernel
#
# # Notebook Content
# 1. What are Autoencoders
# 1. Importing Necessary Libraries and The Data
# 1. Data Overview and Preprocessing
# 1. Building and Compiling Our First Autoencoder
# 1. Fitting Autoencoder
# 1. Testing Our Autoencoder
# 1. Conclusion

# %% [markdown]
# # What are Autoencoders
#
# Autoencoders is a unsupervised deep learning approach. Generally it is used to extract the data. An autoencoder includes two part, Encoder and Decoder, encoder compress the data and extract important features, decoder decompress the data.
#
# Let's take a look at the diagram below:
# ![image.png](attachment:image.png)
#
#
# ***Thanks Towards Data Science for this image, you can check their tutorial from this link: https://towardsdatascience.com/applied-deep-learning-part-3-autoencoders-1c083af4d798?gi=f7f61cfbffe***
#
# There are several use fields of Autoencoders. You can use Autoencoders in order to avoid overfitting, data augmentation, denosing (cleaning images, signals or something)
#
# Let's implement it using Python.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.models import Model
from keras import layers
from keras.datasets import fashion_mnist

# %%
# Autoencoders is a unsupervised approach, so we don't need labels

(x_train,_),(x_test,_) = fashion_mnist.load_data()

print("Shape of x_train ",x_train.shape)
print("Shape o x_test   ",x_test.shape)
# Out:
# Shape of x_train  (60000, 28, 28)
# Shape o x_test    (10000, 28, 28)

# %% [markdown]
# # Data Overview and Preprocessing
# In this section I will take a look at the data and after that I will prepare the data.

# %%
import random

plt.figure(figsize=(7,7))
for i in range(36):
    plt.subplot(6,6,i+1)
    # showing random samples
    plt.imshow(x_train[random.randint(0,len(x_train))],cmap="gray")
    plt.axis("off")
plt.show()

# %% [markdown]
# * As you can understand from its name, fashion mnist dataset includes images of clothes. There are 10 unique classes in this dataset.

# %% [markdown]
# Now let's prepare the data. First we'll rescale the data between 0 and 1, then we'll flatten the images (28x28 => 784)

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# * Now let's flatten the image

# %%
img_shape = x_train.shape
img_shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train.reshape(len(x_train),img_shape[1]*img_shape[2])
x_test = x_test.reshape(len(x_test),img_shape[1]*img_shape[2])

print("Shape of x_train is ",x_train.shape)
print("Shape of x_test  is ",x_test.shape)
# Out:
# Shape of x_train is  (60000, 784)
# Shape of x_test  is  (10000, 784)

# %% [markdown]
# # Building and Compiling Our First Autoencoder
# In this section I am going to build and compile our first autoencoder.
#
# There are several types of Autoencoders, such as Convolutional Autoencoders, Variational Autoencoders. But in this tutorial, we'll build a simple Autoencoder using simple Dense layers and ReLU activation function.
#
# And we'll use Keras' Functional API

# %%
# Input layer
input_layer = layers.Input(shape=(784,))
# Encoding: 784 features to 32 features
encoder_layer1 = layers.Dense(32,activation="relu")(input_layer)
# Encoding: 32 features to 16 features
encoder_layer2 = layers.Dense(16,activation="relu")(encoder_layer1)
# Decoding: 16 features to 32 features
decoder_layer1 = layers.Dense(32,activation="relu")(encoder_layer2)
# Decoding: 32 features to 784 features
# Our images are scaled between 0 and 1 so we will use sigmoid
output_layer = layers.Dense(784,activation="sigmoid")(decoder_layer1)


autoencoder = Model(input_layer,output_layer)


autoencoder.compile(loss="binary_crossentropy",optimizer="RMSprop")

# %%
autoencoder.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_9 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                544
# _________________________________________________________________
# dense_11 (Dense)             (None, 784)               25872
# =================================================================
# Total params: 52,064
# Trainable params: 52,064
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Fitting Autoencoder
# In this section I am going to train our autoencoder model.

# %%
history = autoencoder.fit(x_train,
                x_train,
                shuffle=True,
                epochs=200,
                validation_data=(x_test,x_test),
                batch_size=256
               )

# Autoencoders are supervised algorithms, so our labels are also our data.
# Out:
# Epoch 1/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4090 - val_loss: 0.3589
# Epoch 2/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3418 - val_loss: 0.3316
# Epoch 3/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3264 - val_loss: 0.3237
# Epoch 4/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3201 - val_loss: 0.3216
# Epoch 5/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3158 - val_loss: 0.3152
# Epoch 6/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3127 - val_loss: 0.3137
# Epoch 7/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3103 - val_loss: 0.3103
# Epoch 8/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3083 - val_loss: 0.3106
# Epoch 9/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3067 - val_loss: 0.3067
# Epoch 10/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3053 - val_loss: 0.3062
# Epoch 11/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3040 - val_loss: 0.3050
# Epoch 12/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3030 - val_loss: 0.3053
# Epoch 13/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3021 - val_loss: 0.3031
# Epoch 14/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3012 - val_loss: 0.3019
# Epoch 15/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3005 - val_loss: 0.3016
# Epoch 16/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2998 - val_loss: 0.3012
# Epoch 17/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2993 - val_loss: 0.3028
# Epoch 18/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2987 - val_loss: 0.3016
# Epoch 19/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2982 - val_loss: 0.3012
# Epoch 20/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2977 - val_loss: 0.3003
# Epoch 21/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2972 - val_loss: 0.2994
# Epoch 22/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2968 - val_loss: 0.3000
# Epoch 23/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2964 - val_loss: 0.2985
# Epoch 24/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2961 - val_loss: 0.2986
# Epoch 25/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2957 - val_loss: 0.2981
# Epoch 26/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2954 - val_loss: 0.2978
# Epoch 27/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2950 - val_loss: 0.2964
# Epoch 28/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2948 - val_loss: 0.2969
# Epoch 29/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2945 - val_loss: 0.2972
# Epoch 30/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2942 - val_loss: 0.2961
# Epoch 31/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2940 - val_loss: 0.2960
# Epoch 32/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2938 - val_loss: 0.2959
# Epoch 33/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2936 - val_loss: 0.2964
# Epoch 34/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2934 - val_loss: 0.2956
# Epoch 35/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2932 - val_loss: 0.2966
# Epoch 36/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2930 - val_loss: 0.2947
# Epoch 37/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2929 - val_loss: 0.2961
# Epoch 38/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2927 - val_loss: 0.2947
# Epoch 39/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2926 - val_loss: 0.2959
# Epoch 40/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2924 - val_loss: 0.2947
# Epoch 41/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2923 - val_loss: 0.2955
# Epoch 42/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2922 - val_loss: 0.2946
# Epoch 43/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2920 - val_loss: 0.2938
# Epoch 44/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2919 - val_loss: 0.2937
# Epoch 45/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2918 - val_loss: 0.2940
# Epoch 46/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2916 - val_loss: 0.2941
# Epoch 47/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2916 - val_loss: 0.2945
# Epoch 48/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2914 - val_loss: 0.2943
# Epoch 49/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2913 - val_loss: 0.2930
# Epoch 50/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2912 - val_loss: 0.2935
# Epoch 51/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2911 - val_loss: 0.2940
# Epoch 52/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2910 - val_loss: 0.2934
# Epoch 53/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2909 - val_loss: 0.2934
# Epoch 54/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2908 - val_loss: 0.2924
# Epoch 55/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2907 - val_loss: 0.2931
# Epoch 56/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2906 - val_loss: 0.2925
# Epoch 57/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2905 - val_loss: 0.2931
# Epoch 58/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2904 - val_loss: 0.2930
# Epoch 59/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2904 - val_loss: 0.2921
# Epoch 60/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2903 - val_loss: 0.2928
# Epoch 61/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2902 - val_loss: 0.2923
# Epoch 62/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2901 - val_loss: 0.2923
# Epoch 63/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2900 - val_loss: 0.2923
# Epoch 64/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2899 - val_loss: 0.2925
# Epoch 65/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2898 - val_loss: 0.2935
# Epoch 66/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2897 - val_loss: 0.2920
# Epoch 67/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2897 - val_loss: 0.2923
# Epoch 68/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2896 - val_loss: 0.2918
# Epoch 69/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2895 - val_loss: 0.2923
# Epoch 70/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2894 - val_loss: 0.2910
# Epoch 71/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2894 - val_loss: 0.2916
# Epoch 72/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2893 - val_loss: 0.2933
# Epoch 73/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2892 - val_loss: 0.2920
# Epoch 74/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2891 - val_loss: 0.2913
# Epoch 75/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2890 - val_loss: 0.2928
# Epoch 76/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2889 - val_loss: 0.2908
# Epoch 77/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2889 - val_loss: 0.2919
# Epoch 78/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2888 - val_loss: 0.2913
# Epoch 79/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2888 - val_loss: 0.2925
# Epoch 80/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2887 - val_loss: 0.2919
# Epoch 81/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2886 - val_loss: 0.2911
# Epoch 82/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2886 - val_loss: 0.2907
# Epoch 83/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2885 - val_loss: 0.2909
# Epoch 84/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2885 - val_loss: 0.2911
# Epoch 85/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2884 - val_loss: 0.2900
# Epoch 86/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2884 - val_loss: 0.2909
# Epoch 87/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2883 - val_loss: 0.2912
# Epoch 88/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2883 - val_loss: 0.2908
# Epoch 89/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2882 - val_loss: 0.2901
# Epoch 90/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2882 - val_loss: 0.2905
# Epoch 91/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2881 - val_loss: 0.2920
# Epoch 92/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2881 - val_loss: 0.2901
# Epoch 93/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2881 - val_loss: 0.2910
# Epoch 94/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2881 - val_loss: 0.2897
# Epoch 95/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2880 - val_loss: 0.2903
# Epoch 96/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2880 - val_loss: 0.2909
# Epoch 97/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2879 - val_loss: 0.2899
# Epoch 98/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2879 - val_loss: 0.2900
# Epoch 99/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2879 - val_loss: 0.2909
# Epoch 100/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2878 - val_loss: 0.2900
# Epoch 101/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2878 - val_loss: 0.2904
# Epoch 102/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2878 - val_loss: 0.2910
# Epoch 103/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2877 - val_loss: 0.2905
# Epoch 104/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2877 - val_loss: 0.2902
# Epoch 105/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2877 - val_loss: 0.2906
# Epoch 106/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2877 - val_loss: 0.2908
# Epoch 107/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2876 - val_loss: 0.2898
# Epoch 108/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2876 - val_loss: 0.2892
# Epoch 109/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2876 - val_loss: 0.2903
# Epoch 110/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2876 - val_loss: 0.2902
# Epoch 111/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2875 - val_loss: 0.2903
# Epoch 112/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2875 - val_loss: 0.2897
# Epoch 113/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2875 - val_loss: 0.2896
# Epoch 114/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2875 - val_loss: 0.2900
# Epoch 115/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2874 - val_loss: 0.2893
# Epoch 116/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2874 - val_loss: 0.2901
# Epoch 117/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2874 - val_loss: 0.2899
# Epoch 118/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2874 - val_loss: 0.2894
# Epoch 119/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2873 - val_loss: 0.2891
# Epoch 120/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2873 - val_loss: 0.2898
# Epoch 121/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2873 - val_loss: 0.2903
# Epoch 122/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2873 - val_loss: 0.2893
# Epoch 123/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2873 - val_loss: 0.2899
# Epoch 124/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2873 - val_loss: 0.2901
# Epoch 125/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2873 - val_loss: 0.2900
# Epoch 126/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2872 - val_loss: 0.2894
# Epoch 127/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2872 - val_loss: 0.2903
# Epoch 128/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2872 - val_loss: 0.2888
# Epoch 129/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2872 - val_loss: 0.2897
# Epoch 130/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2872 - val_loss: 0.2894
# Epoch 131/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2871 - val_loss: 0.2892
# Epoch 132/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2871 - val_loss: 0.2895
# Epoch 133/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2871 - val_loss: 0.2915
# Epoch 134/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2871 - val_loss: 0.2905
# Epoch 135/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2871 - val_loss: 0.2909
# Epoch 136/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2870 - val_loss: 0.2903
# Epoch 137/200
# 235/235 [==============================] - 2s 8ms/step - loss: 0.2870 - val_loss: 0.2891
# Epoch 138/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2870 - val_loss: 0.2895
# Epoch 139/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2870 - val_loss: 0.2906
# Epoch 140/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2870 - val_loss: 0.2891
# Epoch 141/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2870 - val_loss: 0.2888
# Epoch 142/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2870 - val_loss: 0.2900
# Epoch 143/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2869 - val_loss: 0.2899
# Epoch 144/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2869 - val_loss: 0.2894
# Epoch 145/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2869 - val_loss: 0.2894
# Epoch 146/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2869 - val_loss: 0.2885
# Epoch 147/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2869 - val_loss: 0.2893
# Epoch 148/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2869 - val_loss: 0.2887
# Epoch 149/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2869 - val_loss: 0.2883
# Epoch 150/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2868 - val_loss: 0.2894
# Epoch 151/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2868 - val_loss: 0.2889
# Epoch 152/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2868 - val_loss: 0.2893
# Epoch 153/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2868 - val_loss: 0.2887
# Epoch 154/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2868 - val_loss: 0.2898
# Epoch 155/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2868 - val_loss: 0.2886
# Epoch 156/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2868 - val_loss: 0.2895
# Epoch 157/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2868 - val_loss: 0.2894
# Epoch 158/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2867 - val_loss: 0.2890
# Epoch 159/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2867 - val_loss: 0.2901
# Epoch 160/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2867 - val_loss: 0.2891
# Epoch 161/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2867 - val_loss: 0.2887
# Epoch 162/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2867 - val_loss: 0.2889
# Epoch 163/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2867 - val_loss: 0.2897
# Epoch 164/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2867 - val_loss: 0.2897
# Epoch 165/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2866 - val_loss: 0.2894
# Epoch 166/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2867 - val_loss: 0.2894
# Epoch 167/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2866 - val_loss: 0.2890
# Epoch 168/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2866 - val_loss: 0.2903
# Epoch 169/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2866 - val_loss: 0.2889
# Epoch 170/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2866 - val_loss: 0.2890
# Epoch 171/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2866 - val_loss: 0.2889
# Epoch 172/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2866 - val_loss: 0.2890
# Epoch 173/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2866 - val_loss: 0.2893
# Epoch 174/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2865 - val_loss: 0.2892
# Epoch 175/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2866 - val_loss: 0.2899
# Epoch 176/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2866 - val_loss: 0.2895
# Epoch 177/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2865 - val_loss: 0.2893
# Epoch 178/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2865 - val_loss: 0.2888
# Epoch 179/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2865 - val_loss: 0.2887
# Epoch 180/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2865 - val_loss: 0.2883
# Epoch 181/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2865 - val_loss: 0.2894
# Epoch 182/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2865 - val_loss: 0.2888
# Epoch 183/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2865 - val_loss: 0.2887
# Epoch 184/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2865 - val_loss: 0.2893
# Epoch 185/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2865 - val_loss: 0.2889
# Epoch 186/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2865 - val_loss: 0.2884
# Epoch 187/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2864 - val_loss: 0.2894
# Epoch 188/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2864 - val_loss: 0.2886
# Epoch 189/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2864 - val_loss: 0.2890
# Epoch 190/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2864 - val_loss: 0.2898
# Epoch 191/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2864 - val_loss: 0.2892
# Epoch 192/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2864 - val_loss: 0.2891
# Epoch 193/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2864 - val_loss: 0.2889
# Epoch 194/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2864 - val_loss: 0.2886
# Epoch 195/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2864 - val_loss: 0.2904
# Epoch 196/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2864 - val_loss: 0.2888
# Epoch 197/200
# 235/235 [==============================] - 2s 6ms/step - loss: 0.2863 - val_loss: 0.2900
# Epoch 198/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2863 - val_loss: 0.2889
# Epoch 199/200
# 235/235 [==============================] - 1s 6ms/step - loss: 0.2863 - val_loss: 0.2887
# Epoch 200/200
# 235/235 [==============================] - 2s 7ms/step - loss: 0.2863 - val_loss: 0.2887

# %% [markdown]
# * Our model is trained, before examining training history, let's save our model's weights.

# %%
autoencoder.save_weights('autoencoder_model.h5')

# %% [markdown]
# * Now let's check our training history

# %%
import seaborn
seaborn.set_style('darkgrid')
plt.figure(figsize=(12,4))
plt.plot(range(200),history.history["loss"],color="red",label="Train Loss")
plt.plot(range(200),history.history["val_loss"],color="#CCCC00",label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Testing Our Autoencoder
# In this section I am going to test our autoencoder.

# %%
# In order to see encoded image, I will create an encoder using trained layers.
encoder = Model(input_layer,encoder_layer2)

# Let's check encoded images
encoded_images = encoder.predict(x_test)
encoded_images = encoded_images.reshape(-1,4,4)



# Visualize them
plt.figure(figsize=(12,4))
for i in range(12):
    plt.subplot(2,12,i+1)
    plt.imshow(x_test[32*i].reshape(28,28),cmap="gray")
    plt.axis("off")
    
    plt.subplot(2,12,i+13)
    plt.imshow(encoded_images[32*i].reshape(4,4),cmap="gray")
    plt.axis("off")

plt.show()

# %% [markdown]
# * And now let's decoded images.

# %%
decoded_images = autoencoder.predict(x_test)

plt.figure(figsize=(12,4))
for i in range(12):
    plt.subplot(2,12,i+1)
    plt.imshow(x_test[32*i].reshape(28,28),cmap="gray")
    plt.axis("off")
    
    plt.subplot(2,12,i+13)
    plt.imshow(decoded_images[32*i].reshape(28,28),cmap="gray")
    plt.axis("off")

plt.show()

# %% [markdown]
# * Amazing, our autoencoder works well. It encoded and decoded our images greatly. It is really impressive.

# %% [markdown]
# # Conclusion
# Thanks for your attention, if you have any question in your mind, please ask. I will definetely return.

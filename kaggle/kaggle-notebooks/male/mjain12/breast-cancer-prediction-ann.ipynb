# %% [markdown]
# **PREDICTING BREAST CANCER USING ARTIFICIAL NEURAL NETWORKS.**
#
# * The features that have been computed from digitized images of the cell nuclei, which can be used to build a model to predict whether a tumor is benign or malignant.
# * 1 = Malignant (Cancerous) - Present (M)
# * 0 = Benign (Not Cancerous) -Absent (B)
#
# **HERE I HAVE APPLIED SOME TECHNIQUES TO AVOID OVERFITTING ALSO**

# %%
#importing libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
#importing dataset
ds = pd.read_csv('../input/breast-cancer-wisconsin-data/data.csv')

# %%
#reviewing dataset
pd.set_option('display.max_columns',None)
ds.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
# 2         0.2069                 0.05999     0.7456      0.7869         4.585
# 3         0.2597                 0.09744     0.4956      1.1560         3.445
# 4         0.1809                 0.05883     0.7572      0.7813         5.438
#
#    area_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0   153.40       0.006399         0.04904       0.05373            0.01587
# 1    74.08       0.005225         0.01308       0.01860            0.01340
# 2    94.03       0.006150         0.04006       0.03832            0.02058
# 3    27.23       0.009110         0.07458       0.05661            0.01867
# 4    94.44       0.011490         0.02461       0.05688            0.01885
#
#    symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0      0.03003              0.006193         25.38          17.33
# 1      0.01389              0.003532         24.99          23.41
# 2      0.02250              0.004571         23.57          25.53
# 3      0.05963              0.009208         14.91          26.50
# 4      0.01756              0.005115         22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN

# %%
#dropping unnecessary features
ds.drop(['id', 'Unnamed: 32'], axis = 1, inplace = True)

# %%
#checking type of feaures
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB

# %%
#dataset has 569 rows and 31 columns
ds.shape
# Out:
# (569, 31)

# %%
#checking for null values
ds.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# **NO MISSING VALUES**

# %%
#taking care of categorical values
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds['diagnosis']=le.fit_transform(ds['diagnosis'])

# %%
plt.figure(figsize = (8,6))
sns.countplot(x = 'diagnosis', data = ds)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %% [markdown]
# **AROUND 350 ARE Benign**

# %%
plt.figure(figsize=(16,14))
sns.heatmap(ds.corr(), cmap='Blues', annot = True)
plt.title("Correlation Map", fontweight = "bold", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Map')

# %% [markdown]
# **CORRELATION WAS FOUND IN SOME FEATURES**
#
# **WE CAN EITHER REMOVE THE HIGH CORRELATED FEATURES OR WE CAN USE ALL THE FEATURES, I AM USING ALL FEATURES.**
#
# * **REMOVING CORRELATED FEATURES MAY INCREASE ACCURACY**

# %%
#defining dependent and independent variables
x = ds.drop('diagnosis', axis=1)
y = ds['diagnosis']

# %%
#splitting data into training and testing set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# **FEATURE SCALING IS NECESSARY IN ANN**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from tensorflow.keras.layers import Dropout


#CREATING THE ANN AS SEQUENCE OF LAYERS
ann = tf.keras.models.Sequential()

#ADDING FIRST HIDDEN LAYER WITH 30 NEURONS, THE INPUT LAYER WILL BE ADDED AUTOMATICALLY,
ann.add(tf.keras.layers.Dense(units = 30,activation = 'relu'))
ann.add(Dropout(0.5))

#ADDING 2ND HIDDEN LAYER WITH 30 NEURONS
ann.add(tf.keras.layers.Dense(units = 30,activation = 'relu'))
ann.add(Dropout(0.5))

#ADDING OUTPUT LAYER WITH 1 NEURON , AS THIS IS A BINARY CLASSIFICATION
ann.add(tf.keras.layers.Dense(units = 1,activation = 'sigmoid'))

#COMPILING THE ANN USING STOCHASTIC GRADIENT DESCENT (optimizer = 'adam')
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#setting callbacks for monitoring maximum accuracy
from tensorflow.keras.callbacks import EarlyStopping
early = EarlyStopping(monitor = 'accuracy', mode = 'max',patience = 25)

# %%
#TRAINING THE ANN WITH BATCH SIZE OF 32 (THIS IS A BATCH LEARNING)
ann.fit(x_train, y_train,batch_size = 32, epochs = 400,callbacks = [early])
# Out:
# Epoch 1/400
# 15/15 [==============================] - 1s 1ms/step - loss: 0.7810 - accuracy: 0.5062
# Epoch 2/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5984 - accuracy: 0.6813
# Epoch 3/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4632 - accuracy: 0.7968
# Epoch 4/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3993 - accuracy: 0.8523
# Epoch 5/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3607 - accuracy: 0.8568
# Epoch 6/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2858 - accuracy: 0.8988
# Epoch 7/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2617 - accuracy: 0.9094
# Epoch 8/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2586 - accuracy: 0.9021
# Epoch 9/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2409 - accuracy: 0.9155
# Epoch 10/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2261 - accuracy: 0.9134
# Epoch 11/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2159 - accuracy: 0.9352
# Epoch 12/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2191 - accuracy: 0.9201
# Epoch 13/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.2061 - accuracy: 0.9379
# Epoch 14/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1625 - accuracy: 0.9376
# Epoch 15/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1843 - accuracy: 0.9319
# Epoch 16/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1608 - accuracy: 0.9517
# Epoch 17/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1481 - accuracy: 0.9509
# Epoch 18/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1562 - accuracy: 0.9511
# Epoch 19/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1160 - accuracy: 0.9700
# Epoch 20/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1490 - accuracy: 0.9450
# Epoch 21/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1545 - accuracy: 0.9435
# Epoch 22/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1262 - accuracy: 0.9544
# Epoch 23/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1043 - accuracy: 0.9646
# Epoch 24/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0951 - accuracy: 0.9703
# Epoch 25/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0898 - accuracy: 0.9720
# Epoch 26/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1184 - accuracy: 0.9788
# Epoch 27/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9729
# Epoch 28/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1117 - accuracy: 0.9608
# Epoch 29/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1501 - accuracy: 0.9638
# Epoch 30/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1252 - accuracy: 0.9685
# Epoch 31/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1103 - accuracy: 0.9770
# Epoch 32/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0889 - accuracy: 0.9644
# Epoch 33/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0881 - accuracy: 0.9781
# Epoch 34/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0996 - accuracy: 0.9696
# Epoch 35/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1104 - accuracy: 0.9667
# Epoch 36/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1362 - accuracy: 0.9806
# Epoch 37/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0924 - accuracy: 0.9664
# Epoch 38/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0712 - accuracy: 0.9828
# Epoch 39/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0771 - accuracy: 0.9725
# Epoch 40/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0808 - accuracy: 0.9813
# Epoch 41/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 0.9805
# Epoch 42/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0667 - accuracy: 0.9810
# Epoch 43/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9768
# Epoch 44/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0849 - accuracy: 0.9712
# Epoch 45/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0658 - accuracy: 0.9804
# Epoch 46/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0530 - accuracy: 0.9900
# Epoch 47/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0555 - accuracy: 0.9920
# Epoch 48/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0555 - accuracy: 0.9855
# Epoch 49/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0649 - accuracy: 0.9709
# Epoch 50/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0863 - accuracy: 0.9776
# Epoch 51/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0526 - accuracy: 0.9823
# Epoch 52/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0594 - accuracy: 0.9829
# Epoch 53/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0892 - accuracy: 0.9763
# Epoch 54/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9745
# Epoch 55/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9884
# Epoch 56/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9857
# Epoch 57/400
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9829
# Epoch 58/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 0.9752
# Epoch 59/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0630 - accuracy: 0.9781
# Epoch 60/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0703 - accuracy: 0.9714
# Epoch 61/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0840 - accuracy: 0.9669
# Epoch 62/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0834 - accuracy: 0.9774
# Epoch 63/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0556 - accuracy: 0.9816
# Epoch 64/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0702 - accuracy: 0.9714
# Epoch 65/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0542 - accuracy: 0.9785
# Epoch 66/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0700 - accuracy: 0.9840
# Epoch 67/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0608 - accuracy: 0.9810
# Epoch 68/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0671 - accuracy: 0.9756
# Epoch 69/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0549 - accuracy: 0.9873
# Epoch 70/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0494 - accuracy: 0.9844
# Epoch 71/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9909
# Epoch 72/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0513 - accuracy: 0.9862
# Epoch 73/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0613 - accuracy: 0.9702
# Epoch 74/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9903
# Epoch 75/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0394 - accuracy: 0.9914
# Epoch 76/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0716 - accuracy: 0.9861
# Epoch 77/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0328 - accuracy: 0.9946
# Epoch 78/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0627 - accuracy: 0.9763
# Epoch 79/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0426 - accuracy: 0.9881
# Epoch 80/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9934
# Epoch 81/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0601 - accuracy: 0.9816
# Epoch 82/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0479 - accuracy: 0.9797
# Epoch 83/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0697 - accuracy: 0.9827
# Epoch 84/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0457 - accuracy: 0.9805
# Epoch 85/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0486 - accuracy: 0.9863
# Epoch 86/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0575 - accuracy: 0.9859
# Epoch 87/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0340 - accuracy: 0.9896
# Epoch 88/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0631 - accuracy: 0.9818
# Epoch 89/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0581 - accuracy: 0.9785
# Epoch 90/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0431 - accuracy: 0.9895
# Epoch 91/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0365 - accuracy: 0.9848
# Epoch 92/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0758 - accuracy: 0.9678
# Epoch 93/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0409 - accuracy: 0.9859
# Epoch 94/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0618 - accuracy: 0.9818
# Epoch 95/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 0.9914
# Epoch 96/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0670 - accuracy: 0.9820
# Epoch 97/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0625 - accuracy: 0.9732
# Epoch 98/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0450 - accuracy: 0.9881
# Epoch 99/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0465 - accuracy: 0.9833
# Epoch 100/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0436 - accuracy: 0.9888
# Epoch 101/400
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0400 - accuracy: 0.9845

# %%
losses = pd.DataFrame(ann.history.history)
losses.plot()
# Out:
# <AxesSubplot:>

# %%
#GETTING ACCURACY AND CONFUSION MATRIX
from sklearn.metrics import confusion_matrix,accuracy_score
y_pred = ann.predict(x_test)
y_pred  = y_pred > 0.5
cm = confusion_matrix(y_pred,y_test)
ac = accuracy_score(y_pred,y_test)

# %%
sns.heatmap(cm,annot = True)
plt.title('CONFUSION MATRIX')
print('Accuracy - {}%'.format(ac*100))
# Out:
# Accuracy - 95.6140350877193%

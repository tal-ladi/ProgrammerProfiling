# %% [markdown]
# # Goal
# To answer all queries related to the given data, much like Google search but for the given dataset
#
# The queries include all the questions given in all the tasks
#
# I thought about making a different notebook for each query but in the following notebook i have achieved a method to answer all queries with a single notebook and high accuracy
#
#
# # About the NoteBook
#
# In this notebook i have converted all the json files to a single pd.DataFrame object, then i combined all the useful information and tokenized the words to Lemmatize them using NLTK.
# In layman terms, i converted each word to a simpler version of the word so that it can be easy for the user to find the most related research paper quickly. In the end i use the Google USE to  compare the similarity between the query and the documents and return the documents which are most similar to the query
#
#
#
#
# ## About the Functions used
#
# First i converted all json to a single dataframe
#
# After that i combined the useful information like Title, Authors, Text etc.
#
# After that i striped them from garbage like next line, extra spacing, and converted the sentences to tokens, i.e. seperated each word from the sentence
#
# After that i converted each word to its Lemmatized form
#
#
# The above mentioned operations took around **20-24 hours** excluding the time i had to restart because Kaggle only lets me run 9 hours consecutively, so i had to do it in iterations while saving the information
#
# The Lemmatized information preprocessing is time taking, like i said 20 hours, that is why i have uploaded the dataset containing the Lemmatized words here:
#
# ### www.kaggle.com/alizahidraja/covid19-allresearchpapers-lemmatizedinformation
#
#
#
#
# Then I trained the Google USE with my processed data and finethe similarity between the query and all the documents, and return the most similar documents
#
# That's it!
#
# Hope this search engine is of use to everyone who is working on these research papers
#
#
#
# ## About the Author
# I am a 21 year old who hope to see the world free of this virus as soon as possible

# %%
import pandas as pd
import numpy as np
import os 
import re
import operator
import nltk 
import json
from copy import deepcopy
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer

from tqdm.notebook import tqdm
from time import sleep

import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import linear_kernel

# %% [markdown]
# ### Helper Functions from https://www.kaggle.com/xhlulu/cord-19-eda-parse-json-and-generate-clean-csv

# %%
#Helper Functions by https://www.kaggle.com/xhlulu/cord-19-eda-parse-json-and-generate-clean-csv

def format_name(author):
    middle_name = " ".join(author['middle'])
    
    if author['middle']:
        return " ".join([author['first'], middle_name, author['last']])
    else:
        return " ".join([author['first'], author['last']])


def format_affiliation(affiliation):
    text = []
    location = affiliation.get('location')
    if location:
        text.extend(list(affiliation['location'].values()))
    
    institution = affiliation.get('institution')
    if institution:
        text = [institution] + text
    return ", ".join(text)

def format_authors(authors, with_affiliation=False):
    name_ls = []
    
    for author in authors:
        name = format_name(author)
        if with_affiliation:
            affiliation = format_affiliation(author['affiliation'])
            if affiliation:
                name_ls.append(f"{name} ({affiliation})")
            else:
                name_ls.append(name)
        else:
            name_ls.append(name)
    
    return ", ".join(name_ls)

def format_body(body_text):
    texts = [(di['section'], di['text']) for di in body_text]
    texts_di = {di['section']: "" for di in body_text}
    
    for section, text in texts:
        texts_di[section] += text

    body = ""

    for section, text in texts_di.items():
        body += section
        body += "\n\n"
        body += text
        body += "\n\n"
    
    return body

def format_bib(bibs):
    if type(bibs) == dict:
        bibs = list(bibs.values())
    bibs = deepcopy(bibs)
    formatted = []
    
    for bib in bibs:
        bib['authors'] = format_authors(
            bib['authors'], 
            with_affiliation=False
        )
        formatted_ls = [str(bib[k]) for k in ['title', 'authors', 'venue', 'year']]
        formatted.append(", ".join(formatted_ls))

        
    return "; ".join(formatted)


def load_files(dirname):
    filenames = os.listdir(dirname)
    raw_files = []

    for filename in tqdm(filenames):
        filename = dirname + filename
        file = json.load(open(filename, 'rb'))
        raw_files.append(file)
    
    return raw_files

def generate_clean_df(all_files):
    cleaned_files = []
    
    for file in tqdm(all_files):
        features = [
            file['paper_id'],
            file['metadata']['title'],
            format_authors(file['metadata']['authors']),
            format_authors(file['metadata']['authors'], 
                           with_affiliation=True),
            format_body(file['abstract']),
            format_body(file['body_text']),
            format_bib(file['bib_entries']),
            file['metadata']['authors'],
            file['bib_entries']
        ]

        cleaned_files.append(features)

    col_names = ['paper_id', 'title', 'authors',
                 'affiliations', 'abstract', 'text', 
                 'bibliography','raw_authors','raw_bibliography']

    clean_df = pd.DataFrame(cleaned_files, columns=col_names)
    clean_df = clean_df.drop(['raw_authors', 'raw_bibliography'], axis=1)
    clean_df.head()
    
    return clean_df

# %% [markdown]
# # Combining all Files to a single DataFrame

# %%
#pmc_dir = '/kaggle/input/CORD-19-research-challenge/pmc_custom_license/pmc_custom_license/'
#pmc_files = load_files(pmc_dir)
#all_df = generate_clean_df(pmc_files)

biorxiv_dir = '/kaggle/input/CORD-19-research-challenge/biorxiv_medrxiv/biorxiv_medrxiv/'
biorxiv_files = load_files(biorxiv_dir)
all_df = generate_clean_df(biorxiv_files)

noncomm_dir="/kaggle/input/CORD-19-research-challenge/noncomm_use_subset/noncomm_use_subset/"
noncomm_files = load_files(noncomm_dir)
all_df = all_df.append(generate_clean_df(noncomm_files))

comm_dir="/kaggle/input/CORD-19-research-challenge/comm_use_subset/comm_use_subset/"
comm_files = load_files(comm_dir)
all_df = all_df.append(generate_clean_df(comm_files))

print(all_df.shape)
all_df.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=885.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=885.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2353.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2353.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9118.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=9118.0), HTML(value='')))
# (12356, 7)
#                                    paper_id  \
# 0  c6039f8933305c9f44a44c81a15b321b6c2848dc
# 1  67a2ae408efcb6686a22ae27435c7e4fa10c4a21
# 2  982689f92bf67e90a43fc142c605da9a5045f756
# 3  f33c6d94b0efaa198f8f3f20e644625fa3fe10d2
# 4  c8c052d27aaf8015316dcd2644fa5e0b3870cea1
#
#                                                title  \
# 0  Far-UVC light: A new tool to control the sprea...
# 1  Title: First 12 patients with coronavirus disease
# 2  Estimation of instant case fatality rate of CO...
# 3  Sequencing of the human IG light chain loci fr...
# 4  Modeling the Comparative Impact of Individual ...
#
#                                              authors  \
# 0  David Welch, Manuela Buonanno, Veljko Grilj, I...
# 1  Zhang Y , Chen C , Zhu S , Shu C , Wang D , So...
# 2  Lei Cao, Ting-Ting Huang, Jun-Xia Zhang, Qi Qi...
# 3  Corey T Watson, Karyn Meltz Steinberg, Tina A ...
# 4  Corey M Peak, Rebecca Kahn, Yonatan H Grad, La...
#
#                                         affiliations  \
# 0  David Welch (Columbia University Medical Cente...
# 1  Zhang Y , Chen C , Zhu S , Shu C , Wang D , So...
# 2  Lei Cao, Ting-Ting Huang, Jun-Xia Zhang, Qi Qi...
# 3  Corey T Watson (Simon Fraser University, V5A 1...
# 4  Corey M Peak (Harvard T.H. Chan School of Publ...
#
#                                             abstract  \
# 0  Abstract\n\nAirborne-mediated microbial diseas...
# 1  Abstract\n\nIntroduction: More than 93,000 cas...
# 2  Abstract\n\nBackground The outbreak of coronav...
# 3  Abstract\n\nGermline variation at immunoglobul...
# 4  Abstract\n\nIndividual quarantine and active m...
#
#                                                 text  \
# 0  3\n\nAirborne-mediated microbial diseases repr...
# 1  INTRODUCTION\n\nIn December 2019, an outbreak ...
# 2  Introduction\n\nThe novel coronavirus pneumoni...
# 3  Introduction\n\nAntibodies are essential compo...
# 4  Introduction\n\nIn December 2019, Coronavirus ...
#
#                                         bibliography
# 0  Global, regional, and national life expectancy...
# 1  World Health Organization, , Coronavirus disea...
# 2  Outbreak of pneumonia of unknown etiology in W...
# 3  Janeway's immunobiology. 7 edn, K Murphy, P Tr...
# 4  Coronavirus 2019-nCoV Global Cases, , , None; ...

# %% [markdown]
# ### Sorting the DataFrame as i had to do this in iterations and had to ensure the order

# %%
#i had to do this in iterations so had to make sure that the data is in the correct order
all_df=all_df.sort_values(by=['paper_id'])

# %% [markdown]
# ## Combining all the useful information

# %%
#Combining the info so that we can search based on all the given information
all_df['useful_info']=all_df.title+all_df.authors+all_df.affiliations+all_df.abstract+all_df.text+all_df.bibliography

# %%
all_df.head()
# Out:
#                                       paper_id  \
# 2105  000b7d1517ceebb34e1e3e817695b6de03e2fa78
# 1600  00142f93c18b07350be89e96372d240372437ed9
# 731   0015023cc06b5362d332b3baf348d11567ca2fbb
# 1653  0022796bb2112abd2e6423ba2d57751db06049fb
# 6113  00326efcca0852dc6e39dc6b7786267e1bc4f194
#
#                                                   title  \
# 2105  Supplementary Information An eco-epidemiologic...
# 1600  immunity to pathogens taught by specialized hu...
# 731   The RNA pseudoknots in foot-and-mouth disease ...
# 1653  Public Health Responses to and Challenges for ...
# 6113  a section of the journal Frontiers in Pediatri...
#
#                                                 authors  \
# 2105  Julien Mélade, Nicolas Wieseke 4#, Beza Ramazi...
# 1600  Elisabetta Padovan, Marina Cella, Shahram Sale...
# 731   Joseph C Ward, Lidia Lasecka-Dykes, Chris Neil...
# 1653  Elvina Viennet, Scott A Ritchie, Craig R Willi...
# 6113  Jan Hau Lee, Oguz Dursun, Phuc Huu Phan, Yek K...
#
#                                            affiliations  \
# 2105  Julien Mélade (2 rue Maxime Rivière, 97490 Sai...
# 1600  Elisabetta Padovan, Marina Cella, Shahram Sale...
# 731   Joseph C Ward, Lidia Lasecka-Dykes, Chris Neil...
# 1653  Elvina Viennet (The Australian National Univer...
# 6113  Jan Hau Lee, Oguz Dursun, Phuc Huu Phan, Yek K...
#
#                                                abstract  \
# 2105
# 1600  Abstract\n\nDendritic cells (DCs) are speciali...
# 731   Abstract\n\nword count: 194 22 Text word count...
# 1653  Abstract\n\nDengue has a negative impact in lo...
# 6113  Abstract\n\nFifteen years ago, United Nations ...
#
#                                                    text  \
# 2105  \n\n- Figure S1 : Phylogeny of all sequences b...
# 1600  \n\niNTRODUCTiON Human beings are constantly e...
# 731   \n\nVP3, and VP0 (which is further processed t...
# 1653  Introduction\n\nPathogens and vectors can now ...
# 6113  \n\nIn addition to preventative care and nutri...
#
#                                            bibliography  \
# 2105  NDV/HQ266603/Chicken/1992, , , None; MuV/FJ375...
# 1600  The dendritic cell system and its role in immu...
# 731   Genetic economy in 598 picornaviruses: Foot-an...
# 1653  The global distribution and burden of dengue, ...
# 6113  Global, regional, and national levels of neona...
#
#                                             useful_info
# 2105  Supplementary Information An eco-epidemiologic...
# 1600  immunity to pathogens taught by specialized hu...
# 731   The RNA pseudoknots in foot-and-mouth disease ...
# 1653  Public Health Responses to and Challenges for ...
# 6113  a section of the journal Frontiers in Pediatri...

# %% [markdown]
# ## Removing the garbage and storing in lower case

# %%
all_df.useful_info =all_df.useful_info.replace(to_replace='[!"#$%&\'()*+,/:;<=>?@[\\]^_`{|}~]',value=' ',regex=True) #remove punctuation
all_df.useful_info =all_df.useful_info.replace(to_replace='-',value=' ',regex=True)
all_df.useful_info =all_df.useful_info.replace(to_replace='\s+',value=' ',regex=True)    #remove new line
all_df.useful_info =all_df.useful_info.replace(to_replace='  ',value='',regex=True)   #remove double white space  
all_df.useful_info =all_df.useful_info.replace(to_replace="'",value='',regex=True)   


all_df.useful_info =all_df.useful_info.apply(lambda x:x.strip())  # Ltrim and Rtrim of whitespace

all_df['useful_info']=[entry.lower() for entry in all_df['useful_info']] #Lowercase

# %% [markdown]
# # Tokenizing the information

# %%
all_df['info_tokenize']= [word_tokenize(entry) for entry in tqdm(all_df.useful_info)] #Tokenize
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12356.0), HTML(value='')))

# %% [markdown]
# # WordLemmatizer function (that took 20-24 hours) that converts each document words to Lemmatized form

# %%
def wordLemmatizer(data):
    tag_map = defaultdict(lambda : wn.NOUN)
    tag_map['J'] = wn.ADJ
    tag_map['V'] = wn.VERB
    tag_map['R'] = wn.ADV
    clean_k =pd.DataFrame()
    word_Lemmatized = WordNetLemmatizer()
    for index,entry in tqdm(enumerate(data)):
        
        Final_words = []
        for word, tag in pos_tag(entry):
            if len(word)>1 and word not in stopwords.words('english') and word.isalpha():
                word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
                Final_words.append(word_Final)
        
        clean_k.loc[index,'Keyword_final'] = str(Final_words)
    clean_k=clean_k.replace(to_replace ="'", value = '', regex = True)
    clean_k=clean_k.replace(to_replace =" ", value = '', regex = True)
    clean_k=clean_k.replace(to_replace ="\[", value = '', regex = True)
    clean_k=clean_k.replace(to_replace ='\]', value = '', regex = True)
    return clean_k

# %% [markdown]
# ### This is just 10 of the entries to show the data output

# %%
wordLemmatizer(all_df['info_tokenize'][:10])
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
#                                        Keyword_final
# 0  supplementary,information,eco,epidemiological,...
# 1  immunity,pathogen,teach,specialized,human,dend...
# 2  rna,pseudoknots,foot,mouth,disease,virus,dispe...
# 3  public,health,response,challenge,control,dengu...
# 4  section,journal,frontier,pediatrics,review,ped...
# 5  mini,review,function,deubiquitinating,enzyme,n...
# 6  fecal,microbiota,unconjugated,fecal,bile,acid,...
# 7  evaluation,tuberculosis,programme,ningxia,hui,...
# 8  gpi,anchor,single,chain,fv,effective,way,captu...
# 9  healthcare,resource,adjust,vulnerability,towar...

# %% [markdown]
# # Creating Search Engine with Universal Sentence Encoder

# %%
del all_df

all_df = pd.read_csv('/kaggle/input/covid19-allresearchpapers-lemmatizedinformation/COVID-19_AllResearchPapers_LemmatizedInformation.csv')

# %%
print(all_df.shape)
all_df.head()
# Out:
# (13202, 8)
#                                    paper_id  \
# 0  000b7d1517ceebb34e1e3e817695b6de03e2fa78
# 1  00142f93c18b07350be89e96372d240372437ed9
# 2  0015023cc06b5362d332b3baf348d11567ca2fbb
# 3  0022796bb2112abd2e6423ba2d57751db06049fb
# 4  002f09dfc9a1323a15bf72e349d8b733ac97a2aa
#
#                                                title  \
# 0  Supplementary Information An eco-epidemiologic...
# 1  immunity to pathogens taught by specialized hu...
# 2  The RNA pseudoknots in foot-and-mouth disease ...
# 3  Public Health Responses to and Challenges for ...
# 4                                                NaN
#
#                                              authors  \
# 0  Julien Mélade, Nicolas Wieseke 4#, Beza Ramazi...
# 1  Elisabetta Padovan, Marina Cella, Shahram Sale...
# 2  Joseph C Ward, Lidia Lasecka-Dykes, Chris Neil...
# 3  Elvina Viennet, Scott A Ritchie, Craig R Willi...
# 4                                                NaN
#
#                                         affiliations  \
# 0  Julien Mélade (2 rue Maxime Rivière, 97490 Sai...
# 1  Elisabetta Padovan, Marina Cella, Shahram Sale...
# 2  Joseph C Ward, Lidia Lasecka-Dykes, Chris Neil...
# 3  Elvina Viennet (The Australian National Univer...
# 4                                                NaN
#
#                                             abstract  \
# 0                                                NaN
# 1  Abstract\n\nDendritic cells (DCs) are speciali...
# 2  Abstract\n\nword count: 194 22 Text word count...
# 3  Abstract\n\nDengue has a negative impact in lo...
# 4                                                NaN
#
#                                                 text  \
# 0  \n\n- Figure S1 : Phylogeny of all sequences b...
# 1  \n\niNTRODUCTiON Human beings are constantly e...
# 2  \n\nVP3, and VP0 (which is further processed t...
# 3  Introduction\n\nPathogens and vectors can now ...
# 4  \n\nT he modern word camel is derived from the...
#
#                                         bibliography  \
# 0  NDV/HQ266603/Chicken/1992, , , None; MuV/FJ375...
# 1  The dendritic cell system and its role in immu...
# 2  Genetic economy in 598 picornaviruses: Foot-an...
# 3  The global distribution and burden of dengue, ...
# 4  Ancient and modern DNA reveal dynamics of dome...
#
#                                     document_keyword
# 0  supplementary,information,eco,epidemiological,...
# 1  immunity,pathogen,teach,specialized,human,dend...
# 2  rna,pseudoknots,foot,mouth,disease,virus,dispe...
# 3  public,health,response,challenge,control,dengu...
# 4  modern,word,camel,derive,latin,word,camelus,gr...

# %%
#Using Google Universal Sentence Encoder
USEmodel = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
train = USEmodel(all_df.document_keyword)
train_m = tf.train.Checkpoint(v=tf.Variable(train))

train_m.f = tf.function( lambda  x: exported_m.v * x, input_signature=[tf.TensorSpec(shape=None, dtype=tf.float32)])

model = train_m.v.numpy()

# %%
model.shape
# Out:
# (13202, 512)

# %%
def SearchDocument(query,size=10):
    q =[query]
    Q_Train = USEmodel(q)
    
    linear_similarities = linear_kernel(Q_Train, model).flatten() 
    
    Top_index_doc = linear_similarities.argsort()[:-(size+1):-1]
    #print(Top_index_doc)
    linear_similarities.sort()
    find = pd.DataFrame()
    for i,index in enumerate(Top_index_doc):
        find.loc[i,'index'] = str(index)
        find.loc[i,'Paper_ID'] = all_df['paper_id'][index] 
        find.loc[i,'Title'] = all_df['title'][index] 
    for j,simScore in enumerate(linear_similarities[:-(size+1):-1]):
        find.loc[j,'Score'] = simScore
        
    if size==1:
        if find.isnull().values.any():
            print("Query: ",query,".  Title of the Research Paper is missing, Paper ID is:",find.loc[0,'Paper_ID'],"\n")
        else:
            print("Query: ",query,".  Title of the Research Paper:",find.loc[0,'Title'],"\n")
    else:
        return find

# %%
SearchDocument("What is Corona Virus")
# Out:
#    index                                  Paper_ID  \
# 0   3307  40c15d7dfd277d6c181783e56c9c996664c2ba5b
# 1   5634  6c781ec28811214ca0cb25d34a6569f975139a58
# 2   6125  75ebad1e8641e5fe2a51214f4d97742ab59a8dae
# 3   6597  7ec36d372303be7d61deb6a7ef724495a6d90614
# 4   6339  7a054783434b19b3fb546990d25b735659fc851a
# 5    802  105268027d44ab275991e358674462f77223e882
# 6   8589  a59fdbfef640d08b4729060ee005ff35f87c0a40
# 7   8086  9b8a2314912eaeb1c509cf88492f463148a0a9ed
# 8  11999  e840685d875ae1d0d6c08a0176f2151b2765a0d0
# 9  12373  efdf0a3bdc300ce80392b2b52be33728db54a51f
#
#                                                Title     Score
# 0  Preparing intensive care for the next pandemic...  0.255075
# 1  Cryo-electron microscopy structure of a corona...  0.216790
# 2  Environmental Health: A Global Access Science ...  0.207758
# 3  Determination of host proteins composing the m...  0.206065
# 4  High-Affinity Recognition of HIV-1 Frameshift-...  0.204040
# 5  Complete Genome Sequence of the Porcine Epidem...  0.203188
# 6  Viral and bacterial upper respiratory tract in...  0.196590
# 7  The nucleocapsid proteins of mouse hepatitis v...  0.195965
# 8  Proteomics analysis reveals protein expression...  0.194890
# 9  A Novel Gene Underlies Bleomycin-Response Vari...  0.191595

# %% [markdown]
# # All Tasks Queries
#
# I have only shown one title for each query but you can see more by giving the argument
#
#
#
#
# ## What is known about transmission, incubation, and environmental stability?

# %%
SearchDocument("What is known about transmission, incubation, and environmental stability?",1)
SearchDocument("Range of incubation periods for the disease in humans (and how this varies across age and health status) and how long individuals are contagious, even after recovery.",1)
SearchDocument("Prevalence of asymptomatic shedding and transmission (e.g., particularly children).",1)
SearchDocument("Seasonality of transmission.",1)
SearchDocument("Physical science of the coronavirus (e.g., charge distribution, adhesion to hydrophilic/phobic surfaces, environmental survival to inform decontamination efforts for affected areas and provide information about viral shedding).",1)
SearchDocument("Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood).",1)
SearchDocument("Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood).",1)
SearchDocument("Natural history of the virus and shedding of it from an infected person",1)
SearchDocument("Implementation of diagnostics and products to improve clinical processes",1)
SearchDocument("Disease models, including animal models for infection, disease and transmission",1)
SearchDocument("Tools and studies to monitor phenotypic change and potential adaptation of the virus",1)
SearchDocument("Immune response and immunity",1)
SearchDocument("Effectiveness of movement control strategies to prevent secondary transmission in health care and community settings",1)
SearchDocument("Effectiveness of personal protective equipment (PPE) and its usefulness to reduce risk of transmission in health care and community settings",1)
SearchDocument("Role of the environment in transmission",1)
# Out:
# Query:  What is known about transmission, incubation, and environmental stability? .  Title of the Research Paper: microorganisms Zika Outbreak Emergency Preparedness and Response of Malaysian Private Healthcare Professionals: Are They Ready?
#
# Query:  Range of incubation periods for the disease in humans (and how this varies across age and health status) and how long individuals are contagious, even after recovery. .  Title of the Research Paper: Emergence of MERS-CoV in the Middle East: Origins, Transmission, Treatment, and Perspectives
#
# Query:  Prevalence of asymptomatic shedding and transmission (e.g., particularly children). .  Title of the Research Paper: Cyclophilin A Associates with Enterovirus-71 Virus Capsid and Plays an Essential Role in Viral Infection as an Uncoating Regulator
#
# Query:  Seasonality of transmission. .  Title of the Research Paper: Vaccines and Therapeutics Against Hantaviruses
#
# Query:  Physical science of the coronavirus (e.g., charge distribution, adhesion to hydrophilic/phobic surfaces, environmental survival to inform decontamination efforts for affected areas and provide information about viral shedding). .  Title of the Research Paper: Information theory-based algorithm for in silico prediction of PCR products with whole genomic sequences as templates
#
# Query:  Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood). .  Title of the Research Paper: Natural Vertical Transmission of Zika Virus in Larval Aedes aegypti Populations, Morelos, Mexico
#
# Query:  Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood). .  Title of the Research Paper: Natural Vertical Transmission of Zika Virus in Larval Aedes aegypti Populations, Morelos, Mexico
#
# Query:  Natural history of the virus and shedding of it from an infected person .  Title of the Research Paper: Integrated cluster-and case-based surveillance for detecting stage III zoonotic pathogens: an example of Nipah virus surveillance in Bangladesh
#
# Query:  Implementation of diagnostics and products to improve clinical processes .  Title of the Research Paper: Virome heterogeneity and connectivity in waterfowl and shorebird communities
#
# Query:  Disease models, including animal models for infection, disease and transmission .  Title of the Research Paper: Open Forum Infectious Diseases Bioaerosol Sampling in Clinical Settings: A Promising, Noninvasive Approach for Detecting Respiratory Viruses
#
# Query:  Tools and studies to monitor phenotypic change and potential adaptation of the virus .  Title of the Research Paper: Activation of Innate Immune-Response Genes in Little Brown Bats (Myotis lucifugus) Infected with the Fungus Pseudogymnoascus destructans
#
# Query:  Immune response and immunity .  Title of the Research Paper: The Study of Viral RNA Diversity in Bird Samples Using De Novo Designed Multiplex Genus-Specific Primer Panels
#
# Query:  Effectiveness of movement control strategies to prevent secondary transmission in health care and community settings .  Title of the Research Paper: A Conformation-Sensitive Monoclonal Antibody against the A2 Domain of von Willebrand Factor Reduces Its Proteolysis by ADAMTS13
#
# Query:  Effectiveness of personal protective equipment (PPE) and its usefulness to reduce risk of transmission in health care and community settings .  Title of the Research Paper: ELM: enhanced lowest common ancestor based method for detecting a pathogenic virus from a large sequence dataset
#
# Query:  Role of the environment in transmission .  Title of the Research Paper: Gene Expression Networks in the Murine Pulmonary Myocardium Provide Insight into the Pathobiology of Atrial Fibrillation

# %% [markdown]
# ## What do we know about COVID-19 risk factors?

# %%
SearchDocument("What do we know about COVID-19 risk factors?",1)
SearchDocument("Data on potential risks factors",1)
SearchDocument("Smoking, pre-existing pulmonary disease",1)
SearchDocument("Co-infections (determine whether co-existing respiratory/viral infections make the virus more transmissible or virulent) and other co-morbidities",1)
SearchDocument("Neonates and pregnant women",1)
SearchDocument("Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences.",1)
SearchDocument("Transmission dynamics of the virus, including the basic reproductive number, incubation period, serial interval, modes of transmission and environmental factors")
SearchDocument("Severity of disease, including risk of fatality among symptomatic hospitalized patients, and high-risk patient groups",1)
SearchDocument("Susceptibility of populations",1)
SearchDocument("Public health mitigation measures that could be effective for control",1)
# Out:
# Query:  What do we know about COVID-19 risk factors? .  Title of the Research Paper: Advanced Querying Features for Disease Surveillance Systems Advanced Querying Features for Disease Surveillance Systems
#
# Query:  Data on potential risks factors .  Title of the Research Paper: Biochemical Characterization of Middle East Respiratory Syndrome Coronavirus Helicase
#
# Query:  Smoking, pre-existing pulmonary disease .  Title of the Research Paper: Long-Term Prediction of Emergency Department Revenue and Visitor Volume Using Autoregressive Integrated Moving Average Model
#
# Query:  Co-infections (determine whether co-existing respiratory/viral infections make the virus more transmissible or virulent) and other co-morbidities .  Title of the Research Paper: Identification of IFITM1 and IFITM3 in Goose: Gene Structure, Expression Patterns, and Immune Reponses against Tembusu Virus Infection
#
# Query:  Neonates and pregnant women .  Title of the Research Paper: Cell-type specific requirements for thiol/disulfide exchange during HIV-1 entry and infection
#
# Query:  Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences. .  Title of the Research Paper: Emerging Infections: What Have We Learned from SARS?
#
# Query:  Severity of disease, including risk of fatality among symptomatic hospitalized patients, and high-risk patient groups .  Title of the Research Paper: A Virus-Encoded Cell-Cell Fusion Machine Dependent on Surrogate Adhesins
#
# Query:  Susceptibility of populations .  Title of the Research Paper: Combination Therapy Using Chimeric Monoclonal Antibodies Protects Mice from Lethal H5N1 Infection and Prevents Formation of Escape Mutants
#
# Query:  Public health mitigation measures that could be effective for control .  Title of the Research Paper: Primary biliary cirrhosis

# %% [markdown]
# ## What do we know about virus genetics, origin, and evolution?

# %%
SearchDocument("What do we know about virus genetics, origin, and evolution?",1)
SearchDocument("Real-time tracking of whole genomes and a mechanism for coordinating the rapid dissemination of that information to inform the development of diagnostics and therapeutics and to track variations of the virus over time.",1)
SearchDocument("Access to geographic and temporal diverse sample sets to understand geographic distribution and genomic differences, and determine whether there is more than one strain in circulation. Multi-lateral agreements such as the Nagoya Protocol could be leveraged.",1)
SearchDocument("Evidence that livestock could be infected (e.g., field surveillance, genetic sequencing, receptor binding) and serve as a reservoir after the epidemic appears to be over.",1)
SearchDocument("Evidence of whether farmers are infected, and whether farmers could have played a role in the origin.",1)
SearchDocument("Surveillance of mixed wildlife- livestock farms for SARS-CoV-2 and other coronaviruses in Southeast Asia.",1)
SearchDocument("Experimental infections to test host range for this pathogen.",1)
SearchDocument("Animal host(s) and any evidence of continued spill-over to humans",1)
SearchDocument("Socioeconomic and behavioral risk factors for this spill-over",1)
SearchDocument("Sustainable risk reduction strategies",1)
# Out:
# Query:  What do we know about virus genetics, origin, and evolution? .  Title of the Research Paper: Detection of Mycobacterium ulcerans by the Loop Mediated Isothermal Amplification Method
#
# Query:  Real-time tracking of whole genomes and a mechanism for coordinating the rapid dissemination of that information to inform the development of diagnostics and therapeutics and to track variations of the virus over time. .  Title of the Research Paper: Chimeric Pneumoviridae fusion proteins as immunogens to induce cross-neutralizing antibody responses
#
# Query:  Access to geographic and temporal diverse sample sets to understand geographic distribution and genomic differences, and determine whether there is more than one strain in circulation. Multi-lateral agreements such as the Nagoya Protocol could be leveraged. .  Title of the Research Paper: Epidemiological parameter review and comparative dynamics of influenza, respiratory syncytial virus, rhinovirus, human coronavirus, and adenovirus
#
# Query:  Evidence that livestock could be infected (e.g., field surveillance, genetic sequencing, receptor binding) and serve as a reservoir after the epidemic appears to be over. .  Title of the Research Paper: Emergence of MERS-CoV in the Middle East: Origins, Transmission, Treatment, and Perspectives
#
# Query:  Evidence of whether farmers are infected, and whether farmers could have played a role in the origin. .  Title of the Research Paper: Viral communities associated with porcine respiratory disease complex in intensive commercial farms in Sichuan province, China
#
# Query:  Surveillance of mixed wildlife- livestock farms for SARS-CoV-2 and other coronaviruses in Southeast Asia. .  Title of the Research Paper: The Journal of Infectious Diseases The Domestic Ferret (Mustela putorius furo) as a Lethal Infection Model for 3 Species of Ebolavirus
#
# Query:  Experimental infections to test host range for this pathogen. .  Title of the Research Paper: Associations between media use and health information-seeking behavior on vaccinations in South Korea
#
# Query:  Animal host(s) and any evidence of continued spill-over to humans .  Title of the Research Paper: acute Hemorrhagic encephalitis Responding to Combined Decompressive Craniectomy, Intravenous Immunoglobulin, and Corticosteroid therapies: association with Novel RANBP2 Variant
#
# Query:  Socioeconomic and behavioral risk factors for this spill-over .  Title of the Research Paper: Article 140
#
# Query:  Sustainable risk reduction strategies .  Title of the Research Paper: Signatures of malaria- associated pathology revealed by high-resolution whole-blood transcriptomics in a rodent model of malaria OPEN

# %% [markdown]
# ## Key Sub-Questions

# %%
SearchDocument("Are there geographic variations in the rate of COVID-19 spread?",1)
SearchDocument("Are there geographic variations in the mortality rate of COVID-19?",1)
SearchDocument("Is there any evidence to suggest geographic based virus mutations?",1)
# Out:
# Query:  Are there geographic variations in the rate of COVID-19 spread? .  Title of the Research Paper: Characterization of patients transported with extracorporeal respiratory and/or cardiovascular support in the State of São Paulo, Brazil
#
# Query:  Are there geographic variations in the mortality rate of COVID-19? .  Title of the Research Paper is missing, Paper ID is: 691da9d5576aa959e22114a1ebb35548efd276a0
#
# Query:  Is there any evidence to suggest geographic based virus mutations? .  Title of the Research Paper: Characterization of patients transported with extracorporeal respiratory and/or cardiovascular support in the State of São Paulo, Brazil

# %% [markdown]
# ## What do we know about non-pharmaceutical interventions?

# %%
SearchDocument("What do we know about non-pharmaceutical interventions?",1)
SearchDocument("Guidance on ways to scale up NPIs in a more coordinated way (e.g., establish funding, infrastructure and authorities to support real time, authoritative (qualified participants) collaboration with all states to gain consensus on consistent guidance and to mobilize resources to geographic areas where critical shortfalls are identified) to give us time to enhance our health care delivery system capacity to respond to an increase in cases.",1)
SearchDocument("Rapid design and execution of experiments to examine and compare NPIs currently being implemented. DHS Centers for Excellence could potentially be leveraged to conduct these experiments.",1)
SearchDocument("Rapid assessment of the likely efficacy of school closures, travel bans, bans on mass gatherings of various sizes, and other social distancing approaches.",1)
SearchDocument("Methods to control the spread in communities, barriers to compliance and how these vary among different populations.",1)
SearchDocument("Models of potential interventions to predict costs and benefits that take account of such factors as race, income, disability, age, geographic location, immigration status, housing status, employment status, and health insurance status.",1)
SearchDocument("Policy changes necessary to enable the compliance of individuals with limited resources and the underserved with NPIs.",1)
SearchDocument("Research on why people fail to comply with public health advice, even if they want to do so (e.g., social or financial costs may be too high).",1)
SearchDocument("Research on the economic impact of this or any pandemic. This would include identifying policy and programmatic alternatives that lessen/mitigate risks to critical government services, food distribution and supplies, access to critical household supplies, and access to health diagnoses, treatment, and needed care, regardless of ability to pay.",1)
# Out:
# Query:  What do we know about non-pharmaceutical interventions? .  Title of the Research Paper: Faculty of Health Sciences, 9 Department of Science and Technology/National Research Foundation: Vaccine Preventable Diseases, 10 MRC/Wits Rural Public Health and Health Transitions Research Unit (Agincourt), School of Public Health, 11 Department of Internal Medicine, and 12 School of Pathology, Faculty of Health Sciences
#
# Query:  Guidance on ways to scale up NPIs in a more coordinated way (e.g., establish funding, infrastructure and authorities to support real time, authoritative (qualified participants) collaboration with all states to gain consensus on consistent guidance and to mobilize resources to geographic areas where critical shortfalls are identified) to give us time to enhance our health care delivery system capacity to respond to an increase in cases. .  Title of the Research Paper: Pathogenicity and antigenicity of a new variant of Korean nephropathogenic infectious bronchitis virus
#
# Query:  Rapid design and execution of experiments to examine and compare NPIs currently being implemented. DHS Centers for Excellence could potentially be leveraged to conduct these experiments. .  Title of the Research Paper: Identification of climate factors related to human infection with avian influenza A H7N9 and H5N1 viruses in China
#
# Query:  Rapid assessment of the likely efficacy of school closures, travel bans, bans on mass gatherings of various sizes, and other social distancing approaches. .  Title of the Research Paper is missing, Paper ID is: 53f05daf7342372ab5fbeb2f4f5710254fcad893
#
# Query:  Methods to control the spread in communities, barriers to compliance and how these vary among different populations. .  Title of the Research Paper: Dissecting ribosomal particles throughout the kingdoms of life using advanced hybrid mass spectrometry methods
#
# Query:  Models of potential interventions to predict costs and benefits that take account of such factors as race, income, disability, age, geographic location, immigration status, housing status, employment status, and health insurance status. .  Title of the Research Paper is missing, Paper ID is: c1a08ce8f2c5d5311b19822c3df5aa9d25c4d93c
#
# Query:  Policy changes necessary to enable the compliance of individuals with limited resources and the underserved with NPIs. .  Title of the Research Paper: Development and evaluation of a rapid molecular diagnostic test for Zika virus infection by reverse transcription loop-mediated isothermal amplification OPEN
#
# Query:  Research on why people fail to comply with public health advice, even if they want to do so (e.g., social or financial costs may be too high). .  Title of the Research Paper: VIEWPOINTS PaPErS journal of health global Improving health aid for a better planet: The planning, monitoring and evaluation tool (PLaNET)
#
# Query:  Research on the economic impact of this or any pandemic. This would include identifying policy and programmatic alternatives that lessen/mitigate risks to critical government services, food distribution and supplies, access to critical household supplies, and access to health diagnoses, treatment, and needed care, regardless of ability to pay. .  Title of the Research Paper: ORBiT: Oak Ridge biosurveillance toolkit for public health dynamics

# %% [markdown]
# ## What do we know about vaccines and therapeutics?

# %%
SearchDocument("What do we know about vaccines and therapeutics?",1)
SearchDocument("Effectiveness of drugs being developed and tried to treat COVID-19 patients.",1)
SearchDocument("Clinical and bench trials to investigate less common viral inhibitors against COVID-19 such as naproxen, clarithromycin, and minocyclinethat that may exert effects on viral replication.",1)
SearchDocument("Methods evaluating potential complication of Antibody-Dependent Enhancement (ADE) in vaccine recipients.",1)
SearchDocument("Exploration of use of best animal models and their predictive value for a human vaccine.",1)
SearchDocument("Capabilities to discover a therapeutic (not vaccine) for the disease, and clinical effectiveness studies to discover therapeutics, to include antiviral agents.",1)
SearchDocument("Alternative models to aid decision makers in determining how to prioritize and distribute scarce, newly proven therapeutics as production ramps up. This could include identifying approaches for expanding production capacity to ensure equitable and timely distribution to populations in need.",1)
SearchDocument("Efforts targeted at a universal coronavirus vaccine.",1)
SearchDocument("Efforts to develop animal models and standardize challenge studies",1)
SearchDocument("Efforts to develop prophylaxis clinical studies and prioritize in healthcare workers",1)
SearchDocument("Approaches to evaluate risk for enhanced disease after vaccination",1)
SearchDocument("Assays to evaluate vaccine immune response and process development for vaccines, alongside suitable animal models [in conjunction with therapeutics]",1)
# Out:
# Query:  What do we know about vaccines and therapeutics? .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015
#
# Query:  Effectiveness of drugs being developed and tried to treat COVID-19 patients. .  Title of the Research Paper: Hospice utilization during the SARS outbreak in Taiwan
#
# Query:  Clinical and bench trials to investigate less common viral inhibitors against COVID-19 such as naproxen, clarithromycin, and minocyclinethat that may exert effects on viral replication. .  Title of the Research Paper: The effect of corticosteroids on mortality of patients with influenza pneumonia: a systematic review and meta-analysis
#
# Query:  Methods evaluating potential complication of Antibody-Dependent Enhancement (ADE) in vaccine recipients. .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015
#
# Query:  Exploration of use of best animal models and their predictive value for a human vaccine. .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015
#
# Query:  Capabilities to discover a therapeutic (not vaccine) for the disease, and clinical effectiveness studies to discover therapeutics, to include antiviral agents. .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015
#
# Query:  Alternative models to aid decision makers in determining how to prioritize and distribute scarce, newly proven therapeutics as production ramps up. This could include identifying approaches for expanding production capacity to ensure equitable and timely distribution to populations in need. .  Title of the Research Paper: Evaluation of Approaches to Identify the Targets of Cellular Immunity on a Proteome-Wide Scale
#
# Query:  Efforts targeted at a universal coronavirus vaccine. .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015
#
# Query:  Efforts to develop animal models and standardize challenge studies .  Title of the Research Paper: About the Author
#
# Query:  Efforts to develop prophylaxis clinical studies and prioritize in healthcare workers .  Title of the Research Paper: Co-infection with Bartonella henselae and Sarcocystis sp. in a 6-year-old male neutered domestic longhair cat with progressive multifocal neurological signs
#
# Query:  Approaches to evaluate risk for enhanced disease after vaccination .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015
#
# Query:  Assays to evaluate vaccine immune response and process development for vaccines, alongside suitable animal models [in conjunction with therapeutics] .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015

# %% [markdown]
# ## What do we know about diagnostics and surveillance?

# %%
SearchDocument("What do we know about diagnostics and surveillance?",1)
SearchDocument("How widespread current exposure is to be able to make immediate policy recommendations on mitigation measures. Denominators for testing and a mechanism for rapidly sharing that information, including demographics, to the extent possible. Sampling methods to determine asymptomatic disease (e.g., use of serosurveys (such as convalescent samples) and early detection of disease (e.g., use of screening of neutralizing antibodies such as ELISAs).",1)
SearchDocument("Efforts to increase capacity on existing diagnostic platforms and tap into existing surveillance platforms.",1)
SearchDocument("Recruitment, support, and coordination of local expertise and capacity (public, private—commercial, and non-profit, including academic), including legal, ethical, communications, and operational issues.",1)
SearchDocument("National guidance and guidelines about best practices to states (e.g., how states might leverage universities and private laboratories for testing purposes, communications to public health officials and the public).",1)
SearchDocument("Development of a point-of-care test (like a rapid influenza test) and rapid bed-side tests, recognizing the tradeoffs between speed, accessibility, and accuracy.",1)
SearchDocument("Rapid design and execution of targeted surveillance experiments calling for all potential testers using PCR in a defined area to start testing and report to a specific entity. These experiments could aid in collecting longitudinal samples, which are critical to understanding the impact of ad hoc local interventions (which also need to be recorded).",1)
SearchDocument("Separation of assay development issues from instruments, and the role of the private sector to help quickly migrate assays onto those devices.",1)
SearchDocument("Efforts to track the evolution of the virus (i.e., genetic drift or mutations) and avoid locking into specific reagents and surveillance/detection schemes.",1)
SearchDocument("Latency issues and when there is sufficient viral load to detect the pathogen, and understanding of what is needed in terms of biological and environmental sampling.",1)
SearchDocument("Use of diagnostics such as host response markers (e.g., cytokines) to detect early disease or predict severe disease progression, which would be important to understanding best clinical practice and efficacy of therapeutic interventions.",1)
SearchDocument("Policies and protocols for screening and testing.",1)
SearchDocument("Policies to mitigate the effects on supplies associated with mass testing, including swabs and reagents.",1)
SearchDocument("Technology roadmap for diagnostics.",1)
SearchDocument("Barriers to developing and scaling up new diagnostic tests (e.g., market forces), how future coalition and accelerator models (e.g., Coalition for Epidemic Preparedness Innovations) could provide critical funding for diagnostics, and opportunities for a streamlined regulatory environment.",1)
SearchDocument("New platforms and technology (e.g., CRISPR) to improve response times and employ more holistic approaches to COVID-19 and future diseases.",1)
SearchDocument("Coupling genomics and diagnostic testing on a large scale.",1)
SearchDocument("Enhance capabilities for rapid sequencing and bioinformatics to target regions of the genome that will allow specificity for a particular variant.",1)
SearchDocument("Enhance capacity (people, technology, data) for sequencing with advanced analytics for unknown pathogens, and explore capabilities for distinguishing naturally-occurring pathogens from intentional.",1)
SearchDocument("One Health surveillance of humans and potential sources of future spillover or ongoing exposure for this organism and future pathogens, including both evolutionary hosts (e.g., bats) and transmission hosts (e.g., heavily trafficked and farmed wildlife and domestic food and companion species), inclusive of environmental, demographic, and occupational risk factors.",1)
# Out:
# Query:  What do we know about diagnostics and surveillance? .  Title of the Research Paper: Experimentally confirmed toltrazuril resistance in a field isolate of Cystoisospora suis
#
# Query:  How widespread current exposure is to be able to make immediate policy recommendations on mitigation measures. Denominators for testing and a mechanism for rapidly sharing that information, including demographics, to the extent possible. Sampling methods to determine asymptomatic disease (e.g., use of serosurveys (such as convalescent samples) and early detection of disease (e.g., use of screening of neutralizing antibodies such as ELISAs). .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015
#
# Query:  Efforts to increase capacity on existing diagnostic platforms and tap into existing surveillance platforms. .  Title of the Research Paper: Emerging Themes in Epidemiology Mixing patterns and the spread of close-contact infectious diseases
#
# Query:  Recruitment, support, and coordination of local expertise and capacity (public, private—commercial, and non-profit, including academic), including legal, ethical, communications, and operational issues. .  Title of the Research Paper: C19ORF66 broadly escapes viral-induced endonuclease cleavage and restricts Kaposi's 1
#
# Query:  National guidance and guidelines about best practices to states (e.g., how states might leverage universities and private laboratories for testing purposes, communications to public health officials and the public). .  Title of the Research Paper: Long-Term Stability Monitoring of Printed Proteins on Paper-Based Membranes
#
# Query:  Development of a point-of-care test (like a rapid influenza test) and rapid bed-side tests, recognizing the tradeoffs between speed, accessibility, and accuracy. .  Title of the Research Paper: Porcine deltacoronavirus causes diarrhea in various ages of field-infected pigs in China
#
# Query:  Rapid design and execution of targeted surveillance experiments calling for all potential testers using PCR in a defined area to start testing and report to a specific entity. These experiments could aid in collecting longitudinal samples, which are critical to understanding the impact of ad hoc local interventions (which also need to be recorded). .  Title of the Research Paper: Supplementary Information Stabilized coronavirus spikes are resistant to conformational changes induced by receptor recognition or proteolysis
#
# Query:  Separation of assay development issues from instruments, and the role of the private sector to help quickly migrate assays onto those devices. .  Title of the Research Paper: Comparison of loop-mediated isothermal amplification assay and smear microscopy with culture for the diagnostic accuracy of tuberculosis
#
# Query:  Efforts to track the evolution of the virus (i.e., genetic drift or mutations) and avoid locking into specific reagents and surveillance/detection schemes. .  Title of the Research Paper: Detection of Mycobacterium ulcerans by the Loop Mediated Isothermal Amplification Method
#
# Query:  Latency issues and when there is sufficient viral load to detect the pathogen, and understanding of what is needed in terms of biological and environmental sampling. .  Title of the Research Paper: Genetic and antigenic characterization of influenza A(H3N2) in Cameroon during the 2014-2016 influenza seasons
#
# Query:  Use of diagnostics such as host response markers (e.g., cytokines) to detect early disease or predict severe disease progression, which would be important to understanding best clinical practice and efficacy of therapeutic interventions. .  Title of the Research Paper: Electronic Supplementary Materials Spatial Expansions and Travelling Waves of Rabies in Vampire Bats
#
# Query:  Policies and protocols for screening and testing. .  Title of the Research Paper: Frequent Asymptomatic Respiratory Syncytial Virus Infections During an Epidemic in a Rural Kenyan Household Cohort
#
# Query:  Policies to mitigate the effects on supplies associated with mass testing, including swabs and reagents. .  Title of the Research Paper: molecules Evaluation of the Inhibitory Effects of (E)-1-(2-hydroxy-4,6-dimethoxyphenyl)-3- (naphthalen-1-yl)prop-2-en-1-one (DiNap), a Natural Product Analog, on the Replication of Type 2 PRRSV In Vitro and In Vivo
#
# Query:  Technology roadmap for diagnostics. .  Title of the Research Paper: Severe Acute Respiratory Syndrome: Temporal Stability and Geographic Variation in Case-Fatality Rates and Doubling Times
#
# Query:  Barriers to developing and scaling up new diagnostic tests (e.g., market forces), how future coalition and accelerator models (e.g., Coalition for Epidemic Preparedness Innovations) could provide critical funding for diagnostics, and opportunities for a streamlined regulatory environment. .  Title of the Research Paper: INDUCTION OF MONOCYTE PROCOAGULANT ACTIVITY BY MURINE HEPATITIS VIRUS TYPE 3 PARALLELS DISEASE SUSCEPTIBILITY IN MICE*
#
# Query:  New platforms and technology (e.g., CRISPR) to improve response times and employ more holistic approaches to COVID-19 and future diseases. .  Title of the Research Paper: Enrichment post-library preparation enhances the sensitivity of high- throughput sequencing-based detection and characterization of viruses from complex samples
#
# Query:  Coupling genomics and diagnostic testing on a large scale. .  Title of the Research Paper: Myricetin: A Dietary Molecule with Diverse Biological Activities
#
# Query:  Enhance capabilities for rapid sequencing and bioinformatics to target regions of the genome that will allow specificity for a particular variant. .  Title of the Research Paper: Improving the estimation of the death rate of infected cells from time course data during the acute phase of virus infections: application to acute HIV-1 infection in a humanized mouse model
#
# Query:  Enhance capacity (people, technology, data) for sequencing with advanced analytics for unknown pathogens, and explore capabilities for distinguishing naturally-occurring pathogens from intentional. .  Title of the Research Paper: Molecular characterization of US-like and Asian non-S INDEL strains of porcine epidemic diarrhea virus (PEDV) that circulated in Japan during 2013-2016 and PEDVs collected from recurrent outbreaks
#
# Query:  One Health surveillance of humans and potential sources of future spillover or ongoing exposure for this organism and future pathogens, including both evolutionary hosts (e.g., bats) and transmission hosts (e.g., heavily trafficked and farmed wildlife and domestic food and companion species), inclusive of environmental, demographic, and occupational risk factors. .  Title of the Research Paper: Lung epithelial cells have virus-specific and shared gene expression responses 1 to infection by diverse respiratory viruses 2 3

# %% [markdown]
# ## What has been published about information sharing and inter-sectoral collaboration?

# %%
SearchDocument("What has been published about information sharing and inter-sectoral collaboration?",1)
SearchDocument("Methods for coordinating data-gathering with standardized nomenclature.",1)
SearchDocument("Sharing response information among planners, providers, and others.",1)
SearchDocument("Understanding and mitigating barriers to information-sharing.",1)
SearchDocument("How to recruit, support, and coordinate local (non-Federal) expertise and capacity relevant to public health emergency response (public, private, commercial and non-profit, including academic).",1)
SearchDocument("Integration of federal/state/local public health surveillance systems.",1)
SearchDocument("Value of investments in baseline public health response infrastructure preparedness",1)
SearchDocument("Modes of communicating with target high-risk populations (elderly, health care workers).",1)
SearchDocument("Risk communication and guidelines that are easy to understand and follow (include targeting at risk populations’ families too).",1)
SearchDocument("Communication that indicates potential risk of disease to all population groups.",1)
SearchDocument("Misunderstanding around containment and mitigation.",1)
SearchDocument("Action plan to mitigate gaps and problems of inequity in the Nation’s public health capability, capacity, and funding to ensure all citizens in need are supported and can access information, surveillance, and treatment.",1)
SearchDocument("Measures to reach marginalized and disadvantaged populations.",1)
SearchDocument("Data systems and research priorities and agendas incorporate attention to the needs and circumstances of disadvantaged populations and underrepresented minorities.",1)
SearchDocument("Mitigating threats to incarcerated people from COVID-19, assuring access to information, prevention, diagnosis, and treatment.",1)
SearchDocument("Understanding coverage policies (barriers and opportunities) related to testing, treatment, and care",1)
# Out:
# Query:  What has been published about information sharing and inter-sectoral collaboration? .  Title of the Research Paper: Supplementary material: Estimating the distance to an epidemic threshold
#
# Query:  Methods for coordinating data-gathering with standardized nomenclature. .  Title of the Research Paper: Role of extracellular matrix and microenvironment in regulation of tumor growth and LAR-mediated invasion in glioblastoma
#
# Query:  Sharing response information among planners, providers, and others. .  Title of the Research Paper: Efficient Replication of the Novel Human Betacoronavirus EMC on Primary Human Epithelium Highlights Its Zoonotic Potential
#
# Query:  Understanding and mitigating barriers to information-sharing. .  Title of the Research Paper: Enrichment post-library preparation enhances the sensitivity of high- throughput sequencing-based detection and characterization of viruses from complex samples
#
# Query:  How to recruit, support, and coordinate local (non-Federal) expertise and capacity relevant to public health emergency response (public, private, commercial and non-profit, including academic). .  Title of the Research Paper: Evolutionary and genetic analysis of the VP2 gene of canine parvovirus
#
# Query:  Integration of federal/state/local public health surveillance systems. .  Title of the Research Paper: Long-Term Stability Monitoring of Printed Proteins on Paper-Based Membranes
#
# Query:  Value of investments in baseline public health response infrastructure preparedness .  Title of the Research Paper: UMR1300 Biology, Epidemiology and Risk Analysis in Animal Health
#
# Query:  Modes of communicating with target high-risk populations (elderly, health care workers). .  Title of the Research Paper: Combination Therapy Using Chimeric Monoclonal Antibodies Protects Mice from Lethal H5N1 Infection and Prevents Formation of Escape Mutants
#
# Query:  Risk communication and guidelines that are easy to understand and follow (include targeting at risk populations’ families too). .  Title of the Research Paper: Virology Journal Virus detection and identification using random multiplex (RT)-PCR with 3'-locked random primers
#
# Query:  Communication that indicates potential risk of disease to all population groups. .  Title of the Research Paper: Experimental infection of dogs with a feline endogenous retrovirus RD-114
#
# Query:  Misunderstanding around containment and mitigation. .  Title of the Research Paper: Supplementary Information An eco-epidemiological study of Morbilli-related paramyxovirus infection in Madagascar bats reveals host-switching as the dominant macro-evolutionary mechanism
#
# Query:  Action plan to mitigate gaps and problems of inequity in the Nation’s public health capability, capacity, and funding to ensure all citizens in need are supported and can access information, surveillance, and treatment. .  Title of the Research Paper: Enhanced Autophagy Contributes to Reduced Viral Infection in Black Flying Fox Cells
#
# Query:  Measures to reach marginalized and disadvantaged populations. .  Title of the Research Paper: Can long-term historical data from electronic medical records improve surveillance for epidemics of acute respiratory infections? A systematic evaluation
#
# Query:  Data systems and research priorities and agendas incorporate attention to the needs and circumstances of disadvantaged populations and underrepresented minorities. .  Title of the Research Paper: Antigenic and Pathogenic Characteristics of QX-Type Avian Infectious Bronchitis Virus Strains Isolated in Southwestern China
#
# Query:  Mitigating threats to incarcerated people from COVID-19, assuring access to information, prevention, diagnosis, and treatment. .  Title of the Research Paper: Identification of Ellagic Acid from Plant Rhodiola rosea L. as an Anti-Ebola Virus Entry Inhibitor
#
# Query:  Understanding coverage policies (barriers and opportunities) related to testing, treatment, and care .  Title of the Research Paper: Cytokine production pattern of T lymphocytes in neonatal arterial ischemic stroke during the first month of life-a case study

# %% [markdown]
# ## What has been published about ethical and social science considerations?

# %%
SearchDocument("Efforts to articulate and translate existing ethical principles and standards to salient issues in COVID-2019",1)
SearchDocument("Efforts to embed ethics across all thematic areas, engage with novel ethical issues that arise and coordinate to minimize duplication of oversight",1)
SearchDocument("Efforts to support sustained education, access, and capacity building in the area of ethics",1)
SearchDocument("Efforts to establish a team at WHO that will be integrated within multidisciplinary research and operational platforms and that will connect with existing and expanded global networks of social sciences.",1)
SearchDocument("Efforts to develop qualitative assessment frameworks to systematically collect information related to local barriers and enablers for the uptake and adherence to public health measures for prevention and control. This includes the rapid identification of the secondary impacts of these measures. (e.g. use of surgical masks, modification of health seeking behaviors for SRH, school closures)",1)
SearchDocument("Efforts to identify how the burden of responding to the outbreak and implementing public health measures affects the physical and psychological health of those providing care for Covid-19 patients and identify the immediate needs that must be addressed.",1)
SearchDocument("Efforts to identify the underlying drivers of fear, anxiety and stigma that fuel misinformation and rumor, particularly through social media.",1)
# Out:
# Query:  Efforts to articulate and translate existing ethical principles and standards to salient issues in COVID-2019 .  Title of the Research Paper: Supplemental information: MERS-CoV recombination: implications about the reservoir and potential for adaptation
#
# Query:  Efforts to embed ethics across all thematic areas, engage with novel ethical issues that arise and coordinate to minimize duplication of oversight .  Title of the Research Paper: What Have We Learned About Middle East Respiratory Syndrome Coronavirus Emergence in Humans? A Systematic Literature Review
#
# Query:  Efforts to support sustained education, access, and capacity building in the area of ethics .  Title of the Research Paper: Identification of Ellagic Acid from Plant Rhodiola rosea L. as an Anti-Ebola Virus Entry Inhibitor
#
# Query:  Efforts to establish a team at WHO that will be integrated within multidisciplinary research and operational platforms and that will connect with existing and expanded global networks of social sciences. .  Title of the Research Paper: TMPRSS2 and MSPL Facilitate Trypsin-Independent Porcine Epidemic Diarrhea Virus Replication in Vero Cells
#
# Query:  Efforts to develop qualitative assessment frameworks to systematically collect information related to local barriers and enablers for the uptake and adherence to public health measures for prevention and control. This includes the rapid identification of the secondary impacts of these measures. (e.g. use of surgical masks, modification of health seeking behaviors for SRH, school closures) .  Title of the Research Paper is missing, Paper ID is: 44a3cf460f8ce1edf8df41d96242735398773acd
#
# Query:  Efforts to identify how the burden of responding to the outbreak and implementing public health measures affects the physical and psychological health of those providing care for Covid-19 patients and identify the immediate needs that must be addressed. .  Title of the Research Paper: Can free open access resources strengthen knowledge-based emerging public health priorities, policies and programs in Africa? [version 1; referees: 2 approved]
#
# Query:  Efforts to identify the underlying drivers of fear, anxiety and stigma that fuel misinformation and rumor, particularly through social media. .  Title of the Research Paper is missing, Paper ID is: 6ad14ceec74dc9b3d3dc6db7fc319b9dc22dc546

# %% [markdown]
# ## What has been published about medical care?

# %%
SearchDocument("What has been published about medical care?",1)
SearchDocument("Resources to support skilled nursing facilities and long term care facilities.",1)
SearchDocument("Mobilization of surge medical staff to address shortages in overwhelmed communities",1)
SearchDocument("Age-adjusted mortality data for Acute Respiratory Distress Syndrome (ARDS) with/without other organ failure – particularly for viral etiologies",1)
SearchDocument("Extracorporeal membrane oxygenation (ECMO) outcomes data of COVID-19 patients",1)
SearchDocument("Outcomes data for COVID-19 after mechanical ventilation adjusted for age.",1)
SearchDocument("Knowledge of the frequency, manifestations, and course of extrapulmonary manifestations of COVID-19, including, but not limited to, possible cardiomyopathy and cardiac arrest.",1)
SearchDocument("Application of regulatory standards (e.g., EUA, CLIA) and ability to adapt care to crisis standards of care level.",1)
SearchDocument("Approaches for encouraging and facilitating the production of elastomeric respirators, which can save thousands of N95 masks.",1)
SearchDocument("Best telemedicine practices, barriers and faciitators, and specific actions to remove/expand them within and across state boundaries.",1)
SearchDocument("Guidance on the simple things people can do at home to take care of sick people and manage disease.",1)
SearchDocument("Oral medications that might potentially work.",1)
SearchDocument("Use of AI in real-time health care delivery to evaluate interventions, risk factors, and outcomes in a way that could not be done manually.",1)
SearchDocument("Best practices and critical challenges and innovative solutions and technologies in hospital flow and organization, workforce protection, workforce allocation, community-based support resources, payment, and supply chain management to enhance capacity, efficiency, and outcomes.",1)
SearchDocument("Efforts to define the natural history of disease to inform clinical care, public health interventions, infection prevention control, transmission, and clinical trials",1)
SearchDocument("Efforts to develop a core clinical outcome set to maximize usability of data across a range of trials",1)
SearchDocument("Efforts to determine adjunctive and supportive interventions that can improve the clinical outcomes of infected patients (e.g. steroids, high flow oxygen)",1)
# Out:
# Query:  What has been published about medical care? .  Title of the Research Paper: Complete Genome Sequence of a Porcine Epidemic Diarrhea Virus from a Novel Outbreak in Belgium, January 2015
#
# Query:  Resources to support skilled nursing facilities and long term care facilities. .  Title of the Research Paper: Multicentre randomised controlled trial to investigate the usefulness of continuous pneumatic regulation of tracheal cuff pressure for reducing ventilator-associated pneumonia in mechanically ventilated severe trauma patients: the AGATE study protocol
#
# Query:  Mobilization of surge medical staff to address shortages in overwhelmed communities .  Title of the Research Paper: BMC Public Health Establishing a nationwide emergency department-based syndromic surveillance system for better public health responses in Taiwan
#
# Query:  Age-adjusted mortality data for Acute Respiratory Distress Syndrome (ARDS) with/without other organ failure – particularly for viral etiologies .  Title of the Research Paper: A Virus-Encoded Cell-Cell Fusion Machine Dependent on Surrogate Adhesins
#
# Query:  Extracorporeal membrane oxygenation (ECMO) outcomes data of COVID-19 patients .  Title of the Research Paper is missing, Paper ID is: 86d0072187f1f6d092ce296b13d3cb6fae55e70c
#
# Query:  Outcomes data for COVID-19 after mechanical ventilation adjusted for age. .  Title of the Research Paper: A Single Native Ganglioside GM 1 -Binding Site Is Sufficient for Cholera Toxin To Bind to Cells and Complete the Intoxication Pathway
#
# Query:  Knowledge of the frequency, manifestations, and course of extrapulmonary manifestations of COVID-19, including, but not limited to, possible cardiomyopathy and cardiac arrest. .  Title of the Research Paper: Bat Coronavirus in Brazil Related to Appalachian Ridge and Porcine Epidemic Diarrhea Viruses Tandem Repeat Insertion in African Swine Fever Virus, Russia, 2012
#
# Query:  Application of regulatory standards (e.g., EUA, CLIA) and ability to adapt care to crisis standards of care level. .  Title of the Research Paper: Procalcitonin guidance for reduction of antibiotic use in patients hospitalized with severe acute exacerbations of asthma: a randomized controlled study with 12-month follow-up
#
# Query:  Approaches for encouraging and facilitating the production of elastomeric respirators, which can save thousands of N95 masks. .  Title of the Research Paper: LETTER Simultaneous and systematic analysis of cellular and viral gene expression during Enterovirus 71-induced host shutoff
#
# Query:  Best telemedicine practices, barriers and faciitators, and specific actions to remove/expand them within and across state boundaries. .  Title of the Research Paper: Human intestinal tract serves as an alternative infection route for Middle East respiratory syndrome coronavirus
#
# Query:  Guidance on the simple things people can do at home to take care of sick people and manage disease. .  Title of the Research Paper: Hospice utilization during the SARS outbreak in Taiwan
#
# Query:  Oral medications that might potentially work. .  Title of the Research Paper: Yukie KATAYAMA 2) , Mami OBA 2) , Naomi NISHIURA 2) , Yukiko SASSA 2) , Tsutomu OMATSU 2) , Tetsuya FURUYA 2,4) , Satoshi KOYAMA 5)
#
# Query:  Use of AI in real-time health care delivery to evaluate interventions, risk factors, and outcomes in a way that could not be done manually. .  Title of the Research Paper: Virus Adaptation by Manipulation of Host's Gene Expression
#
# Query:  Best practices and critical challenges and innovative solutions and technologies in hospital flow and organization, workforce protection, workforce allocation, community-based support resources, payment, and supply chain management to enhance capacity, efficiency, and outcomes. .  Title of the Research Paper: Clinical and virological factors associated with gastrointestinal symptoms in patients with acute respiratory infection: a two-year prospective study in general practice medicine
#
# Query:  Efforts to define the natural history of disease to inform clinical care, public health interventions, infection prevention control, transmission, and clinical trials .  Title of the Research Paper: Inhibition of Zika Virus Replication by Silvestrol
#
# Query:  Efforts to develop a core clinical outcome set to maximize usability of data across a range of trials .  Title of the Research Paper: Etiology and Clinical Characterization of Respiratory Virus Infections in Adult Patients Attending an Emergency Department in Beijing
#
# Query:  Efforts to determine adjunctive and supportive interventions that can improve the clinical outcomes of infected patients (e.g. steroids, high flow oxygen) .  Title of the Research Paper: Alternative splicing of CD200 is regulated by an exonic splicing enhancer and SF2/ASF

# %% [markdown]
# # LightGBM Baseline

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/lish-moa/sample_submission.csv
# /kaggle/input/lish-moa/train_targets_scored.csv
# /kaggle/input/lish-moa/train_targets_nonscored.csv
# /kaggle/input/lish-moa/train_features.csv
# /kaggle/input/lish-moa/test_features.csv

# %% [markdown]
# ## Read data

# %%
train = pd.read_csv('/kaggle/input/lish-moa/train_features.csv')

train.shape
# Out:
# (23814, 876)

# %%
train_target = pd.read_csv('/kaggle/input/lish-moa/train_targets_scored.csv')

train_target.shape
# Out:
# (23814, 207)

# %%
test = pd.read_csv('/kaggle/input/lish-moa/test_features.csv')

test.shape
# Out:
# (3982, 876)

# %% [markdown]
# ## Check agonist / antagonist

# %%
antagonists = []

for column in train_target.columns:
    if column.endswith('_agonist'):
        antagonist = column.replace('_agonist', '_antagonist')
        if antagonist in train_target.columns:
            antagonists.append((column, antagonist))

antagonists
# Out:
# [('acetylcholine_receptor_agonist', 'acetylcholine_receptor_antagonist'),
#  ('adenosine_receptor_agonist', 'adenosine_receptor_antagonist'),
#  ('adrenergic_receptor_agonist', 'adrenergic_receptor_antagonist'),
#  ('androgen_receptor_agonist', 'androgen_receptor_antagonist'),
#  ('cannabinoid_receptor_agonist', 'cannabinoid_receptor_antagonist'),
#  ('dopamine_receptor_agonist', 'dopamine_receptor_antagonist'),
#  ('estrogen_receptor_agonist', 'estrogen_receptor_antagonist'),
#  ('gaba_receptor_agonist', 'gaba_receptor_antagonist'),
#  ('glutamate_receptor_agonist', 'glutamate_receptor_antagonist'),
#  ('histamine_receptor_agonist', 'histamine_receptor_antagonist'),
#  ('opioid_receptor_agonist', 'opioid_receptor_antagonist'),
#  ('ppar_receptor_agonist', 'ppar_receptor_antagonist'),
#  ('progesterone_receptor_agonist', 'progesterone_receptor_antagonist'),
#  ('retinoid_receptor_agonist', 'retinoid_receptor_antagonist'),
#  ('serotonin_receptor_agonist', 'serotonin_receptor_antagonist'),
#  ('sigma_receptor_agonist', 'sigma_receptor_antagonist'),
#  ('tlr_agonist', 'tlr_antagonist'),
#  ('trpv_agonist', 'trpv_antagonist')]

# %% [markdown]
# List agonist / antagonist pairs where both features have 1

# %%
for pair in antagonists:
    n = train_target[(train_target[pair[0]] == 1) & (train_target[pair[1]] == 1)].shape[0]
    if n > 0:
        print(pair[0], '-', pair[1])
        print('Number of cases:', n)
# Out:
# gaba_receptor_agonist - gaba_receptor_antagonist
# Number of cases: 6
# progesterone_receptor_agonist - progesterone_receptor_antagonist
# Number of cases: 6
# serotonin_receptor_agonist - serotonin_receptor_antagonist
# Number of cases: 7
# sigma_receptor_agonist - sigma_receptor_antagonist
# Number of cases: 6

# %% [markdown]
# In general agonist and antagonist should not have 1 at the same time

# %% [markdown]
# ## Feature engineering

# %%
# From https://www.kaggle.com/carlmcbrideellis/moa-setting-ctl-vehicle-0-improves-score

train.at[train['cp_type'].str.contains('ctl_vehicle'),train.filter(regex='-.*').columns] = 0.0

test.at[test['cp_type'].str.contains('ctl_vehicle'),test.filter(regex='-.*').columns] = 0.0

# %% [markdown]
# ## OHE

# %%
train_size = train.shape[0]

traintest = pd.concat([train, test])

traintest = pd.concat([traintest, pd.get_dummies(traintest['cp_type'], prefix='cp_type')], axis=1)
traintest = pd.concat([traintest, pd.get_dummies(traintest['cp_time'], prefix='cp_time')], axis=1)
traintest = pd.concat([traintest, pd.get_dummies(traintest['cp_dose'], prefix='cp_dose')], axis=1)

traintest = traintest.drop(['cp_type', 'cp_time', 'cp_dose'], axis=1)

train = traintest[:train_size]
test  = traintest[train_size:]

del traintest

# %%
train.shape
# Out:
# (23814, 880)

# %% [markdown]
# ## Prepare x, y

# %%
x_train = train.drop('sig_id', axis=1)

y_train = train_target.drop('sig_id', axis=1)

x_test = test.drop('sig_id', axis=1)

# %% [markdown]
# ## Feature selection

# %%
# from https://www.kaggle.com/pavelvpster/moa-keras-optuna-rfecv

# 500
selected_features = ['g-0', 'g-1', 'g-2', 'g-3', 'g-4', 'g-5', 'g-6', 'g-7', 'g-8', 'g-9', 'g-10', 'g-11', 'g-12', 'g-13', 'g-14', 'g-15', 'g-16', 'g-17', 'g-18', 'g-19', 'g-20', 'g-21', 'g-22', 'g-23', 'g-24', 'g-25', 'g-26', 'g-27', 'g-28', 'g-29', 'g-30', 'g-31', 'g-32', 'g-33', 'g-34', 'g-35', 'g-36', 'g-37', 'g-38', 'g-39', 'g-40', 'g-41', 'g-42', 'g-43', 'g-44', 'g-45', 'g-46', 'g-47', 'g-48', 'g-49', 'g-50', 'g-51', 'g-52', 'g-53', 'g-54', 'g-55', 'g-56', 'g-57', 'g-58', 'g-59', 'g-60', 'g-61', 'g-62', 'g-63', 'g-64', 'g-65', 'g-66', 'g-67', 'g-68', 'g-69', 'g-70', 'g-71', 'g-72', 'g-73', 'g-74', 'g-75', 'g-76', 'g-77', 'g-78', 'g-79', 'g-80', 'g-81', 'g-82', 'g-83', 'g-84', 'g-85', 'g-86', 'g-87', 'g-88', 'g-89', 'g-90', 'g-91', 'g-92', 'g-93', 'g-94', 'g-95', 'g-96', 'g-97', 'g-98', 'g-99', 'g-100', 'g-101', 'g-102', 'g-103', 'g-104', 'g-105', 'g-106', 'g-107', 'g-108', 'g-109', 'g-110', 'g-111', 'g-112', 'g-113', 'g-114', 'g-115', 'g-116', 'g-117', 'g-118', 'g-121', 'g-122', 'g-123', 'g-125', 'g-126', 'g-127', 'g-128', 'g-129', 'g-130', 'g-131', 'g-132', 'g-133', 'g-139', 'g-144', 'g-149', 'g-152', 'g-153', 'g-154', 'g-155', 'g-158', 'g-161', 'g-162', 'g-165', 'g-166', 'g-167', 'g-168', 'g-169', 'g-170', 'g-171', 'g-172', 'g-173', 'g-174', 'g-175', 'g-176', 'g-177', 'g-178', 'g-179', 'g-180', 'g-182', 'g-185', 'g-188', 'g-189', 'g-191', 'g-192', 'g-193', 'g-194', 'g-195', 'g-196', 'g-197', 'g-198', 'g-199', 'g-200', 'g-201', 'g-202', 'g-203', 'g-204', 'g-209', 'g-211', 'g-213', 'g-214', 'g-217', 'g-220', 'g-221', 'g-222', 'g-223', 'g-225', 'g-226', 'g-229', 'g-233', 'g-239', 'g-240', 'g-243', 'g-244', 'g-246', 'g-247', 'g-250', 'g-254', 'g-255', 'g-256', 'g-257', 'g-259', 'g-261', 'g-262', 'g-265', 'g-269', 'g-270', 'g-271', 'g-273', 'g-279', 'g-282', 'g-284', 'g-286', 'g-289', 'g-292', 'g-294', 'g-295', 'g-298', 'g-299', 'g-300', 'g-303', 'g-306', 'g-310', 'g-311', 'g-312', 'g-314', 'g-316', 'g-317', 'g-318', 'g-320', 'g-321', 'g-323', 'g-326', 'g-327', 'g-328', 'g-332', 'g-333', 'g-335', 'g-339', 'g-340', 'g-341', 'g-346', 'g-347', 'g-351', 'g-353', 'g-355', 'g-357', 'g-360', 'g-364', 'g-365', 'g-370', 'g-375', 'g-383', 'g-385', 'g-388', 'g-389', 'g-390', 'g-391', 'g-392', 'g-399', 'g-401', 'g-402', 'g-403', 'g-404', 'g-409', 'g-417', 'g-423', 'g-424', 'g-425', 'g-426', 'g-428', 'g-429', 'g-430', 'g-431', 'g-433', 'g-434', 'g-438', 'g-439', 'g-440', 'g-441', 'g-443', 'g-444', 'g-445', 'g-446', 'g-447', 'g-448', 'g-449', 'g-450', 'g-451', 'g-452', 'g-453', 'g-454', 'g-455', 'g-456', 'g-460', 'g-461', 'g-463', 'g-465', 'g-467', 'g-470', 'g-473', 'g-474', 'g-475', 'g-476', 'g-481', 'g-483', 'g-485', 'g-486', 'g-489', 'g-490', 'g-495', 'g-500', 'g-501', 'g-502', 'g-504', 'g-509', 'g-513', 'g-516', 'g-517', 'g-518', 'g-527', 'g-531', 'g-535', 'g-540', 'g-542', 'g-543', 'g-544', 'g-547', 'g-548', 'g-549', 'g-552', 'g-556', 'g-558', 'g-562', 'g-566', 'g-571', 'g-572', 'g-573', 'g-574', 'g-578', 'g-584', 'g-585', 'g-590', 'g-592', 'g-595', 'g-596', 'g-600', 'g-602', 'g-603', 'g-605', 'g-606', 'g-611', 'g-612', 'g-615', 'g-617', 'g-618', 'g-619', 'g-620', 'g-623', 'g-624', 'g-625', 'g-626', 'g-627', 'g-628', 'g-629', 'g-630', 'g-631', 'g-632', 'g-633', 'g-634', 'g-635', 'g-636', 'g-637', 'g-638', 'g-639', 'g-640', 'g-643', 'g-645', 'g-646', 'g-648', 'g-651', 'g-654', 'g-657', 'g-658', 'g-659', 'g-660', 'g-661', 'g-662', 'g-663', 'g-664', 'g-665', 'g-666', 'g-668', 'g-670', 'g-672', 'g-673', 'g-674', 'g-675', 'g-677', 'g-678', 'g-679', 'g-685', 'g-689', 'g-695', 'g-697', 'g-698', 'g-699', 'g-701', 'g-702', 'g-703', 'g-704', 'g-707', 'g-709', 'g-710', 'g-712', 'g-713', 'g-714', 'g-715', 'g-721', 'g-722', 'g-724', 'g-725', 'g-726', 'g-734', 'g-736', 'g-737', 'g-740', 'g-742', 'g-743', 'g-745', 'g-747', 'g-750', 'g-751', 'g-752', 'g-753', 'g-756', 'g-757', 'g-758', 'g-759', 'g-760', 'g-761', 'g-762', 'g-763', 'g-764', 'g-766', 'g-767', 'g-768', 'g-769', 'g-770', 'g-771', 'c-0', 'c-1', 'c-2', 'c-3', 'c-4', 'c-5', 'c-11', 'c-12', 'c-14', 'c-19', 'c-20', 'c-21', 'c-22', 'c-23', 'c-25', 'c-27', 'c-32', 'c-35', 'c-36', 'c-37', 'c-40', 'c-47', 'c-54', 'c-55', 'c-57', 'c-58', 'c-61', 'c-62', 'c-63', 'c-65', 'c-66', 'c-71', 'c-74', 'c-75', 'c-77', 'c-78', 'c-79', 'c-80', 'c-81', 'c-82', 'c-83', 'c-84', 'c-85', 'c-86', 'c-87', 'c-88', 'c-89', 'c-90', 'c-91', 'c-92', 'c-93', 'c-97']

# %%
x_train = x_train[selected_features]

x_test = x_test[selected_features]

# %% [markdown]
# ## LightGBM

# %%
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import log_loss

import lightgbm as lgb

# %%
def fit_predict(n_splits, params, x_train, y_train, x_test):
    
    oof = np.zeros(x_train.shape[0])
    
    y_preds = []
    
    cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    for train_idx, valid_idx in cv.split(x_train, y_train):
        
        x_train_train = x_train.iloc[train_idx]
        y_train_train = y_train.iloc[train_idx]
        x_train_valid = x_train.iloc[valid_idx]
        y_train_valid = y_train.iloc[valid_idx]

        lgb_train = lgb.Dataset(data=x_train_train.astype('float32'), label=y_train_train.astype('float32'))
        lgb_valid = lgb.Dataset(data=x_train_valid.astype('float32'), label=y_train_valid.astype('float32'))

        estimator = lgb.train(params, lgb_train, 10000, valid_sets=lgb_valid,
                              early_stopping_rounds=25, verbose_eval=0)

        oof_part = estimator.predict(x_train_valid, num_iteration=estimator.best_iteration)
        oof[valid_idx] = oof_part
        
        if x_test is not None:
            y_part = estimator.predict(x_test, num_iteration=estimator.best_iteration)
            y_preds.append(y_part)
        
    score = log_loss(y_train, oof)
    print('LogLoss Score:', score)
    
    y_pred = np.mean(y_preds, axis=0)
    
    return y_pred, oof, score

# %% [markdown]
# ## Optuna

# %%
import optuna


columns_to_try = [
    'glutamate_receptor_antagonist',
    'dna_inhibitor',
    'serotonin_receptor_antagonist',
    'dopamine_receptor_antagonist',
    'cyclooxygenase_inhibitor'
]

def objective(trial):
    
    params = {
        'objective': 'binary',
        'metric': 'binary_logloss',
        'boosting_type': 'gbdt',
        'boost_from_average': True,
        'num_threads': 4,
        'random_state': 42,
        
        'num_leaves': trial.suggest_int('num_leaves', 10, 1000),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 200),
        'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.001, 0.1),
        'max_depth': trial.suggest_int('max_depth', 1, 100),
        'bagging_fraction': trial.suggest_loguniform('bagging_fraction', .5, .99),
        'feature_fraction': trial.suggest_loguniform('feature_fraction', .5, .99),
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 0.1, 2),
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 0.1, 2)
    }
    
    scores = []
    for column in columns_to_try:
        _, _, score = fit_predict(3, params, x_train, y_train[column], None)
        scores.append(score)
    
    return np.mean(scores)


# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=100)

# %%
# study.best_trial

# %%
columns_1 = [
    '5-alpha_reductase_inhibitor',
    '11-beta-hsd1_inhibitor',
    'adenylyl_cyclase_activator',
    'aldehyde_dehydrogenase_inhibitor',
    'ampk_activator',
    'analgesic',
    'antiarrhythmic',
    'anticonvulsant',
    'antifungal',
    'antihistamine',
    'antimalarial',
    'antiviral',
    'atm_kinase_inhibitor',
    'atp-sensitive_potassium_channel_antagonist',
    'atp_synthase_inhibitor',
    'atr_kinase_inhibitor',
    'autotaxin_inhibitor',
    'bacterial_membrane_integrity_inhibitor',
    'calcineurin_inhibitor',
    'caspase_activator',
    'catechol_o_methyltransferase_inhibitor',
    'cck_receptor_antagonist',
    'chk_inhibitor',
    'coagulation_factor_inhibitor',
    'diuretic',
    'elastase_inhibitor',
    'erbb2_inhibitor',
    'farnesyltransferase_inhibitor',
    'focal_adhesion_kinase_inhibitor',
    'free_radical_scavenger',
    'fungal_squalene_epoxidase_inhibitor',
    'glutamate_inhibitor',
    'gonadotropin_receptor_agonist',
    'histone_lysine_demethylase_inhibitor',
    'hsp_inhibitor',
    'ikk_inhibitor',
    'laxative',
    'leukotriene_inhibitor',
    'lipase_inhibitor',
    'lxr_agonist',
    'mdm_inhibitor',
    'monoacylglycerol_lipase_inhibitor',
    'monopolar_spindle_1_kinase_inhibitor',
    'nicotinic_receptor_agonist',
    'nitric_oxide_production_inhibitor',
    'norepinephrine_reuptake_inhibitor',
    'nrf2_activator',
    'pdk_inhibitor',
    'progesterone_receptor_antagonist',
    'proteasome_inhibitor',
    'protein_phosphatase_inhibitor',
    'protein_tyrosine_kinase_inhibitor',
    'ras_gtpase_inhibitor',
    'retinoid_receptor_antagonist',
    'steroid',
    'syk_inhibitor',
    'tgf-beta_receptor_inhibitor',
    'thrombin_inhibitor',
    'tlr_antagonist',
    'transient_receptor_potential_channel_antagonist',
    'tropomyosin_receptor_kinase_inhibitor',
    'trpv_agonist',
    'ubiquitin_specific_protease_inhibitor',
    'vitamin_d_receptor_agonist'
]

# %%
params_1 = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting_type': 'gbdt',
    'boost_from_average': True,
    'num_threads': 4,
    'random_state': 42,
    
    'learning_rate': 0.01,
    
    # from Optuna result in Version 7
    'num_leaves': 212,
    'min_data_in_leaf': 92,
    'min_child_weight': 0.0010123391323415569,
    'max_depth': 35,
    'bagging_fraction': 0.7968351296815959,
    'feature_fraction': 0.7556374471450119,
    'lambda_l1': 0.23497601594060086,
    'lambda_l2': 0.15889208239516134
}

params_1
# Out:
# {'objective': 'binary',
#  'metric': 'binary_logloss',
#  'boosting_type': 'gbdt',
#  'boost_from_average': True,
#  'num_threads': 4,
#  'random_state': 42,
#  'learning_rate': 0.01,
#  'num_leaves': 212,
#  'min_data_in_leaf': 92,
#  'min_child_weight': 0.0010123391323415569,
#  'max_depth': 35,
#  'bagging_fraction': 0.7968351296815959,
#  'feature_fraction': 0.7556374471450119,
#  'lambda_l1': 0.23497601594060086,
#  'lambda_l2': 0.15889208239516134}

# %%
params_2 = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting_type': 'gbdt',
    'boost_from_average': True,
    'num_threads': 4,
    'random_state': 42,
    
    'learning_rate': 0.01,
    
    # from Optuna result in Version 15
    'num_leaves': 106,
    'min_data_in_leaf': 176,
    'min_child_weight': 0.08961015929882983,
    'max_depth': 3,
    'bagging_fraction': 0.5672004837454858,
    'feature_fraction': 0.611628226420641,
    'lambda_l1': 1.293005852529098,
    'lambda_l2': 1.6012450757049599
}

params_2
# Out:
# {'objective': 'binary',
#  'metric': 'binary_logloss',
#  'boosting_type': 'gbdt',
#  'boost_from_average': True,
#  'num_threads': 4,
#  'random_state': 42,
#  'learning_rate': 0.01,
#  'num_leaves': 106,
#  'min_data_in_leaf': 176,
#  'min_child_weight': 0.08961015929882983,
#  'max_depth': 3,
#  'bagging_fraction': 0.5672004837454858,
#  'feature_fraction': 0.611628226420641,
#  'lambda_l1': 1.293005852529098,
#  'lambda_l2': 1.6012450757049599}

# %% [markdown]
# ## 206 models

# %%
n_splits = 3

y_pred = pd.DataFrame()

oof = pd.DataFrame()

scores = []

for column in y_train.columns:
    print('Column:', column)
    
    if column in columns_1:
        print('Params 1')
        params = params_1
    else:
        print('Params 2')
        params = params_2
    
    y_pred[column], oof[column], score = fit_predict(n_splits, params, x_train, y_train[column], x_test)
    
    scores.append(score)
# Out:
# Column: 5-alpha_reductase_inhibitor
# Params 1
# LogLoss Score: 0.005725280470700635
# Column: 11-beta-hsd1_inhibitor
# Params 1
# LogLoss Score: 0.0061497506499338505
# Column: acat_inhibitor
# Params 2
# LogLoss Score: 0.00795683567434108
# Column: acetylcholine_receptor_agonist
# Params 2
# LogLoss Score: 0.04484739564022455
# Column: acetylcholine_receptor_antagonist
# Params 2
# LogLoss Score: 0.06514522008765823
# Column: acetylcholinesterase_inhibitor
# Params 2
# LogLoss Score: 0.020452570324543052
# Column: adenosine_receptor_agonist
# Params 2
# LogLoss Score: 0.015581759697515149
# Column: adenosine_receptor_antagonist
# Params 2
# LogLoss Score: 0.025587798209756086
# Column: adenylyl_cyclase_activator
# Params 1
# LogLoss Score: 0.002667152226639159
# Column: adrenergic_receptor_agonist
# Params 2
# LogLoss Score: 0.05739618581579899
# Column: adrenergic_receptor_antagonist
# Params 2
# LogLoss Score: 0.07484533952813219
# Column: akt_inhibitor
# Params 2
# LogLoss Score: 0.013256787913477563
# Column: aldehyde_dehydrogenase_inhibitor
# Params 1
# LogLoss Score: 0.0019782864117284435
# Column: alk_inhibitor
# Params 2
# LogLoss Score: 0.010800891697424821
# Column: ampk_activator
# Params 1
# LogLoss Score: 0.0043303432140923415
# Column: analgesic
# Params 1
# LogLoss Score: 0.004318567077661945
# Column: androgen_receptor_agonist
# Params 2
# LogLoss Score: 0.014286472202134715
# Column: androgen_receptor_antagonist
# Params 2
# LogLoss Score: 0.024336837644135724
# Column: anesthetic_-_local
# Params 2
# LogLoss Score: 0.022296018382535594
# Column: angiogenesis_inhibitor
# Params 2
# LogLoss Score: 0.011204902256200997
# Column: angiotensin_receptor_antagonist
# Params 2
# LogLoss Score: 0.011498192101928
# Column: anti-inflammatory
# Params 2
# LogLoss Score: 0.0191056100059258
# Column: antiarrhythmic
# Params 1
# LogLoss Score: 0.002314996355875802
# Column: antibiotic
# Params 2
# LogLoss Score: 0.012367562286094376
# Column: anticonvulsant
# Params 1
# LogLoss Score: 0.004313367734865535
# Column: antifungal
# Params 1
# LogLoss Score: 0.004522980778558814
# Column: antihistamine
# Params 1
# LogLoss Score: 0.0042905963596488106
# Column: antimalarial
# Params 1
# LogLoss Score: 0.006011298699216079
# Column: antioxidant
# Params 2
# LogLoss Score: 0.019968158552715682
# Column: antiprotozoal
# Params 2
# LogLoss Score: 0.01123137422128904
# Column: antiviral
# Params 1
# LogLoss Score: 0.007545046343833174
# Column: apoptosis_stimulant
# Params 2
# LogLoss Score: 0.01446137298723445
# Column: aromatase_inhibitor
# Params 2
# LogLoss Score: 0.014186275889224187
# Column: atm_kinase_inhibitor
# Params 1
# LogLoss Score: 0.0020557511231431088
# Column: atp-sensitive_potassium_channel_antagonist
# Params 1
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# LogLoss Score: 0.0014606792262975635
# Column: atp_synthase_inhibitor
# Params 1
# LogLoss Score: 0.001580833969156658
# Column: atpase_inhibitor
# Params 2
# LogLoss Score: 0.020716869415834886
# Column: atr_kinase_inhibitor
# Params 1
# LogLoss Score: 0.004831796303212654
# Column: aurora_kinase_inhibitor
# Params 2
# LogLoss Score: 0.013578135791061319
# Column: autotaxin_inhibitor
# Params 1
# LogLoss Score: 0.0022464207389122502
# Column: bacterial_30s_ribosomal_subunit_inhibitor
# Params 2
# LogLoss Score: 0.01743924115138867
# Column: bacterial_50s_ribosomal_subunit_inhibitor
# Params 2
# LogLoss Score: 0.022092449773072592
# Column: bacterial_antifolate
# Params 2
# LogLoss Score: 0.010761338794741981
# Column: bacterial_cell_wall_synthesis_inhibitor
# Params 2
# LogLoss Score: 0.04558893277795598
# Column: bacterial_dna_gyrase_inhibitor
# Params 2
# LogLoss Score: 0.024110423331685067
# Column: bacterial_dna_inhibitor
# Params 2
# LogLoss Score: 0.030175215530667425
# Column: bacterial_membrane_integrity_inhibitor
# Params 1
# LogLoss Score: 0.0016460292993857907
# Column: bcl_inhibitor
# Params 2
# LogLoss Score: 0.008184933990156733
# Column: bcr-abl_inhibitor
# Params 2
# LogLoss Score: 0.009947376369379608
# Column: benzodiazepine_receptor_agonist
# Params 2
# LogLoss Score: 0.018539956154227717
# Column: beta_amyloid_inhibitor
# Params 2
# LogLoss Score: 0.00793606405009757
# Column: bromodomain_inhibitor
# Params 2
# LogLoss Score: 0.013010609358991667
# Column: btk_inhibitor
# Params 2
# LogLoss Score: 0.008415169813122526
# Column: calcineurin_inhibitor
# Params 1
# LogLoss Score: 0.002339416541244569
# Column: calcium_channel_blocker
# Params 2
# LogLoss Score: 0.06202518859511907
# Column: cannabinoid_receptor_agonist
# Params 2
# LogLoss Score: 0.012752000808901596
# Column: cannabinoid_receptor_antagonist
# Params 2
# LogLoss Score: 0.016212916966455364
# Column: carbonic_anhydrase_inhibitor
# Params 2
# LogLoss Score: 0.011318385390205575
# Column: casein_kinase_inhibitor
# Params 2
# LogLoss Score: 0.010753120786798711
# Column: caspase_activator
# Params 1
# LogLoss Score: 0.006187721861485413
# Column: catechol_o_methyltransferase_inhibitor
# Params 1
# LogLoss Score: 0.004298486329428288
# Column: cc_chemokine_receptor_antagonist
# Params 2
# LogLoss Score: 0.027229644522351194
# Column: cck_receptor_antagonist
# Params 1
# LogLoss Score: 0.006146156587992738
# Column: cdk_inhibitor
# Params 2
# LogLoss Score: 0.02063028032613926
# Column: chelating_agent
# Params 2
# LogLoss Score: 0.01563445578230114
# Column: chk_inhibitor
# Params 1
# LogLoss Score: 0.0046502443534736345
# Column: chloride_channel_blocker
# Params 2
# LogLoss Score: 0.01281820750992188
# Column: cholesterol_inhibitor
# Params 2
# LogLoss Score: 0.01437119516637442
# Column: cholinergic_receptor_antagonist
# Params 2
# LogLoss Score: 0.015903917211287373
# Column: coagulation_factor_inhibitor
# Params 1
# LogLoss Score: 0.0023390106012612325
# Column: corticosteroid_agonist
# Params 2
# LogLoss Score: 0.008318950708963588
# Column: cyclooxygenase_inhibitor
# Params 2
# LogLoss Score: 0.0872894651389911
# Column: cytochrome_p450_inhibitor
# Params 2
# LogLoss Score: 0.02713182295576965
# Column: dihydrofolate_reductase_inhibitor
# Params 2
# LogLoss Score: 0.00924271170568202
# Column: dipeptidyl_peptidase_inhibitor
# Params 2
# LogLoss Score: 0.008133025486556346
# Column: diuretic
# Params 1
# LogLoss Score: 0.0022836686119760584
# Column: dna_alkylating_agent
# Params 2
# LogLoss Score: 0.013838659944755662
# Column: dna_inhibitor
# Params 2
# LogLoss Score: 0.07802402778369434
# Column: dopamine_receptor_agonist
# Params 2
# LogLoss Score: 0.0313547003965114
# Column: dopamine_receptor_antagonist
# Params 2
# LogLoss Score: 0.08278063216670899
# Column: egfr_inhibitor
# Params 2
# LogLoss Score: 0.023315212438891182
# Column: elastase_inhibitor
# Params 1
# LogLoss Score: 0.0023238259462103486
# Column: erbb2_inhibitor
# Params 1
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# LogLoss Score: 0.0014607891283261545
# Column: estrogen_receptor_agonist
# Params 2
# LogLoss Score: 0.038409064293651686
# Column: estrogen_receptor_antagonist
# Params 2
# LogLoss Score: 0.014235001947226588
# Column: faah_inhibitor
# Params 2
# LogLoss Score: 0.01044760179085699
# Column: farnesyltransferase_inhibitor
# Params 1
# LogLoss Score: 0.004838690488929141
# Column: fatty_acid_receptor_agonist
# Params 2
# LogLoss Score: 0.008068947695552978
# Column: fgfr_inhibitor
# Params 2
# LogLoss Score: 0.011240774179622545
# Column: flt3_inhibitor
# Params 2
# LogLoss Score: 0.026476575728974855
# Column: focal_adhesion_kinase_inhibitor
# Params 1
# LogLoss Score: 0.004121802195266828
# Column: free_radical_scavenger
# Params 1
# LogLoss Score: 0.0061607538322223845
# Column: fungal_squalene_epoxidase_inhibitor
# Params 1
# LogLoss Score: 0.007520155307022114
# Column: gaba_receptor_agonist
# Params 2
# LogLoss Score: 0.02801512047163333
# Column: gaba_receptor_antagonist
# Params 2
# LogLoss Score: 0.04009984728735114
# Column: gamma_secretase_inhibitor
# Params 2
# LogLoss Score: 0.011069153448612357
# Column: glucocorticoid_receptor_agonist
# Params 2
# LogLoss Score: 0.013651982833670763
# Column: glutamate_inhibitor
# Params 1
# LogLoss Score: 0.0045753491902954906
# Column: glutamate_receptor_agonist
# Params 2
# LogLoss Score: 0.02085581088955229
# Column: glutamate_receptor_antagonist
# Params 2
# LogLoss Score: 0.07699477792574515
# Column: gonadotropin_receptor_agonist
# Params 1
# LogLoss Score: 0.006153294300829067
# Column: gsk_inhibitor
# Params 2
# LogLoss Score: 0.010903481850025931
# Column: hcv_inhibitor
# Params 2
# LogLoss Score: 0.020229757691228496
# Column: hdac_inhibitor
# Params 2
# LogLoss Score: 0.01199937455899313
# Column: histamine_receptor_agonist
# Params 2
# LogLoss Score: 0.017019635276855478
# Column: histamine_receptor_antagonist
# Params 2
# LogLoss Score: 0.05455087273137221
# Column: histone_lysine_demethylase_inhibitor
# Params 1
# LogLoss Score: 0.006608081396445442
# Column: histone_lysine_methyltransferase_inhibitor
# Params 2
# LogLoss Score: 0.00898421189155884
# Column: hiv_inhibitor
# Params 2
# LogLoss Score: 0.020373734549955627
# Column: hmgcr_inhibitor
# Params 2
# LogLoss Score: 0.014938822150523173
# Column: hsp_inhibitor
# Params 1
# LogLoss Score: 0.0073356665737793975
# Column: igf-1_inhibitor
# Params 2
# LogLoss Score: 0.009736676693940814
# Column: ikk_inhibitor
# Params 1
# LogLoss Score: 0.00734440208302321
# Column: imidazoline_receptor_agonist
# Params 2
# LogLoss Score: 0.009919581499927634
# Column: immunosuppressant
# Params 2
# LogLoss Score: 0.018486647701905824
# Column: insulin_secretagogue
# Params 2
# LogLoss Score: 0.009555937067512777
# Column: insulin_sensitizer
# Params 2
# LogLoss Score: 0.01313949272332965
# Column: integrin_inhibitor
# Params 2
# LogLoss Score: 0.01281043051750152
# Column: jak_inhibitor
# Params 2
# LogLoss Score: 0.014894957060271417
# Column: kit_inhibitor
# Params 2
# LogLoss Score: 0.020214809553415293
# Column: laxative
# Params 1
# LogLoss Score: 0.0023397149255396403
# Column: leukotriene_inhibitor
# Params 1
# LogLoss Score: 0.0023401741417321416
# Column: leukotriene_receptor_antagonist
# Params 2
# LogLoss Score: 0.017781336428850478
# Column: lipase_inhibitor
# Params 1
# LogLoss Score: 0.004320425863340994
# Column: lipoxygenase_inhibitor
# Params 2
# LogLoss Score: 0.01720642468034737
# Column: lxr_agonist
# Params 1
# LogLoss Score: 0.002163181644227009
# Column: mdm_inhibitor
# Params 1
# LogLoss Score: 0.006383104590275458
# Column: mek_inhibitor
# Params 2
# LogLoss Score: 0.00892194361379846
# Column: membrane_integrity_inhibitor
# Params 2
# LogLoss Score: 0.020670968009455233
# Column: mineralocorticoid_receptor_antagonist
# Params 2
# LogLoss Score: 0.0079682734549058
# Column: monoacylglycerol_lipase_inhibitor
# Params 1
# LogLoss Score: 0.004238781756289318
# Column: monoamine_oxidase_inhibitor
# Params 2
# LogLoss Score: 0.023396046959181235
# Column: monopolar_spindle_1_kinase_inhibitor
# Params 1
# LogLoss Score: 0.005905391555573014
# Column: mtor_inhibitor
# Params 2
# LogLoss Score: 0.017267240646229264
# Column: mucolytic_agent
# Params 2
# LogLoss Score: 0.01426411990348529
# Column: neuropeptide_receptor_antagonist
# Params 2
# LogLoss Score: 0.011277683208134322
# Column: nfkb_inhibitor
# Params 2
# LogLoss Score: 0.03146321802635986
# Column: nicotinic_receptor_agonist
# Params 1
# LogLoss Score: 0.002340197174471648
# Column: nitric_oxide_donor
# Params 2
# LogLoss Score: 0.008478091928223108
# Column: nitric_oxide_production_inhibitor
# Params 1
# LogLoss Score: 0.004050748210803799
# Column: nitric_oxide_synthase_inhibitor
# Params 2
# LogLoss Score: 0.008513428545216613
# Column: norepinephrine_reuptake_inhibitor
# Params 1
# LogLoss Score: 0.0026424806124031586
# Column: nrf2_activator
# Params 1
# LogLoss Score: 0.004566697123317435
# Column: opioid_receptor_agonist
# Params 2
# LogLoss Score: 0.01768482166067428
# Column: opioid_receptor_antagonist
# Params 2
# LogLoss Score: 0.02610145764980202
# Column: orexin_receptor_antagonist
# Params 2
# LogLoss Score: 0.011466244950024145
# Column: p38_mapk_inhibitor
# Params 2
# LogLoss Score: 0.010891655397833464
# Column: p-glycoprotein_inhibitor
# Params 2
# LogLoss Score: 0.007829720600989899
# Column: parp_inhibitor
# Params 2
# LogLoss Score: 0.016146910738683844
# Column: pdgfr_inhibitor
# Params 2
# LogLoss Score: 0.02360587826517974
# Column: pdk_inhibitor
# Params 1
# LogLoss Score: 0.006134106319063436
# Column: phosphodiesterase_inhibitor
# Params 2
# LogLoss Score: 0.05824284267753673
# Column: phospholipase_inhibitor
# Params 2
# LogLoss Score: 0.00791783678557599
# Column: pi3k_inhibitor
# Params 2
# LogLoss Score: 0.028078764677541394
# Column: pkc_inhibitor
# Params 2
# LogLoss Score: 0.009546312278836351
# Column: potassium_channel_activator
# Params 2
# LogLoss Score: 0.015648107208049444
# Column: potassium_channel_antagonist
# Params 2
# LogLoss Score: 0.026280557464778226
# Column: ppar_receptor_agonist
# Params 2
# LogLoss Score: 0.024659904527365148
# Column: ppar_receptor_antagonist
# Params 2
# LogLoss Score: 0.009494050607490735
# Column: progesterone_receptor_agonist
# Params 2
# LogLoss Score: 0.028765493939993114
# Column: progesterone_receptor_antagonist
# Params 1
# LogLoss Score: 0.0057686107590182115
# Column: prostaglandin_inhibitor
# Params 2
# LogLoss Score: 0.011208901546188265
# Column: prostanoid_receptor_antagonist
# Params 2
# LogLoss Score: 0.022761526667110784
# Column: proteasome_inhibitor
# Params 1
# LogLoss Score: 0.0015448870387989437
# Column: protein_kinase_inhibitor
# Params 2
# LogLoss Score: 0.013982956735668026
# Column: protein_phosphatase_inhibitor
# Params 1
# LogLoss Score: 0.002038580338764567
# Column: protein_synthesis_inhibitor
# Params 2
# LogLoss Score: 0.0238943776286762
# Column: protein_tyrosine_kinase_inhibitor
# Params 1
# LogLoss Score: 0.006478086770410343
# Column: radiopaque_medium
# Params 2
# LogLoss Score: 0.01646005091343834
# Column: raf_inhibitor
# Params 2
# LogLoss Score: 0.008125774805817904
# Column: ras_gtpase_inhibitor
# Params 1
# LogLoss Score: 0.004301305992584412
# Column: retinoid_receptor_agonist
# Params 2
# LogLoss Score: 0.014172989110200615
# Column: retinoid_receptor_antagonist
# Params 1
# LogLoss Score: 0.002291368626566114
# Column: rho_associated_kinase_inhibitor
# Params 2
# LogLoss Score: 0.009500521682228443
# Column: ribonucleoside_reductase_inhibitor
# Params 2
# LogLoss Score: 0.008919417928189887
# Column: rna_polymerase_inhibitor
# Params 2
# LogLoss Score: 0.00815276249937537
# Column: serotonin_receptor_agonist
# Params 2
# LogLoss Score: 0.05402079966135905
# Column: serotonin_receptor_antagonist
# Params 2
# LogLoss Score: 0.08189277299376799
# Column: serotonin_reuptake_inhibitor
# Params 2
# LogLoss Score: 0.013443270212368961
# Column: sigma_receptor_agonist
# Params 2
# LogLoss Score: 0.011277546681521635
# Column: sigma_receptor_antagonist
# Params 2
# LogLoss Score: 0.011110279055260871
# Column: smoothened_receptor_antagonist
# Params 2
# LogLoss Score: 0.00810118502253492
# Column: sodium_channel_inhibitor
# Params 2
# LogLoss Score: 0.06054539699606076
# Column: sphingosine_receptor_agonist
# Params 2
# LogLoss Score: 0.008100035532834282
# Column: src_inhibitor
# Params 2
# LogLoss Score: 0.016012738141931694
# Column: steroid
# Params 1
# LogLoss Score: 0.002334687808417667
# Column: syk_inhibitor
# Params 1
# LogLoss Score: 0.005851358080496775
# Column: tachykinin_antagonist
# Params 2
# LogLoss Score: 0.017310342726568503
# Column: tgf-beta_receptor_inhibitor
# Params 1
# LogLoss Score: 0.0027412895585194994
# Column: thrombin_inhibitor
# Params 1
# LogLoss Score: 0.006411729575422184
# Column: thymidylate_synthase_inhibitor
# Params 2
# LogLoss Score: 0.010478360633365214
# Column: tlr_agonist
# Params 2
# LogLoss Score: 0.009599061447581159
# Column: tlr_antagonist
# Params 1
# LogLoss Score: 0.0026910493863736506
# Column: tnf_inhibitor
# Params 2
# LogLoss Score: 0.010804068458969715
# Column: topoisomerase_inhibitor
# Params 2
# LogLoss Score: 0.01617762708832596
# Column: transient_receptor_potential_channel_antagonist
# Params 1
# LogLoss Score: 0.006178182735280052
# Column: tropomyosin_receptor_kinase_inhibitor
# Params 1
# LogLoss Score: 0.0023085824266266346
# Column: trpv_agonist
# Params 1
# LogLoss Score: 0.007066596821269705
# Column: trpv_antagonist
# Params 2
# LogLoss Score: 0.014368244997146002
# Column: tubulin_inhibitor
# Params 2
# LogLoss Score: 0.022823337143907146
# Column: tyrosine_kinase_inhibitor
# Params 2
# LogLoss Score: 0.02005819828655447
# Column: ubiquitin_specific_protease_inhibitor
# Params 1
# LogLoss Score: 0.0023403071925768445
# Column: vegfr_inhibitor
# Params 2
# LogLoss Score: 0.02728052319662914
# Column: vitamin_b
# Params 2
# LogLoss Score: 0.00841027541068324
# Column: vitamin_d_receptor_agonist
# Params 1
# LogLoss Score: 0.006904968276645455
# Column: wnt_inhibitor
# Params 2
# LogLoss Score: 0.009658457247777334

# %%
np.mean(scores)
# Out:
# 0.01585090438896742

# %% [markdown]
# ## Second level models

# %% [markdown]
# To predict each label it uses features + predictions of other labels from first level models

# %%
x_train_2 = pd.concat([x_train, oof], axis=1)

x_train_2.shape
# Out:
# (23814, 706)

# %%
x_test_2 = pd.concat([x_test, y_pred], axis=1)

x_test_2.shape
# Out:
# (3982, 706)

# %%
import optuna


columns_to_try = [
    'antiviral',
    'dna_inhibitor'
]

def objective(trial):
    
    params = {
        'objective': 'binary',
        'metric': 'binary_logloss',
        'boosting_type': 'gbdt',
        'boost_from_average': True,
        'num_threads': 4,
        'random_state': 42,
        
        'num_leaves': trial.suggest_int('num_leaves', 10, 1000),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 200),
        'min_child_weight': trial.suggest_loguniform('min_child_weight', 0.001, 0.1),
        'max_depth': trial.suggest_int('max_depth', 1, 100),
        'bagging_fraction': trial.suggest_loguniform('bagging_fraction', .5, .99),
        'feature_fraction': trial.suggest_loguniform('feature_fraction', .5, .99),
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 0.1, 2),
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 0.1, 2)
    }
    
    scores = []
    for column in columns_to_try:
        _, _, score = fit_predict(3, params, x_train_2.drop(column, axis=1), y_train[column], None)
        scores.append(score)
    
    return np.mean(scores)


# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=100)

# %%
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting_type': 'gbdt',
    'boost_from_average': True,
    'num_threads': 4,
    'random_state': 42,
    
    'learning_rate': 0.01,

    # from Optuna result in Version 21
    'num_leaves': 204,
    'min_data_in_leaf': 109,
    'min_child_weight': 0.0022436199989295377,
    'max_depth': 3,
    'bagging_fraction': 0.8715885202491637,
    'feature_fraction': 0.6187304356714799,
    'lambda_l1': 1.4290015875633637,
    'lambda_l2': 0.7289605844855718
}

params
# Out:
# {'objective': 'binary',
#  'metric': 'binary_logloss',
#  'boosting_type': 'gbdt',
#  'boost_from_average': True,
#  'num_threads': 4,
#  'random_state': 42,
#  'learning_rate': 0.01,
#  'num_leaves': 204,
#  'min_data_in_leaf': 109,
#  'min_child_weight': 0.0022436199989295377,
#  'max_depth': 3,
#  'bagging_fraction': 0.8715885202491637,
#  'feature_fraction': 0.6187304356714799,
#  'lambda_l1': 1.4290015875633637,
#  'lambda_l2': 0.7289605844855718}

# %%
y_pred_2 = pd.DataFrame()

oof_2 = pd.DataFrame()

scores_2 = []

for column in y_train.columns:
    print('Column:', column)
    
    y_pred_2[column], oof_2[column], score = fit_predict(n_splits, params, x_train_2.drop(column, axis=1),
                                                         y_train[column], x_test_2.drop(column, axis=1))
    
    scores_2.append(score)
# Out:
# Column: 5-alpha_reductase_inhibitor
# LogLoss Score: 0.005543716144939268
# Column: 11-beta-hsd1_inhibitor
# LogLoss Score: 0.006171503148469828
# Column: acat_inhibitor
# LogLoss Score: 0.007962988543691955
# Column: acetylcholine_receptor_agonist
# LogLoss Score: 0.044466643898128204
# Column: acetylcholine_receptor_antagonist
# LogLoss Score: 0.06437306359269343
# Column: acetylcholinesterase_inhibitor
# LogLoss Score: 0.02022670032308998
# Column: adenosine_receptor_agonist
# LogLoss Score: 0.015411221068272127
# Column: adenosine_receptor_antagonist
# LogLoss Score: 0.025577647034948414
# Column: adenylyl_cyclase_activator
# LogLoss Score: 0.0026594439538182506
# Column: adrenergic_receptor_agonist
# LogLoss Score: 0.05692153343444525
# Column: adrenergic_receptor_antagonist
# LogLoss Score: 0.07490479052750074
# Column: akt_inhibitor
# LogLoss Score: 0.0133409099557202
# Column: aldehyde_dehydrogenase_inhibitor
# LogLoss Score: 0.0019589729566250667
# Column: alk_inhibitor
# LogLoss Score: 0.010687307787629453
# Column: ampk_activator
# LogLoss Score: 0.004283791876682785
# Column: analgesic
# LogLoss Score: 0.004301705060734309
# Column: androgen_receptor_agonist
# LogLoss Score: 0.014280420633988584
# Column: androgen_receptor_antagonist
# LogLoss Score: 0.02420731391700573
# Column: anesthetic_-_local
# LogLoss Score: 0.022289062206984442
# Column: angiogenesis_inhibitor
# LogLoss Score: 0.011088755490015135
# Column: angiotensin_receptor_antagonist
# LogLoss Score: 0.011442014497444038
# Column: anti-inflammatory
# LogLoss Score: 0.01909257318203027
# Column: antiarrhythmic
# LogLoss Score: 0.0023141723915774434
# Column: antibiotic
# LogLoss Score: 0.012465336769011936
# Column: anticonvulsant
# LogLoss Score: 0.004324389059949058
# Column: antifungal
# LogLoss Score: 0.004361607975546199
# Column: antihistamine
# LogLoss Score: 0.004254115523302376
# Column: antimalarial
# LogLoss Score: 0.006026331778737606
# Column: antioxidant
# LogLoss Score: 0.02007394905880622
# Column: antiprotozoal
# LogLoss Score: 0.011151302672869245
# Column: antiviral
# LogLoss Score: 0.007379470121018955
# Column: apoptosis_stimulant
# LogLoss Score: 0.014609677088875476
# Column: aromatase_inhibitor
# LogLoss Score: 0.014224520305502048
# Column: atm_kinase_inhibitor
# LogLoss Score: 0.0021167880171127774
# Column: atp-sensitive_potassium_channel_antagonist
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# LogLoss Score: 0.001492349369559618
# Column: atp_synthase_inhibitor
# LogLoss Score: 0.001864697286372027
# Column: atpase_inhibitor
# LogLoss Score: 0.02104881704803276
# Column: atr_kinase_inhibitor
# LogLoss Score: 0.004436925437143058
# Column: aurora_kinase_inhibitor
# LogLoss Score: 0.013899628984482937
# Column: autotaxin_inhibitor
# LogLoss Score: 0.002178098235830867
# Column: bacterial_30s_ribosomal_subunit_inhibitor
# LogLoss Score: 0.017342913007045806
# Column: bacterial_50s_ribosomal_subunit_inhibitor
# LogLoss Score: 0.0220598931929167
# Column: bacterial_antifolate
# LogLoss Score: 0.010864717991875076
# Column: bacterial_cell_wall_synthesis_inhibitor
# LogLoss Score: 0.045548795615782824
# Column: bacterial_dna_gyrase_inhibitor
# LogLoss Score: 0.02403660861191721
# Column: bacterial_dna_inhibitor
# LogLoss Score: 0.029788403378739288
# Column: bacterial_membrane_integrity_inhibitor
# LogLoss Score: 0.00179222374835449
# Column: bcl_inhibitor
# LogLoss Score: 0.008578653438707496
# Column: bcr-abl_inhibitor
# LogLoss Score: 0.009541635899361401
# Column: benzodiazepine_receptor_agonist
# LogLoss Score: 0.018471118441690467
# Column: beta_amyloid_inhibitor
# LogLoss Score: 0.007896954329996453
# Column: bromodomain_inhibitor
# LogLoss Score: 0.013020726021719099
# Column: btk_inhibitor
# LogLoss Score: 0.008253262460160254
# Column: calcineurin_inhibitor
# LogLoss Score: 0.0022818313989052806
# Column: calcium_channel_blocker
# LogLoss Score: 0.06182259565718943
# Column: cannabinoid_receptor_agonist
# LogLoss Score: 0.01260612360825734
# Column: cannabinoid_receptor_antagonist
# LogLoss Score: 0.016149198094974882
# Column: carbonic_anhydrase_inhibitor
# LogLoss Score: 0.011183879133492506
# Column: casein_kinase_inhibitor
# LogLoss Score: 0.010928859037373092
# Column: caspase_activator
# LogLoss Score: 0.006127312710239139
# Column: catechol_o_methyltransferase_inhibitor
# LogLoss Score: 0.00432008981927496
# Column: cc_chemokine_receptor_antagonist
# LogLoss Score: 0.027430220356738946
# Column: cck_receptor_antagonist
# LogLoss Score: 0.006123329252308839
# Column: cdk_inhibitor
# LogLoss Score: 0.020812230111556376
# Column: chelating_agent
# LogLoss Score: 0.015764392439084538
# Column: chk_inhibitor
# LogLoss Score: 0.004382658614639358
# Column: chloride_channel_blocker
# LogLoss Score: 0.01273322131025744
# Column: cholesterol_inhibitor
# LogLoss Score: 0.014274057870723342
# Column: cholinergic_receptor_antagonist
# LogLoss Score: 0.015843661032650117
# Column: coagulation_factor_inhibitor
# LogLoss Score: 0.002314045804400488
# Column: corticosteroid_agonist
# LogLoss Score: 0.008441262711643405
# Column: cyclooxygenase_inhibitor
# LogLoss Score: 0.08716808433884098
# Column: cytochrome_p450_inhibitor
# LogLoss Score: 0.026678352612011434
# Column: dihydrofolate_reductase_inhibitor
# LogLoss Score: 0.008995824379659567
# Column: dipeptidyl_peptidase_inhibitor
# LogLoss Score: 0.008240793138530303
# Column: diuretic
# LogLoss Score: 0.0023187348066924973
# Column: dna_alkylating_agent
# LogLoss Score: 0.013740884646540977
# Column: dna_inhibitor
# LogLoss Score: 0.07858704549786429
# Column: dopamine_receptor_agonist
# LogLoss Score: 0.031011340470079012
# Column: dopamine_receptor_antagonist
# LogLoss Score: 0.08274117774004074
# Column: egfr_inhibitor
# LogLoss Score: 0.023764669332389562
# Column: elastase_inhibitor
# LogLoss Score: 0.0023318107183667664
# Column: erbb2_inhibitor
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# LogLoss Score: 0.0014923493695596184
# Column: estrogen_receptor_agonist
# LogLoss Score: 0.03826391159582671
# Column: estrogen_receptor_antagonist
# LogLoss Score: 0.014201045118819722
# Column: faah_inhibitor
# LogLoss Score: 0.010524687950952604
# Column: farnesyltransferase_inhibitor
# LogLoss Score: 0.0042872396381464385
# Column: fatty_acid_receptor_agonist
# LogLoss Score: 0.008112813541268046
# Column: fgfr_inhibitor
# LogLoss Score: 0.011458206019881097
# Column: flt3_inhibitor
# LogLoss Score: 0.02384783160739258
# Column: focal_adhesion_kinase_inhibitor
# LogLoss Score: 0.0037460158642241156
# Column: free_radical_scavenger
# LogLoss Score: 0.006135037898408241
# Column: fungal_squalene_epoxidase_inhibitor
# LogLoss Score: 0.0072099300877252045
# Column: gaba_receptor_agonist
# LogLoss Score: 0.028135945629089564
# Column: gaba_receptor_antagonist
# LogLoss Score: 0.03987921604540091
# Column: gamma_secretase_inhibitor
# LogLoss Score: 0.010978582553162622
# Column: glucocorticoid_receptor_agonist
# LogLoss Score: 0.014558590017962605
# Column: glutamate_inhibitor
# LogLoss Score: 0.004582015204173029
# Column: glutamate_receptor_agonist
# LogLoss Score: 0.020748170043158685
# Column: glutamate_receptor_antagonist
# LogLoss Score: 0.07648702479145311
# Column: gonadotropin_receptor_agonist
# LogLoss Score: 0.006069055046428346
# Column: gsk_inhibitor
# LogLoss Score: 0.011551599874772365
# Column: hcv_inhibitor
# LogLoss Score: 0.020404710616027163
# Column: hdac_inhibitor
# LogLoss Score: 0.012085078602847979
# Column: histamine_receptor_agonist
# LogLoss Score: 0.017153970543044367
# Column: histamine_receptor_antagonist
# LogLoss Score: 0.0544275454604838
# Column: histone_lysine_demethylase_inhibitor
# LogLoss Score: 0.006526267227807831
# Column: histone_lysine_methyltransferase_inhibitor
# LogLoss Score: 0.009139213569015602
# Column: hiv_inhibitor
# LogLoss Score: 0.02029305043370236
# Column: hmgcr_inhibitor
# LogLoss Score: 0.015138519536377888
# Column: hsp_inhibitor
# LogLoss Score: 0.007145073510664895
# Column: igf-1_inhibitor
# LogLoss Score: 0.010056520259660988
# Column: ikk_inhibitor
# LogLoss Score: 0.00687524564422743
# Column: imidazoline_receptor_agonist
# LogLoss Score: 0.009864616451880364
# Column: immunosuppressant
# LogLoss Score: 0.018369807911617658
# Column: insulin_secretagogue
# LogLoss Score: 0.009474086167177717
# Column: insulin_sensitizer
# LogLoss Score: 0.01284653984456703
# Column: integrin_inhibitor
# LogLoss Score: 0.012701449146836788
# Column: jak_inhibitor
# LogLoss Score: 0.015301179907209094
# Column: kit_inhibitor
# LogLoss Score: 0.01979441789040351
# Column: laxative
# LogLoss Score: 0.0023394697940310864
# Column: leukotriene_inhibitor
# LogLoss Score: 0.0023393690850212973
# Column: leukotriene_receptor_antagonist
# LogLoss Score: 0.017966558519599343
# Column: lipase_inhibitor
# LogLoss Score: 0.004328227582365394
# Column: lipoxygenase_inhibitor
# LogLoss Score: 0.017229251334629096
# Column: lxr_agonist
# LogLoss Score: 0.0018559468982955714
# Column: mdm_inhibitor
# LogLoss Score: 0.006520609252369831
# Column: mek_inhibitor
# LogLoss Score: 0.00871248513890141
# Column: membrane_integrity_inhibitor
# LogLoss Score: 0.020372882918645828
# Column: mineralocorticoid_receptor_antagonist
# LogLoss Score: 0.008051106979074893
# Column: monoacylglycerol_lipase_inhibitor
# LogLoss Score: 0.004268082973522079
# Column: monoamine_oxidase_inhibitor
# LogLoss Score: 0.023344715223177954
# Column: monopolar_spindle_1_kinase_inhibitor
# LogLoss Score: 0.005413657956400023
# Column: mtor_inhibitor
# LogLoss Score: 0.017508615846464456
# Column: mucolytic_agent
# LogLoss Score: 0.014372178194411136
# Column: neuropeptide_receptor_antagonist
# LogLoss Score: 0.011309638191984963
# Column: nfkb_inhibitor
# LogLoss Score: 0.03116840030146053
# Column: nicotinic_receptor_agonist
# LogLoss Score: 0.0023334406937021877
# Column: nitric_oxide_donor
# LogLoss Score: 0.008499214288215649
# Column: nitric_oxide_production_inhibitor
# LogLoss Score: 0.004058456622501658
# Column: nitric_oxide_synthase_inhibitor
# LogLoss Score: 0.008471299793511982
# Column: norepinephrine_reuptake_inhibitor
# LogLoss Score: 0.0026338552696907433
# Column: nrf2_activator
# LogLoss Score: 0.004555495062883727
# Column: opioid_receptor_agonist
# LogLoss Score: 0.017688125806495297
# Column: opioid_receptor_antagonist
# LogLoss Score: 0.026098057232388606
# Column: orexin_receptor_antagonist
# LogLoss Score: 0.011345268158042203
# Column: p38_mapk_inhibitor
# LogLoss Score: 0.010682604181828662
# Column: p-glycoprotein_inhibitor
# LogLoss Score: 0.007902491240723886
# Column: parp_inhibitor
# LogLoss Score: 0.016206764331936623
# Column: pdgfr_inhibitor
# LogLoss Score: 0.02270210413341913
# Column: pdk_inhibitor
# LogLoss Score: 0.005903016088182489
# Column: phosphodiesterase_inhibitor
# LogLoss Score: 0.05795032579632069
# Column: phospholipase_inhibitor
# LogLoss Score: 0.007929412866579432
# Column: pi3k_inhibitor
# LogLoss Score: 0.02816559132345517
# Column: pkc_inhibitor
# LogLoss Score: 0.009386256701014997
# Column: potassium_channel_activator
# LogLoss Score: 0.015541002111867458
# Column: potassium_channel_antagonist
# LogLoss Score: 0.026339225728236593
# Column: ppar_receptor_agonist
# LogLoss Score: 0.02414347880803872
# Column: ppar_receptor_antagonist
# LogLoss Score: 0.009554050056136769
# Column: progesterone_receptor_agonist
# LogLoss Score: 0.029113480976184797
# Column: progesterone_receptor_antagonist
# LogLoss Score: 0.005414247358351246
# Column: prostaglandin_inhibitor
# LogLoss Score: 0.011255171882762868
# Column: prostanoid_receptor_antagonist
# LogLoss Score: 0.022955766848206705
# Column: proteasome_inhibitor
# LogLoss Score: 0.0018860231416887704
# Column: protein_kinase_inhibitor
# LogLoss Score: 0.014005440528905642
# Column: protein_phosphatase_inhibitor
# LogLoss Score: 0.0021126210315910226
# Column: protein_synthesis_inhibitor
# LogLoss Score: 0.023983520304160327
# Column: protein_tyrosine_kinase_inhibitor
# LogLoss Score: 0.006421660471498339
# Column: radiopaque_medium
# LogLoss Score: 0.016357144069015186
# Column: raf_inhibitor
# LogLoss Score: 0.008419433918752505
# Column: ras_gtpase_inhibitor
# LogLoss Score: 0.004298464961307684
# Column: retinoid_receptor_agonist
# LogLoss Score: 0.014525900135429313
# Column: retinoid_receptor_antagonist
# LogLoss Score: 0.002323633052651143
# Column: rho_associated_kinase_inhibitor
# LogLoss Score: 0.009462496222068158
# Column: ribonucleoside_reductase_inhibitor
# LogLoss Score: 0.00880098203127428
# Column: rna_polymerase_inhibitor
# LogLoss Score: 0.008118207127381585
# Column: serotonin_receptor_agonist
# LogLoss Score: 0.05396195725594626
# Column: serotonin_receptor_antagonist
# LogLoss Score: 0.08138305541924076
# Column: serotonin_reuptake_inhibitor
# LogLoss Score: 0.013081412102483524
# Column: sigma_receptor_agonist
# LogLoss Score: 0.011239422427782158
# Column: sigma_receptor_antagonist
# LogLoss Score: 0.0111110173853224
# Column: smoothened_receptor_antagonist
# LogLoss Score: 0.007877552325661313
# Column: sodium_channel_inhibitor
# LogLoss Score: 0.06003730834410005
# Column: sphingosine_receptor_agonist
# LogLoss Score: 0.008057797233812244
# Column: src_inhibitor
# LogLoss Score: 0.015917271474294573
# Column: steroid
# LogLoss Score: 0.0023304744587369663
# Column: syk_inhibitor
# LogLoss Score: 0.005463444114654604
# Column: tachykinin_antagonist
# LogLoss Score: 0.01739633764024972
# Column: tgf-beta_receptor_inhibitor
# LogLoss Score: 0.0025762787192438836
# Column: thrombin_inhibitor
# LogLoss Score: 0.006375798990803041
# Column: thymidylate_synthase_inhibitor
# LogLoss Score: 0.010332639553157521
# Column: tlr_agonist
# LogLoss Score: 0.009628426513892858
# Column: tlr_antagonist
# LogLoss Score: 0.0026913179258206566
# Column: tnf_inhibitor
# LogLoss Score: 0.010991685285901453
# Column: topoisomerase_inhibitor
# LogLoss Score: 0.016592330727777375
# Column: transient_receptor_potential_channel_antagonist
# LogLoss Score: 0.006179911237709674
# Column: tropomyosin_receptor_kinase_inhibitor
# LogLoss Score: 0.002314131724693801
# Column: trpv_agonist
# LogLoss Score: 0.007161551682941662
# Column: trpv_antagonist
# LogLoss Score: 0.01426648395126252
# Column: tubulin_inhibitor
# LogLoss Score: 0.023004442572462414
# Column: tyrosine_kinase_inhibitor
# LogLoss Score: 0.019774740242481607
# Column: ubiquitin_specific_protease_inhibitor
# LogLoss Score: 0.0023176115173767033
# Column: vegfr_inhibitor
# LogLoss Score: 0.02644801924476347
# Column: vitamin_b
# LogLoss Score: 0.008417998828195253
# Column: vitamin_d_receptor_agonist
# LogLoss Score: 0.006443649574730686
# Column: wnt_inhibitor
# LogLoss Score: 0.009604570507716138

# %%
y_pred = y_pred_2

oof = oof_2

scores = scores_2

# %%
np.mean(scores)
# Out:
# 0.015792320268412187

# %% [markdown]
# ### Scores

# %%
score = pd.DataFrame()
score['feature'] = y_train.columns
score['score'] = scores + [0] * (len(y_train.columns) - len(scores))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,40))

sns.barplot(x="score", y="feature", data=score)

plt.show()

# %% [markdown]
# ## Check

# %%
for pair in antagonists:
    n = y_pred[(y_pred[pair[0]] > 0.5) & (y_pred[pair[1]] > 0.5)].shape[0]
    if n > 0:
        print(pair[0], '-', pair[1])
        print('Number of cases:', n)

# %% [markdown]
# ## Submit predictions

# %%
submission = pd.read_csv('/kaggle/input/lish-moa/sample_submission.csv')

columns = list(set(submission.columns) & set(y_pred.columns))
submission[columns] = y_pred[columns]

submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ## Save OOF and scores

# %%
oof.to_csv('oof.csv', index=False)

score.to_csv('score.csv', index=False)

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import xgboost as xgb
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")

# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
PATH = "/kaggle/input/house-prices-advanced-regression-techniques/"

# %%
train_df = pd.read_csv(PATH + "train.csv")
test_df = pd.read_csv(PATH + "test.csv")
sub_df = pd.read_csv(PATH + "sample_submission.csv")

# %%
print('train_df shape :: ',train_df.shape)
print('test_df shape :: ',test_df.shape)
# Out:
# train_df shape ::  (1460, 81)
# test_df shape ::  (1459, 80)

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# House prices are tend to relevant with it's age and location.<br>
# Let's check the average 'YearBuilt' and 'MSZoning'.<br>

# %%
grouped = train_df['YearBuilt'].groupby(train_df['MSZoning'])
print(grouped.mean())
# Out:
# MSZoning
# C (all)    1924.100000
# FV         2004.507692
# RH         1945.687500
# RL         1975.461338
# RM         1943.256881
# Name: YearBuilt, dtype: float64

# %% [markdown]
# Clearly, the houses in category 'FV' are recently bulit. If null values exist in 'MSZoning', we can reference a mean value of each 'MSZoning', but since no nulls in here let's go another task.

# %%
grouped = train_df['SalePrice'].groupby(train_df['MSZoning'])
print(grouped.mean())
# Out:
# MSZoning
# C (all)     74528.000000
# FV         214014.061538
# RH         131558.375000
# RL         191004.994787
# RM         126316.830275
# Name: SalePrice, dtype: float64

# %% [markdown]
# We have 80 columns and 1 label column. Quite huge.. <br>
# Which column is our target??

# %%
for col in train_df.columns:
    if col not in test_df.columns:
        print(col, "is the target column")
# Out:
# SalePrice is the target column

# %%
sns.distplot(train_df['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# Thus, our task is to predict 'SalePrice'. The distribution of 'SalePrice' looks a little bit skewed. we will evenly spread the distribution with 'np.log1p' function later.<br><br>
# For now, what features do we have?

# %% [markdown]
# ### Data Fields
# - **SalePrice:** the property's sale price in dollars<br>
# - **MSSubClass:** the building class<br>
# - **MSZoning:** the general zoning classification<br>
# - **LotFrontage:** Linear feet of street connected to property<br>
# - **LotArea:** Lot size in square feet<br>
# - **Street:** Type of road access<br>
# - **Alley:** Type of alley access<br>
# - **LotShape:** General shape of property<br>
# - **LandContour:** Flatness of the property<br>
# - **Utilities:** Type of unitilities available<br>
# - **LotConfig:** Lot configuration<br>
# - **LandSlope:** Slope of property<br>
# - **Neighborhood:** Physical locations within Ames city limits<br>
# - **Condition1:** Proximity to main road or railroad<br>
# - **Condition2:** Proximity to main road or railroad (if a second is present)<br>
# - **BldgType:** Type of dwelling<br>
# - **HouseStyle:** Style of dwelling<br>
# - **OverallQual:** Overall material and finish quality<br>
# - **OverallCond:** Overall condition rating<br>
# - **YearBuilt:** Original construction date<br>
# - **YearRemodAdd:** Remodel date<br>
# - **RoofStyle:** Type of roof<br>
# - **RoofMatl:** Roof material<br>
# - **Exterior1st:** Exterior covering on house<br>
# - **Exterior2nd:** Exterior covering on house (if more than one material)<br>
# - **MasVnrType:** Masonry veneer type<br>
# - **MasVnrArea:** Masonry veneer area in square feet<br>
# - **ExterQual:** Exterior material quality<br>
# - **ExterCond:** Present condition of the material on the exterior<br>
# - **Foundation:** Type of foundation<br>
# - **BsmtQual:** Height of the basement<br>
# - **BsmtCond:** General condition of the basement<br>
# - **BsmtExposure:** Walkout or garden level basement walls<br>
# - **BsmtFinType1:** Quality of basement finished area<br>
# - **BsmtFinSF1:** Type 1 finished square feet<br>
# - **BsmtFinType2:** Quality of second finished area (if present)<br>
# - **BsmtFinSF2:** Type 2 finished square feet<br>
# - **BsmtUnfSF:** Unfinished square feet of basement area<br>
# - **TotalBsmtSF:** Total square feet of basement area<br>
# - **Heating:** Type of heating<br>
# - **HeatingQC:** Heating quality and condition<br>
# - **CentralAir:** Central air conditioning<br>
# - **Electrical:** Electrical system<br>
# - **1stFlrSF:** First Floor square feet<br>
# - **2ndFlrSF:** Second floor square feet<br>
# - **LowQualFinSF:** Low quality finished square feet (all floors)<br>
# - **GrLivArea:** Above grade (ground) living area square feet<br>
# - **BsmtFullBath:** Basement full bathrooms<br>
# - **BsmtHalfBath:** Basement half bathrooms<br>
# - **FullBath:** Full bathrooms above grade<br>
# - **HalfBath:** Half baths above grade<br>
# - **Bedroom:** Number of bedrooms above basement level<br>
# - **Kitchen:** Number of kitchens<br>
# - **KitchenQual:** Kitchen quality<br>
# - **TotRmsAbvGrd:** Total rooms above grade (does not include bathrooms)<br>
# - **Functional:** Home functionality rating<br>
# - **Fireplaces:** Number of fireplaces<br>
# - **FireplaceQu:** Fireplace quality<br>
# - **GarageType:** Garage location<br>
# - **GarageYrBlt:** Year garage was built<br>
# - **GarageFinish:** Interior finish of the garage<br>
# - **GarageCars:** Size of garage in car capacity<br>
# - **GarageArea:** Size of garage in square feet<br>
# - **GarageQual:** Garage quality<br>
# - **GarageCond:** Garage condition<br>
# - **PavedDrive:** Paved driveway<br>
# - **WoodDeckSF:** Wood deck area in square feet<br>
# - **OpenPorchSF:** Open porch area in square feet<br>
# - **EnclosedPorch:** Enclosed porch area in square feet<br>
# - **3SsnPorch:** Three season porch area in square feet<br>
# - **ScreenPorch:** Screen porch area in square feet<br>
# - **PoolArea:** Pool area in square feet<br>
# - **PoolQC:** Pool quality<br>
# - **Fence:** Fence quality<br>
# - **MiscFeature:** Miscellaneous feature not covered in other categories<br>
# - **MiscVal:** Value of miscellaneous feature<br>
# - **MoSold:** Month Sold<br>
# - **YrSold:** Year Sold<br>
# - **SaleType:** Type of sale<br>
# - **SaleCondition:** Condition of sale<br><br><br>
#
# Are these features crucial to predict the SalePrice?? I'm not sure<br>
# But more data is better than less. Let's preprocessing them!<br>

# %% [markdown]
# ### 1. Preprocessing
# Let's check out the type of each column.<br>
# How do the train and test data have different distributions? How many nulls are in each column? Can we fill the null value with any referenced column? Is there a duplicated value?

# %%
sns.distplot(train_df['OverallQual'])
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='Density'>

# %%
sns.distplot(test_df['OverallQual'])
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='Density'>

# %%
for col in train_df.columns:
    if train_df[col].isnull().sum() > 0:
        print("[[",col,']] column has >>', train_df[col].isnull().sum(), '<< nulls\n')
# Out:
# [[ LotFrontage ]] column has >> 259 << nulls
#
# [[ Alley ]] column has >> 1369 << nulls
#
# [[ MasVnrType ]] column has >> 8 << nulls
#
# [[ MasVnrArea ]] column has >> 8 << nulls
#
# [[ BsmtQual ]] column has >> 37 << nulls
#
# [[ BsmtCond ]] column has >> 37 << nulls
#
# [[ BsmtExposure ]] column has >> 38 << nulls
#
# [[ BsmtFinType1 ]] column has >> 37 << nulls
#
# [[ BsmtFinType2 ]] column has >> 38 << nulls
#
# [[ Electrical ]] column has >> 1 << nulls
#
# [[ FireplaceQu ]] column has >> 690 << nulls
#
# [[ GarageType ]] column has >> 81 << nulls
#
# [[ GarageYrBlt ]] column has >> 81 << nulls
#
# [[ GarageFinish ]] column has >> 81 << nulls
#
# [[ GarageQual ]] column has >> 81 << nulls
#
# [[ GarageCond ]] column has >> 81 << nulls
#
# [[ PoolQC ]] column has >> 1453 << nulls
#
# [[ Fence ]] column has >> 1179 << nulls
#
# [[ MiscFeature ]] column has >> 1406 << nulls

# %% [markdown]
# Let's drop the features that have hundreds or thousands of nulls.

# %%
null_dominant_cols = ["Alley","PoolQC","Fence","MiscFeature","FireplaceQu"]
train_df.drop(columns=null_dominant_cols, inplace=True)
test_df.drop(columns=null_dominant_cols, inplace=True)

# %%
def preprocess(df):
    categorical_cols = ["LotConfig","LotArea","LandSlope","Neighborhood","Condition1",\
                       "Condition2","BldgType","HouseStyle","RoofStyle","RoofMatl",\
                       "Exterior1st","Exterior2nd","MasVnrType","ExterQual","ExterCond",\
                       "Foundation","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1",
                       "BsmtFinSF1","BsmtFinType2","BsmtFinSF2","BsmtUnfSF","YearRemodAdd",\
                       "TotalBsmtSF","Heating","HeatingQC","CentralAir","Utilities",\
                        "Electrical","KitchenQual","Functional","PavedDrive","SaleType",\
                        "GarageType","GarageFinish","GarageQual","GarageCond",\
                        "SaleCondition","MSZoning","LotShape","Street","LandContour"]

    df['MasVnrType'].fillna('None', inplace=True)
    df['BsmtQual'].fillna('None', inplace=True)
    df['BsmtCond'].fillna('None', inplace=True)
    df['BsmtExposure'].fillna('None', inplace=True)
    df['BsmtFinType1'].fillna('None', inplace=True)
    df['BsmtFinType2'].fillna('None', inplace=True)
    df['Electrical'].fillna('None', inplace=True)
    df['GarageType'].fillna('None', inplace=True)
    df['GarageFinish'].fillna('None', inplace=True)
    df['GarageQual'].fillna('None', inplace=True)
    df['GarageCond'].fillna('None', inplace=True)
    df['Exterior1st'].fillna('None', inplace=True)
    df['Exterior2nd'].fillna('None', inplace=True)
    df['Utilities'].fillna('None', inplace=True)
    df['Electrical'].fillna('None', inplace=True)
    df['KitchenQual'].fillna('None', inplace=True)
    df['Functional'].fillna('None', inplace=True)
    df['SaleType'].fillna('None', inplace=True)
    df['MSZoning'].fillna('None', inplace=True)
    # The mean value of 'LotArea' is too large compare to other values. 
    # Thus, with 'np.log1p', the absolute values of 'LotArea' will be harmonized with other features
    df['LotArea'] = np.log1p(df['LotArea'])
    
    df['LotFrontage'].fillna(np.mean(df['LotFrontage']), inplace=True)
    df['MasVnrArea'].fillna(0, inplace=True)
    df['GarageYrBlt'].fillna(df['YearBuilt'], inplace=True)
    
    for col in categorical_cols:
        encoder = LabelEncoder()
        df[col] = encoder.fit_transform(df[col])

    df['MasVnrArea'] = df['MasVnrArea'].astype(int)
    return df

# %%
train_df = preprocess(train_df)
test_df = preprocess(test_df)

# %% [markdown]
# "Alley","PoolQC","Fence" and "MiscFeature" have over a thousand null values, and  "LotFrontage","FireplaceQu" have hundreds of null values. Others columns have relatively small numbers of null values.<br><br>
# The below codes are check the duplicated values in each dataframe, and we can see that there is no duplicated value here.

# %%
print("former shape: ", train_df.shape, " test : ", test_df.shape)
train_df.drop_duplicates()
test_df.drop_duplicates()
print("latter shape: ", train_df.shape, " test : ", test_df.shape)
# Out:
# former shape:  (1460, 76)  test :  (1459, 75)
# latter shape:  (1460, 76)  test :  (1459, 75)

# %% [markdown]
# ### 2. Feature Engineering

# %% [markdown]
# How do we check a valuable feature for helping price prediction?

# %%
train_corrmatrix = train_df.corr()
cols = train_corrmatrix.nlargest(40, "SalePrice")['SalePrice'].index
cm = np.corrcoef(train_df[cols].values.T)
plt.figure(figsize=(50,50))
sns.set(font_scale=2)
sns.heatmap(cm, cbar=True, linewidths=2, vmax=.9, square=True, annot=True,\
           fmt=".2f", annot_kws={"size":17},yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Since this is a SIMPLE EDA, we will remove the features that have an under 0.02 effect on 'SalePrice'.<br><br> Note that this could be hurt the performance of model due to a Heatmap ONLY checking the linear relationship between the features. i.e. Heatmap cannot check the non-linear relationships between the features.<br><br>
# Many valuable models have non-linearity, so we cannot check which feature could be effective in models.

# %%
cols = list(cols)
cols.extend(["YrSold"])
test_cols = []
for col in cols:
    if col != "SalePrice":
        test_cols.append(col)
        
print('Choosed features : ', cols)
# Out:
# Choosed features :  ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'GarageYrBlt', 'YearRemodAdd', 'MasVnrArea', 'Fireplaces', 'LotArea', 'Foundation', 'BsmtFinSF1', 'LotFrontage', 'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'HalfBath', 'CentralAir', 'GarageCond', 'Electrical', 'PavedDrive', 'BsmtFullBath', 'RoofStyle', 'SaleCondition', 'Neighborhood', 'GarageQual', 'HouseStyle', 'BsmtUnfSF', 'BedroomAbvGr', 'RoofMatl', 'ExterCond', 'Functional', 'ScreenPorch', 'Exterior2nd', 'Exterior1st', 'YrSold']

# %%
train_df = train_df[cols]
test_df = test_df[test_cols]

# %%
def add_features(df):
    df['house_age1'] = df['YrSold'] - df['YearBuilt']
    df['house_age2'] = df['YrSold'] - df['YearRemodAdd']
    df['garage_age'] = df['YrSold'] - df['GarageYrBlt']
    
    df['total_area'] = np.log1p(df['GrLivArea'] + df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF'])
    df['num_rooms'] = df['TotRmsAbvGrd'] + df['BedroomAbvGr'] + df['FullBath']
    return df

# %%
train_df = add_features(train_df)
test_df = add_features(test_df)

# %%
train_df['YrSold'] = train_df['YrSold'].replace({2008:2, 
                                                 2007:1, 
                                                 2006:0, 
                                                 2009:3, 
                                                 2010:4})
test_df['YrSold'] = test_df['YrSold'].replace({2008:2, 
                                                 2007:1, 
                                                 2006:0, 
                                                 2009:3, 
                                                 2010:4})

# %%
train_df.head()
# Out:
#    SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 0     208500            7       1710           2         548          179
# 1     181500            6       1262           2         460          441
# 2     223500            7       1786           2         608          214
# 3     140000            7       1717           3         642          117
# 4     250000            8       2198           3         836          370
#
#    1stFlrSF  FullBath  TotRmsAbvGrd  YearBuilt  ...  Functional  ScreenPorch  \
# 0       856         2             8       2003  ...           6            0
# 1      1262         2             6       1976  ...           6            0
# 2       920         2             6       2001  ...           6            0
# 3       961         1             7       1915  ...           6            0
# 4      1145         2             9       2000  ...           6            0
#
#    Exterior2nd  Exterior1st  YrSold  house_age1  house_age2  garage_age  \
# 0           13           12       2           5        1955         5.0
# 1            8            8       1          31        1981        31.0
# 2           13           12       2           7        1956         7.0
# 3           15           13       0          91        1986         8.0
# 4           13           12       2           8        1958         8.0
#
#    total_area  num_rooms
# 0    8.188689         13
# 1    7.994970         11
# 2    8.239329         11
# 3    8.175266         11
# 4    8.469472         15
#
# [5 rows x 46 columns]

# %%
sns.distplot(train_df['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# The above plot looks skewed. Let's make the distribution to follow the Gaussian.

# %%
train_label = np.log1p(train_df['SalePrice'])
train_df.drop(columns=['SalePrice'], inplace=True)

# %%
train_df.head()
# Out:
#    OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  1stFlrSF  \
# 0            7       1710           2         548          179       856
# 1            6       1262           2         460          441      1262
# 2            7       1786           2         608          214       920
# 3            7       1717           3         642          117       961
# 4            8       2198           3         836          370      1145
#
#    FullBath  TotRmsAbvGrd  YearBuilt  GarageYrBlt  ...  Functional  \
# 0         2             8       2003       2003.0  ...           6
# 1         2             6       1976       1976.0  ...           6
# 2         2             6       2001       2001.0  ...           6
# 3         1             7       1915       1998.0  ...           6
# 4         2             9       2000       2000.0  ...           6
#
#    ScreenPorch  Exterior2nd  Exterior1st  YrSold  house_age1  house_age2  \
# 0            0           13           12       2           5        1955
# 1            0            8            8       1          31        1981
# 2            0           13           12       2           7        1956
# 3            0           15           13       0          91        1986
# 4            0           13           12       2           8        1958
#
#    garage_age  total_area  num_rooms
# 0         5.0    8.188689         13
# 1        31.0    7.994970         11
# 2         7.0    8.239329         11
# 3         8.0    8.175266         11
# 4         8.0    8.469472         15
#
# [5 rows x 45 columns]

# %% [markdown]
# ### 3. Build Models

# %% [markdown]
# #### 3.1 Simple XGBoost

# %%
xgb_param = {'learning_rate': 0.03,
             'max_depth': 40,
             'verbosity': 3,
             'nthread': 5,
             'random_state': 0,
             'subsample': 0.7,
             'n_estimators': 5000,
             'colsample_bytree': 0.8}

# %%
model_xgb = xgb.XGBRegressor(learning_rate=xgb_param['learning_rate'],
                            max_depth=xgb_param['max_depth'],
                            verbosity=xgb_param['verbosity'],
                            nthread=xgb_param['nthread'],
                            random_state=xgb_param['random_state'],
                            subsample=xgb_param['subsample'],
                            n_estimators=xgb_param['n_estimators'],
                            colsample_bytree=xgb_param['colsample_bytree'])

# %%
model_xgb.fit(train_df, train_label)
xgb_train_pred = model_xgb.predict(train_df)
xgb_test_pred = np.expm1(model_xgb.predict(test_df))

def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

print(rmsle(train_label, xgb_train_pred))
# Out:
# [07:40:45] DEBUG: ../src/gbm/gbtree.cc:155: Using tree method: 2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=5
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=5
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=3
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=5
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=6
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=5
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=7
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=5
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=6
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=5
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=5
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=7
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=7
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=7
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 66 extra nodes, 0 pruned nodes, max_depth=7
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=9
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=10
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 70 extra nodes, 0 pruned nodes, max_depth=12
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 64 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=10
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=8
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 76 extra nodes, 0 pruned nodes, max_depth=11
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=12
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 90 extra nodes, 0 pruned nodes, max_depth=11
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 92 extra nodes, 0 pruned nodes, max_depth=9
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=10
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=11
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=10
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 98 extra nodes, 0 pruned nodes, max_depth=12
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 126 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 96 extra nodes, 0 pruned nodes, max_depth=10
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 122 extra nodes, 0 pruned nodes, max_depth=12
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 148 extra nodes, 0 pruned nodes, max_depth=15
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 150 extra nodes, 0 pruned nodes, max_depth=17
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 162 extra nodes, 0 pruned nodes, max_depth=13
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 116 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 172 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 164 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 174 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 170 extra nodes, 0 pruned nodes, max_depth=16
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 184 extra nodes, 0 pruned nodes, max_depth=15
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 200 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 160 extra nodes, 0 pruned nodes, max_depth=14
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 210 extra nodes, 0 pruned nodes, max_depth=18
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 210 extra nodes, 0 pruned nodes, max_depth=19
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 234 extra nodes, 0 pruned nodes, max_depth=21
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 230 extra nodes, 0 pruned nodes, max_depth=17
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 230 extra nodes, 0 pruned nodes, max_depth=21
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 262 extra nodes, 0 pruned nodes, max_depth=16
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 226 extra nodes, 0 pruned nodes, max_depth=20
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 258 extra nodes, 0 pruned nodes, max_depth=19
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 216 extra nodes, 0 pruned nodes, max_depth=16
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 274 extra nodes, 0 pruned nodes, max_depth=19
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 300 extra nodes, 0 pruned nodes, max_depth=18
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 306 extra nodes, 0 pruned nodes, max_depth=20
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 296 extra nodes, 0 pruned nodes, max_depth=17
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 304 extra nodes, 0 pruned nodes, max_depth=21
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 340 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 338 extra nodes, 0 pruned nodes, max_depth=20
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 346 extra nodes, 0 pruned nodes, max_depth=20
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 332 extra nodes, 0 pruned nodes, max_depth=19
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 376 extra nodes, 0 pruned nodes, max_depth=18
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 382 extra nodes, 0 pruned nodes, max_depth=19
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 396 extra nodes, 0 pruned nodes, max_depth=17
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 408 extra nodes, 0 pruned nodes, max_depth=20
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 392 extra nodes, 0 pruned nodes, max_depth=21
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 464 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 418 extra nodes, 0 pruned nodes, max_depth=18
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 434 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 424 extra nodes, 0 pruned nodes, max_depth=19
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 454 extra nodes, 0 pruned nodes, max_depth=20
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 494 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 498 extra nodes, 0 pruned nodes, max_depth=21
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 500 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 492 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 438 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 440 extra nodes, 0 pruned nodes, max_depth=20
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 530 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 478 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 588 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 512 extra nodes, 0 pruned nodes, max_depth=19
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 556 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 536 extra nodes, 0 pruned nodes, max_depth=19
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 560 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 572 extra nodes, 0 pruned nodes, max_depth=22
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 594 extra nodes, 0 pruned nodes, max_depth=22
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 540 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 598 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 626 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 590 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 638 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 582 extra nodes, 0 pruned nodes, max_depth=22
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 602 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 612 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 666 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 604 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 664 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 640 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 646 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 670 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 626 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 658 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 680 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 746 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 716 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 718 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 752 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 718 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 732 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 734 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 774 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 778 extra nodes, 0 pruned nodes, max_depth=22
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 724 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 728 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 768 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 800 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 786 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 778 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 758 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 804 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 750 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 818 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 740 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 800 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 794 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 782 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 766 extra nodes, 0 pruned nodes, max_depth=22
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 810 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 780 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 824 extra nodes, 0 pruned nodes, max_depth=22
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 822 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 826 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 860 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 838 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 836 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 812 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 812 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 800 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 852 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 866 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 872 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 872 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 862 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 798 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 890 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=39
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 864 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 824 extra nodes, 0 pruned nodes, max_depth=37
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 884 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 902 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 952 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 864 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 880 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 946 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 888 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 902 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 874 extra nodes, 0 pruned nodes, max_depth=36
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 920 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 930 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 860 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 882 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 908 extra nodes, 0 pruned nodes, max_depth=22
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 920 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 888 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 912 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 892 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 912 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 902 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 906 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 900 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 956 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 890 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 940 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 916 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 886 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 918 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 982 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 918 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 892 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 882 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 872 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 900 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 912 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 900 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 914 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 890 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 882 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 916 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 902 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 924 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 900 extra nodes, 0 pruned nodes, max_depth=38
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 934 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 894 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 908 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 932 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 908 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 904 extra nodes, 0 pruned nodes, max_depth=36
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 908 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 890 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 910 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 918 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 906 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 898 extra nodes, 0 pruned nodes, max_depth=40
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 914 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 902 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 894 extra nodes, 0 pruned nodes, max_depth=36
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 914 extra nodes, 0 pruned nodes, max_depth=40
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 880 extra nodes, 0 pruned nodes, max_depth=39
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 860 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 864 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 822 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 928 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 856 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 908 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 888 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 888 extra nodes, 0 pruned nodes, max_depth=39
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 896 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 876 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 846 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 840 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 856 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 884 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 868 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 844 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 884 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 854 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 836 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 886 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 840 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 874 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 836 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 870 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 854 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 848 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 848 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 818 extra nodes, 0 pruned nodes, max_depth=36
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 854 extra nodes, 0 pruned nodes, max_depth=40
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 846 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 890 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 808 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 762 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 828 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 824 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 798 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 774 extra nodes, 0 pruned nodes, max_depth=40
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 802 extra nodes, 0 pruned nodes, max_depth=36
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 850 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 794 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 784 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 806 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 818 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 804 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 800 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 814 extra nodes, 0 pruned nodes, max_depth=37
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 752 extra nodes, 0 pruned nodes, max_depth=25
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 748 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 734 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 792 extra nodes, 0 pruned nodes, max_depth=36
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 768 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 790 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 750 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 796 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 784 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 766 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 756 extra nodes, 0 pruned nodes, max_depth=39
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 758 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 732 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 776 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 756 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 764 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 752 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 726 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 762 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 696 extra nodes, 0 pruned nodes, max_depth=23
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 728 extra nodes, 0 pruned nodes, max_depth=36
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 732 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 712 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 722 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 714 extra nodes, 0 pruned nodes, max_depth=37
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 692 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 722 extra nodes, 0 pruned nodes, max_depth=39
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 684 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 712 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 672 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 708 extra nodes, 0 pruned nodes, max_depth=37
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 688 extra nodes, 0 pruned nodes, max_depth=40
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 660 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 686 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 650 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 676 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 676 extra nodes, 0 pruned nodes, max_depth=37
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 664 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 684 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 676 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 620 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 638 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 616 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 618 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 646 extra nodes, 0 pruned nodes, max_depth=30
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 644 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 614 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 642 extra nodes, 0 pruned nodes, max_depth=26
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 624 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 648 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 596 extra nodes, 0 pruned nodes, max_depth=29
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 614 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 582 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 580 extra nodes, 0 pruned nodes, max_depth=40
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 558 extra nodes, 0 pruned nodes, max_depth=21
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 580 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 548 extra nodes, 0 pruned nodes, max_depth=28
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 606 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 564 extra nodes, 0 pruned nodes, max_depth=40
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 516 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 608 extra nodes, 0 pruned nodes, max_depth=32
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 562 extra nodes, 0 pruned nodes, max_depth=33
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 568 extra nodes, 0 pruned nodes, max_depth=27
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 560 extra nodes, 0 pruned nodes, max_depth=34
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 566 extra nodes, 0 pruned nodes, max_depth=24
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 554 extra nodes, 0 pruned nodes, max_depth=31
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 542 extra nodes, 0 pruned nodes, max_depth=35
# [07:40:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 556 extra nodes, 0 pruned nodes, max_depth=34
# ...
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=7
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=10
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [07:41:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [07:41:18] ======== Monitor (0): Learner ========
# [07:41:18] Configure: 1e-06s, 1 calls @ 1us
#
# [07:41:18] EvalOneIter: 0.014969s, 5000 calls @ 14969us
#
# [07:41:18] GetGradient: 0.296963s, 5000 calls @ 296963us
#
# [07:41:18] PredictRaw: 1.60837s, 5000 calls @ 1608368us
#
# [07:41:18] UpdateOneIter: 21.0315s, 5000 calls @ 21031535us
#
# [07:41:18] ======== Monitor (0): GBTree ========
# [07:41:18] BoostNewTrees: 19.0511s, 5000 calls @ 19051077us
#
# [07:41:18] CommitModel: 0.006127s, 5000 calls @ 6127us
#
# [07:41:18] ======== Monitor (0): TreePruner ========
# [07:41:18] PrunerUpdate: 0.615242s, 5000 calls @ 615242us
#
# 0.0015472064547879059

# %%
sub_df['SalePrice'] = xgb_test_pred
sub_df.to_csv('xgb_submission.csv', index=False)

# %% [markdown]
# #### 3.2 Ensemble XGB + LGBM

# %%
lgb_param = {'num_leaves': 5000,
             'objective':'huber',
             'max_depth': 5000,
             'learning_rate': 0.05,
             "bagging_fraction": 0.7,
             "bagging_seed": 11,
             "metric": 'rmse',
             "verbosity": -1,
             "random_state": 0}

# %%
model_lgb = lgb.LGBMRegressor(num_leaves=lgb_param['num_leaves'],
                 objective=lgb_param['objective'],
                 max_depth=lgb_param['max_depth'],
                 learning_rate=lgb_param['learning_rate'],
                 bagging_seed=lgb_param['bagging_seed'],
                 metric=lgb_param['metric'],
                 verbosity=lgb_param['verbosity'],
                 random_state=lgb_param['random_state'])

# %%
model_lgb.fit(train_df, train_label)
lgb_train_pred = model_lgb.predict(train_df)
lgb_test_pred = np.expm1(model_lgb.predict(test_df))

print(rmsle(train_label, lgb_train_pred))
# Out:
# 0.06608876083012337

# %%
sub_df['SalePrice'] = lgb_test_pred
sub_df.to_csv('lgb_submission.csv', index=False)

# %% [markdown]
# #### 3.3 Stacking (will be updated)

# %% [markdown]
# ### 4. Feature Importances

# %%
from xgboost import plot_importance
fig, ax = plt.subplots(figsize=(50,50))
plot_importance(model_xgb, ax=ax)
plt.show()

# %%
from lightgbm import plot_importance
fig, ax = plt.subplots(figsize=(50,50))
plot_importance(model_lgb, ax=ax)
plt.show()

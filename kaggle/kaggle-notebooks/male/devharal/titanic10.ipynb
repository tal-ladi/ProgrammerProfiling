# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
train =pd.read_csv('/kaggle/input/titanic/train.csv') 
test3 = pd.read_csv('/kaggle/input/titanic/test.csv')
ss =pd.read_csv('/kaggle/input/titanic/gender_submission.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train=train.drop(['Ticket','Name'],axis=1)

# %%
test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_19/2541137542.py in <module>
# ----> 1 test.head()
#
# NameError: name 'test' is not defined

# %%
test3=test3.drop(['Ticket','Name'],axis=1)

# %%
test3.head()

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
le = LabelEncoder()
#New variable for outlet

var_mod = ['Sex','Cabin','Embarked']
le = LabelEncoder()
for i in var_mod:
    train[i] = le.fit_transform(train[i])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
le = LabelEncoder()
#New variable for outlet

var_mod = ['Sex','Cabin','Embarked']
le = LabelEncoder()
for i in var_mod:
    test3[i] = le.fit_transform(test3[i])

# %%
train.head()

# %%
train.columns

# %%
test.head()

# %%
train.head()

# %%
train1=train.drop(['Survived'],axis=1)
test1=train.Survived

# %%
train1.head()

# %%
test1.head()

# %%
train1=train1.fillna(0)

# %%
test3=test3.fillna(0)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(max_depth=1,min_samples_leaf=30)
regressor.fit(train1, test1)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(max_depth=5)
regressor.fit(train1, test1)

# %%
from sklearn.linear_model import  LinearRegression
regressor = LinearRegression()
regressor.fit(train1, test1)

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(train1, test1)

# %%
y_pred = regressor.predict(test3)

# %%
y_pred

# %%
submission = pd.DataFrame({
'PassengerId':test3['PassengerId'],

'Survived': y_pred
},columns=['PassengerId','Survived'])

# %%
submission.head()

# %%
pd.DataFrame(submission, columns=["PassengerId","Survived"]).to_csv("dev.csv",index=False)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/commonlitreadabilityprize/sample_submission.csv
# /kaggle/input/commonlitreadabilityprize/train.csv
# /kaggle/input/commonlitreadabilityprize/test.csv

# %%
! pip download tensorflow_text
! pip download tf_models_official
! pip download setuptools_scm
# Out:
# Collecting tensorflow_text
#   Downloading tensorflow_text-2.4.3-cp37-cp37m-manylinux1_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 1.2 MB/s
# Collecting tensorflow<2.5,>=2.4.0
#   Downloading tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl (394.3 MB)
#      |████████████████████████████████| 394.3 MB 11 kB/s
# Collecting tensorflow-hub>=0.8.0
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 56.3 MB/s
# Collecting wheel~=0.35
#   Downloading wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 41.8 MB/s
# Collecting absl-py~=0.10
#   Downloading absl_py-0.12.0-py3-none-any.whl (129 kB)
#      |████████████████████████████████| 129 kB 57.5 MB/s
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 588 kB/s
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.15.8-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 37.4 MB/s
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 43.7 MB/s
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 45.0 MB/s
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.5 MB/s
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 45.1 MB/s
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 26.1 MB/s
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 3.2 MB/s
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 5.2 MB/s
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.30.0-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 52.4 MB/s
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.0 MB/s
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 48.2 MB/s
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.0-py3-none-manylinux2010_x86_64.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 46.3 MB/s
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 41.0 MB/s
# Collecting setuptools>=41.0.0
#   Downloading setuptools-56.1.0-py3-none-any.whl (785 kB)
#      |████████████████████████████████| 785 kB 42.0 MB/s
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 50.9 MB/s
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.0.1-py3-none-any.whl (16 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.6 MB/s
# Collecting certifi>=2017.4.17
#   Downloading certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 49.5 MB/s
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 3.3 MB/s
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 38.5 MB/s
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 35.0 MB/s
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 37.4 MB/s
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Saved ./tensorflow_text-2.4.3-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl
# Saved ./gast-0.3.3-py2.py3-none-any.whl
# Saved ./absl_py-0.12.0-py3-none-any.whl
# Saved ./astunparse-1.6.3-py2.py3-none-any.whl
# Saved ./flatbuffers-1.12-py2.py3-none-any.whl
# Saved ./google_pasta-0.2.0-py3-none-any.whl
# Saved ./grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl
# Saved ./h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./Keras_Preprocessing-1.1.2-py2.py3-none-any.whl
# Saved ./numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl
# Saved ./opt_einsum-3.3.0-py3-none-any.whl
# Saved ./protobuf-3.15.8-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./six-1.15.0-py2.py3-none-any.whl
# Saved ./tensorboard-2.5.0-py3-none-any.whl
# Saved ./google_auth-1.30.0-py2.py3-none-any.whl
# Saved ./cachetools-4.2.2-py3-none-any.whl
# Saved ./google_auth_oauthlib-0.4.4-py2.py3-none-any.whl
# Saved ./Markdown-3.3.4-py3-none-any.whl
# Saved ./pyasn1_modules-0.2.8-py2.py3-none-any.whl
# Saved ./pyasn1-0.4.8-py2.py3-none-any.whl
# Saved ./requests-2.25.1-py2.py3-none-any.whl
# Saved ./certifi-2020.12.5-py2.py3-none-any.whl
# Saved ./chardet-4.0.0-py2.py3-none-any.whl
# Saved ./idna-2.10-py2.py3-none-any.whl
# Saved ./requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Saved ./oauthlib-3.1.0-py2.py3-none-any.whl
# Saved ./rsa-4.7.2-py3-none-any.whl
# Saved ./tensorboard_data_server-0.6.0-py3-none-manylinux2010_x86_64.whl
# Saved ./tensorboard_plugin_wit-1.8.0-py3-none-any.whl
# Saved ./tensorflow_estimator-2.4.0-py2.py3-none-any.whl
# Saved ./tensorflow_hub-0.12.0-py2.py3-none-any.whl
# Saved ./termcolor-1.1.0.tar.gz
# Saved ./typing_extensions-3.7.4.3-py3-none-any.whl
# Saved ./urllib3-1.26.4-py2.py3-none-any.whl
# Saved ./Werkzeug-1.0.1-py2.py3-none-any.whl
# Saved ./wheel-0.36.2-py2.py3-none-any.whl
# Saved ./wrapt-1.12.1.tar.gz
# Saved ./importlib_metadata-4.0.1-py3-none-any.whl
# Saved ./zipp-3.4.1-py3-none-any.whl
# Saved ./setuptools-56.1.0-py3-none-any.whl
# Successfully downloaded tensorflow-text tensorflow gast absl-py astunparse flatbuffers google-pasta grpcio h5py keras-preprocessing numpy opt-einsum protobuf six tensorboard google-auth cachetools google-auth-oauthlib markdown pyasn1-modules pyasn1 requests certifi chardet idna requests-oauthlib oauthlib rsa tensorboard-data-server tensorboard-plugin-wit tensorflow-estimator tensorflow-hub termcolor typing-extensions urllib3 werkzeug wheel wrapt importlib-metadata zipp setuptools
# Collecting tf_models_official
#   Downloading tf_models_official-2.4.0-py2.py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 1.2 MB/s
# Collecting google-api-python-client>=1.6.7
#   Downloading google_api_python_client-2.3.0-py2.py3-none-any.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 933 kB/s
# Collecting kaggle>=1.3.9
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 3.4 MB/s
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.1.48-cp37-cp37m-manylinux2014_x86_64.whl (37.6 MB)
#      |████████████████████████████████| 37.6 MB 25.3 MB/s
# Collecting pycocotools
#   Downloading pycocotools-2.0.2.tar.gz (23 kB)
# Collecting gin-config
#   Downloading gin_config-0.4.0-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.3 MB/s
# Collecting Pillow
#   Downloading Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 71 kB/s
# Collecting numpy>=1.15.4
#   Downloading numpy-1.20.2-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 47.1 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 44.6 MB/s
# Collecting tensorflow-datasets
#   Downloading tensorflow_datasets-4.2.0-py3-none-any.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 48.0 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.3 MB/s
# Collecting tensorflow>=2.4.0
#   File was already downloaded /kaggle/working/tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.5.0-py2.py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 33.7 MB/s
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 41.3 MB/s
# Collecting psutil>=5.4.3
#   Downloading psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 32.5 MB/s
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 4.2 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 34.2 MB/s
# Collecting tf-slim>=1.1.0
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 30.5 MB/s
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 6.1 MB/s
# Collecting six
#   File was already downloaded /kaggle/working/six-1.15.0-py2.py3-none-any.whl
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting Cython
#   Downloading Cython-0.29.23-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 28.0 MB/s
# Collecting google-cloud-bigquery>=0.31.0
#   Downloading google_cloud_bigquery-2.15.0-py2.py3-none-any.whl (221 kB)
#      |████████████████████████████████| 221 kB 52.5 MB/s
# Collecting scipy>=0.19.1
#   Downloading scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 43.1 MB/s
# Collecting tensorflow-hub>=0.6.0
#   File was already downloaded /kaggle/working/tensorflow_hub-0.12.0-py2.py3-none-any.whl
# Collecting pandas>=0.22.0
#   Downloading pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 45.5 MB/s
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl (703 kB)
#      |████████████████████████████████| 703 kB 38.6 MB/s
# Collecting google-api-core<2dev,>=1.21.0
#   Downloading google_api_core-1.26.3-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 742 kB/s
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting httplib2<1dev,>=0.15.0
#   Downloading httplib2-0.19.1-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 2.6 MB/s
# Collecting uritemplate<4dev,>=3.0.0
#   Downloading uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Collecting google-auth<2dev,>=1.16.0
#   File was already downloaded /kaggle/working/google_auth-1.30.0-py2.py3-none-any.whl
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 41.1 MB/s
# Collecting setuptools>=40.3.0
#   File was already downloaded /kaggle/working/setuptools-56.1.0-py3-none-any.whl
# Collecting packaging>=14.3
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 3.4 MB/s
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 50.1 MB/s
# Collecting requests<3.0.0dev,>=2.18.0
#   File was already downloaded /kaggle/working/requests-2.25.1-py2.py3-none-any.whl
# Collecting protobuf>=3.12.0
#   File was already downloaded /kaggle/working/protobuf-3.15.8-cp37-cp37m-manylinux1_x86_64.whl
# Collecting rsa<5,>=3.1.4
#   File was already downloaded /kaggle/working/rsa-4.7.2-py3-none-any.whl
# Collecting cachetools<5.0,>=2.0.0
#   File was already downloaded /kaggle/working/cachetools-4.2.2-py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1
#   File was already downloaded /kaggle/working/pyasn1_modules-0.2.8-py2.py3-none-any.whl
# Collecting proto-plus>=1.10.0
#   Downloading proto_plus-1.18.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 895 kB/s
# Collecting google-cloud-core<2.0dev,>=1.4.1
#   Downloading google_cloud_core-1.6.0-py2.py3-none-any.whl (28 kB)
# Collecting google-resumable-media<2.0dev,>=0.6.0
#   Downloading google_resumable_media-1.2.0-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 2.8 MB/s
# Collecting grpcio<2.0dev,>=1.29.0
#   Downloading grpcio-1.37.1-cp37-cp37m-manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 47.0 MB/s
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.1.2-cp37-cp37m-manylinux2014_x86_64.whl (38 kB)
# Collecting cffi>=1.0.0
#   Downloading cffi-1.14.5-cp37-cp37m-manylinux1_x86_64.whl (402 kB)
#      |████████████████████████████████| 402 kB 42.2 MB/s
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 39.6 MB/s
# Collecting pyparsing<3,>=2.4.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 3.3 MB/s
# Collecting certifi
#   File was already downloaded /kaggle/working/certifi-2020.12.5-py2.py3-none-any.whl
# Collecting python-dateutil
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 36.1 MB/s
# Collecting tqdm
#   Downloading tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 2.5 MB/s
# Collecting python-slugify
#   Downloading python_slugify-5.0.0-py2.py3-none-any.whl (6.8 kB)
# Collecting urllib3
#   File was already downloaded /kaggle/working/urllib3-1.26.4-py2.py3-none-any.whl
# Collecting pyasn1<0.5.0,>=0.4.6
#   File was already downloaded /kaggle/working/pyasn1-0.4.8-py2.py3-none-any.whl
# Collecting chardet<5,>=3.0.2
#   File was already downloaded /kaggle/working/chardet-4.0.0-py2.py3-none-any.whl
# Collecting idna<3,>=2.5
#   File was already downloaded /kaggle/working/idna-2.10-py2.py3-none-any.whl
# Collecting h5py~=2.10.0
#   File was already downloaded /kaggle/working/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl
# Collecting google-pasta~=0.2
#   File was already downloaded /kaggle/working/google_pasta-0.2.0-py3-none-any.whl
# Collecting wrapt~=1.12.1
#   File was already downloaded /kaggle/working/wrapt-1.12.1.tar.gz
# Collecting opt-einsum~=3.3.0
#   File was already downloaded /kaggle/working/opt_einsum-3.3.0-py3-none-any.whl
# Collecting numpy>=1.15.4
#   File was already downloaded /kaggle/working/numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl
# Collecting tensorboard~=2.4
#   File was already downloaded /kaggle/working/tensorboard-2.5.0-py3-none-any.whl
# Collecting grpcio<2.0dev,>=1.29.0
#   File was already downloaded /kaggle/working/grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl
# Collecting typing-extensions~=3.7.4
#   File was already downloaded /kaggle/working/typing_extensions-3.7.4.3-py3-none-any.whl
# Collecting gast==0.3.3
#   File was already downloaded /kaggle/working/gast-0.3.3-py2.py3-none-any.whl
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   File was already downloaded /kaggle/working/tensorflow_estimator-2.4.0-py2.py3-none-any.whl
# Collecting astunparse~=1.6.3
#   File was already downloaded /kaggle/working/astunparse-1.6.3-py2.py3-none-any.whl
# Collecting flatbuffers~=1.12.0
#   File was already downloaded /kaggle/working/flatbuffers-1.12-py2.py3-none-any.whl
# Collecting wheel~=0.35
#   File was already downloaded /kaggle/working/wheel-0.36.2-py2.py3-none-any.whl
# Collecting absl-py~=0.10
#   File was already downloaded /kaggle/working/absl_py-0.12.0-py3-none-any.whl
# Collecting keras-preprocessing~=1.1.2
#   File was already downloaded /kaggle/working/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl
# Collecting termcolor~=1.1.0
#   File was already downloaded /kaggle/working/termcolor-1.1.0.tar.gz
# Collecting tensorboard-plugin-wit>=1.6.0
#   File was already downloaded /kaggle/working/tensorboard_plugin_wit-1.8.0-py3-none-any.whl
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   File was already downloaded /kaggle/working/tensorboard_data_server-0.6.0-py3-none-manylinux2010_x86_64.whl
# Collecting werkzeug>=0.11.15
#   File was already downloaded /kaggle/working/Werkzeug-1.0.1-py2.py3-none-any.whl
# Collecting markdown>=2.6.8
#   File was already downloaded /kaggle/working/Markdown-3.3.4-py3-none-any.whl
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   File was already downloaded /kaggle/working/google_auth_oauthlib-0.4.4-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.7.0
#   File was already downloaded /kaggle/working/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Collecting importlib-metadata
#   File was already downloaded /kaggle/working/importlib_metadata-4.0.1-py3-none-any.whl
# Collecting oauthlib>=3.0.0
#   File was already downloaded /kaggle/working/oauthlib-3.1.0-py2.py3-none-any.whl
# Collecting dm-tree~=0.1.1
#   Downloading dm_tree-0.1.6-cp37-cp37m-manylinux_2_24_x86_64.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.5 MB/s
# Collecting zipp>=0.5
#   File was already downloaded /kaggle/working/zipp-3.4.1-py3-none-any.whl
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 27.8 MB/s
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.7 MB/s
# Collecting scikit-learn>=0.21.3
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 43.1 MB/s
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 46.8 MB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting typeguard>=2.7
#   Downloading typeguard-2.12.0-py3-none-any.whl (16 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-5.1.2-py3-none-any.whl (25 kB)
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-0.30.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 359 kB/s
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 44.6 MB/s
# Collecting dill
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 5.2 MB/s
# Collecting attrs>=18.1.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 2.8 MB/s
# Saved ./tf_models_official-2.4.0-py2.py3-none-any.whl
# Saved ./google_api_python_client-2.3.0-py2.py3-none-any.whl
# Saved ./google_api_core-1.26.3-py2.py3-none-any.whl
# Saved ./google_auth_httplib2-0.1.0-py2.py3-none-any.whl
# Saved ./google_cloud_bigquery-2.15.0-py2.py3-none-any.whl
# Saved ./google_cloud_core-1.6.0-py2.py3-none-any.whl
# Saved ./google_resumable_media-1.2.0-py2.py3-none-any.whl
# Saved ./google_crc32c-1.1.2-cp37-cp37m-manylinux2014_x86_64.whl
# Saved ./cffi-1.14.5-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./googleapis_common_protos-1.53.0-py2.py3-none-any.whl
# Saved ./httplib2-0.19.1-py3-none-any.whl
# Saved ./kaggle-1.5.12.tar.gz
# Saved ./packaging-20.9-py2.py3-none-any.whl
# Saved ./pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./proto_plus-1.18.1-py3-none-any.whl
# Saved ./psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl
# Saved ./py-cpuinfo-8.0.0.tar.gz
# Saved ./pyparsing-2.4.7-py2.py3-none-any.whl
# Saved ./python_dateutil-2.8.1-py2.py3-none-any.whl
# Saved ./pytz-2021.1-py2.py3-none-any.whl
# Saved ./PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./tensorflow_model_optimization-0.5.0-py2.py3-none-any.whl
# Saved ./dm_tree-0.1.6-cp37-cp37m-manylinux_2_24_x86_64.whl
# Saved ./tf_slim-1.1.0-py2.py3-none-any.whl
# Saved ./uritemplate-3.0.1-py2.py3-none-any.whl
# Saved ./Cython-0.29.23-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./dataclasses-0.6-py3-none-any.whl
# Saved ./gin_config-0.4.0-py2.py3-none-any.whl
# Saved ./matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./cycler-0.10.0-py2.py3-none-any.whl
# Saved ./kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl
# Saved ./oauth2client-4.1.3-py2.py3-none-any.whl
# Saved ./opencv_python_headless-4.5.1.48-cp37-cp37m-manylinux2014_x86_64.whl
# Saved ./pycocotools-2.0.2.tar.gz
# Saved ./pycparser-2.20-py2.py3-none-any.whl
# Saved ./python_slugify-5.0.0-py2.py3-none-any.whl
# Saved ./text_unidecode-1.3-py2.py3-none-any.whl
# Saved ./sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl
# Saved ./seqeval-1.2.2.tar.gz
# Saved ./scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl
# Saved ./joblib-1.0.1-py3-none-any.whl
# Saved ./threadpoolctl-2.1.0-py3-none-any.whl
# Saved ./tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl
# Saved ./typeguard-2.12.0-py3-none-any.whl
# Saved ./tensorflow_datasets-4.2.0-py3-none-any.whl
# Saved ./attrs-20.3.0-py2.py3-none-any.whl
# Saved ./dill-0.3.3-py2.py3-none-any.whl
# Saved ./future-0.18.2.tar.gz
# Saved ./importlib_resources-5.1.2-py3-none-any.whl
# Saved ./promise-2.3.tar.gz
# Saved ./tensorflow_metadata-0.30.0-py3-none-any.whl
# Saved ./tqdm-4.60.0-py2.py3-none-any.whl
# Successfully downloaded tf-models-official google-api-python-client google-api-core google-auth cachetools google-auth-httplib2 google-cloud-bigquery google-cloud-core google-resumable-media google-crc32c cffi googleapis-common-protos httplib2 kaggle packaging pandas proto-plus protobuf psutil py-cpuinfo pyasn1-modules pyasn1 pyparsing python-dateutil pytz pyyaml requests certifi chardet idna rsa scipy six tensorflow gast absl-py astunparse flatbuffers google-pasta grpcio h5py keras-preprocessing numpy opt-einsum tensorboard google-auth-oauthlib markdown requests-oauthlib oauthlib tensorboard-data-server tensorboard-plugin-wit tensorflow-estimator tensorflow-hub tensorflow-model-optimization dm-tree termcolor tf-slim typing-extensions uritemplate urllib3 werkzeug wheel wrapt Cython dataclasses gin-config importlib-metadata zipp matplotlib cycler kiwisolver Pillow oauth2client opencv-python-headless pycocotools pycparser python-slugify text-unidecode sentencepiece seqeval scikit-learn joblib threadpoolctl tensorflow-addons typeguard tensorflow-datasets attrs dill future importlib-resources promise tensorflow-metadata tqdm setuptools
# Collecting setuptools_scm
#   Using cached setuptools_scm-6.0.1-py3-none-any.whl (27 kB)
# Collecting setuptools>=45
#   File was already downloaded /kaggle/working/setuptools-56.1.0-py3-none-any.whl
# Saved ./setuptools_scm-6.0.1-py3-none-any.whl
# Successfully downloaded setuptools-scm setuptools

# %%
! ls
# Out:
# Cython-0.29.23-cp37-cp37m-manylinux1_x86_64.whl
# Keras_Preprocessing-1.1.2-py2.py3-none-any.whl
# Markdown-3.3.4-py3-none-any.whl
# Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl
# PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl
# Werkzeug-1.0.1-py2.py3-none-any.whl
# __notebook__.ipynb
# absl_py-0.12.0-py3-none-any.whl
# astunparse-1.6.3-py2.py3-none-any.whl
# attrs-20.3.0-py2.py3-none-any.whl
# cachetools-4.2.2-py3-none-any.whl
# certifi-2020.12.5-py2.py3-none-any.whl
# cffi-1.14.5-cp37-cp37m-manylinux1_x86_64.whl
# chardet-4.0.0-py2.py3-none-any.whl
# cycler-0.10.0-py2.py3-none-any.whl
# dataclasses-0.6-py3-none-any.whl
# dill-0.3.3-py2.py3-none-any.whl
# dm_tree-0.1.6-cp37-cp37m-manylinux_2_24_x86_64.whl
# flatbuffers-1.12-py2.py3-none-any.whl
# future-0.18.2.tar.gz
# gast-0.3.3-py2.py3-none-any.whl
# gin_config-0.4.0-py2.py3-none-any.whl
# google_api_core-1.26.3-py2.py3-none-any.whl
# google_api_python_client-2.3.0-py2.py3-none-any.whl
# google_auth-1.30.0-py2.py3-none-any.whl
# google_auth_httplib2-0.1.0-py2.py3-none-any.whl
# google_auth_oauthlib-0.4.4-py2.py3-none-any.whl
# google_cloud_bigquery-2.15.0-py2.py3-none-any.whl
# google_cloud_core-1.6.0-py2.py3-none-any.whl
# google_crc32c-1.1.2-cp37-cp37m-manylinux2014_x86_64.whl
# google_pasta-0.2.0-py3-none-any.whl
# google_resumable_media-1.2.0-py2.py3-none-any.whl
# googleapis_common_protos-1.53.0-py2.py3-none-any.whl
# grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl
# h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl
# httplib2-0.19.1-py3-none-any.whl
# idna-2.10-py2.py3-none-any.whl
# importlib_metadata-4.0.1-py3-none-any.whl
# importlib_resources-5.1.2-py3-none-any.whl
# joblib-1.0.1-py3-none-any.whl
# kaggle-1.5.12.tar.gz
# kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl
# matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl
# numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl
# oauth2client-4.1.3-py2.py3-none-any.whl
# oauthlib-3.1.0-py2.py3-none-any.whl
# opencv_python_headless-4.5.1.48-cp37-cp37m-manylinux2014_x86_64.whl
# opt_einsum-3.3.0-py3-none-any.whl
# packaging-20.9-py2.py3-none-any.whl
# pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl
# promise-2.3.tar.gz
# proto_plus-1.18.1-py3-none-any.whl
# protobuf-3.15.8-cp37-cp37m-manylinux1_x86_64.whl
# psutil-5.8.0-cp37-cp37m-manylinux2010_x86_64.whl
# py-cpuinfo-8.0.0.tar.gz
# pyasn1-0.4.8-py2.py3-none-any.whl
# pyasn1_modules-0.2.8-py2.py3-none-any.whl
# pycocotools-2.0.2.tar.gz
# pycparser-2.20-py2.py3-none-any.whl
# pyparsing-2.4.7-py2.py3-none-any.whl
# python_dateutil-2.8.1-py2.py3-none-any.whl
# python_slugify-5.0.0-py2.py3-none-any.whl
# pytz-2021.1-py2.py3-none-any.whl
# requests-2.25.1-py2.py3-none-any.whl
# requests_oauthlib-1.3.0-py2.py3-none-any.whl
# rsa-4.7.2-py3-none-any.whl
# scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl
# scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl
# sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl
# seqeval-1.2.2.tar.gz
# setuptools-56.1.0-py3-none-any.whl
# setuptools_scm-6.0.1-py3-none-any.whl
# six-1.15.0-py2.py3-none-any.whl
# tensorboard-2.5.0-py3-none-any.whl
# tensorboard_data_server-0.6.0-py3-none-manylinux2010_x86_64.whl
# tensorboard_plugin_wit-1.8.0-py3-none-any.whl
# tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl
# tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl
# tensorflow_datasets-4.2.0-py3-none-any.whl
# tensorflow_estimator-2.4.0-py2.py3-none-any.whl
# tensorflow_hub-0.12.0-py2.py3-none-any.whl
# tensorflow_metadata-0.30.0-py3-none-any.whl
# tensorflow_model_optimization-0.5.0-py2.py3-none-any.whl
# tensorflow_text-2.4.3-cp37-cp37m-manylinux1_x86_64.whl
# termcolor-1.1.0.tar.gz
# text_unidecode-1.3-py2.py3-none-any.whl
# tf_models_official-2.4.0-py2.py3-none-any.whl
# tf_slim-1.1.0-py2.py3-none-any.whl
# threadpoolctl-2.1.0-py3-none-any.whl
# tqdm-4.60.0-py2.py3-none-any.whl
# typeguard-2.12.0-py3-none-any.whl
# typing_extensions-3.7.4.3-py3-none-any.whl
# uritemplate-3.0.1-py2.py3-none-any.whl
# urllib3-1.26.4-py2.py3-none-any.whl
# wheel-0.36.2-py2.py3-none-any.whl
# wrapt-1.12.1.tar.gz
# zipp-3.4.1-py3-none-any.whl

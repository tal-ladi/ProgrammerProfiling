# %% [markdown]
# RMS Titanic was a British passenger liner that sank in the North Atlantic Ocean in the early hours of 15 April 1912, after colliding with an iceberg during her maiden voyage from Southampton to New York City. There were an estimated 2,224 passengers and crew aboard, and more than 1,500 died, making it one of the deadliest commercial peacetime maritime disasters in modern history. RMS Titanic was the largest ship afloat at the time she entered service and was the second of three Olympic-class ocean liners operated by the White Star Line.

# %% [markdown]
# <img src="https://miro.medium.com/max/750/0*wKmr2Sffqkr9FimI.gif" alt="vac" border="0"></a>

# %% [markdown]
# The “Titanic: Machine Learning from Disaster” is a classical problem for beginners in Machine Learning.
# The challenge is to predict, based on a set of training data, which people would survive the disaster and which would not. Obviously, this is just a challenge to try discover a correlation between the features of the people who survived and not and use it to make predictions.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %% [markdown]
# # Understanding problem/ Discovering Data
# In this notebook, we will build a predictive model that is going to predict what sort of people were more likely to survive in the shipwreck Titatic. The data is provided to us in 2 sets : train dataset and test set.

# %%
#titanic_features = pd.read_csv('train.csv')
df = pd.read_csv("../input/titanic/train.csv")
df_test = pd.read_csv("../input/titanic/test.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Exploratory Data Analysis:
# The Beginning When you download the data from the Kaggle, they make available 2 datasets. One corresponds to train, with data to train your model, this dataset already have the answer of who survived and who not. And before you ask me, I don’t know if this is true. But we have some problems in this data …

# %% [markdown]
# # Checking missing values in the dataset

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# The Embarked feature has only 2 missing values, which can easily be filled. It will be much more tricky, to deal with the ‘Age’ feature, which has 177 missing values. The ‘Cabin’ feature needs further investigation.

# %%
import seaborn as sns
sns.heatmap(df.isnull(), yticklabels = False, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <img src="https://miro.medium.com/max/660/0*aF7XRizN9CFij6cK.gif" alt="vac" border="0"></a>

# %% [markdown]
# We have few data for this problem. But that doesn’t mean we can’t solve the problem!

# %% [markdown]
# # Features:
# + PassengerId: Unique Id of a passenger
# + Survival: Survival
# + Pclass: Ticket class
# + Name:
# + Sex: Sex
# + Age: Age in years
# + Sibsp: # of siblings / spouses aboard the Titanic
# + Parch: # of parents / children aboard the Titanic
# + Ticket: Ticket number
# + Fare: Passenger fare
# + Cabin: Cabin number
# + Embarked: Port of Embarkation
#
# From the table above, we can note a few things:
# + We have a few categorical variabes that need to be either converted to numerical or one-hot encoded, so that the machine learning algorithms can process them.
# + The features have widely different ranges, and we will need to convert into roughly the same scale.
# + Some features contain missing values (NaN = not a number), that we need to deal with.

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# As the observation above, we already see Age and Cabin have numbers of missing data. Depends on the dataset we would consider how to deal with these missing data. Since our dataset is not a big data, dropping columns might not be a good idea in this case but also depends on how much that data meaningful contribute to our dataset. Now, check in detail ...

# %% [markdown]
# Overall look on Survived data we have in our training set as we know the main point of this analyzation is about who were more likely to survive and who were not.

# %%
sns.set_style('ticks')
sns.countplot(x='Survived', data = df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# Usign countplot helps us to see the overall of Survived / Not survived and as we can see the number of people who were not survived is higher than people survived :(

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', hue='Sex', data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# Lets see one more feature, Pclass and see how Pclass tells us about who were survived or not.

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', hue='Pclass', data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# So obviously we could give a unfailry conclude here that people in 1st class were likely have more chance to survive and there were many people in the 3rd class died.

# %%
sns.set_style('whitegrid')
sns.countplot(x='SibSp', data=df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
import pandas as pd
import plotly.express as px
temp = df.groupby(by="Cabin").count()
name = temp.Survived.index
val = temp.Survived.values

fig = px.scatter_polar(temp, r=val, theta=name,color=name, symbol=val, 
                       size=val,color_discrete_sequence=px.colors.sequential.Plasma_r, title='Survived by Cabin')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="ad2b42a5-5796-4f52-95d0-cd09a2395789" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad2b42a5-5796-4f52-95d0-cd09a2395789")) {                    Plotly.newPlot(                        "ad2b42a5-5796-4f52-95d0-cd09a2395789",                        [{"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A10, 1", "marker": {"color": "#f0f921", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A10, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A10"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A14, 1", "marker": {"color": "#fdca26", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A14, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A14"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A16, 1", "marker": {"color": "#fb9f3a", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A16, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A16"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A19, 1", "marker": {"color": "#ed7953", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A19, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A19"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A20, 1", "marker": {"color": "#d8576b", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A20, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A20"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A23, 1", "marker": {"color": "#bd3786", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A23, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A23"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A24, 1", "marker": {"color": "#9c179e", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A24, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A24"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A26, 1", "marker": {"color": "#7201a8", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A26, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A26"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A31, 1", "marker": {"color": "#46039f", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A31, 1", "r": [1], "showlegend": true, "subplot": "polar", "theta": ["A31"], "type": "scatterpolar"}, {"hovertemplate": "Cabin=%{theta}<br>symbol=1<br>r=%{r}<br>size=%{marker.size}<extra></extra>", "legendgroup": "A32, 1", "marker": {"color": "#0d0887", "size": [1], "sizemode": "area", "sizeref": 0.01, "symbol": "circle"}, "mode": "markers", "name": "A32, 1", "r": [1], "showlegend": true, "s ...

# %%
import plotly.express as px
t0 = df.iloc[(df["Survived"]==0).values]
t1 = df.iloc[(df["Survived"]==1).values]

temp0 = t0.groupby(by="Embarked").count()
name0 = temp0.Survived.index
val0 = temp0.Survived.values

temp1 = t1.groupby(by="Embarked").count()
name1 = temp1.Survived.index
val1 = temp1.Survived.values

fig = px.scatter_polar(r=val1+val0, theta=name1,color=np.round(val1/(val0+val1)*100,0), 
                       symbol=val0, size=np.round(val1/(val0+val1)*100,0),
                       color_discrete_sequence=px.colors.sequential.Plasma_r, title='Survived by Cabin')
fig.show()
# Out:
# <div>                            <div id="df3ae4ba-0dc0-4886-81aa-23bf1030590f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df3ae4ba-0dc0-4886-81aa-23bf1030590f")) {                    Plotly.newPlot(                        "df3ae4ba-0dc0-4886-81aa-23bf1030590f",                        [{"hovertemplate": "symbol=75<br>r=%{r}<br>theta=%{theta}<br>size=%{marker.size}<br>color=%{marker.color}<extra></extra>", "legendgroup": "75", "marker": {"color": [55.0], "coloraxis": "coloraxis", "size": [55.0], "sizemode": "area", "sizeref": 0.1375, "symbol": "circle"}, "mode": "markers", "name": "75", "r": [168], "showlegend": true, "subplot": "polar", "theta": ["C"], "type": "scatterpolar"}, {"hovertemplate": "symbol=47<br>r=%{r}<br>theta=%{theta}<br>size=%{marker.size}<br>color=%{marker.color}<extra></extra>", "legendgroup": "47", "marker": {"color": [39.0], "coloraxis": "coloraxis", "size": [39.0], "sizemode": "area", "sizeref": 0.1375, "symbol": "diamond"}, "mode": "markers", "name": "47", "r": [77], "showlegend": true, "subplot": "polar", "theta": ["Q"], "type": "scatterpolar"}, {"hovertemplate": "symbol=427<br>r=%{r}<br>theta=%{theta}<br>size=%{marker.size}<br>color=%{marker.color}<extra></extra>", "legendgroup": "427", "marker": {"color": [34.0], "coloraxis": "coloraxis", "size": [34.0], "sizemode": "area", "sizeref": 0.1375, "symbol": "square"}, "mode": "markers", "name": "427", "r": [644], "showlegend": true, "subplot": "polar", "theta": ["S"], "type": "scatterpolar"}],                        {"coloraxis": {"colorbar": {"title": {"text": "color"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"itemsizing": "constant", "title": {"text": "symbol"}, "tracegroupgap": 0}, "polar": {"angularaxis": {"direction": "clockwise", "rotation": 90}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [ ...

# %% [markdown]
# + Over 72% of the passengers embarked from the port ‘Southampton’, 18% from the port ‘Cherbourg’ and the rest from the port ‘Queenstown’.
# + Passengers from port ‘Southampton’ have a low survival rate of 34%, while those from the port ‘Cherbourg’ have a survival rate of 55%.

# %%
import plotly.express as px
man = df.iloc[((df["Survived"]==1)&(df["Sex"]=="male")).values]
woman = df.iloc[((df["Survived"]==1)&(df["Sex"]=="female")).values]

M = man.groupby(by="Embarked").count()
name = M.Survived.index
Mn = M.Survived.values

F = woman.groupby(by="Embarked").count()
Fn = F.Survived.values

fig = px.scatter_polar(r=Mn + Fn, theta=name,color=np.round(Mn/(Mn+Fn)*100,0), 
                       symbol=Fn, size=np.round(Fn/(Mn+Fn)*100,0),
                       color_discrete_sequence=px.colors.sequential.Plasma_r, title='Survived by Cabin')
fig.show()
# Out:
# <div>                            <div id="8903fc67-8f93-4582-ac8a-5366d134531a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8903fc67-8f93-4582-ac8a-5366d134531a")) {                    Plotly.newPlot(                        "8903fc67-8f93-4582-ac8a-5366d134531a",                        [{"hovertemplate": "symbol=64<br>r=%{r}<br>theta=%{theta}<br>size=%{marker.size}<br>color=%{marker.color}<extra></extra>", "legendgroup": "64", "marker": {"color": [31.0], "coloraxis": "coloraxis", "size": [69.0], "sizemode": "area", "sizeref": 0.225, "symbol": "circle"}, "mode": "markers", "name": "64", "r": [93], "showlegend": true, "subplot": "polar", "theta": ["C"], "type": "scatterpolar"}, {"hovertemplate": "symbol=27<br>r=%{r}<br>theta=%{theta}<br>size=%{marker.size}<br>color=%{marker.color}<extra></extra>", "legendgroup": "27", "marker": {"color": [10.0], "coloraxis": "coloraxis", "size": [90.0], "sizemode": "area", "sizeref": 0.225, "symbol": "diamond"}, "mode": "markers", "name": "27", "r": [30], "showlegend": true, "subplot": "polar", "theta": ["Q"], "type": "scatterpolar"}, {"hovertemplate": "symbol=140<br>r=%{r}<br>theta=%{theta}<br>size=%{marker.size}<br>color=%{marker.color}<extra></extra>", "legendgroup": "140", "marker": {"color": [35.0], "coloraxis": "coloraxis", "size": [65.0], "sizemode": "area", "sizeref": 0.225, "symbol": "square"}, "mode": "markers", "name": "140", "r": [217], "showlegend": true, "subplot": "polar", "theta": ["S"], "type": "scatterpolar"}],                        {"coloraxis": {"colorbar": {"title": {"text": "color"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "legend": {"itemsizing": "constant", "title": {"text": "symbol"}, "tracegroupgap": 0}, "polar": {"angularaxis": {"direction": "clockwise", "rotation": 90}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.22 ...

# %% [markdown]
# + Women have a survival rate of 65%, while men have a survival rate of about 35%.
# + Women on port Q and on port S have a higher chance of survival (90%). The inverse is true, if they are at port C.
# + Men have a high survival probability if they are on port C, but a low probability if they are on port Q or S.

# %%
S = df.iloc[(df["Survived"]==1).values]
temp = S.groupby(by="Pclass").count()
name = temp.Survived.index
val = temp.Survived.values
fig = px.pie(temp, values=val, names=name, title='Survived by Pclass')
fig.show()
# Out:
# <div>                            <div id="3b5ac2e2-806b-4ddc-8648-d5e554c9553b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b5ac2e2-806b-4ddc-8648-d5e554c9553b")) {                    Plotly.newPlot(                        "3b5ac2e2-806b-4ddc-8648-d5e554c9553b",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Pclass=%{label}<br>value=%{value}<extra></extra>", "labels": [1, 2, 3], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [136, 87, 119]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [ ...

# %%
S = df.iloc[(df["Survived"]==1).values]
temp = S.groupby(by="Sex").count()
name = temp.Survived.index
val = temp.Survived.values
fig = px.pie(temp, values=val, names=name, title='Survived by Sex')
fig.show()
# Out:
# <div>                            <div id="a0b4be7d-9db3-4b77-a3e8-ff3972a30e6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0b4be7d-9db3-4b77-a3e8-ff3972a30e6d")) {                    Plotly.newPlot(                        "a0b4be7d-9db3-4b77-a3e8-ff3972a30e6d",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Sex=%{label}<br>value=%{value}<extra></extra>", "labels": ["female", "male"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [233, 109]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": ...

# %% [markdown]
# So among more than thousands of people in the ship, lets see what was the Age of these people through distribution plot.
# + You can see that men have a high probability of survival when they are between 18 and 30 years old, which is also a little bit true for women but not fully.
# + For women the survival chances are higher between 14 and 40.
# + For men the probability of survival is very low between the age of 5 and 18, but that isn’t true for women.
# + Another thing to note is that infants also have a little bit higher probability of survival.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
grid = sns.FacetGrid(df, col='Survived', row='Pclass', size=3.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/axisgrid.py:316: UserWarning:
#
# The `size` parameter has been renamed to `height`; please update your code.

# %% [markdown]
# The plot above confirms our assumption about pclass 1, but we can also spot a high probability that a person in pclass 3 will not survive.

# %% [markdown]
# # Adapting the Data and solving Inconsistencies
# I’ll just resume the problems of these data and how we can solve it, the focus of this post is build a model who will works to our problem.

# %%
df.shape
# Out:
# (891, 12)

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_train = df.drop(columns="Survived")
df_train.head(2)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
ntrain = df_train.shape[0]
ntest = df_test.shape[0]
y = df.Survived

data = pd.concat((df_train, df_test)).reset_index(drop=True) 
data.shape
# Out:
# (1309, 11)

# %%
data.head(2)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
data.head(2)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0  A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# Now, it's time to deal with our cabin column. As we saw above, Cabin column is the column contains many NaN values. As I mentioned this is not only a messy data but also not a huge big data with a lot of features, so fill in the gaps by leverage the data instead of losing observations. I will fill the missing values by character "U" for unknow in Cabin column.
#
# The rest values contain a character and numbers follow behind that character, I decide to just extract the first letter of the Cabin column value to get a general information out of this big missing value column.

# %% [markdown]
# We will use the Name feature to extract the Titles from the Name, so that we can build a new feature out of that.

# %%
data['Title'] = data['Name'].apply(lambda x: x.split(",")[1].split(".")[0])

# %% [markdown]
# As a reminder, we have to deal with Cabin (687), Embarked (2) and Age (177). First I thought, we have to delete the ‘Cabin’ variable but then I found something interesting. A cabin number looks like ‘C123’ and the letter refers to the deck. Therefore we’re going to extract these and create a new feature, that contains a persons deck. Afterwords we will convert the feature into a numeric variable.

# %%
data.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Title'],
#       dtype='object')

# %%
data['Cabin'] = data['Cabin'].fillna("C")

#Turning cabin number into Deck
data['Deck'] = data['Cabin'].str[:1]

data["Cabin"] = data["Cabin"].factorize()[0]

data['Age'] = data['Age'].fillna(data.Age.mean())
data['Embarked'] = data['Embarked'].fillna("S")
data['Fare'] = data['Fare'].fillna(-999)
data["Fare"] = (data["Fare"] - data["Fare"].min()) / (data["Fare"].max() - data["Fare"].min())

data["Avg_Fare"] = data["Fare"] / (1 + data["SibSp"] + data["Parch"])
data["relatives"] = data["SibSp"] + data["Parch"]

data["Sex"] = data["Sex"].factorize()[0]
data["Embarked"] = data["Embarked"].factorize()[0]
data["Name"] = data["Name"].factorize()[0]
data["Avg_Age"] = (data["Age"] - data["Age"].mean()) / data["Age"].std()
data["Ticket"] = data["Ticket"].factorize()[0]

# %%
data.head(2)
# Out:
#    PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket      Fare  \
# 0            1       3     0    0  22.0      1      0       0  0.665805
# 1            2       1     1    1  38.0      1      0       1  0.708174
#
#    Cabin  Embarked Title Deck  Avg_Fare  relatives   Avg_Age
# 0      0         0    Mr    C  0.332902          1 -0.611738
# 1      1         1   Mrs    C  0.354087          1  0.630190

# %% [markdown]
# Considering theory that Name, PassengerId are not having any significant contribution for our data, we decide to drop them.

# %%
data = data.drop(columns = ["PassengerId"])

# %%
data.isnull().sum()
# Out:
# Pclass       0
# Name         0
# Sex          0
# Age          0
# SibSp        0
# Parch        0
# Ticket       0
# Fare         0
# Cabin        0
# Embarked     0
# Title        0
# Deck         0
# Avg_Fare     0
# relatives    0
# Avg_Age      0
# dtype: int64

# %%
from scipy.stats import norm, skew

numeric_feats = data.dtypes[data.dtypes != 'object'].index
skewed_feats = data[numeric_feats].apply(lambda x: skew(x)).sort_values(ascending=False)
high_skew = skewed_feats[abs(skewed_feats) > 0.5]
high_skew
# Out:
# SibSp        3.839814
# Parch        3.664872
# relatives    2.849808
# Cabin        2.358506
# Embarked     1.406496
# Sex          0.601499
# Pclass      -0.597961
# Avg_Fare    -0.607741
# Fare        -1.108328
# dtype: float64

# %% [markdown]
# We converted these "high skew" columns to "normal" by taking logarith:

# %%
for feature in high_skew.index:
    data[feature] = np.log1p(np.abs(data[feature]))

# %% [markdown]
# Fill null values with random numbers, which are computed based on the mean age value in regards to the standard deviation.

# %%
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict

# build dictionary function
cols=np.array(data.columns[data.dtypes != object])
d = defaultdict(LabelEncoder)

# only for categorical columns apply dictionary by calling fit_transform 
trainL = data.apply(lambda x: d[x.name].fit_transform(x))
trainL[cols] = data[cols]

# %%
trainL.head(2)
# Out:
#      Pclass  Name       Sex   Age     SibSp  Parch  Ticket      Fare  \
# 0  1.386294     0  0.000000  22.0  0.693147    0.0       0  0.510308
# 1  0.693147     1  0.693147  38.0  0.693147    0.0       1  0.535425
#
#       Cabin  Embarked  Title  Deck  Avg_Fare  relatives   Avg_Age
# 0  0.000000  0.000000     12     2  0.287359   0.693147 -0.611738
# 1  0.693147  0.693147     13     2  0.303127   0.693147  0.630190

# %%
#from sklearn.preprocessing import StandardScaler
# Capture all the numerical features so that we can scale them later
#numerical_features = list(trainL.select_dtypes(include=['int64', 'float64', 'int32']).columns)
#numerical_features

# Feature scaling - Standard scaler
#SS = StandardScaler()
#dataS = pd.DataFrame(data = trainL)
#dataS[numerical_features] = SS.fit_transform(dataS[numerical_features])

# %%
dataS = trainL
dataS.head(2)
# Out:
#      Pclass  Name       Sex   Age     SibSp  Parch  Ticket      Fare  \
# 0  1.386294     0  0.000000  22.0  0.693147    0.0       0  0.510308
# 1  0.693147     1  0.693147  38.0  0.693147    0.0       1  0.535425
#
#       Cabin  Embarked  Title  Deck  Avg_Fare  relatives   Avg_Age
# 0  0.000000  0.000000     12     2  0.287359   0.693147 -0.611738
# 1  0.693147  0.693147     13     2  0.303127   0.693147  0.630190

# %%
dataS.shape
# Out:
# (1309, 15)

# %% [markdown]
# # ML Modelling

# %% [markdown]
# Now, we finished the worse part of your problem. It’s time to make Machine Learning, baby!
#
# <img src="https://i.gifer.com/3Y0.gif" alt="vac" border="0"></a>

# %%
X = dataS[:ntrain].values
Z = dataS[ntrain:].values
y = df['Survived'].values

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from numpy import where
import collections

counter = collections.Counter(y)
print(counter)

smt = SMOTE(random_state=0)
X, y = smt.fit_sample(X, y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
counter = collections.Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
    row_ix = where(y == label)[0]
    plt.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
    plt.legend()
    plt.show()
# Out:
# Counter({0: 549, 1: 342})
# Counter({0: 549, 1: 549})

# %% [markdown]
# Now, we creat a function to calculate the deviations and to illustrate the results:

# %%
def Models(models, title, X_train, X_test, y_train, y_test, X, y):
    model = models
    model.fit(X_train,y_train)
    
    train_matrix = pd.crosstab(y_train, model.predict(X_train), rownames=['Actual'], colnames=['Predicted'])    
    test_matrix = pd.crosstab(y_test, model.predict(X_test), rownames=['Actual'], colnames=['Predicted'])
    matrix = pd.crosstab(y, model.predict(X), rownames=['Actual'], colnames=['Predicted'])
    
    f,(ax1,ax2,ax3) = plt.subplots(1,3,sharey=True, figsize=(15, 2))
    
    g1 = sns.heatmap(train_matrix, annot=True, fmt=".1f", cbar=False,annot_kws={"size": 18},ax=ax1)
    g1.set_title(title)
    g1.set_ylabel('Total = {}'.format(y_train.sum()), fontsize=14, rotation=90)
    g1.set_xlabel('Accuracy score (TrainSet): {}'.format(accuracy_score(model.predict(X_train), y_train)))
    g1.set_xticklabels(['Not Survived','Survived'],fontsize=12)

    g2 = sns.heatmap(test_matrix, annot=True, fmt=".1f",cbar=False,annot_kws={"size": 18},ax=ax2)
    g2.set_ylabel('Total = {}'.format(y_test.sum()), fontsize=14, rotation=90)
    g2.set_xlabel('Accuracy score (TestSet): {}'.format(accuracy_score(model.predict(X_test), y_test)))
    g2.set_xticklabels(['Not Survived','Survived'],fontsize=12)

    g3 = sns.heatmap(matrix, annot=True, fmt=".1f",cbar=False,annot_kws={"size": 18},ax=ax3)
    g3.set_ylabel('Total = {}'.format(y.sum()), fontsize=14, rotation=90)
    g3.set_xlabel('Accuracy score (Total): {}'.format(accuracy_score(model.predict(X), y)))
    g3.set_xticklabels(['Not Survived','Survived'],fontsize=12)
    plt.show()

# %% [markdown]
# And other function to show the precision and recovery curves of each model:

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
def ROCs(model):
    y_scores = model.predict_proba(X_train)
    y_scores = y_scores[:,1]
    precision, recall, threshold = precision_recall_curve(y_train, y_scores)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, y_scores)

    f,(ax1,ax2,ax3) = plt.subplots(1,3,sharey=True, figsize=(25, 7))

    ax1.plot(threshold, precision[:-1], "r-", label="precision", linewidth=2)
    ax1.plot(threshold, recall[:-1], "b", label="recall", linewidth=2)
    ax1.legend(loc="upper right", fontsize=14)
    ax1.set_xlabel("threshold", fontsize=14)
    ax1.axis([0, 1., 0, 1.])

    ax2.plot(recall, precision, "g--", linewidth=2)
    ax2.set_ylabel("recall", fontsize=14, rotation=90)
    ax2.set_xlabel("precision", fontsize=14)
    ax2.axis([0, 1., 0, 1.])

    ax3.plot(false_positive_rate, true_positive_rate, linewidth=2, label=label)
    ax3.plot([0, 1], [0, 1], 'r', linewidth=4)
    ax3.axis([0, 1, 0, 1])
    ax3.set_xlabel('False Positive Rate (FPR)', fontsize=14)
    ax3.set_ylabel('True Positive Rate (TPR)', fontsize=14)

    plt.show()

# %% [markdown]
# We start first with the CatBoostClassifier model:

# %%
# %%time
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

params = {'loss_function':'Logloss','eval_metric':'AUC','verbose': False,
          'learning_rate': 0.05,'depth': 2,'l2_leaf_reg': 1,'n_estimators': 100}
CBC = CatBoostClassifier(**params)
Models(CBC, "CatBoostClassifier", X_train, X_test, y_train, y_test, X, y)
# Out:
# CPU times: user 631 ms, sys: 47.9 ms, total: 679 ms
# Wall time: 854 ms

# %% [markdown]
# <img src="https://i.gifer.com/4j.gif" alt="vac" border="0"></a>

# %% [markdown]
# # Precision Recall Curve
# For each person the model has to classify, it computes a probability based on a function and it classifies the person as survived (when the score is bigger the than threshold) or as not survived (when the score is smaller than the threshold). That’s why the threshold plays an important part. We will plot the precision and recall with the threshold:

# %%
ROCs(CBC)

# %% [markdown]
# + Above you can clearly see that the recall is falling of rapidly at a precision of around 82%. Because of that you may want to select the precision/recall tradeoff before that.
# + You are now able to choose a threshold, that gives you the best precision/recall tradeoff for your current machine learning problem. If you want for example a precision of 80%, you can easily look at the plots and see that you would need a threshold of around 0.4. Then you could train a model with exactly that threshold and would get the desired accuracy.
#
# Another way is to plot the precision and recall against each other:

# %% [markdown]
# # ROC AUC Curve
# Another way to evaluate and compare your binary classifier is provided by the ROC AUC Curve. This curve plots the true positive rate (also called recall) against the false positive rate (ratio of incorrectly classified negative instances), instead of plotting the precision versus the recall.
#
# + The red line in the middel represents a purely random classifier (e.g a coin flip) and therefore your classifier should be as far away from it as possible. Our  model seems to do a good job.
# + We also have a tradeoff here, because the classifier produces more false positives, the higher the true positive rate is.
#
# # ROC AUC Score
# + The ROC AUC Score is the corresponding score to the ROC AUC Curve. It is simply computed by measuring the area under the curve, which is called AUC.
# + A classifiers that is 100% correct, would have a ROC AUC Score of 1 and a completely random classiffier would have a score of 0.5.

# %% [markdown]
# # Gradient Boost

# %%
from sklearn.ensemble.gradient_boosting import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import fbeta_score, make_scorer

param_test1 = {
    'n_estimators': [120, 130,140],
    'max_depth': [1, 2, 3],
    'subsample':[0.3, 0.5, 0.7, 1],
    'learning_rate': [0.006, 0.008, 0.01],
    'max_features': [0.3, 0.5, 0.7, 1]
}

scoring = {'AUC': 'roc_auc', 'Accuracy': make_scorer(accuracy_score)}

gsearch1 = GridSearchCV(estimator = GradientBoostingClassifier(), 
                       param_grid = param_test1, scoring=scoring, iid=False, cv=3, verbose = 5, refit='Accuracy')
gsearch1.fit(X_train, y_train)
gsearch1.best_params_, gsearch1.best_score_
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning:
#
# The sklearn.ensemble.gradient_boosting module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# Fitting 3 folds for each of 432 candidates, totalling 1296 fits
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.3, AUC=0.912, Accuracy=0.836, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.3, AUC=0.879, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.3, AUC=0.872, Accuracy=0.807, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.5, AUC=0.911, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.5, AUC=0.878, Accuracy=0.804, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.5
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.5, AUC=0.870, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.7, AUC=0.908, Accuracy=0.823, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.7, AUC=0.878, Accuracy=0.794, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=0.7, AUC=0.867, Accuracy=0.807, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=1, AUC=0.910, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=1, AUC=0.876, Accuracy=0.785, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=120, subsample=1, AUC=0.867, Accuracy=0.804, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.3, AUC=0.912, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.3, AUC=0.879, Accuracy=0.791, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.3, AUC=0.868, Accuracy=0.804, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.5, AUC=0.914, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.5, AUC=0.877, Accuracy=0.801, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.5, AUC=0.869, Accuracy=0.807, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.7, AUC=0.911, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.7, AUC=0.879, Accuracy=0.810, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=0.7, AUC=0.870, Accuracy=0.807, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=1, AUC=0.911, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=1, AUC=0.880, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=130, subsample=1, AUC=0.868, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.3, AUC=0.911, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.3, AUC=0.872, Accuracy=0.778, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.3, AUC=0.864, Accuracy=0.791, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.5, AUC=0.913, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.5, AUC=0.878, Accuracy=0.801, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.5, AUC=0.869, Accuracy=0.801, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.7, AUC=0.910, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.7, AUC=0.864, Accuracy=0.772, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=0.7, AUC=0.872, Accuracy=0.810, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=1, AUC=0.912, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=1, AUC=0.882, Accuracy=0.794, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.3, n_estimators=140, subsample=1, AUC=0.867, Accuracy=0.804, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.3, AUC=0.909, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.3, AUC=0.881, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.3, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.5, AUC=0.911, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.5, AUC=0.877, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.5, AUC=0.861, Accuracy=0.807, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.7, AUC=0.910, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.7, AUC=0.881, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=0.7, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=1, AUC=0.909, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=1, AUC=0.881, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=120, subsample=1, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.3, AUC=0.908, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.3, AUC=0.876, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.3, AUC=0.866, Accuracy=0.801, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.5, AUC=0.908, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.5, AUC=0.878, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.5, AUC=0.860, Accuracy=0.807, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.7, AUC=0.909, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.7, AUC=0.880, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=0.7, AUC=0.863, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=1, AUC=0.909, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=1, AUC=0.883, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=130, subsample=1, AUC=0.862, Accuracy=0.807, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.3, AUC=0.907, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.3, AUC=0.876, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.3, AUC=0.859, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.5, AUC=0.908, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.5, AUC=0.883, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.5, AUC=0.865, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.7, AUC=0.909, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.7, AUC=0.881, Accuracy=0.823, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=0.7, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=1, AUC=0.909, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=1, AUC=0.881, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.5, n_estimators=140, subsample=1, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.3, AUC=0.907, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.3, AUC=0.877, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.3, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.5, AUC=0.907, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.5, AUC=0.877, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.5, AUC=0.860, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.7, AUC=0.908, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.7, AUC=0.876, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=0.7, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=1, AUC=0.907, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=120, subsample=1, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.3, AUC=0.911, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.3, AUC=0.874, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.3, AUC=0.859, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.5, AUC=0.910, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.5, AUC=0.878, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.5, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.7, AUC=0.907, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.7, AUC=0.878, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=0.7, AUC=0.865, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=1, AUC=0.908, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=1, AUC=0.879, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=130, subsample=1, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.3, AUC=0.913, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.3, AUC=0.874, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.3, AUC=0.858, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.5, AUC=0.909, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.5, AUC=0.879, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.5, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.7, AUC=0.908, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.7, AUC=0.876, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=0.7, AUC=0.864, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=1, AUC=0.907, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=1, AUC=0.876, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=0.7, n_estimators=140, subsample=1, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.3, AUC=0.894, Accuracy=0.791, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.3, AUC=0.866, Accuracy=0.765, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.3, AUC=0.841, Accuracy=0.785, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.5, AUC=0.868, Accuracy=0.759, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.5, AUC=0.850, Accuracy=0.762, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.5, AUC=0.843, Accuracy=0.781, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.7, AUC=0.907, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.7, AUC=0.825, Accuracy=0.772, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=0.7, AUC=0.826, Accuracy=0.768, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=1, AUC=0.905, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=1, AUC=0.825, Accuracy=0.743, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=120, subsample=1, AUC=0.828, Accuracy=0.772, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.3, AUC=0.884, Accuracy=0.762, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.3, AUC=0.843, Accuracy=0.756, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.3, AUC=0.848, Accuracy=0.788, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.5, AUC=0.897, Accuracy=0.781, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.5, AUC=0.862, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.5, AUC=0.850, Accuracy=0.781, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.7, AUC=0.902, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.7, AUC=0.841, Accuracy=0.778, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=0.7, AUC=0.831, Accuracy=0.781, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=1, AUC=0.892, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=1, AUC=0.827, Accuracy=0.752, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=130, subsample=1, AUC=0.845, Accuracy=0.791, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.3, AUC=0.909, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.3, AUC=0.833, Accuracy=0.736, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.3, AUC=0.859, Accuracy=0.791, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.5, AUC=0.907, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.5, AUC=0.868, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.5, AUC=0.834, Accuracy=0.775, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.7, AUC=0.901, Accuracy=0.797, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.7, AUC=0.820, Accuracy=0.727, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=0.7, AUC=0.837, Accuracy=0.785, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=1, AUC=0.893, Accuracy=0.794, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=1, AUC=0.816, Accuracy=0.720, total=   0.1s
# [CV] learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=1, max_features=1, n_estimators=140, subsample=1, AUC=0.836, Accuracy=0.785, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.3, AUC=0.917, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.3, AUC=0.895, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.3, AUC=0.877, Accuracy=0.810, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.5, AUC=0.917, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.5, AUC=0.898, Accuracy=0.810, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.5, AUC=0.880, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.7, AUC=0.919, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.7, AUC=0.899, Accuracy=0.814, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=0.7, AUC=0.876, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=1, AUC=0.920, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=1, AUC=0.903, Accuracy=0.846, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=120, subsample=1, AUC=0.878, Accuracy=0.810, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.3, AUC=0.917, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.3, AUC=0.895, Accuracy=0.810, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.3, AUC=0.876, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.5, AUC=0.918, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.5, AUC=0.897, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.5, AUC=0.879, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.7, AUC=0.921, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.7, AUC=0.900, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=0.7, AUC=0.880, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=1, AUC=0.918, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=1, AUC=0.897, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=130, subsample=1, AUC=0.880, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.3, AUC=0.921, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.3, AUC=0.893, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.3, AUC=0.876, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.5, AUC=0.919, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.5, AUC=0.901, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.5, AUC=0.879, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.7, AUC=0.921, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.7, AUC=0.902, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=0.7, AUC=0.880, Accuracy=0.823, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=1, AUC=0.921, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=1, AUC=0.899, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.3, n_estimators=140, subsample=1, AUC=0.880, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.3, AUC=0.913, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.3, AUC=0.900, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.3, AUC=0.875, Accuracy=0.823, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.5, AUC=0.917, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.5, AUC=0.895, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.5, AUC=0.875, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.7, AUC=0.918, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.7, AUC=0.899, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=0.7, AUC=0.871, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=1, AUC=0.915, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=1, AUC=0.895, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=120, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.3, AUC=0.915, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.3, AUC=0.899, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.3, AUC=0.877, Accuracy=0.823, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.5, AUC=0.918, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.5, AUC=0.895, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.5, AUC=0.874, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.7, AUC=0.916, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.7, AUC=0.896, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=0.7, AUC=0.872, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=1, AUC=0.920, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=1, AUC=0.896, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=130, subsample=1, AUC=0.872, Accuracy=0.823, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.3, AUC=0.916, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.3, AUC=0.897, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.3, AUC=0.875, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.5, AUC=0.917, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.5, AUC=0.899, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.5, AUC=0.876, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.7, AUC=0.916, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.7, AUC=0.896, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=0.7, AUC=0.877, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=1
# [CV]  learning_rate=0.006, max_depth=2, max_features=0.5, n_estimators=140, subsample=1, AUC=0.916, Accuracy=0.830, total=   0.1s
# ...
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.3, AUC=0.923, Accuracy=0.836, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.3, AUC=0.901, Accuracy=0.855, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.3, AUC=0.874, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.5, AUC=0.921, Accuracy=0.839, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.5, AUC=0.907, Accuracy=0.865, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.5, AUC=0.877, Accuracy=0.826, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.7, AUC=0.928, Accuracy=0.842, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.7, AUC=0.907, Accuracy=0.862, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=0.7, AUC=0.877, Accuracy=0.823, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=1, AUC=0.921, Accuracy=0.836, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=1, AUC=0.903, Accuracy=0.859, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=120, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.3, AUC=0.920, Accuracy=0.836, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.3, AUC=0.904, Accuracy=0.852, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.3, AUC=0.874, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.5, AUC=0.923, Accuracy=0.836, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.5, AUC=0.908, Accuracy=0.868, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.5, AUC=0.876, Accuracy=0.823, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.7, AUC=0.922, Accuracy=0.839, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.7, AUC=0.907, Accuracy=0.862, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=0.7, AUC=0.875, Accuracy=0.820, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=1, AUC=0.920, Accuracy=0.830, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=1, AUC=0.906, Accuracy=0.865, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=130, subsample=1, AUC=0.877, Accuracy=0.810, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.3, AUC=0.920, Accuracy=0.836, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.3, AUC=0.907, Accuracy=0.859, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.3, AUC=0.877, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.5, AUC=0.924, Accuracy=0.836, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.5, AUC=0.905, Accuracy=0.862, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.5, AUC=0.876, Accuracy=0.826, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.7, AUC=0.926, Accuracy=0.836, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.7, AUC=0.907, Accuracy=0.859, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=0.7, AUC=0.875, Accuracy=0.814, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=1, AUC=0.923, Accuracy=0.836, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=1, AUC=0.904, Accuracy=0.865, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=0.7, n_estimators=140, subsample=1, AUC=0.877, Accuracy=0.814, total=   0.2s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.3, AUC=0.914, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.3, AUC=0.891, Accuracy=0.842, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.3, AUC=0.872, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.5, AUC=0.916, Accuracy=0.823, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.5, AUC=0.887, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.5, AUC=0.875, Accuracy=0.817, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.7, AUC=0.914, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.7, AUC=0.892, Accuracy=0.855, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=0.7, AUC=0.879, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=1, AUC=0.918, Accuracy=0.849, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=1, AUC=0.891, Accuracy=0.842, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=120, subsample=1, AUC=0.874, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.3, AUC=0.912, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.3, AUC=0.889, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.3, AUC=0.872, Accuracy=0.810, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.5, AUC=0.916, Accuracy=0.836, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.5, AUC=0.893, Accuracy=0.846, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.5, AUC=0.881, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.7, AUC=0.915, Accuracy=0.846, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.7, AUC=0.897, Accuracy=0.846, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=0.7, AUC=0.874, Accuracy=0.830, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=1, AUC=0.919, Accuracy=0.842, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=1, AUC=0.893, Accuracy=0.852, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=130, subsample=1, AUC=0.876, Accuracy=0.842, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.3, AUC=0.920, Accuracy=0.836, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.3, AUC=0.881, Accuracy=0.807, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.3
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.3, AUC=0.879, Accuracy=0.836, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.5, AUC=0.918, Accuracy=0.839, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.5, AUC=0.895, Accuracy=0.852, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.5
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.5, AUC=0.878, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.7, AUC=0.916, Accuracy=0.833, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.7, AUC=0.893, Accuracy=0.849, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=0.7, AUC=0.872, Accuracy=0.826, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=1, AUC=0.914, Accuracy=0.820, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=1, AUC=0.896, Accuracy=0.855, total=   0.1s
# [CV] learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=1
# [CV]  learning_rate=0.01, max_depth=3, max_features=1, n_estimators=140, subsample=1, AUC=0.881, Accuracy=0.842, total=   0.1s
# [Parallel(n_jobs=1)]: Done 1296 out of 1296 | elapsed:  2.5min finished
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py:849: FutureWarning:
#
# The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
# ({'learning_rate': 0.01,
#   'max_depth': 3,
#   'max_features': 0.3,
#   'n_estimators': 140,
#   'subsample': 1},
#  0.8467309753483386)

# %%
GBC = GradientBoostingClassifier(learning_rate=0.008, n_estimators=130,max_depth= 3,subsample=.7, max_features=.3)
Models(GBC, "GradientBoostingClassifier", X_train, X_test, y_train, y_test, X, y)

# %%
ROCs(GBC)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import fbeta_score, make_scorer

param_test1 = {'n_estimators': [80,90,100],'max_depth': [1, 2],
               'min_child_weight': [1,2],'subsample':[1],
               'colsample_bytree':[1],'reg_alpha':[0],
               'learning_rate': [0.013, 0.015, 0.017]}
scoring = {'AUC': 'roc_auc', 'Accuracy': make_scorer(accuracy_score)}

gsearch1 = GridSearchCV(estimator = XGBClassifier(), 
                       param_grid = param_test1, 
                       scoring=scoring, iid=False, cv=3, verbose = 5, refit='Accuracy')
gsearch1.fit(X_train, y_train)
gsearch1.best_params_, gsearch1.best_score_
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.881, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.881, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:50] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=1, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.904, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.876, Accuracy=0.810, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.872, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.904, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.876, Accuracy=0.810, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.906, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.876, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.904, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.876, Accuracy=0.810, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.872, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.904, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.876, Accuracy=0.810, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.906, Accuracy=0.820, total=   0.1s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.876, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.013, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:51] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.896, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.856, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.848, Accuracy=0.797, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.883, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.015, max_depth=1, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:52] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# ...
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.876, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.912, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.882, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.912, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.887, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=1, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.878, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.906, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.876, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=80, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.912, Accuracy=0.820, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.882, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=90, reg_alpha=0, subsample=1, AUC=0.874, Accuracy=0.814, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.912, Accuracy=0.820, total=   0.1s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.887, Accuracy=0.817, total=   0.0s
# [CV] colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [CV]  colsample_bytree=1, learning_rate=0.017, max_depth=2, min_child_weight=2, n_estimators=100, reg_alpha=0, subsample=1, AUC=0.878, Accuracy=0.817, total=   0.1s
# [14:33:54] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed:    4.3s finished
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py:849: FutureWarning:
#
# The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# ({'colsample_bytree': 1,
#   'learning_rate': 0.017,
#   'max_depth': 2,
#   'min_child_weight': 1,
#   'n_estimators': 100,
#   'reg_alpha': 0,
#   'subsample': 1},
#  0.8177920685959271)

# %%
XGBC = XGBClassifier(learning_rate=0.017, n_estimators=90, max_depth= 2, min_child_weight= 1, colsample_bytree= 1.,reg_alpha= 0,subsample= 1)
Models(XGBC, "GradientBoostingClassifier", X_train, X_test, y_train, y_test, X, y)
# Out:
# [14:33:55] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
ROCs(XGBC)

# %%
# %%time
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

params = {'loss_function':'Logloss','eval_metric':'AUC','verbose': False,
          'learning_rate': 0.025,'depth': 2,'l2_leaf_reg': 1,'n_estimators': 110}
CBC = CatBoostClassifier(**params)
Models(CBC, "CatBoostClassifier", X_train, X_test, y_train, y_test, X, y)
# Out:
# CPU times: user 609 ms, sys: 47.3 ms, total: 656 ms
# Wall time: 584 ms

# %%
CBC.fit(X_train, y_train)
result = CBC.predict(Z)
sub = pd.DataFrame()
sub = pd.DataFrame({'PassengerId':df_test.PassengerId,'Survived':result}) 
sub.to_csv('my_submission.csv', index=False)
sub.head(2)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1

# %% [markdown]
# Nice ! We think that score is good enough to submit the predictions for the test-set to the Kaggle leaderboard.

# %% [markdown]
# # Conclusion:
# Through out the data visualization with the help of the dataset, we could se that some groups of people were more likely to survive such as women, children and upper class. CatBoostClassifier, XGBoost, GradientBoostingClassifier yielded similar result in this case on the test set.

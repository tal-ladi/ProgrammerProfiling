# %% [markdown]
# # Implementation of Multiple Linear Regression using 3 ways

# %% [markdown]
# 1. Ordinary Least Square method through Matrix operation.
# 2. Ordinary Least Square method from StatsModels
# 3. Gradient Descent Method from Scikit-Learn

# %% [markdown]
# ## Predicting House Prices using Multiple Linear Regression

# %% [markdown]
# ### Importing Liraries

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### Loading Data

# %%
data = pd.read_csv("../input/home-data-for-ml-course/train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ### Checking Correlation

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_42512a1e_13b5_11eb_930b_0242ac130202row0_col0,#T_42512a1e_13b5_11eb_930b_0242ac130202row1_col1,#T_42512a1e_13b5_11eb_930b_0242ac130202row2_col2,#T_42512a1e_13b5_11eb_930b_0242ac130202row3_col3,#T_42512a1e_13b5_11eb_930b_0242ac130202row4_col4,#T_42512a1e_13b5_11eb_930b_0242ac130202row5_col5,#T_42512a1e_13b5_11eb_930b_0242ac130202row6_col6,#T_42512a1e_13b5_11eb_930b_0242ac130202row7_col7,#T_42512a1e_13b5_11eb_930b_0242ac130202row8_col8,#T_42512a1e_13b5_11eb_930b_0242ac130202row9_col9,#T_42512a1e_13b5_11eb_930b_0242ac130202row10_col10,#T_42512a1e_13b5_11eb_930b_0242ac130202row11_col11,#T_42512a1e_13b5_11eb_930b_0242ac130202row12_col12,#T_42512a1e_13b5_11eb_930b_0242ac130202row13_col13,#T_42512a1e_13b5_11eb_930b_0242ac130202row14_col14,#T_42512a1e_13b5_11eb_930b_0242ac130202row15_col15,#T_42512a1e_13b5_11eb_930b_0242ac130202row16_col16,#T_42512a1e_13b5_11eb_930b_0242ac130202row17_col17,#T_42512a1e_13b5_11eb_930b_0242ac130202row18_col18,#T_42512a1e_13b5_11eb_930b_0242ac130202row19_col19,#T_42512a1e_13b5_11eb_930b_0242ac130202row20_col20,#T_42512a1e_13b5_11eb_930b_0242ac130202row21_col21,#T_42512a1e_13b5_11eb_930b_0242ac130202row22_col22,#T_42512a1e_13b5_11eb_930b_0242ac130202row23_col23,#T_42512a1e_13b5_11eb_930b_0242ac130202row24_col24,#T_42512a1e_13b5_11eb_930b_0242ac130202row25_col25,#T_42512a1e_13b5_11eb_930b_0242ac130202row26_col26,#T_42512a1e_13b5_11eb_930b_0242ac130202row27_col27,#T_42512a1e_13b5_11eb_930b_0242ac130202row28_col28,#T_42512a1e_13b5_11eb_930b_0242ac130202row29_col29,#T_42512a1e_13b5_11eb_930b_0242ac130202row30_col30,#T_42512a1e_13b5_11eb_930b_0242ac130202row31_col31,#T_42512a1e_13b5_11eb_930b_0242ac130202row32_col32,#T_42512a1e_13b5_11eb_930b_0242ac130202row33_col33,#T_42512a1e_13b5_11eb_930b_0242ac130202row34_col34,#T_42512a1e_13b5_11eb_930b_0242ac130202row35_col35,#T_42512a1e_13b5_11eb_930b_0242ac130202row36_col36,#T_42512a1e_13b5_11eb_930b_0242ac130202row37_col37{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col1,#T_42512a1e_13b5_11eb_930b_0242ac130202row2_col30,#T_42512a1e_13b5_11eb_930b_0242ac130202row3_col26,#T_42512a1e_13b5_11eb_930b_0242ac130202row3_col27,#T_42512a1e_13b5_11eb_930b_0242ac130202row8_col20,#T_42512a1e_13b5_11eb_930b_0242ac130202row14_col6,#T_42512a1e_13b5_11eb_930b_0242ac130202row15_col9,#T_42512a1e_13b5_11eb_930b_0242ac130202row16_col30,#T_42512a1e_13b5_11eb_930b_0242ac130202row17_col27,#T_42512a1e_13b5_11eb_930b_0242ac130202row24_col20,#T_42512a1e_13b5_11eb_930b_0242ac130202row25_col16,#T_42512a1e_13b5_11eb_930b_0242ac130202row28_col24,#T_42512a1e_13b5_11eb_930b_0242ac130202row29_col20,#T_42512a1e_13b5_11eb_930b_0242ac130202row30_col2,#T_42512a1e_13b5_11eb_930b_0242ac130202row35_col2,#T_42512a1e_13b5_11eb_930b_0242ac130202row35_col6{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col2,#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col6,#T_42512a1e_13b5_11eb_930b_0242ac130202row1_col19,#T_42512a1e_13b5_11eb_930b_0242ac130202row1_col30,#T_42512a1e_13b5_11eb_930b_0242ac130202row7_col8,#T_42512a1e_13b5_11eb_930b_0242ac130202row7_col20,#T_42512a1e_13b5_11eb_930b_0242ac130202row9_col7,#T_42512a1e_13b5_11eb_930b_0242ac130202row18_col30,#T_42512a1e_13b5_11eb_930b_0242ac130202row28_col1,#T_42512a1e_13b5_11eb_930b_0242ac130202row28_col3,#T_42512a1e_13b5_11eb_930b_0242ac130202row28_col5,#T_42512a1e_13b5_11eb_930b_0242ac130202row30_col1,#T_42512a1e_13b5_11eb_930b_0242ac130202row32_col13,#T_42512a1e_13b5_11eb_930b_0242ac130202row33_col5,#T_42512a1e_13b5_11eb_930b_0242ac130202row34_col1,#T_42512a1e_13b5_11eb_930b_0242ac130202row35_col5,#T_42512a1e_13b5_11eb_930b_0242ac130202row36_col30{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col3,#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col24,#T_42512a1e_13b5_11eb_930b_0242ac130202row1_col23,#T_42512a1e_13b5_11eb_930b_0242ac130202row11_col36,#T_42512a1e_13b5_11eb_930b_0242ac130202row14_col10,#T_42512a1e_13b5_11eb_930b_0242ac130202row15_col24,#T_42512a1e_13b5_11eb_930b_0242ac130202row26_col36,#T_42512a1e_13b5_11eb_930b_0242ac130202row31_col16{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col4,#T_42512a1e_13b5_11eb_930b_0242ac130202row3_col33,#T_42512a1e_13b5_11eb_930b_0242ac130202row4_col15,#T_42512a1e_13b5_11eb_930b_0242ac130202row6_col10,#T_42512a1e_13b5_11eb_930b_0242ac130202row9_col10,#T_42512a1e_13b5_11eb_930b_0242ac130202row13_col18,#T_42512a1e_13b5_11eb_930b_0242ac130202row15_col4,#T_42512a1e_13b5_11eb_930b_0242ac130202row19_col5,#T_42512a1e_13b5_11eb_930b_0242ac130202row20_col15,#T_42512a1e_13b5_11eb_930b_0242ac130202row23_col32,#T_42512a1e_13b5_11eb_930b_0242ac130202row25_col35,#T_42512a1e_13b5_11eb_930b_0242ac130202row31_col8,#T_42512a1e_13b5_11eb_930b_0242ac130202row32_col7,#T_42512a1e_13b5_11eb_930b_0242ac130202row34_col36,#T_42512a1e_13b5_11eb_930b_0242ac130202row35_col28,#T_42512a1e_13b5_11eb_930b_0242ac130202row36_col4,#T_42512a1e_13b5_11eb_930b_0242ac130202row36_col15,#T_42512a1e_13b5_11eb_930b_0242ac130202row36_col28{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col5,#T_42512a1e_13b5_11eb_930b_0242ac130202row1_col9,#T_42512a1e_13b5_11eb_930b_0242ac130202row2_col8,#T_42512a1e_13b5_11eb_930b_0242ac130202row7_col14,#T_42512a1e_13b5_11eb_930b_0242ac130202row14_col24,#T_42512a1e_13b5_11eb_930b_0242ac130202row21_col5,#T_42512a1e_13b5_11eb_930b_0242ac130202row23_col30,#T_42512a1e_13b5_11eb_930b_0242ac130202row25_col20,#T_42512a1e_13b5_11eb_930b_0242ac130202row27_col14,#T_42512a1e_13b5_11eb_930b_0242ac130202row33_col1,#T_42512a1e_13b5_11eb_930b_0242ac130202row33_col6,#T_42512a1e_13b5_11eb_930b_0242ac130202row36_col2{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col7,#T_42512a1e_13b5_11eb_930b_0242ac130202row1_col16,#T_42512a1e_13b5_11eb_930b_0242ac130202row5_col21,#T_42512a1e_13b5_11eb_930b_0242ac130202row13_col15,#T_42512a1e_13b5_11eb_930b_0242ac130202row20_col32,#T_42512a1e_13b5_11eb_930b_0242ac130202row23_col10,#T_42512a1e_13b5_11eb_930b_0242ac130202row26_col10,#T_42512a1e_13b5_11eb_930b_0242ac130202row31_col36,#T_42512a1e_13b5_11eb_930b_0242ac130202row33_col22,#T_42512a1e_13b5_11eb_930b_0242ac130202row33_col29,#T_42512a1e_13b5_11eb_930b_0242ac130202row37_col33{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col8,#T_42512a1e_13b5_11eb_930b_0242ac130202row1_col24,#T_42512a1e_13b5_11eb_930b_0242ac130202row5_col31,#T_42512a1e_13b5_11eb_930b_0242ac130202row6_col21,#T_42512a1e_13b5_11eb_930b_0242ac130202row8_col33,#T_42512a1e_13b5_11eb_930b_0242ac130202row9_col31,#T_42512a1e_13b5_11eb_930b_0242ac130202row19_col32,#T_42512a1e_13b5_11eb_930b_0242ac130202row25_col31,#T_42512a1e_13b5_11eb_930b_0242ac130202row33_col34,#T_42512a1e_13b5_11eb_930b_0242ac130202row34_col29,#T_42512a1e_13b5_11eb_930b_0242ac130202row35_col0{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col9,#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col11,#T_42512a1e_13b5_11eb_930b_0242ac130202row7_col5,#T_42512a1e_13b5_11eb_930b_0242ac130202row12_col23,#T_42512a1e_13b5_11eb_930b_0242ac130202row19_col24,#T_42512a1e_13b5_11eb_930b_0242ac130202row20_col21,#T_42512a1e_13b5_11eb_930b_0242ac130202row28_col11,#T_42512a1e_13b5_11eb_930b_0242ac130202row28_col27,#T_42512a1e_13b5_11eb_930b_0242ac130202row30_col5{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col10,#T_42512a1e_13b5_11eb_930b_0242ac130202row0_col26,#T_42512a1e_13b5_11eb_930b_0242ac130202row3_col18,#T_42512a1e_13b5_11eb_930b_0242ac130202row13_col5,#T_42512a1e_13b5

# %% [markdown]
# ### Input Vectors

# %% [markdown]
# Lets choose input vectors on the basis of correlation.
#
# **sm.add_constant()** in following cell adds constant unit vector as a coefficient for beta0 or theta0 or intercept

# %%
endog = data['SalePrice']
exog = sm.add_constant(data[['OverallQual','YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','GrLivArea','FullBath','TotRmsAbvGrd','GarageCars','GarageArea']])
print(exog)
# Out:
#       const  OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  \
# 0       1.0            7       2003          2003          856       856
# 1       1.0            6       1976          1976         1262      1262
# 2       1.0            7       2001          2002          920       920
# 3       1.0            7       1915          1970          756       961
# 4       1.0            8       2000          2000         1145      1145
# ...     ...          ...        ...           ...          ...       ...
# 1455    1.0            6       1999          2000          953       953
# 1456    1.0            6       1978          1988         1542      2073
# 1457    1.0            7       1941          2006         1152      1188
# 1458    1.0            5       1950          1996         1078      1078
# 1459    1.0            5       1965          1965         1256      1256
#
#       GrLivArea  FullBath  TotRmsAbvGrd  GarageCars  GarageArea
# 0          1710         2             8           2         548
# 1          1262         2             6           2         460
# 2          1786         2             6           2         608
# 3          1717         1             7           3         642
# 4          2198         2             9           3         836
# ...         ...       ...           ...         ...         ...
# 1455       1647         2             7           2         460
# 1456       2073         2             7           2         500
# 1457       2340         2             9           1         252
# 1458       1078         1             5           1         240
# 1459       1256         1             6           1         276
#
# [1460 rows x 11 columns]

# %% [markdown]
# ## 1.Ordinary Least Square method through Matrix operation.

# %% [markdown]
# Formula for parameter estimation is
#
# **β = (X'X)ˉ¹X'y**

# %% [markdown]
# Lets Convert the input and output vectors to array to implement the above formula.

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# * input vector - exog
# * output vector - endog

# %%
X = exog.to_numpy()
y = endog.to_numpy()

# %% [markdown]
# Taking **transpose** of X using **np.transpose(X)**

# %%
xt = np.transpose(X)
print(xt)
# Out:
# [[1.000e+00 1.000e+00 1.000e+00 ... 1.000e+00 1.000e+00 1.000e+00]
#  [7.000e+00 6.000e+00 7.000e+00 ... 7.000e+00 5.000e+00 5.000e+00]
#  [2.003e+03 1.976e+03 2.001e+03 ... 1.941e+03 1.950e+03 1.965e+03]
#  ...
#  [8.000e+00 6.000e+00 6.000e+00 ... 9.000e+00 5.000e+00 6.000e+00]
#  [2.000e+00 2.000e+00 2.000e+00 ... 1.000e+00 1.000e+00 1.000e+00]
#  [5.480e+02 4.600e+02 6.080e+02 ... 2.520e+02 2.400e+02 2.760e+02]]

# %% [markdown]
# **Multiplying** xt (X Transpose) with X using **np.matmul(xt,X)**

# %%
xt_X = np.matmul(xt,X)
print(xt_X)
# Out:
# [[1.46000000e+03 8.90500000e+03 2.87805100e+06 2.89790400e+06
#   1.54384700e+06 1.69743500e+06 2.21257700e+06 2.28500000e+03
#   9.51600000e+03 2.58000000e+03 6.90551000e+05]
#  [8.90500000e+03 5.71050000e+04 1.75890190e+07 1.76981700e+07
#   9.89248600e+06 1.07246710e+07 1.41239760e+07 1.45490000e+04
#   5.94430000e+04 1.66420000e+04 4.45435200e+06]
#  [2.87805100e+06 1.75890190e+07 5.67474021e+09 5.71308422e+09
#   3.05090344e+09 3.35090271e+09 4.36619005e+09 4.51571500e+06
#   1.87654310e+07 5.10358300e+06 1.36577344e+09]
#  [2.89790400e+06 1.76981700e+07 5.71308422e+09 5.75257228e+09
#   3.06817533e+09 3.37197974e+09 4.39621720e+09 4.54270400e+06
#   1.88973700e+07 5.13042200e+06 1.37304419e+09]
#  [1.54384700e+06 9.89248600e+06 3.05090344e+09 3.06817533e+09
#   1.91331187e+09 1.99770523e+09 2.49263664e+09 2.53037900e+06
#   1.03595990e+07 2.93604500e+06 7.96809277e+08]
#  [1.69743500e+06 1.07246710e+07 3.35090271e+09 3.37197974e+09
#   1.99770523e+09 2.19153094e+09 2.74016355e+09 2.77487900e+06
#   1.14389890e+07 3.18475300e+06 8.61917115e+08]
#  [2.21257700e+06 1.41239760e+07 4.36619005e+09 4.39621720e+09
#   2.49263664e+09 2.74016355e+09 3.75595326e+09 3.72893500e+06
#   1.54498360e+07 4.17760500e+06 1.12338258e+09]
#  [2.28500000e+03 1.45490000e+04 4.51571500e+06 4.54270400e+06
#   2.53037900e+06 2.77487900e+06 3.72893500e+06 4.01900000e+03
#   1.56180000e+04 4.32000000e+03 1.15047300e+06]
#  [9.51600000e+03 5.94430000e+04 1.87654310e+07 1.88973700e+07
#   1.03595990e+07 1.14389890e+07 1.54498360e+07 1.56180000e+04
#   6.58780000e+04 1.74580000e+04 4.67216400e+06]
#  [2.58000000e+03 1.66420000e+04 5.10358300e+06 5.13042200e+06
#   2.93604500e+06 3.18475300e+06 4.17760500e+06 4.32000000e+03
#   1.74580000e+04 5.37400000e+03 1.42601000e+06]
#  [6.90551000e+05 4.45435200e+06 1.36577344e+09 1.37304419e+09
#   7.96809277e+08 8.61917115e+08 1.12338258e+09 1.15047300e+06
#   4.67216400e+06 1.42601000e+06 3.93311459e+08]]

# %% [markdown]
# Taking **Inverse** of xt_x using **np.linalg.inv(xt_x)**

# %%
xt_X_inv = np.linalg.inv(xt_X)
print(xt_X_inv)
# Out:
# [[ 1.15922974e+01  4.02655456e-02 -1.93944269e-03 -4.06160749e-03
#    3.72993704e-05 -3.25222182e-05 -4.93290663e-05  8.01149656e-02
#   -1.08299083e-02  3.62639158e-02  4.11657913e-06]
#  [ 4.02655456e-02  9.84960043e-04 -9.74065790e-06 -1.25190617e-05
#   -7.83657348e-07  4.42337423e-07 -1.05697829e-06 -8.05936337e-05
#    5.48715552e-05 -3.34804705e-04  1.12710098e-07]
#  [-1.93944269e-03 -9.74065790e-06  1.76255717e-06 -7.32449785e-07
#   -2.42988222e-08  1.21469299e-08  3.05980959e-08 -2.87511476e-05
#    3.16114656e-06 -1.64343121e-05 -6.69546226e-09]
#  [-4.06160749e-03 -1.25190617e-05 -7.32449785e-07  2.81575949e-06
#    5.87415799e-09  2.14275304e-09 -6.72521993e-10 -1.31115421e-05
#    1.13724203e-06 -2.05458728e-06  4.16634079e-09]
#  [ 3.72993704e-05 -7.83657348e-07 -2.42988222e-08  5.87415799e-09
#    1.28299160e-08 -1.08800172e-08 -2.10639452e-11  7.72162072e-07
#    2.37092470e-07  7.02679371e-07 -2.45352373e-09]
#  [-3.25222182e-05  4.42337423e-07  1.21469299e-08  2.14275304e-09
#   -1.08800172e-08  1.68987186e-08 -2.89225248e-09 -4.56109492e-07
#   -1.03092035e-08 -1.33706688e-07 -2.35802960e-09]
#  [-4.93290663e-05 -1.05697829e-06  3.05980959e-08 -6.72521993e-10
#   -2.10639452e-11 -2.89225248e-09  1.24573998e-08 -2.10481340e-06
#   -2.23546660e-06  4.18457544e-07 -3.33008786e-09]
#  [ 8.01149656e-02 -8.05936337e-05 -2.87511476e-05 -1.31115421e-05
#    7.72162072e-07 -4.56109492e-07 -2.10481340e-06  5.00317825e-03
#   -2.78172867e-04 -5.05104967e-04  1.81054723e-06]
#  [-1.08299083e-02  5.48715552e-05  3.16114656e-06  1.13724203e-06
#    2.37092470e-07 -1.03092035e-08 -2.23546660e-06 -2.78172867e-04
#    8.70796489e-04 -1.97407967e-04  5.58279542e-07]
#  [ 3.62639158e-02 -3.34804705e-04 -1.64343121e-05 -2.05458728e-06
#    7.02679371e-07 -1.33706688e-07  4.18457544e-07 -5.05104967e-04
#   -1.97407967e-04  6.44430285e-03 -1.75054978e-05]
#  [ 4.11657913e-06  1.12710098e-07 -6.69546226e-09  4.16634079e-09
#   -2.45352373e-09 -2.35802960e-09 -3.33008786e-09  1.81054723e-06
#    5.58279542e-07 -1.75054978e-05  7.39342583e-08]]

# %% [markdown]
# **Multiplying** xt_X_inv with xt using **np.matmul(xt_X_inv,xt)**

# %%
xt_X_inv_xt = np.matmul(xt_X_inv,xt)
print(xt_X_inv_xt)
# Out:
# [[-7.78363941e-02  8.92629183e-02 -5.14323613e-02 ... -4.89221760e-02
#   -8.00663356e-02 -1.86009574e-03]
#  [ 1.44385781e-04 -2.42730471e-05 -2.87691719e-05 ...  3.16060580e-04
#   -4.13339784e-04 -3.61326706e-04]
#  [ 2.88476633e-05 -1.35992859e-05  2.08787121e-05 ... -4.49337854e-05
#   -2.42308968e-05  3.11169383e-05]
#  ...
#  [ 8.56490977e-04 -1.15956037e-05 -1.01444610e-03 ...  2.25278082e-04
#   -2.74351550e-04  2.71160064e-04]
#  [-1.20426030e-03  1.60857836e-03 -1.75663399e-03 ... -1.22434946e-03
#    2.57315862e-04 -5.77349920e-04]
#  [ 3.61888842e-06 -4.50992051e-06  6.38658333e-06 ... -3.38132125e-06
#   -3.99602562e-06 -2.45491341e-06]]

# %% [markdown]
# Finally getting **beta** by multiplying xt_X_inv_xt and y

# %%
beta = np.matmul(xt_X_inv_xt,y)
print(beta)
# Out:
# [-1.18619377e+06  1.96045898e+04  2.68240707e+02  2.96481161e+02
#   1.98650991e+01  1.41737355e+01  5.12971178e+01 -6.79087146e+03
#   3.31050771e+01  1.04179010e+04  1.49475334e+01]

# %% [markdown]
# ## 2.Ordinary Least Square method from StatsModels

# %%
mod = sm.OLS(endog,exog)
results = mod.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     495.4
# Date:                Wed, 21 Oct 2020   Prob (F-statistic):               0.00
# Time:                        15:51:20   Log-Likelihood:                -17459.
# No. Observations:                1460   AIC:                         3.494e+04
# Df Residuals:                    1449   BIC:                         3.500e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.186e+06   1.29e+05     -9.187      0.000   -1.44e+06   -9.33e+05
# OverallQual    1.96e+04   1190.159     16.472      0.000    1.73e+04    2.19e+04
# YearBuilt      268.2407     50.346      5.328      0.000     169.481     367.000
# YearRemodAdd   296.4812     63.635      4.659      0.000     171.655     421.307
# TotalBsmtSF     19.8651      4.295      4.625      0.000      11.439      28.291
# 1stFlrSF        14.1737      4.930      2.875      0.004       4.504      23.844
# GrLivArea       51.2971      4.233     12.119      0.000      42.994      59.600
# FullBath     -6790.8715   2682.369     -2.532      0.011   -1.21e+04   -1529.130
# TotRmsAbvGrd    33.1051   1119.061      0.030      0.976   -2162.048    2228.258
# GarageCars    1.042e+04   3044.272      3.422      0.001    4446.249    1.64e+04
# GarageArea      14.9475     10.311      1.450      0.147      -5.279      35.174
# ==============================================================================
# Omnibus:                      477.814   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            58906.279
# Skew:                          -0.412   Prob(JB):                         0.00
# Kurtosis:                      34.107   Cond. No.                     4.69e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.69e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Calculating Residual Standard Error

# %% [markdown]
# ![RSS.png](attachment:RSS.png)

# %%
def RSE(y_true, y_predicted):
   
    y_true = np.array(y_true)
    y_predicted = np.array(y_predicted)
    RSS = np.sum(np.square(y_true - y_predicted))

    rse = math.sqrt(RSS / (len(y_true) - 2))
    return rse

# %%
yp= results.predict()
ypa = np.array(yp)
yta = data['SalePrice']
eterms =yta-ypa


data1 = pd.DataFrame(eterms)
data1['SalePrice'].hist(bins=10)

# %%
rse= RSE(data['SalePrice'],results.predict())
print(rse)
# Out:
# 37805.14859147038

# %% [markdown]
# ## 3.Gradient Descent Method from Scikit-Learn

# %%
from sklearn import linear_model
X = data[['OverallQual','YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','GrLivArea','FullBath','TotRmsAbvGrd','GarageCars','GarageArea']]
y = data['SalePrice']

lm = linear_model.LinearRegression()
model = lm.fit(X,y)
lm.coef_
# Out:
# array([ 1.96045898e+04,  2.68240707e+02,  2.96481161e+02,  1.98650991e+01,
#         1.41737355e+01,  5.12971178e+01, -6.79087146e+03,  3.31050771e+01,
#         1.04179010e+04,  1.49475334e+01])

# %%
lm.intercept_
# Out:
# -1186193.7666661476

# %% [markdown]
# ### Predicting the result for test data

# %%
test = pd.read_csv('../input/home-data-for-ml-course/test.csv')

# %%
X_test = data[['OverallQual','YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','GrLivArea','FullBath','TotRmsAbvGrd','GarageCars','GarageArea']]

# %%
y_pred = lm.predict(X_test)

# %%
y_pred
# Out:
# array([214741.72468546, 169346.70949012, 220816.47032609, ...,
#        227093.91227879, 126047.07735366, 136640.78777021])

# %% [markdown]
# I hope you liked it.

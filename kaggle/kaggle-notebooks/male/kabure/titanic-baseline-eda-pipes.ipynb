# %% [markdown]
# <h1> Welcome to my Titanic Kernel! </h1>
# This kernel covers: Data Exploration and Visualization, data handling and modelling, Features preprocessing, ML pipeline, automated hyper parameter with HyperOpt and prediction of a dependent variable ('survived').
#
# When I started on Data Science field, my second work on Kaggle was on titanic Dataset and now, I want to improve my work here.
#
# I will use a easy code that maybe could be useful to many people that are starting on Data Science or PyData libraries.

# %% [markdown]
# ## <font color="red">If this kernel were useful for you, please <b>UPVOTE</b> the kernel =)</font>
# Also, don't forget to give me your feedback, it's many important to me

# %% [markdown]
# If you want many other simple kernels with pythonic code <a href="https://www.kaggle.com/kabure/kernels">CLICK HERE</a> <br>

# %% [markdown]
# <i>*I'm from Brazil, so english is not my first language, sorry about some mistakes</i>

# %% [markdown]
# # Table of Contents:
#
# **1. [Introduction](#Introduction)** <br>
# **2. [Librarys](#Librarys)** <br>
# **3. [Knowning the data](#Known)** <br>
# **4. [Exploring some Variables](#Explorations)** <br>
# **5. [Preprocessing](#Prepocess)** <br>
# **6. [Modelling](#Model)** <br>
# **7. [Validation](#Validation)** <br>

# %% [markdown]
# <a id="Introduction"></a> <br>
# # **1. Introduction:**
# <h3> The data have 891 entries on train dataset and 418 on test dataset</h3>
# - 10 columns in train_csv and 9 columns in train_test

# %% [markdown]
# <h2>Competition Description: </h2>
# The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this challenge, we ask you to complete the analysis of what sorts of people were likely to survive. In particular, we ask you to apply the tools of machine learning to predict which passengers survived the tragedy.

# %% [markdown]
# <h3>Data Dictionary</h3><br>
# Variable	Definition	Key<br>
# <b>survival</b>	Survival	0 = No, 1 = Yes<br>
# <b>pclass</b>	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd<br>
# <b>sex</b>	Sex	<br>
# <b>Age</b>	Age in years	<br>
# <b>sibsp</b>	# of siblings / spouses aboard the Titanic	<br>
# <b>parch</b>	# of parents / children aboard the Titanic	<br>
# <b>ticket</b>	Ticket number	<br>
# <b>fare</b>	Passenger fare	<br>
# <b>cabin</b>	Cabin number	<br>
# <b>embarked	</b>Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton<br>
# <h3>Variable Notes</h3><br>
# <b>pclass: </b>A proxy for socio-economic status (SES)<br>
# 1st = Upper<br>
# 2nd = Middle<br>
# 3rd = Lower<br>
# <b>age: </b>Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5<br>
# <b>sibsp:</b> The dataset defines family relations in this way...<br>
# - <b>Sibling </b>= brother, sister, stepbrother, stepsister<br>
# - <b>Spouse </b>= husband, wife (mistresses and fiancés were ignored)<br>
#
# <b>parch: </b>The dataset defines family relations in this way...<br>
# - <b>Parent</b> = mother, father<br>
# - <b>Child </b>= daughter, son, stepdaughter, stepson<br>
#
# Some children travelled only with a nanny, therefore parch=0 for them.<br>

# %% [markdown]
# I am using the beapproachs as possible but if you think I can do anything another best way, please, let me know.

# %% [markdown]
# <a id="Librarys"></a> <br>
# # **2. Importing Librarys:**

# %%
#This librarys is to work with matrices
import pandas as pd 
# This librarys is to work with vectors
import numpy as np
# This library is to create some graphics algorithmn
import seaborn as sns
# to render the graphs
import matplotlib.pyplot as plt
# import module to set some ploting parameters
from matplotlib import rcParams
# Library to work with Regular Expressions
import re
import gc

from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, accuracy_score, make_scorer
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold
from xgboost import XGBClassifier
import xgboost as xgb

## Hyperopt modules
from hyperopt import fmin, hp, tpe, Trials, space_eval, STATUS_OK, STATUS_RUNNING
from functools import partial

from scipy import stats

# This function makes the plot directly on browser
# %matplotlib inline

# Seting a universal figure size 
rcParams['figure.figsize'] = 12,5

# %% [markdown]
# ## Importing Datasets

# %%
# Importing train dataset
df_train = pd.read_csv("../input/titanic/train.csv")

# Importing test dataset
df_test = pd.read_csv("../input/titanic/test.csv")

submission = pd.read_csv("../input/titanic/gender_submission.csv", index_col='PassengerId')

# %% [markdown]
# <a id="Known"></a> <br>
# # **3. First look at the data:**
# - I will implement a function to we summary all columns in a meaningful table.

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 

    return summary

# %% [markdown]
# ## Summary of df train

# %%
resumetable(df_train)
# Out:
# Dataset Shape: (891, 12)
#            Name   dtypes  Missing  Uniques              First Value  \
# 0   PassengerId    int64        0      891                        1
# 1      Survived    int64        0        2                        0
# 2        Pclass    int64        0        3                        3
# 3          Name   object        0      891  Braund, Mr. Owen Harris
# 4           Sex   object        0        2                     male
# 5           Age  float64      177       88                       22
# 6         SibSp    int64        0        7                        1
# 7         Parch    int64        0        7                        0
# 8        Ticket   object        0      681                A/5 21171
# 9          Fare  float64        0      248                     7.25
# 10        Cabin   object      687      147                      NaN
# 11     Embarked   object        2        3                        S
#
#                                          Second Value             Third Value  \
# 0                                                   2                       3
# 1                                                   1                       1
# 2                                                   1                       3
# 3   Cumings, Mrs. John Bradley (Florence Briggs Th...  Heikkinen, Miss. Laina
# 4                                              female                  female
# 5                                                  38                      26
# 6                                                   1                       0
# 7                                                   0                       0
# 8                                            PC 17599        STON/O2. 3101282
# 9                                             71.2833                   7.925
# 10                                                C85                     NaN
# 11                                                  C                       S
#
#     Entropy
# 0      9.80
# 1      0.96
# 2      1.44
# 3      9.80
# 4      0.94
# 5      5.84
# 6      1.34
# 7      1.13
# 8      9.23
# 9      7.04
# 10     7.07
# 11     1.10

# %% [markdown]
# Cool!! We can see very important information about all our data. <br>
# Our target is "Survived" column that informs if the passenger survived or not the disaster

# %% [markdown]
# ## Summary of df test

# %%
resumetable(df_test)
# Out:
# Dataset Shape: (418, 11)
#            Name   dtypes  Missing  Uniques       First Value  \
# 0   PassengerId    int64        0      418               892
# 1        Pclass    int64        0        3                 3
# 2          Name   object        0      418  Kelly, Mr. James
# 3           Sex   object        0        2              male
# 4           Age  float64       86       79              34.5
# 5         SibSp    int64        0        7                 0
# 6         Parch    int64        0        8                 0
# 7        Ticket   object        0      363            330911
# 8          Fare  float64        1      169            7.8292
# 9         Cabin   object      327       76               NaN
# 10     Embarked   object        0        3                 Q
#
#                         Second Value                Third Value  Entropy
# 0                                893                        894     8.71
# 1                                  3                          2     1.48
# 2   Wilkes, Mrs. James (Ellen Needs)  Myles, Mr. Thomas Francis     8.71
# 3                             female                       male     0.95
# 4                                 47                         62     5.73
# 5                                  1                          0     1.24
# 6                                  0                          0     1.11
# 7                             363272                     240276     8.42
# 8                                  7                     9.6875     6.72
# 9                                NaN                        NaN     6.17
# 10                                 S                          Q     1.25

# %% [markdown]
# In df test, we have missing values only on

# %% [markdown]
# <a id="Known"></a> <br>
# # **4. Exploring the data:**
# - Different of the other Kernel, as now I am more experienced in data science, I will start by the target distribution

# %%
df_train['Survived'].replace({0:'No', 1:'Yes'}, inplace=True)

# %%
total = len(df_train)
plt.figure(figsize=(12,7))
#plt.subplot(121)
g = sns.countplot(x='Survived', data=df_train, color='green')
g.set_title(f"Passengers alive or died Distribution \nTotal Passengers: {total}", 
            fontsize=22)
g.set_xlabel("Passenger Survived?", fontsize=18)
g.set_ylabel('Count', fontsize=18)
for p in g.patches:
    height = p.get_height()
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=15) 
g.set_ylim(0, total *.70)

plt.show()

# %% [markdown]
# Cool. We can see that only 38.38% of passengers survived. <br>
# Let's explore our other featuers and try to find some patterns

# %% [markdown]
# # Let's start exploring Age Column
# I will start by the "simplest" columns that are columns that don't need some transformations or have only few unique values.
# The first objective is to:
# - Explore the features
# - Imput missing values
# - See the distribution of numerical and categorical features
# - Understand the difference between groups that survived and not

# %%
#First I will look my distribuition without NaN's
#I will create a df to look distribuition 
age_high_zero_died = df_train[(df_train["Age"] > 0) & 
                              (df_train["Survived"] == 'No')]
age_high_zero_surv = df_train[(df_train["Age"] > 0) & 
                              (df_train["Survived"] == 'Yes')]

#figure size
plt.figure(figsize=(16,5))

plt.subplot(121)
plt.suptitle('Age Distributions', fontsize=22)
sns.distplot(df_train[(df_train["Age"] > 0)]["Age"], bins=24)
plt.title("Distribuition of Age",fontsize=20)
plt.xlabel("Age Range",fontsize=15)
plt.ylabel("Probability",fontsize=15)

plt.subplot(122)

sns.distplot(age_high_zero_surv["Age"], bins=24, color='r', label='Survived')
sns.distplot(age_high_zero_died["Age"], bins=24, color='blue', label='Not Survived')
plt.title("Distribution of Age by Target",fontsize=20)
plt.xlabel("Age",fontsize=15)
plt.ylabel("Probability",fontsize=15)
plt.legend()


plt.show()

# %% [markdown]
# Interesting! A big part of all passengers has between 20 to 40 old years. <br>
# When we analyze the distribution by the target we can note that youngest adults has a highest density in not survived passengers.
#
# I will continue working in Age feature but before, I will try to understand the other columns. Maybe it could work well together

# %% [markdown]
# # Gender Column
# Understanding Gender distribution and distribution by target

# %%
def plot_categoricals(df, col=None, cont='Age', binary=None, dodge=True):
    tmp = pd.crosstab(df[col], df[binary], normalize='index') * 100
    tmp = tmp.reset_index()

    plt.figure(figsize=(16,12))

    plt.subplot(221)
    g= sns.countplot(x=col, data=df, order=list(tmp[col].values) , color='green')
    g.set_title(f'{col} Distribuition', 
                fontsize=20)
    g.set_xlabel(f'{col} Values',fontsize=17)
    g.set_ylabel('Count Distribution', fontsize=17)
    sizes = []
    for p in g.patches:
        height = p.get_height()
        sizes.append(height)
        g.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.0f}'.format(height),
                ha="center", fontsize=15) 
    g.set_ylim(0,max(sizes)*1.15)

    plt.subplot(222)
    g1= sns.countplot(x=col, data=df, order=list(tmp[col].values),
                     hue=binary,palette="hls")
    g1.set_title(f'{col} Distribuition by {binary} ratio %', 
                fontsize=20)
    gt = g1.twinx()
    gt = sns.pointplot(x=col, y='Yes', data=tmp, order=list(tmp[col].values),
                       color='black', legend=False)
    gt.set_ylim(0,tmp['Yes'].max()*1.1)
    gt.set_ylabel("Survived %Ratio", fontsize=16)
    g1.set_ylabel('Count Distribuition',fontsize=17)
    g1.set_xlabel(f'{col} Values', fontsize=17)
    
    sizes = []
    
    for p in g1.patches:
        height = p.get_height()
        sizes.append(height)
        g1.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(height/total*100),
                ha="center", fontsize=10) 
    g1.set_ylim(0,max(sizes)*1.15)

    plt.subplot(212)
    g2= sns.swarmplot(x=col, y=cont, data=df, dodge=dodge, order=list(tmp[col].values),
                     hue="Survived",palette="hls")
    g2.set_title(f'{cont} Distribution by {col} and {binary}', 
                fontsize=20)
    g2.set_ylabel(f'{cont} Distribuition',fontsize=17)
    g2.set_xlabel(f'{col} Values', fontsize=17)


    plt.suptitle(f'{col} Distributions', fontsize=22)
    plt.subplots_adjust(hspace = 0.4, top = 0.90)
    
    plt.show()

# %%
plot_categoricals(df_train, col='Sex', cont='Age', binary='Survived')

# %% [markdown]
# Cool. Now we can see meaningful informations about the passengers. <br>
# The distribution of Ages and Gender by Survived can show us a interesting pattern in people who survived and who not

# %% [markdown]
# # PClass
# - Other feature that I think that could be important to understand the passenger's survivors
# - Let's understand distributions of Pclass and how it is distributed in considering our target feature

# %%
plot_categoricals(df_train, col='Pclass', cont='Age', binary='Survived')

# %% [markdown]
# We can see that 55% of passengers are in the 3rd Class and also, is the Class where more people died. <br>
# Let's use the powerful <b>pd.crosstab</b> to see the distribution of Pclass by Sex and get the ratio of survivors

# %%
(round(pd.crosstab(df_train['Survived'], [df_train['Pclass'], df_train['Sex']], 
             normalize='columns' ) * 100,2))
# Out:
# Pclass        1             2             3
# Sex      female   male female   male female   male
# Survived
# No         3.19  63.11   7.89  84.26   50.0  86.46
# Yes       96.81  36.89  92.11  15.74   50.0  13.54

# %% [markdown]
# I noted one interesting thing. <br>
# In first and second class the female have 92%+ of survivors, and in 3rd class the ratio is 50% in female survivors<br>
# Another interesting information is that in first class the percent of male survivors are almost 37% and in 2 and 3 class the ratio is 15.7 and 13.5 respectivelly.

# %% [markdown]
# # Embarked Feature
# - Exploring the Distributions of the feature
# - Filling Na's values (we have only 2 missing values in this feature)

# %%
plot_categoricals(df_train, col='Embarked', cont='Age', binary='Survived')

# %% [markdown]
# Another interesting information. We can see that 72.4% of all passengers embarked in "S" (Southampton). <br>
# Also, 47% of all died passengers is from S.

# %% [markdown]
# ### Let's fill na's in Embarked

# %%
#lets input the NA's with the highest frequency
df_train["Embarked"] = df_train["Embarked"].fillna('S')

# %% [markdown]
# ## Crossing Embarked by PClass and Survived

# %%
(round(pd.crosstab(df_train['Survived'], [df_train['Embarked'], df_train['Pclass']], 
             normalize='columns' ) * 100,2))
# Out:
# Embarked      C                   Q                   S
# Pclass        1      2      3     1      2     3      1      2      3
# Survived
# No        30.59  47.06  62.12  50.0  33.33  62.5  41.09  53.66  81.02
# Yes       69.41  52.94  37.88  50.0  66.67  37.5  58.91  46.34  18.98

# %% [markdown]
# ## Crossing Embarked by Sex and Survived

# %%
(round(pd.crosstab(df_train['Survived'], [df_train['Embarked'], df_train['Sex']], 
             normalize='columns' ) * 100,2))
# Out:
# Embarked      C             Q             S
# Sex      female   male female   male female   male
# Survived
# No        12.33  69.47   25.0  92.68  30.73  82.54
# Yes       87.67  30.53   75.0   7.32  69.27  17.46

# %% [markdown]
# We can see that we have we have different ratios when considering the Embarked place and Sex. It could be useful to build some features.

# %% [markdown]
# # Fare Column

# %% [markdown]
# ## Looking quantiles of Fare

# %%
df_train['Fare'].quantile([.01, .1, .25, .5, .75, .9, .99]).reset_index()
# Out:
#    index       Fare
# 0   0.01    0.00000
# 1   0.10    7.55000
# 2   0.25    7.91040
# 3   0.50   14.45420
# 4   0.75   31.00000
# 5   0.90   77.95830
# 6   0.99  249.00622

# %% [markdown]
# # Geting the Fare Log

# %%
df_train['Fare_log'] = np.log(df_train['Fare'] + 1)
df_test['Fare_log'] = np.log(df_test['Fare'] + 1)

# %% [markdown]
# ## Ploting Fare Distribution

# %%
# Seting the figure size
plt.figure(figsize=(16,10))

# Understanding the Fare Distribuition 
plt.subplot(221)
sns.distplot(df_train["Fare"], bins=50 )
plt.title("Fare Distribuition", fontsize=20)
plt.xlabel("Fare", fontsize=15)
plt.ylabel("Density",fontsize=15)

plt.subplot(222)
sns.distplot(df_train["Fare_log"], bins=50 )
plt.title("Fare LOG Distribuition", fontsize=20)
plt.xlabel("Fare (Log)", fontsize=15)
plt.ylabel("Density",fontsize=15)

plt.subplot(212)
g1 = plt.scatter(range(df_train[df_train.Survived == 'No'].shape[0]),
                 np.sort(df_train[df_train.Survived == 'No']['Fare'].values), 
                 label='No Survived', alpha=.5)
g1 = plt.scatter(range(df_train[df_train.Survived == 'Yes'].shape[0]),
                 np.sort(df_train[df_train.Survived == 'Yes']['Fare'].values), 
                 label='Survived', alpha=.5)
g1= plt.title("Fare ECDF Distribution", fontsize=18)
g1 = plt.xlabel("Index")
g1 = plt.ylabel("Fare Amount", fontsize=15)
g1 = plt.legend()

plt.suptitle('Fare Distributions', fontsize=22)
plt.subplots_adjust(hspace = 0.4, top = 0.90)

plt.show()

# %% [markdown]
# Cool. We can note that the big part of passengers paid less than USD 100. We can't see some difference between the survived or not group. <br>
# I will try cross Fare by other features and try to find some interesting patterns

# %% [markdown]
# <br>
# Description of Fare variable<br>
# - Min: 0<br>
# - Median: 14.45<br>
# - Mean: 32.20<br>
# - Max: 512.32<br>
# - Std: 49.69<br>

# %% [markdown]
# # Categorical features by Fare

# %%
def ploting_cat_group(df, col):
    plt.figure(figsize=(14,6))
    tmp = pd.crosstab(df['Survived'], df[col], 
                      values=df['Fare'], aggfunc='mean').unstack(col).reset_index().rename(columns={0:'FareMean'})
    g = sns.barplot(x=col, y='FareMean', hue='Survived', data=tmp)
    g.set_xlabel(f'{col} values', fontsize=18)
    g.set_ylabel('Fare Mean', fontsize=18)
    g.set_title(f"Fare Distribution by {col} ", fontsize=20)
    
    plt.show()

# %% [markdown]
# ## Fare mean by Pclass

# %%
ploting_cat_group(df_train, 'Pclass')

# %% [markdown]
# The fist class passengers has highest Fare mean, that make many sense. But we can't see a high difference between second and third class Fare mean

# %% [markdown]
# ## Fare mean by Embarked

# %%
ploting_cat_group(df_train, 'Embarked')

# %% [markdown]
# People of C has a highest Fare mean.

# %% [markdown]
# ## Fare mean by Sex

# %%
ploting_cat_group(df_train, 'Sex')

# %% [markdown]
# We can see that We can infer that pooverty people had more probability to die.

# %% [markdown]
# ## Fare by Age

# %%
plt.figure(figsize=(14,6))
g = sns.scatterplot(x='Age', y='Fare_log', data=df_train, hue='Survived')
g.set_title('Fare Distribution by Age', fontsize= 22)
g.set_xlabel('Age Distribution', fontsize=18)
g.set_ylabel("Fare Log Distribution", fontsize=18)

plt.show()

# %% [markdown]
# Cool! We can see see the Fare distribution by Age and confirm and infer some questions. For example, the first class, probably has a highest age mean. Let's confirm that.

# %%
df_train.groupby(['Survived', 'Pclass'])['Age'].mean().unstack('Survived').reset_index()
# Out:
# Survived  Pclass         No        Yes
# 0              1  43.695312  35.368197
# 1              2  33.544444  25.901566
# 2              3  26.555556  20.646118

# %% [markdown]
# Cool!!! Exactly what I tought. We can see that in 3 class we have a smallest Age mean

# %% [markdown]
# # Names Column

# %%
df_train['Name'].unique()[:10]
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)'], dtype=object)

# %% [markdown]
# We can note that all names have the titles of passengers. Let's use regex to extract titles of passengers.

# %% [markdown]
# ### Let's see the extracted titles

# %%
# Extracting the prefix of all Passengers
df_train['Title'] = df_train.Name.apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))
df_test['Title'] = df_test.Name.apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))

(df_train['Title'].value_counts(normalize=True) * 100).head(5)
# Out:
# Mr        58.024691
# Miss      20.426487
# Mrs       14.029181
# Master     4.489338
# Dr         0.785634
# Name: Title, dtype: float64

# %% [markdown]
# ## Mapping the titles

# %%
#Now, I will identify the social status of each title

Title_Dictionary = {
        "Capt":       "Officer",
        "Col":        "Officer",
        "Major":      "Officer",
        "Dr":         "Officer",
        "Rev":        "Officer",
        "Jonkheer":   "Royalty",
        "Don":        "Royalty",
        "Sir" :       "Royalty",
        "the Countess":"Royalty",
        "Dona":       "Royalty",
        "Lady" :      "Royalty",
        "Mme":        "Mrs",
        "Ms":         "Mrs",
        "Mrs" :       "Mrs",
        "Mlle":       "Miss",
        "Miss" :      "Miss",
        "Mr" :        "Mr",
        "Master" :    "Master"
}
    
# we map each title to correct category
df_train['Title'] = df_train.Title.map(Title_Dictionary)
df_test['Title'] = df_test.Title.map(Title_Dictionary)

# %% [markdown]
# # Ploting Title Distributions

# %%
plot_categoricals(df_train, col='Title', cont='Age', binary='Survived')

# %% [markdown]
# Very interesting information. The data has 18 Officer's and we can note that Officer's have the highest Age mean. <br>
# Curiously we can note that "Master" has a very low Age distribution. It sounds very strange to me.

# %% [markdown]
# # Let's use some features to help us fill Age NaN's

# %%
#Let's group the median age by sex, pclass and title, to have any idea and maybe input in Age NAN's
age_group = df_train.groupby(["Sex","Pclass","Title"])["Age"]

#printing the variabe that we created by median
age_group.median().unstack('Pclass').reset_index()
# Out:
# Pclass     Sex    Title     1     2     3
# 0       female     Miss  30.0  24.0  18.0
# 1       female      Mrs  40.0  31.5  31.0
# 2       female  Officer  49.0   NaN   NaN
# 3       female  Royalty  48.0   NaN   NaN
# 4         male   Master   4.0   1.0   4.0
# 5         male       Mr  40.0  31.0  26.0
# 6         male  Officer  51.0  46.5   NaN
# 7         male  Royalty  40.0   NaN   NaN

# %%
#inputing the values on Age Na's 
# using the groupby to transform this variables
df_train.loc[df_train.Age.isnull(), 'Age'] = df_train.groupby(['Sex','Pclass','Title']).Age.transform('median')
df_test.loc[df_train.Age.isnull(), 'Age'] = df_test.groupby(['Sex','Pclass','Title']).Age.transform('median')

# printing the total of nulls in Age Feature
print(df_train["Age"].isnull().sum())
# Out:
# 0

# %%
#df_train.Age = df_train.Age.fillna(-0.5)

#creating the intervals that we need to cut each range of ages
interval = (0, 5, 12, 18, 25, 35, 60, 120) 

#Seting the names that we want use to the categorys
cats = ['babies', 'Children', 'Teen', 'Student', 'Young', 'Adult', 'Senior']

# Applying the pd.cut and using the parameters that we created 
df_train["Age_cat"] = pd.cut(df_train.Age, interval, labels=cats)
df_test["Age_cat"] = pd.cut(df_test.Age, interval, labels=cats)

# Printing the new Category
df_train["Age_cat"].unique()
# Out:
# [Student, Adult, Young, babies, Teen, Children, Senior]
# Categories (7, object): [babies < Children < Teen < Student < Young < Adult < Senior]

# %% [markdown]
# # Ploting Age Cat Distributions - Fare

# %%
plot_categoricals(df_train, col='Age_cat', cont='Fare', binary='Survived')

# %% [markdown]
# # Sibsp	feature
# this feature refers to siblings / spouses aboard the Titanic

# %%
plot_categoricals(df_train, col='SibSp', cont='Age', binary='Survived')

# %% [markdown]
# # Parch	feature
# The feature refers to parents / children aboard the Titanic	<br>

# %%
plot_categoricals(df_train, col='Parch', cont='Age', binary='Survived', dodge=False)

# %% [markdown]
# # Creating the Family Size feature

# %%
#Create a new column and sum the Parch + SibSp + 1 that refers the people self
df_train["FSize"] = df_train["Parch"] + df_train["SibSp"] + 1
df_test["FSize"] = df_test["Parch"] + df_test["SibSp"] + 1

family_map = {1: 'Alone', 2: 'Small', 3: 'Small', 4: 'Small', 
              5: 'Medium', 6: 'Medium', 7: 'Large', 8: 'Large',
              11: 'Large'}

df_train['FSize'] = df_train['FSize'].map(family_map)
df_test['FSize'] = df_test['FSize'].map(family_map)

# %% [markdown]
# # Ploting Family Size

# %%
plot_categoricals(df_train, col='FSize', cont='Fare', binary='Survived', dodge=True)

# %% [markdown]
# Cool!!! We can see that 60% of passengers are traveling alone. Curiosly, we can note that these people have a highest ratio of Not survived Passengers. <br>
# The chance to survive is highest to people with small families on the boat.

# %% [markdown]
# # Keep thinking about Familys
# ### Extracting Sur Names
# - Taking advantage that we are dealing with family features, lets extract sur name from Name Features

# %%
## I saw this code in another kernel and it is very useful
## Link: https://www.kaggle.com/gunesevitan/advanced-feature-engineering-tutorial-with-titanic
import string

def extract_surname(data):    
    
    families = []
    
    for i in range(len(data)):        
        name = data.iloc[i]

        if '(' in name:
            name_no_bracket = name.split('(')[0] 
        else:
            name_no_bracket = name
            
        family = name_no_bracket.split(',')[0]
        title = name_no_bracket.split(',')[1].strip().split(' ')[0]
        
        for c in string.punctuation:
            family = family.replace(c, '').strip()
            
        families.append(family)
            
    return families

# %%
df_train['Family'] = extract_surname(df_train['Name'])
df_test['Family'] = extract_surname(df_test['Name'])

# %% [markdown]
# ## Ticket feature
# - Understanding and creading new feature

# %%
df_train['Ticket'].value_counts()[:10]
# Out:
# 1601            7
# 347082          7
# CA. 2343        7
# 3101295         6
# CA 2144         6
# 347088          6
# 382652          5
# S.O.C. 14879    5
# 17421           4
# 2666            4
# Name: Ticket, dtype: int64

# %% [markdown]
# Ticket is a very sparse data, with many values. So, lets try associate it with Family's and feed our model

# %%
df_train['Ticket_Frequency'] = df_train.groupby('Ticket')['Ticket'].transform('count')
df_test['Ticket_Frequency'] = df_test.groupby('Ticket')['Ticket'].transform('count')

# %%
# Creating a list of families and tickets that are occuring in both training and test set
non_unique_families = [x for x in df_train['Family'].unique() if x in df_test['Family'].unique()]
non_unique_tickets = [x for x in df_train['Ticket'].unique() if x in df_test['Ticket'].unique()]

# %% [markdown]
# ## Let's see the means of Fare

# %%
df_train.groupby(['Survived', 'FSize'])['Fare'].mean().unstack('FSize').reset_index()
# Out:
# FSize Survived      Alone      Large      Medium      Small
# 0           No  14.127258  48.502976   45.187639  36.095497
# 1          Yes  37.568891  25.521875  182.083333  54.632619

# %% [markdown]
# Now it look's better and clearly

# %%
#Filling the NA's with -0.5
df_train.Fare = df_train.Fare.fillna(-1)
df_test.Fare = df_test.Fare.fillna(-1)
#intervals to categorize
quant = (-1, 0, 12, 30, 80, 100, 200, 600)

#Labels without input values
label_quants = ['NoInf', 'quart_1', 'quart_2', 'quart_3', 'quart_4', 'quart_5', 'quart_6']

#doing the cut in fare and puting in a new column
df_train["Fare_cat"] = pd.cut(df_train.Fare, quant, labels=label_quants)
df_test["Fare_cat"] = pd.cut(df_test.Fare, quant, labels=label_quants)

# %%
plot_categoricals(df_train, col='Fare_cat', cont='Age', binary='Survived', dodge=False)

# %%
# Excellent implementation from: 
# https://www.kaggle.com/franjmartin21/titanic-pipelines-k-fold-validation-hp-tuning

def cabin_extract(df):
    return df['Cabin'].apply(lambda x: str(x)[0] if(pd.notnull(x)) else str('M'))

df_train['Cabin'] = cabin_extract(df_train)
df_test['Cabin'] = cabin_extract(df_test)

# %%
plot_categoricals(df_train, col='Cabin', cont='Age', binary='Survived', dodge=True)

# %% [markdown]
# ### Seting Cabin into Groups

# %%
pd.crosstab(df_train['Cabin'], df_train['Pclass'])
# Out:
# Pclass   1    2    3
# Cabin
# A       15    0    0
# B       47    0    0
# C       59    0    0
# D       29    4    0
# E       25    4    3
# F        0    8    5
# G        0    0    4
# M       40  168  479
# T        1    0    0

# %% [markdown]
# Based on informations of the boat and the confirmation of te crosstab.
# - ABC cabins are to first class
# - DE cabins are to first and second class
# - FG are majority to third class
# - M are the missing values
# - On the Boat Deck there were **6** rooms labeled as **T, U, W, X, Y, Z**, but only the **T** cabin is present in the dataset.

# %%
df_train['Cabin'] = df_train['Cabin'].replace(['A', 'B', 'C'], 'ABC')
df_train['Cabin'] = df_train['Cabin'].replace(['D', 'E'], 'DE')
df_train['Cabin'] = df_train['Cabin'].replace(['F', 'G'], 'FG')
# Passenger in the T deck is changed to A
df_train.loc[df_train['Cabin'] == 'T', 'Cabin'] = 'A'

df_test['Cabin'] = df_test['Cabin'].replace(['A', 'B', 'C'], 'ABC')
df_test['Cabin'] = df_test['Cabin'].replace(['D', 'E'], 'DE')
df_test['Cabin'] = df_test['Cabin'].replace(['F', 'G'], 'FG')
df_test.loc[df_test['Cabin'] == 'T', 'Cabin'] = 'A'

# %% [markdown]
# # End of EDA

# %% [markdown]
# # Modelling
# - To a better understanding of the modelling part, I will delete df and train and

# %% [markdown]
# ## Dropping unecessary features

# %%
from pandas.api.types import CategoricalDtype 
family_cats = CategoricalDtype(categories=['Alone', 'Small', 'Medium', 'Large'], ordered=True)

# %%
df_train.FSize = df_train.FSize.astype(family_cats)
df_test.FSize = df_test.FSize.astype(family_cats)

# %%
df_train.Age_cat = df_train.Age_cat.cat.codes
df_train.Fare_cat = df_train.Fare_cat.cat.codes
df_test.Age_cat = df_test.Age_cat.cat.codes
df_test.Fare_cat = df_test.Fare_cat.cat.codes
df_train.FSize = df_train.FSize.cat.codes
df_test.FSize = df_test.FSize.cat.codes

# %%
#Now lets drop the variable Fare, Age and ticket that is irrelevant now
df_train.drop([ 'Ticket', 'Name'], axis=1, inplace=True)
df_test.drop(['Ticket', 'Name', ], axis=1, inplace=True)
#df_train.drop(["Fare", 'Ticket', 'Age', 'Cabin', 'Name', 'SibSp', 'Parch'], axis=1, inplace=True)
#df_test.drop(["Fare", 'Ticket', 'Age', 'Cabin', 'Name', 'SibSp', 'Parch'], axis=1, inplace=True)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Now we might have information enough to think about the model structure

# %%
df_test['Survived'] = 'test'
df = pd.concat([df_train, df_test], axis=0, sort=False )

# %% [markdown]
# # Encoding and getting Dummies of categorical features

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Family'] = le.fit_transform(df['Family'].astype(str))

# %% [markdown]
# ### Dummies

# %%
df = pd.get_dummies(df, columns=['Sex', 'Cabin', 'Embarked', 'Title'],\
                          prefix=['Sex', "Cabin", 'Emb', 'Title'], drop_first=True)

df_train, df_test = df[df['Survived'] != 'test'], df[df['Survived'] == 'test'].drop('Survived', axis=1)
del df

# %%
df_train['Survived'].replace({'Yes':1, 'No':0}, inplace=True)

# %%
print(f'Train shape: {df_train.shape}')
print(f'Train shape: {df_test.shape}')
# Out:
# Train shape: (891, 25)
# Train shape: (418, 24)

# %%
df_train.drop(['Age', 'Fare','Fare_log','Family', 'SibSp', 'Parch'], axis=1, inplace=True)
df_test.drop(['Age', 'Fare','Fare_log','Family', 'SibSp', 'Parch'], axis=1, inplace=True)

# %% [markdown]
# ## Setting X and Y

# %%
X_train = df_train.drop(["Survived","PassengerId"],axis=1)
y_train = df_train["Survived"]

X_test = df_test.drop(["PassengerId"],axis=1)

# %%
resumetable(X_train)
# Out:
# Dataset Shape: (891, 17)
#                 Name dtypes  Missing  Uniques  First Value  Second Value  \
# 0             Pclass  int64        0        3            3             1
# 1            Age_cat   int8        0        7            3             5
# 2              FSize   int8        0        4            1             1
# 3   Ticket_Frequency  int64        0        7            1             1
# 4           Fare_cat   int8        0        7            1             3
# 5           Sex_male  uint8        0        2            1             0
# 6          Cabin_ABC  uint8        0        2            0             1
# 7           Cabin_DE  uint8        0        2            0             0
# 8           Cabin_FG  uint8        0        2            0             0
# 9            Cabin_M  uint8        0        2            1             0
# 10             Emb_Q  uint8        0        2            0             0
# 11             Emb_S  uint8        0        2            1             0
# 12        Title_Miss  uint8        0        2            0             0
# 13          Title_Mr  uint8        0        2            1             0
# 14         Title_Mrs  uint8        0        2            0             1
# 15     Title_Officer  uint8        0        2            0             0
# 16     Title_Royalty  uint8        0        2            0             0
#
#     Third Value  Entropy
# 0             3     1.44
# 1             4     2.34
# 2             0     1.30
# 3             1     1.70
# 4             1     2.02
# 5             0     0.94
# 6             0     0.57
# 7             0     0.38
# 8             0     0.14
# 9             1     0.78
# 10            0     0.42
# 11            1     0.85
# 12            1     0.73
# 13            0     0.98
# 14            0     0.59
# 15            0     0.14
# 16            0     0.04

# %% [markdown]
# <a id="Model"></a> <br>
# # **6. Modelling Pipeline of models to find the algo that best fit our problem **

# %%
#Importing the auxiliar and preprocessing librarys 
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.metrics import accuracy_score

#Models
import warnings
warnings.filterwarnings("ignore")

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.linear_model import RidgeClassifier, SGDClassifier, LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier, BaggingClassifier, VotingClassifier, RandomTreesEmbedding

# %%
clfs = []
seed = 3

clfs.append(("LogReg", 
             Pipeline([("Scaler", StandardScaler()),
                       ("LogReg", LogisticRegression())])))

clfs.append(("XGBClassifier",
             Pipeline([("Scaler", StandardScaler()),
                       ("XGB", XGBClassifier())]))) 
clfs.append(("KNN", 
             Pipeline([("Scaler", StandardScaler()),
                       ("KNN", KNeighborsClassifier())]))) 

clfs.append(("DecisionTreeClassifier", 
             Pipeline([("Scaler", StandardScaler()),
                       ("DecisionTrees", DecisionTreeClassifier())]))) 

clfs.append(("RandomForestClassifier", 
             Pipeline([("Scaler", StandardScaler()),
                       ("RandomForest", RandomForestClassifier(n_estimators=100))]))) 

clfs.append(("GradientBoostingClassifier", 
             Pipeline([("Scaler", StandardScaler()),
                       ("GradientBoosting", GradientBoostingClassifier(n_estimators=100))]))) 

clfs.append(("RidgeClassifier", 
             Pipeline([("Scaler", StandardScaler()),
                       ("RidgeClassifier", RidgeClassifier())])))

clfs.append(("BaggingRidgeClassifier",
             Pipeline([("Scaler", StandardScaler()),
                       ("BaggingClassifier", BaggingClassifier())])))

clfs.append(("ExtraTreesClassifier",
             Pipeline([("Scaler", StandardScaler()),
                       ("ExtraTrees", ExtraTreesClassifier())])))

#'neg_mean_absolute_error', 'neg_mean_squared_error','r2'
scoring = 'accuracy'
n_folds = 7

results, names  = [], [] 

for name, model  in clfs:
    kfold = KFold(n_splits=n_folds, random_state=seed)
    cv_results = cross_val_score(model, X_train, y_train, 
                                 cv= 5, scoring=scoring,
                                 n_jobs=-1)    
    names.append(name)
    results.append(cv_results)    
    msg = "%s: %f (+/- %f)" % (name, cv_results.mean(),  cv_results.std())
    print(msg)
    
# boxplot algorithm comparison
fig = plt.figure(figsize=(15,6))
fig.suptitle('Classifier Algorithm Comparison', fontsize=22)
ax = fig.add_subplot(111)
sns.boxplot(x=names, y=results)
ax.set_xticklabels(names)
ax.set_xlabel("Algorithmn", fontsize=20)
ax.set_ylabel("Accuracy of Models", fontsize=18)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

plt.show()
# Out:
# LogReg: 0.830580 (+/- 0.025937)
# XGBClassifier: 0.826143 (+/- 0.034173)
# KNN: 0.813789 (+/- 0.025042)
# DecisionTreeClassifier: 0.782378 (+/- 0.026920)
# RandomForestClassifier: 0.803689 (+/- 0.028386)
# GradientBoostingClassifier: 0.829494 (+/- 0.031221)
# RidgeClassifier: 0.826067 (+/- 0.019576)
# BaggingRidgeClassifier: 0.795842 (+/- 0.028190)
# ExtraTreesClassifier: 0.798121 (+/- 0.039290)

# %% [markdown]
# Very cool! Based on the result of our CVLet's try model LogReg and XGBClassifier to predict who will survive or not

# %% [markdown]
# # HyperOpt - Automated Bayeasian Hyperparameter serach.

# %% [markdown]
# # HyperOpt with Random Forest

# %%
import time

def objective(params):
    time1 = time.time()
    params = {
        'max_depth': params['max_depth'],
        'max_features': params['max_features'],
        'n_estimators': params['n_estimators'],
        'min_samples_split': params['min_samples_split'],
        'criterion': params['criterion']
    }

    print("\n############## New Run ################")
    print(f"params = {params}")
    FOLDS = 10
    count=1

    skf = StratifiedKFold(n_splits=FOLDS, random_state=42, shuffle=True)

    kf = KFold(n_splits=FOLDS, shuffle=False, random_state=42)

    score_mean = 0
    for tr_idx, val_idx in kf.split(X_train, y_train):
        clf = RandomForestClassifier(
            random_state=4, 
            verbose=0,  n_jobs=-1, 
            **params
        )

        X_tr, X_vl = X_train.iloc[tr_idx, :], X_train.iloc[val_idx, :]
        y_tr, y_vl = y_train.iloc[tr_idx], y_train.iloc[val_idx]
        
        clf.fit(X_tr, y_tr)
        #y_pred_train = clf.predict_proba(X_vl)[:,1]
        #print(y_pred_train)
        score = make_scorer(accuracy_score)(clf, X_vl, y_vl)
        # plt.show()
        score_mean += score
        print(f'{count} CV - score: {round(score, 4)}')
        count += 1
    time2 = time.time() - time1
    print(f"Total Time Run: {round(time2 / 60,2)}")
    gc.collect()
    print(f'Mean ROC_AUC: {score_mean / FOLDS}')
    del X_tr, X_vl, y_tr, y_vl, clf, score
    return -(score_mean / FOLDS)

rf_space = {
    'max_depth': hp.choice('max_depth', range(2,8)),
    'max_features': hp.choice('max_features', range(1,X_train.shape[1])),
    'n_estimators': hp.choice('n_estimators', range(100,500)),
    'min_samples_split': hp.choice('min_samples_split', range(5,35)),
    'criterion': hp.choice('criterion', ["gini", "entropy"])
}

# %% [markdown]
# ## Running the HyperOpt to get the best params

# %%
best = fmin(fn=objective,
            space=rf_space,
            algo=tpe.suggest,
            max_evals=40, 
            # trials=trials
           )
# Out:
#
# ############## New Run ################
# params = {'max_depth': 5, 'max_features': 11, 'n_estimators': 248, 'min_samples_split': 24, 'criterion': 'entropy'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8764
# 3 CV - score: 0.7753
# 4 CV - score: 0.8427
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.764
# 9 CV - score: 0.8764
# 10 CV - score: 0.8427
# Total Time Run: 0.11
# Mean ROC_AUC: 0.8226841448189763
#
# ############## New Run ################
# params = {'max_depth': 2, 'max_features': 8, 'n_estimators': 207, 'min_samples_split': 17, 'criterion': 'entropy'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8202
# 3 CV - score: 0.764
# 4 CV - score: 0.8652
# 5 CV - score: 0.7865
# 6 CV - score: 0.809
# 7 CV - score: 0.7753
# 8 CV - score: 0.7978
# 9 CV - score: 0.8539
# 10 CV - score: 0.809
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8092009987515606
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 10, 'n_estimators': 447, 'min_samples_split': 18, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8427
# 3 CV - score: 0.764
# 4 CV - score: 0.8427
# 5 CV - score: 0.8539
# 6 CV - score: 0.8427
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8764
# 10 CV - score: 0.8876
# Total Time Run: 0.19
# Mean ROC_AUC: 0.8316479400749064
#
# ############## New Run ################
# params = {'max_depth': 3, 'max_features': 10, 'n_estimators': 199, 'min_samples_split': 34, 'criterion': 'entropy'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7865
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8282896379525593
#
# ############## New Run ################
# params = {'max_depth': 6, 'max_features': 16, 'n_estimators': 378, 'min_samples_split': 7, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8652
# 3 CV - score: 0.7528
# 4 CV - score: 0.8427
# 5 CV - score: 0.8539
# 6 CV - score: 0.8315
# 7 CV - score: 0.7865
# 8 CV - score: 0.7865
# 9 CV - score: 0.8876
# 10 CV - score: 0.8539
# Total Time Run: 0.17
# Mean ROC_AUC: 0.8294007490636703
#
# ############## New Run ################
# params = {'max_depth': 4, 'max_features': 14, 'n_estimators': 462, 'min_samples_split': 5, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.7978
# 8 CV - score: 0.7978
# 9 CV - score: 0.8764
# 10 CV - score: 0.8427
# Total Time Run: 0.2
# Mean ROC_AUC: 0.8271660424469414
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 8, 'n_estimators': 373, 'min_samples_split': 33, 'criterion': 'gini'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8539
# 5 CV - score: 0.8315
# 6 CV - score: 0.8427
# 7 CV - score: 0.7865
# 8 CV - score: 0.7753
# 9 CV - score: 0.8764
# 10 CV - score: 0.8539
# Total Time Run: 0.16
# Mean ROC_AUC: 0.8260549313358302
#
# ############## New Run ################
# params = {'max_depth': 4, 'max_features': 14, 'n_estimators': 416, 'min_samples_split': 23, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8652
# 3 CV - score: 0.7865
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.809
# 8 CV - score: 0.7865
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.17
# Mean ROC_AUC: 0.8294132334581773
#
# ############## New Run ################
# params = {'max_depth': 3, 'max_features': 2, 'n_estimators': 105, 'min_samples_split': 30, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.7865
# 8 CV - score: 0.764
# 9 CV - score: 0.8652
# 10 CV - score: 0.809
# Total Time Run: 0.06
# Mean ROC_AUC: 0.8181772784019975
#
# ############## New Run ################
# params = {'max_depth': 5, 'max_features': 5, 'n_estimators': 125, 'min_samples_split': 25, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.7865
# 9 CV - score: 0.8876
# 10 CV - score: 0.8539
# Total Time Run: 0.06
# Mean ROC_AUC: 0.8316479400749064
#
# ############## New Run ################
# params = {'max_depth': 5, 'max_features': 13, 'n_estimators': 371, 'min_samples_split': 33, 'criterion': 'entropy'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8876
# 3 CV - score: 0.7865
# 4 CV - score: 0.8427
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.15
# Mean ROC_AUC: 0.8271660424469414
#
# ############## New Run ################
# params = {'max_depth': 5, 'max_features': 5, 'n_estimators': 144, 'min_samples_split': 31, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.809
# 8 CV - score: 0.7865
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.08
# Mean ROC_AUC: 0.8282771535580524
#
# ############## New Run ################
# params = {'max_depth': 4, 'max_features': 9, 'n_estimators': 444, 'min_samples_split': 8, 'criterion': 'entropy'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8764
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7865
# 9 CV - score: 0.8764
# 10 CV - score: 0.8427
# Total Time Run: 0.18
# Mean ROC_AUC: 0.8282896379525593
#
# ############## New Run ################
# params = {'max_depth': 3, 'max_features': 12, 'n_estimators': 153, 'min_samples_split': 22, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8652
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.7978
# 8 CV - score: 0.7865
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.08
# Mean ROC_AUC: 0.8282896379525593
#
# ############## New Run ################
# params = {'max_depth': 2, 'max_features': 8, 'n_estimators': 303, 'min_samples_split': 15, 'criterion': 'gini'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8202
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.7865
# 6 CV - score: 0.809
# 7 CV - score: 0.7865
# 8 CV - score: 0.7978
# 9 CV - score: 0.8539
# 10 CV - score: 0.809
# Total Time Run: 0.13
# Mean ROC_AUC: 0.8114481897627964
#
# ############## New Run ################
# params = {'max_depth': 3, 'max_features': 7, 'n_estimators': 450, 'min_samples_split': 30, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7865
# 9 CV - score: 0.8764
# 10 CV - score: 0.8202
# Total Time Run: 0.18
# Mean ROC_AUC: 0.8237952559300874
#
# ############## New Run ################
# params = {'max_depth': 5, 'max_features': 8, 'n_estimators': 187, 'min_samples_split': 23, 'criterion': 'entropy'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8652
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.809
# 8 CV - score: 0.7753
# 9 CV - score: 0.8764
# 10 CV - score: 0.8539
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8271660424469414
#
# ############## New Run ################
# params = {'max_depth': 6, 'max_features': 13, 'n_estimators': 302, 'min_samples_split': 23, 'criterion': 'entropy'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8764
# 3 CV - score: 0.7753
# 4 CV - score: 0.8427
# 5 CV - score: 0.8202
# 6 CV - score: 0.8315
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8764
# 10 CV - score: 0.8539
# Total Time Run: 0.14
# Mean ROC_AUC: 0.8282771535580524
#
# ############## New Run ################
# params = {'max_depth': 2, 'max_features': 3, 'n_estimators': 173, 'min_samples_split': 16, 'criterion': 'entropy'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8427
# 3 CV - score: 0.7528
# 4 CV - score: 0.8539
# 5 CV - score: 0.7978
# 6 CV - score: 0.809
# 7 CV - score: 0.764
# 8 CV - score: 0.764
# 9 CV - score: 0.8539
# 10 CV - score: 0.7978
# Total Time Run: 0.08
# Mean ROC_AUC: 0.8035955056179775
#
# ############## New Run ################
# params = {'max_depth': 5, 'max_features': 16, 'n_estimators': 211, 'min_samples_split': 33, 'criterion': 'entropy'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8876
# 3 CV - score: 0.7865
# 4 CV - score: 0.8427
# 5 CV - score: 0.809
# 6 CV - score: 0.809
# 7 CV - score: 0.7865
# 8 CV - score: 0.7753
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8249188514357053
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 10, 'n_estimators': 214, 'min_samples_split': 25, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8427
# 5 CV - score: 0.8539
# 6 CV - score: 0.8315
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8764
# 10 CV - score: 0.8876
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8327715355805243
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 10, 'n_estimators': 333, 'min_samples_split': 18, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8427
# 3 CV - score: 0.7528
# 4 CV - score: 0.8427
# 5 CV - score: 0.8539
# 6 CV - score: 0.8427
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8876
# 10 CV - score: 0.8876
# Total Time Run: 0.15
# Mean ROC_AUC: 0.8316479400749064
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 10, 'n_estimators': 214, 'min_samples_split': 19, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8652
# 3 CV - score: 0.7865
# 4 CV - score: 0.8427
# 5 CV - score: 0.8539
# 6 CV - score: 0.8539
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8764
# 10 CV - score: 0.8876
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8372659176029963
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 6, 'n_estimators': 186, 'min_samples_split': 19, 'criterion': 'gini'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8764
# 3 CV - score: 0.764
# 4 CV - score: 0.8427
# 5 CV - score: 0.8315
# 6 CV - score: 0.8539
# 7 CV - score: 0.7865
# 8 CV - score: 0.7753
# 9 CV - score: 0.8652
# 10 CV - score: 0.8539
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8260549313358302
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 1, 'n_estimators': 104, 'min_samples_split': 25, 'criterion': 'gini'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.7978
# 3 CV - score: 0.764
# 4 CV - score: 0.8539
# 5 CV - score: 0.8315
# 6 CV - score: 0.8315
# 7 CV - score: 0.809
# 8 CV - score: 0.7753
# 9 CV - score: 0.8764
# 10 CV - score: 0.8539
# Total Time Run: 0.06
# Mean ROC_AUC: 0.8204369538077403
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 4, 'n_estimators': 214, 'min_samples_split': 19, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8764
# 3 CV - score: 0.764
# 4 CV - score: 0.8764
# 5 CV - score: 0.8315
# 6 CV - score: 0.8315
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8764
# 10 CV - score: 0.8539
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8316479400749064
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 15, 'n_estimators': 214, 'min_samples_split': 26, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8315
# 3 CV - score: 0.7978
# 4 CV - score: 0.8427
# 5 CV - score: 0.8652
# 6 CV - score: 0.8539
# 7 CV - score: 0.7865
# 8 CV - score: 0.7753
# 9 CV - score: 0.8876
# 10 CV - score: 0.8764
# Total Time Run: 0.1
# Mean ROC_AUC: 0.8350187265917605
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 15, 'n_estimators': 260, 'min_samples_split': 12, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8652
# 3 CV - score: 0.764
# 4 CV - score: 0.8427
# 5 CV - score: 0.8427
# 6 CV - score: 0.8315
# 7 CV - score: 0.7978
# 8 CV - score: 0.764
# 9 CV - score: 0.8989
# 10 CV - score: 0.8989
# Total Time Run: 0.12
# Mean ROC_AUC: 0.8327840199750313
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 15, 'n_estimators': 480, 'min_samples_split': 20, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8427
# 3 CV - score: 0.7865
# 4 CV - score: 0.8427
# 5 CV - score: 0.8652
# 6 CV - score: 0.8427
# 7 CV - score: 0.7865
# 8 CV - score: 0.7753
# 9 CV - score: 0.8876
# 10 CV - score: 0.8876
# Total Time Run: 0.21
# Mean ROC_AUC: 0.8350187265917602
#
# ############## New Run ################
# params = {'max_depth': 6, 'max_features': 11, 'n_estimators': 123, 'min_samples_split': 26, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8427
# 3 CV - score: 0.7865
# 4 CV - score: 0.8539
# 5 CV - score: 0.8315
# 6 CV - score: 0.809
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8876
# 10 CV - score: 0.8539
# Total Time Run: 0.07
# Mean ROC_AUC: 0.8271535580524345
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 15, 'n_estimators': 377, 'min_samples_split': 26, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8427
# 3 CV - score: 0.7978
# 4 CV - score: 0.8427
# 5 CV - score: 0.8652
# 6 CV - score: 0.8539
# 7 CV - score: 0.7865
# 8 CV - score: 0.7753
# 9 CV - score: 0.8876
# 10 CV - score: 0.8876
# Total Time Run: 0.16
# Mean ROC_AUC: 0.8372659176029963
#
# ############## New Run ################
# params = {'max_depth': 2, 'max_features': 3, 'n_estimators': 451, 'min_samples_split': 28, 'criterion': 'gini'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7528
# 4 CV - score: 0.8539
# 5 CV - score: 0.7753
# 6 CV - score: 0.7978
# 7 CV - score: 0.7753
# 8 CV - score: 0.7753
# 9 CV - score: 0.8427
# 10 CV - score: 0.7978
# Total Time Run: 0.18
# Mean ROC_AUC: 0.8024594257178528
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 15, 'n_estimators': 126, 'min_samples_split': 27, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8315
# 3 CV - score: 0.7978
# 4 CV - score: 0.8427
# 5 CV - score: 0.8539
# 6 CV - score: 0.8539
# 7 CV - score: 0.7865
# 8 CV - score: 0.7753
# 9 CV - score: 0.8876
# 10 CV - score: 0.8539
# Total Time Run: 0.08
# Mean ROC_AUC: 0.8305368289637952
#
# ############## New Run ################
# params = {'max_depth': 6, 'max_features': 9, 'n_estimators': 341, 'min_samples_split': 29, 'criterion': 'gini'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8427
# 5 CV - score: 0.8315
# 6 CV - score: 0.8315
# 7 CV - score: 0.7865
# 8 CV - score: 0.764
# 9 CV - score: 0.8764
# 10 CV - score: 0.8539
# Total Time Run: 0.15
# Mean ROC_AUC: 0.8215730337078652
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 10, 'n_estimators': 312, 'min_samples_split': 21, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8427
# 5 CV - score: 0.8539
# 6 CV - score: 0.8427
# 7 CV - score: 0.7978
# 8 CV - score: 0.7753
# 9 CV - score: 0.8652
# 10 CV - score: 0.8876
# Total Time Run: 0.14
# Mean ROC_AUC: 0.8316479400749064
#
# ############## New Run ################
# params = {'max_depth': 4, 'max_features': 1, 'n_estimators': 377, 'min_samples_split': 14, 'criterion': 'entropy'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8427
# 6 CV - score: 0.8202
# 7 CV - score: 0.7865
# 8 CV - score: 0.7416
# 9 CV - score: 0.8652
# 10 CV - score: 0.8539
# Total Time Run: 0.16
# Mean ROC_AUC: 0.8215480649188514
#
# ############## New Run ################
# params = {'max_depth': 7, 'max_features': 2, 'n_estimators': 265, 'min_samples_split': 32, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8539
# 3 CV - score: 0.764
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.764
# 9 CV - score: 0.8764
# 10 CV - score: 0.8539
# Total Time Run: 0.12
# Mean ROC_AUC: 0.8237952559300874
#
# ############## New Run ################
# params = {'max_depth': 2, 'max_features': 6, 'n_estimators': 195, 'min_samples_split': 10, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.7865
# 6 CV - score: 0.809
# 7 CV - score: 0.7753
# 8 CV - score: 0.7978
# 9 CV - score: 0.8427
# 10 CV - score: 0.7978
# Total Time Run: 0.09
# Mean ROC_AUC: 0.8125468164794007
#
# ############## New Run ################
# params = {'max_depth': 3, 'max_features': 7, 'n_estimators': 468, 'min_samples_split': 6, 'criterion': 'gini'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7865
# 9 CV - score: 0.8764
# 10 CV - score: 0.8202
# Total Time Run: 0.19
# Mean ROC_AUC: 0.8237952559300874
#
# ############## New Run ################
# params = {'max_depth': 4, 'max_features': 4, 'n_estimators': 169, 'min_samples_split': 13, 'criterion': 'gini'}
# 1 CV - score: 0.8333
# 2 CV - score: 0.8539
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7865
# 9 CV - score: 0.8764
# 10 CV - score: 0.8315
# Total Time Run: 0.08
# Mean ROC_AUC: 0.8260299625468164
# 100%|██████████| 40/40 [05:06<00:00,  7.68s/it, best loss: -0.8372659176029963]

# %% [markdown]
# ## Best params

# %%
best_params = space_eval(rf_space, best)
best_params
# Out:
# {'criterion': 'gini',
#  'max_depth': 7,
#  'max_features': 10,
#  'min_samples_split': 19,
#  'n_estimators': 214}

# %% [markdown]
# ## Predicting the X_test with Random Forest

# %%
clf = RandomForestClassifier(
        **best_params, random_state=4,
        )

clf.fit(X_train, y_train)

y_preds= clf.predict(X_test)

submission['Survived'] = y_preds.astype(int)
submission.to_csv('Titanic_rf_model_pred.csv')

# %% [markdown]
# _______________________________________________
# # Predicting X_test with Logreg and HyperOpt

# %% [markdown]
# ### Calculating the class_weights

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',
                                                  np.unique(y_train),
                                                  y_train)

# %% [markdown]
# # Objective LogReg

# %%
def objective_logreg(params):
    time1 = time.time()
    params = {
        'tol': params['tol'],
        'C': params['C'],
        'solver': params['solver'],
    }

    print("\n############## New Run ################")
    print(f"params = {params}")
    FOLDS = 10
    count=1

    skf = StratifiedKFold(n_splits=FOLDS, random_state=42, shuffle=True)

    kf = KFold(n_splits=FOLDS, shuffle=False, random_state=42)

    score_mean = 0
    for tr_idx, val_idx in kf.split(X_train, y_train):
        clf = LogisticRegression(
            random_state=4,  
            **params
        )

        X_tr, X_vl = X_train.iloc[tr_idx, :], X_train.iloc[val_idx, :]
        y_tr, y_vl = y_train.iloc[tr_idx], y_train.iloc[val_idx]
        
        clf.fit(X_tr, y_tr)
        score = make_scorer(accuracy_score)(clf, X_vl, y_vl)
        score_mean += score
        print(f'{count} CV - score: {round(score, 4)}')
        count += 1
    time2 = time.time() - time1
    print(f"Total Time Run: {round(time2 / 60,2)}")
    gc.collect()
    print(f'Mean ROC_AUC: {score_mean / FOLDS}')
    del X_tr, X_vl, y_tr, y_vl, clf, score
    return -(score_mean / FOLDS)

space_logreg = {
    'tol' : hp.uniform('tol', 0.00001, 0.001),
    'C' : hp.uniform('C', 0.001, 2),
    'solver' : hp.choice('solver', ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']),
}

# %% [markdown]
# ## Running LogReg HyperOpt

# %%
best = fmin(fn=objective_logreg,
            space=space_logreg,
            algo=tpe.suggest,
            max_evals=45, 
            # trials=trials
           )
# Out:
#
# ############## New Run ################
# params = {'tol': 0.0003841633512661545, 'C': 1.0361767525424304, 'solver': 'liblinear'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8876
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.830561797752809
#
# ############## New Run ################
# params = {'tol': 0.0007820702578950973, 'C': 0.6133314893831534, 'solver': 'sag'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.809
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.828314606741573
#
# ############## New Run ################
# params = {'tol': 0.0007600970135228536, 'C': 0.29659923070293903, 'solver': 'lbfgs'}
# 1 CV - score: 0.7889
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.8202
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8272034956304617
#
# ############## New Run ################
# params = {'tol': 0.0009935081656791344, 'C': 1.9984129133779516, 'solver': 'newton-cg'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8327840199750313
#
# ############## New Run ################
# params = {'tol': 0.0005442270745413515, 'C': 1.3775421000664765, 'solver': 'lbfgs'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.83167290886392
#
# ############## New Run ################
# params = {'tol': 0.0008905993399561832, 'C': 1.5606045897208836, 'solver': 'lbfgs'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 0.0001105892717936011, 'C': 1.192724350397618, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8315
# 7 CV - score: 0.8202
# 8 CV - score: 0.809
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8339200998751559
#
# ############## New Run ################
# params = {'tol': 0.0008181117734522974, 'C': 0.1970645236865281, 'solver': 'sag'}
# 1 CV - score: 0.7889
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.7978
# 7 CV - score: 0.809
# 8 CV - score: 0.8315
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8249563046192259
#
# ############## New Run ################
# params = {'tol': 0.0007647808674526268, 'C': 1.7050644224037155, 'solver': 'liblinear'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8876
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8316853932584269
#
# ############## New Run ################
# params = {'tol': 0.00026683477723226577, 'C': 0.8540357815516393, 'solver': 'liblinear'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8876
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.828314606741573
#
# ############## New Run ################
# params = {'tol': 0.00017887620395597257, 'C': 1.8943480163138184, 'solver': 'sag'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 0.0002312414444894978, 'C': 0.9947013195289484, 'solver': 'saga'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.809
# 8 CV - score: 0.7978
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8283021223470662
#
# ############## New Run ################
# params = {'tol': 0.00022436930060753277, 'C': 0.6114301557634633, 'solver': 'newton-cg'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.809
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.828314606741573
#
# ############## New Run ################
# params = {'tol': 0.00016527056241881984, 'C': 0.01687241319332237, 'solver': 'newton-cg'}
# 1 CV - score: 0.7556
# 2 CV - score: 0.8202
# 3 CV - score: 0.7978
# 4 CV - score: 0.8315
# 5 CV - score: 0.8202
# 6 CV - score: 0.7978
# 7 CV - score: 0.7978
# 8 CV - score: 0.809
# 9 CV - score: 0.8876
# 10 CV - score: 0.8202
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8137578027465668
#
# ############## New Run ################
# params = {'tol': 0.0002488158832056076, 'C': 0.6663431547958075, 'solver': 'saga'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.83167290886392
#
# ############## New Run ################
# params = {'tol': 0.0008897243186637766, 'C': 1.7045490607664486, 'solver': 'sag'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 0.0008889600035703113, 'C': 1.51343193912254, 'solver': 'sag'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 7.358252194436093e-05, 'C': 1.6661763253004476, 'solver': 'sag'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 6.242583381367151e-05, 'C': 0.741707548175706, 'solver': 'sag'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 0.00041514658481779236, 'C': 0.5394589278006827, 'solver': 'liblinear'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8876
# 5 CV - score: 0.8202
# 6 CV - score: 0.7865
# 7 CV - score: 0.7978
# 8 CV - score: 0.809
# 9 CV - score: 0.8876
# 10 CV - score: 0.8315
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8226966292134833
#
# ############## New Run ################
# params = {'tol': 0.0005805431925079518, 'C': 1.2286052572780473, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.809
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.832796504369538
#
# ############## New Run ################
# params = {'tol': 0.0006191739872672069, 'C': 1.2884538988810266, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.83167290886392
#
# ############## New Run ################
# params = {'tol': 0.0006379964505650221, 'C': 1.1758812916239207, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8315
# 7 CV - score: 0.8202
# 8 CV - score: 0.809
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.832796504369538
#
# ############## New Run ################
# params = {'tol': 0.0006584618352158144, 'C': 1.1209148461323533, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8315
# 7 CV - score: 0.8202
# 8 CV - score: 0.809
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.832796504369538
#
# ############## New Run ################
# params = {'tol': 0.00035282738127349693, 'C': 0.9699622141031173, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.809
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 0.00048609191196426834, 'C': 1.4099821369797356, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.83167290886392
#
# ############## New Run ################
# params = {'tol': 0.0006662299843025532, 'C': 1.077592778179556, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.809
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 0.0004968435242051664, 'C': 0.4527319837723388, 'solver': 'saga'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.809
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8294257178526842
#
# ############## New Run ################
# params = {'tol': 0.000354755133433345, 'C': 0.8303001834184602, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.832796504369538
#
# ############## New Run ################
# params = {'tol': 1.1157874860522068e-05, 'C': 0.8128942395364205, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.832796504369538
#
# ############## New Run ################
# params = {'tol': 2.2760814681539734e-05, 'C': 0.9848956074656576, 'solver': 'saga'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.809
# 8 CV - score: 0.7978
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8283021223470662
#
# ############## New Run ################
# params = {'tol': 0.0005617298125603693, 'C': 1.207280736583541, 'solver': 'lbfgs'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.809
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.832796504369538
#
# ############## New Run ################
# params = {'tol': 0.00041085697471969257, 'C': 1.8326285033875367, 'solver': 'lbfgs'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8327840199750313
#
# ############## New Run ################
# params = {'tol': 9.7941576377999e-05, 'C': 0.1969086638918771, 'solver': 'newton-cg'}
# 1 CV - score: 0.7889
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8652
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.809
# 8 CV - score: 0.8315
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.01
# Mean ROC_AUC: 0.826079900124844
#
# ############## New Run ################
# params = {'tol': 0.0006978305755282516, 'C': 1.4128337106011317, 'solver': 'lbfgs'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.83167290886392
#
# ############## New Run ################
# params = {'tol': 0.0009847992074494066, 'C': 1.3396535200601585, 'solver': 'newton-cg'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.83167290886392
#
# ############## New Run ################
# params = {'tol': 0.0004527630744169295, 'C': 1.5433831333858041, 'solver': 'liblinear'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8876
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8305617977528088
#
# ############## New Run ################
# params = {'tol': 0.0003176643085246499, 'C': 0.4215123263879439, 'solver': 'newton-cg'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.809
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8305617977528088
#
# ############## New Run ################
# params = {'tol': 0.00012047215273335851, 'C': 0.8526775188603134, 'solver': 'liblinear'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8876
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.828314606741573
#
# ############## New Run ################
# params = {'tol': 0.0003162495130389676, 'C': 0.32364672966182073, 'solver': 'newton-cg'}
# 1 CV - score: 0.7889
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.8202
# 9 CV - score: 0.8876
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8260799001248438
#
# ############## New Run ################
# params = {'tol': 0.0005462791744649145, 'C': 1.9563657685639968, 'solver': 'saga'}
# 1 CV - score: 0.8111
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8316729088639201
#
# ############## New Run ################
# params = {'tol': 0.000802320430422103, 'C': 1.823351128329208, 'solver': 'lbfgs'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.01
# Mean ROC_AUC: 0.8327840199750313
#
# ############## New Run ################
# params = {'tol': 0.0005871986545235854, 'C': 1.6157540193015145, 'solver': 'newton-cg'}
# 1 CV - score: 0.8222
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.8202
# 6 CV - score: 0.809
# 7 CV - score: 0.8202
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8539
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8327840199750313
#
# ############## New Run ################
# params = {'tol': 2.4296016617541476e-05, 'C': 0.9118676190833205, 'solver': 'liblinear'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8315
# 3 CV - score: 0.7753
# 4 CV - score: 0.8876
# 5 CV - score: 0.8202
# 6 CV - score: 0.8202
# 7 CV - score: 0.7978
# 8 CV - score: 0.7978
# 9 CV - score: 0.9101
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.828314606741573
#
# ############## New Run ################
# params = {'tol': 0.00013230537734437036, 'C': 0.7541139578703613, 'solver': 'newton-cg'}
# 1 CV - score: 0.8
# 2 CV - score: 0.8427
# 3 CV - score: 0.7753
# 4 CV - score: 0.8764
# 5 CV - score: 0.809
# 6 CV - score: 0.8202
# 7 CV - score: 0.809
# 8 CV - score: 0.8202
# 9 CV - score: 0.8989
# 10 CV - score: 0.8427
# Total Time Run: 0.0
# Mean ROC_AUC: 0.8294382022471909
# 100%|██████████| 45/45 [00:21<00:00,  2.31it/s, best loss: -0.8339200998751559]

# %%
best_params = space_eval(space_logreg, best)
best_params
# Out:
# {'C': 1.192724350397618, 'solver': 'newton-cg', 'tol': 0.0001105892717936011}

# %%
clf = LogisticRegression(
        **best_params, random_state=4,
        )

clf.fit(X_train, y_train)

y_preds= clf.predict(X_test)

submission['Survived'] = y_preds.astype(int)
submission.to_csv('Titanic_logreg_model_pred.csv')

# %% [markdown]
# # Stay tuned and don't forget to votesup this kernel =)

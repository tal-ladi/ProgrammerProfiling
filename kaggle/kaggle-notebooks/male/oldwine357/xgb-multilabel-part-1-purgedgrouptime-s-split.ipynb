# %% [markdown]
# #### This is fork of https://www.kaggle.com/code1110/janestreet-faster-inference-by-xgb-with-treelite beautifull notebook on how to make faster prediction with xgb!! <br>
#
# #### I'm using PurgedGroupTimeSeriesSplit for validation with multitarget.

# %% [markdown]
# # Install treelite

# %%
# !pip --quiet install ../input/treelite/treelite-0.93-py3-none-manylinux2010_x86_64.whl

# %%
# !pip --quiet install ../input/treelite/treelite_runtime-0.93-py3-none-manylinux2010_x86_64.whl

# %% [markdown]
# # Imports 🛬

# %%
import numpy as np
import pandas as pd

import os, sys
import gc
import math
import random
import pathlib
from tqdm import tqdm
from typing import List, NoReturn, Union, Tuple, Optional, Text, Generic, Callable, Dict
from sklearn.preprocessing import MinMaxScaler, StandardScaler, QuantileTransformer
from sklearn.decomposition import PCA
from sklearn import linear_model
import operator
import xgboost as xgb
import lightgbm as lgb
from tqdm import tqdm

# treelite
import treelite
import treelite_runtime 

# visualize
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
from matplotlib_venn import venn2
from matplotlib import pyplot
from matplotlib.ticker import ScalarFormatter
sns.set_context("talk")
style.use('fivethirtyeight')
pd.options.display.max_columns = None

import warnings
warnings.filterwarnings('ignore')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # PurgedGroupTimeSeriesSplit

# %%
from sklearn.metrics import roc_auc_score

from sklearn.model_selection import KFold
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """

    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

# %% [markdown]
# # Config 🔧

# %%
SEED = 42 # Happy new year!
# INPUT_DIR = '../input/jane-street-market-prediction/'
START_DATE = 85
INPUT_DIR = '../input/janestreet-save-as-feather/'
TRADING_THRESHOLD = 0.502 # 0 ~ 1: The smaller, the more aggressive

# %% [markdown]
# # Load Data and Data Preprocessing

# %%
os.listdir(INPUT_DIR)
# Out:
# ['example_test.feather',
#  'features.feather',
#  '__results__.html',
#  'example_sample_submission.feather',
#  '__resultx__.html',
#  '__notebook__.ipynb',
#  '__output__.json',
#  'train.feather',
#  'custom.css']

# %%
# %%time

def load_data(input_dir=INPUT_DIR):
    train = pd.read_feather(pathlib.Path(input_dir + 'train.feather'))
    #features = pd.read_feather(pathlib.Path(input_dir + 'features.feather'))
    #example_test = pd.read_feather(pathlib.Path(input_dir + 'example_test.feather'))
    #ss = pd.read_feather(pathlib.Path(input_dir + 'example_sample_submission.feather'))
    return train
train = load_data(INPUT_DIR)
# Out:
# CPU times: user 739 ms, sys: 2.28 s, total: 3.02 s
# Wall time: 18.7 s

# %%
# reduce train
train = train.query(f'date > {START_DATE}')
train.fillna(train.mean(),inplace=True)
train = train[train['weight'] != 0]

# %%
# features
features = train.columns[train.columns.str.startswith('feature')].values.tolist()
print('{} features used'.format(len(features)))
# Out:
# 130 features used

# %%
# target
train['action'] = (train['resp'] > 0).astype('int')
f_mean = np.mean(train[features[1:]].values,axis=0)

# %% [markdown]
# # Model💪

# %%
params = {'n_estimators': 473, 'max_depth': 7, 'min_child_weight': 6, 
 'learning_rate': 0.015944928866056352, 'subsample': 0.608128483148888, 
 'gamma': 0, 'colsample_bytree': 0.643875232059528,'objective':'binary:logistic',
'eval_metric': 'auc','tree_method': 'gpu_hist', 'random_state': 42,} 

params_1 = {'n_estimators': 494, 'max_depth': 8, 'min_child_weight': 6, 'learning_rate': 0.009624384025871735, 
            'subsample': 0.8328412036014541, 'gamma': 0, 'colsample_bytree': 0.715303237773365,
           'objective':'binary:logistic', 'eval_metric': 'auc','tree_method': 'gpu_hist', 'random_state': 42,}

# %%
training = True
import pickle

if training:
    import time
    import gc
    resp_cols = ['resp_1', 'resp_2', 'resp_3', 'resp', 'resp_4']
    X = train[features].values
    #y = train['action'].values
    y = np.stack([(train[c] > 0).astype('int') for c in resp_cols]).T #Multitarget
    groups = train['date'].values
    models = []
    scores = []

    cv = PurgedGroupTimeSeriesSplit(
        n_splits=4,
        group_gap=20,
    )
    for t in tqdm(range(y.shape[1])):
        yy = y[:,t]
        for i, (train_index, valid_index) in enumerate(cv.split(
                X,
                yy,
                groups=groups)):
            print(f'Target {t} Fold {i} started at {time.ctime()}')
            X_train, X_valid = X[train_index], X[valid_index]
            y_train, y_valid = yy[train_index], yy[valid_index]
            model = xgb.XGBClassifier(**params_1, n_jobs = -1)
            model.fit(X_train, y_train, 
                    eval_set=[(X_valid, y_valid)], eval_metric='auc',
                    verbose=100, callbacks = [xgb.callback.EarlyStopping(rounds=300,save_best=True)])
            pred = model.predict(X_valid)
            score = roc_auc_score(y_valid,pred)
            model.save_model(f'my_model_{t}_{i}.model')
            pickle.dump(model, open(f'my_model_{t}_{i}.pkl', "wb"))
            models.append(model)
            scores.append(score)
            del score, model
        print(scores)
        del X_train, X_valid, y_train, y_valid
        rubbish = gc.collect()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Target 0 Fold 0 started at Sun Feb 21 12:19:19 2021
# [0]	validation_0-auc:0.53744
# [100]	validation_0-auc:0.56566
# [200]	validation_0-auc:0.56833
# [300]	validation_0-auc:0.56957
# [400]	validation_0-auc:0.57003
# [493]	validation_0-auc:0.57007
# Target 0 Fold 1 started at Sun Feb 21 12:19:39 2021
# [0]	validation_0-auc:0.54563
# [100]	validation_0-auc:0.56937
# [200]	validation_0-auc:0.57229
# [300]	validation_0-auc:0.57432
# [400]	validation_0-auc:0.57544
# [493]	validation_0-auc:0.57608
# Target 0 Fold 2 started at Sun Feb 21 12:20:08 2021
# [0]	validation_0-auc:0.54878
# [100]	validation_0-auc:0.56771
# [200]	validation_0-auc:0.57023
# [300]	validation_0-auc:0.57189
# [400]	validation_0-auc:0.57316
# [493]	validation_0-auc:0.57390
# Target 0 Fold 3 started at Sun Feb 21 12:20:45 2021
# [0]	validation_0-auc:0.55592
# [100]	validation_0-auc:0.57441
# [200]	validation_0-auc:0.57751
# [300]	validation_0-auc:0.57945
# [400]	validation_0-auc:0.58059
# [493]	validation_0-auc:0.58152
#  20%|██        | 1/5 [02:07<08:31, 127.91s/it]
# [0.5477137954436678, 0.551518135583025, 0.549069821122234, 0.5548460713496856]
# Target 1 Fold 0 started at Sun Feb 21 12:21:26 2021
# [0]	validation_0-auc:0.53220
# [100]	validation_0-auc:0.55392
# [200]	validation_0-auc:0.55519
# [300]	validation_0-auc:0.55532
# [400]	validation_0-auc:0.55534
# [493]	validation_0-auc:0.55528
# Target 1 Fold 1 started at Sun Feb 21 12:21:45 2021
# [0]	validation_0-auc:0.53609
# [100]	validation_0-auc:0.55539
# [200]	validation_0-auc:0.55804
# [300]	validation_0-auc:0.56019
# [400]	validation_0-auc:0.56159
# [493]	validation_0-auc:0.56233
# Target 1 Fold 2 started at Sun Feb 21 12:22:13 2021
# [0]	validation_0-auc:0.53421
# [100]	validation_0-auc:0.55012
# [200]	validation_0-auc:0.55213
# [300]	validation_0-auc:0.55346
# [400]	validation_0-auc:0.55432
# [493]	validation_0-auc:0.55510
# Target 1 Fold 3 started at Sun Feb 21 12:22:50 2021
# [0]	validation_0-auc:0.54142
# [100]	validation_0-auc:0.55994
# [200]	validation_0-auc:0.56258
# [300]	validation_0-auc:0.56434
# [400]	validation_0-auc:0.56542
# [493]	validation_0-auc:0.56611
#  40%|████      | 2/5 [04:10<06:15, 125.02s/it]
# [0.5477137954436678, 0.551518135583025, 0.549069821122234, 0.5548460713496856, 0.5376534665958275, 0.5420470800093996, 0.5357101737399761, 0.543466924956549]
# Target 2 Fold 0 started at Sun Feb 21 12:23:29 2021
# [0]	validation_0-auc:0.51450
# [100]	validation_0-auc:0.52659
# [200]	validation_0-auc:0.52690
# [300]	validation_0-auc:0.52700
# [400]	validation_0-auc:0.52715
# [493]	validation_0-auc:0.52675
# Target 2 Fold 1 started at Sun Feb 21 12:23:47 2021
# [0]	validation_0-auc:0.51753
# [100]	validation_0-auc:0.53336
# [200]	validation_0-auc:0.53494
# [300]	validation_0-auc:0.53555
# [400]	validation_0-auc:0.53613
# [493]	validation_0-auc:0.53670
# Target 2 Fold 2 started at Sun Feb 21 12:24:14 2021
# [0]	validation_0-auc:0.51162
# [100]	validation_0-auc:0.52521
# [200]	validation_0-auc:0.52699
# [300]	validation_0-auc:0.52848
# [400]	validation_0-auc:0.52962
# [493]	validation_0-auc:0.53015
# Target 2 Fold 3 started at Sun Feb 21 12:24:49 2021
# [0]	validation_0-auc:0.52275
# [100]	validation_0-auc:0.53843
# [200]	validation_0-auc:0.53986
# [300]	validation_0-auc:0.54036
# [400]	validation_0-auc:0.54081
# [493]	validation_0-auc:0.54095
#  60%|██████    | 3/5 [06:08<04:03, 121.75s/it]
# [0.5477137954436678, 0.551518135583025, 0.549069821122234, 0.5548460713496856, 0.5376534665958275, 0.5420470800093996, 0.5357101737399761, 0.543466924956549, 0.5162229286949249, 0.5244767351144575, 0.5192414232170681, 0.5260218473107998]
# Target 3 Fold 0 started at Sun Feb 21 12:25:27 2021
# [0]	validation_0-auc:0.51200
# [100]	validation_0-auc:0.52055
# [200]	validation_0-auc:0.52246
# [300]	validation_0-auc:0.52389
# [400]	validation_0-auc:0.52422
# [493]	validation_0-auc:0.52425
# Target 3 Fold 1 started at Sun Feb 21 12:25:45 2021
# [0]	validation_0-auc:0.51960
# [100]	validation_0-auc:0.53207
# [200]	validation_0-auc:0.53263
# [300]	validation_0-auc:0.53276
# [400]	validation_0-auc:0.53319
# [493]	validation_0-auc:0.53325
# Target 3 Fold 2 started at Sun Feb 21 12:26:11 2021
# [0]	validation_0-auc:0.50803
# [100]	validation_0-auc:0.51528
# [200]	validation_0-auc:0.51646
# [300]	validation_0-auc:0.51756
# [400]	validation_0-auc:0.51817
# [493]	validation_0-auc:0.51886
# Target 3 Fold 3 started at Sun Feb 21 12:26:45 2021
# [0]	validation_0-auc:0.51509
# [100]	validation_0-auc:0.52753
# [200]	validation_0-auc:0.53002
# [300]	validation_0-auc:0.53098
# [400]	validation_0-auc:0.53179
# [493]	validation_0-auc:0.53245
#  80%|████████  | 4/5 [08:03<01:59, 119.02s/it]
# [0.5477137954436678, 0.551518135583025, 0.549069821122234, 0.5548460713496856, 0.5376534665958275, 0.5420470800093996, 0.5357101737399761, 0.543466924956549, 0.5162229286949249, 0.5244767351144575, 0.5192414232170681, 0.5260218473107998, 0.514835761058067, 0.5215884543001081, 0.5135617900225867, 0.5213728685441515]
# Target 4 Fold 0 started at Sun Feb 21 12:27:22 2021
# [0]	validation_0-auc:0.51068
# [100]	validation_0-auc:0.51618
# [200]	validation_0-auc:0.51789
# [300]	validation_0-auc:0.51776
# [400]	validation_0-auc:0.51830
# [493]	validation_0-auc:0.51881
# Target 4 Fold 1 started at Sun Feb 21 12:27:40 2021
# [0]	validation_0-auc:0.51670
# [100]	validation_0-auc:0.52147
# [200]	validation_0-auc:0.52177
# [300]	validation_0-auc:0.52247
# [400]	validation_0-auc:0.52271
# [493]	validation_0-auc:0.52253
# Target 4 Fold 2 started at Sun Feb 21 12:28:04 2021
# [0]	validation_0-auc:0.50902
# [100]	validation_0-auc:0.51170
# [200]	validation_0-auc:0.51244
# [300]	validation_0-auc:0.51338
# [400]	validation_0-auc:0.51409
# [493]	validation_0-auc:0.51430
# Target 4 Fold 3 started at Sun Feb 21 12:28:38 2021
# [0]	validation_0-auc:0.51279
# [100]	validation_0-auc:0.52334
# [200]	validation_0-auc:0.52409
# [300]	validation_0-auc:0.52593
# [400]	validation_0-auc:0.52695
# [493]	validation_0-auc:0.52744
# 100%|██████████| 5/5 [09:56<00:00, 119.24s/it]
# [0.5477137954436678, 0.551518135583025, 0.549069821122234, 0.5548460713496856, 0.5376534665958275, 0.5420470800093996, 0.5357101737399761, 0.543466924956549, 0.5162229286949249, 0.5244767351144575, 0.5192414232170681, 0.5260218473107998, 0.514835761058067, 0.5215884543001081, 0.5135617900225867, 0.5213728685441515, 0.5116925083091616, 0.5162101892863364, 0.5095164429705878, 0.5171819554035509]

# %% [markdown]
# # Compile with Treelite
# Simply follow the tutorial: https://treelite.readthedocs.io/en/latest/tutorials/first.html

# %%
# pass to treelite
if training:
    model_0 = treelite.Model.load('my_model_0_3.model', model_format='xgboost')
    model_1 = treelite.Model.load('my_model_1_3.model', model_format='xgboost')
    model_2 = treelite.Model.load('my_model_2_3.model', model_format='xgboost')
    model_3 = treelite.Model.load('my_model_3_3.model', model_format='xgboost')
    model_4 = treelite.Model.load('my_model_4_3.model', model_format='xgboost')

# %%
if training:
    m = [model_0,model_1,model_2,model_3,model_4]
    for j,i in enumerate(m):
        toolchain = 'gcc'
        i.export_lib(toolchain=toolchain, libpath=f'./mymodel_{j}.so',
                     params={'parallel_comp': 32}, verbose=True)
# Out:
# [12:29:13] ../src/compiler/ast_native.cc:44: Using ASTNativeCompiler
# [12:29:13] ../src/compiler/ast/split.cc:29: Parallel compilation enabled; member trees will be divided into 32 translation units.
# [12:29:14] ../src/c_api/c_api.cc:286: Code generation finished. Writing code to files...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file recipe.json...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu27.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu22.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu24.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu21.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu8.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu5.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu6.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu3.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu7.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu26.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu16.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu14.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file header.h...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu0.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu4.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu19.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file main.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu2.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu9.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu10.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu30.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu23.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu1.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu12.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu29.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu11.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu25.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu13.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu15.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu17.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu28.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu18.c...
# [12:29:14] ../src/c_api/c_api.cc:291: Writing file tu20.c...
# [12:29:14] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:263: WARNING: some of the source files are long. Expect long compilation time. You may want to adjust the parameter parallel_comp.
#
# [12:29:14] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:104: Compiling sources files in directory ./tmpi5ph1zsv into object files (*.o)...
# [12:30:57] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:133: Generating dynamic shared library ./tmpi5ph1zsv/predictor.so...
# [12:30:58] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:278: Generated shared library in 104.09 seconds
# [12:30:58] ../src/compiler/ast_native.cc:44: Using ASTNativeCompiler
# [12:30:58] ../src/compiler/ast/split.cc:29: Parallel compilation enabled; member trees will be divided into 32 translation units.
# [12:30:59] ../src/c_api/c_api.cc:286: Code generation finished. Writing code to files...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file recipe.json...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu27.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu22.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu24.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu21.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu8.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu5.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu6.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu3.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu7.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu26.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu16.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu14.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file header.h...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu0.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu4.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu19.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file main.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu2.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu9.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu10.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu30.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu23.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu1.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu12.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu29.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu11.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu25.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu13.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu15.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu17.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu28.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu18.c...
# [12:30:59] ../src/c_api/c_api.cc:291: Writing file tu20.c...
# [12:30:59] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:263: WARNING: some of the source files are long. Expect long compilation time. You may want to adjust the parameter parallel_comp.
#
# [12:30:59] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:104: Compiling sources files in directory ./tmp6m12p37u into object files (*.o)...
# [12:32:39] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:133: Generating dynamic shared library ./tmp6m12p37u/predictor.so...
# [12:32:39] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:278: Generated shared library in 100.34 seconds
# [12:32:39] ../src/compiler/ast_native.cc:44: Using ASTNativeCompiler
# [12:32:39] ../src/compiler/ast/split.cc:29: Parallel compilation enabled; member trees will be divided into 32 translation units.
# [12:32:40] ../src/c_api/c_api.cc:286: Code generation finished. Writing code to files...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file recipe.json...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu27.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu22.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu24.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu21.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu8.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu5.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu6.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu3.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu7.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu26.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu16.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu14.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file header.h...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu0.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu4.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu19.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file main.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu2.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu9.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu10.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu30.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu23.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu1.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu12.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu29.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu11.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu25.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu13.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu15.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu17.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu28.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu18.c...
# [12:32:40] ../src/c_api/c_api.cc:291: Writing file tu20.c...
# [12:32:40] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:263: WARNING: some of the source files are long. Expect long compilation time. You may want to adjust the parameter parallel_comp.
#
# [12:32:40] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:104: Compiling sources files in directory ./tmp83s3p4uw into object files (*.o)...
# [12:34:08] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:133: Generating dynamic shared library ./tmp83s3p4uw/predictor.so...
# [12:34:08] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:278: Generated shared library in 88.27 seconds
# [12:34:08] ../src/compiler/ast_native.cc:44: Using ASTNativeCompiler
# [12:34:08] ../src/compiler/ast/split.cc:29: Parallel compilation enabled; member trees will be divided into 32 translation units.
# [12:34:09] ../src/c_api/c_api.cc:286: Code generation finished. Writing code to files...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file recipe.json...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu27.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu22.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu24.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu21.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu8.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu5.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu6.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu3.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu7.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu26.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu16.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu14.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file header.h...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu0.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu4.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu19.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file main.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu2.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu9.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu10.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu30.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu23.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu1.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu12.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu29.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu11.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu25.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu13.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu15.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu17.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu28.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu18.c...
# [12:34:09] ../src/c_api/c_api.cc:291: Writing file tu20.c...
# [12:34:09] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:263: WARNING: some of the source files are long. Expect long compilation time. You may want to adjust the parameter parallel_comp.
#
# [12:34:09] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:104: Compiling sources files in directory ./tmpu2z3ohkt into object files (*.o)...
# [12:35:28] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:133: Generating dynamic shared library ./tmpu2z3ohkt/predictor.so...
# [12:35:28] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:278: Generated shared library in 78.87 seconds
# [12:35:28] ../src/compiler/ast_native.cc:44: Using ASTNativeCompiler
# [12:35:28] ../src/compiler/ast/split.cc:29: Parallel compilation enabled; member trees will be divided into 32 translation units.
# [12:35:29] ../src/c_api/c_api.cc:286: Code generation finished. Writing code to files...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file recipe.json...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu27.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu22.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu24.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu21.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu8.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu5.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu6.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu3.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu7.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu26.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu16.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu14.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file header.h...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu0.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu4.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu19.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file main.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu2.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu9.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu10.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu30.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu23.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu1.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu12.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu29.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu11.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu25.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu13.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu15.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu17.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu28.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu18.c...
# [12:35:29] ../src/c_api/c_api.cc:291: Writing file tu20.c...
# [12:35:29] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:263: WARNING: some of the source files are long. Expect long compilation time. You may want to adjust the parameter parallel_comp.
#
# [12:35:29] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:104: Compiling sources files in directory ./tmp5x3262s9 into object files (*.o)...
# [12:36:44] /opt/conda/lib/python3.7/site-packages/treelite/contrib/util.py:133: Generating dynamic shared library ./tmp5x3262s9/predictor.so...
# [12:36:44] /opt/conda/lib/python3.7/site-packages/treelite/contrib/__init__.py:278: Generated shared library in 75.41 seconds

# %%
# predictor from treelite
if training:
    predictor_0 = treelite_runtime.Predictor(f'./mymodel_{0}.so', verbose=True)
    predictor_1 = treelite_runtime.Predictor(f'./mymodel_{1}.so', verbose=True)
    predictor_2 = treelite_runtime.Predictor(f'./mymodel_{2}.so', verbose=True)
    predictor_3 = treelite_runtime.Predictor(f'./mymodel_{3}.so', verbose=True)
    predictor_4 = treelite_runtime.Predictor(f'./mymodel_{4}.so', verbose=True)
# Out:
# [12:36:44] /opt/conda/lib/python3.7/site-packages/treelite_runtime/predictor.py:311: Dynamic shared library /kaggle/working/mymodel_0.so has been successfully loaded into memory
# [12:36:44] /opt/conda/lib/python3.7/site-packages/treelite_runtime/predictor.py:311: Dynamic shared library /kaggle/working/mymodel_1.so has been successfully loaded into memory
# [12:36:44] /opt/conda/lib/python3.7/site-packages/treelite_runtime/predictor.py:311: Dynamic shared library /kaggle/working/mymodel_2.so has been successfully loaded into memory
# [12:36:44] /opt/conda/lib/python3.7/site-packages/treelite_runtime/predictor.py:311: Dynamic shared library /kaggle/working/mymodel_3.so has been successfully loaded into memory
# [12:36:44] /opt/conda/lib/python3.7/site-packages/treelite_runtime/predictor.py:311: Dynamic shared library /kaggle/working/mymodel_4.so has been successfully loaded into memory

# %% [markdown]
# # 🏹Submission🎯

# %%
import janestreet
env = janestreet.make_env() # initialize the environment
iter_test = env.iter_test() # an iterator which loops over the test set

# %%
f = np.median 
index_features = [n for n in range(1,(len(features) + 1))]
for (test_df, pred_df) in tqdm(iter_test):
    
    if test_df['weight'].item() > 0:
        
        
        x_tt = test_df.values[0][index_features].reshape(1,-1)
            
        if np.isnan(x_tt[:, 1:].sum()):
            x_tt[:, 1:] = np.nan_to_num(x_tt[:, 1:]) + np.isnan(x_tt[:, 1:]) * f_mean
        
        # inference with treelite
        batch = treelite_runtime.Batch.from_npy2d(x_tt)
        pred_0 = predictor_0.predict(batch)
        pred_1 = predictor_1.predict(batch)
        pred_2 = predictor_2.predict(batch)
        pred_3 = predictor_3.predict(batch)
        pred_4 = predictor_4.predict(batch)
        
        # Prediction
        pred = np.stack([pred_0,pred_1,pred_2,pred_3,pred_4],axis=0).T
        pred = f(pred)
        pred_df.action = int(pred >= TRADING_THRESHOLD)
        
    else:
         pred_df['action'].values[0] = 0
    env.predict(pred_df)
# Out:
# 15219it [02:32, 99.83it/s]

# %% [markdown]
# # If this notebook helped Please do Upvote 💘💙✅
#
# ## Part 2 getting ready with feature selction!!!

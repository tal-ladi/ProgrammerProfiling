# %% [markdown]
# ## **Notebook Imports**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

import tensorflow as tf

import optuna

# %% [markdown]
# ## **Importing Data**

# %%
train = pd.read_csv('../input/titanic/train.csv')
test = pd.read_csv('../input/titanic/test.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
target = train['Survived'].astype(int)
test_ids = test['PassengerId']

# %%
train1 = train.drop(['PassengerId', 'Survived'], axis= 1)
test1 = test.drop('PassengerId', axis=1)

# %%
data1 = pd.concat([train1, test1], axis= 0).reset_index(drop= True)
data1.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
data1.isna().sum()
# Out:
# Pclass         0
# Name           0
# Sex            0
# Age          263
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Cabin       1014
# Embarked       2
# dtype: int64

# %%
data1.drop(['Name', 'Ticket', 'Cabin'], axis= 1, inplace= True)

# %%
data1.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ## **EDA**

# %%
sns.countplot(x = target, palette= 'winter')
plt.xlabel('Titanic Survival Rate');

# %% [markdown]
# So, it's clear from the above plot that majority of the people onboarding the titanic did not survived.

# %% [markdown]
# It seems like most of our independent varaibles are not correlated except `SibSp` and `Parch`. We will deal with that while doing feature engineering

# %%
sns.set_context('notebook', font_scale= 1.2)
fig, ax = plt.subplots(2, figsize = (20, 13))

plt.suptitle('Distribution of Age and Fair based on target variable', fontsize = 20)

# I am using the training dataset only to plot these as we don't have target variable in our test dataset
ax1 = sns.histplot(x ='Age', data= train, hue= 'Survived', kde= True, ax= ax[0], palette= 'winter')
ax1.set(xlabel = 'Age', title= 'Distribution of Age based on target variable')

ax2 = sns.histplot(x ='Fare', data= train, hue= 'Survived', kde= True, ax= ax[1], palette= 'viridis')
ax2.set(xlabel = 'Fare', title= 'Distribution of Fare based on target variable')

plt.show()

# %% [markdown]
# It is evident from the plot that children did tend to have more chances of survival as compared to older individuals

# %%
sns.countplot(x = 'Sex', data= train, hue= 'Survived', palette= 'pastel')
plt.title('Survival chance based on Gender', fontsize = 15);

# %% [markdown]
# Now that's a clear pattern here. It seems like females were 3 times more likely to survive as compared to males.

# %%
sns.countplot(x = 'Pclass', data= train, hue= 'Survived', palette= 'pastel')
plt.title('Survival chance based on Ticket Class', fontsize = 15);

# %% [markdown]
# We can also conclude that people travelling in 3rd class were less likely to survive as compared to people travelling in first class

# %% [markdown]
# ## **Filling Missing Values**

# %%
def knn_impute(df, na_target):
    df = df.copy()
    
    numeric_df = df.select_dtypes(np.number)
    non_na_columns = numeric_df.loc[: ,numeric_df.isna().sum() == 0].columns
    
    y_train = numeric_df.loc[numeric_df[na_target].isna() == False, na_target]
    X_train = numeric_df.loc[numeric_df[na_target].isna() == False, non_na_columns]
    X_test = numeric_df.loc[numeric_df[na_target].isna() == True, non_na_columns]
    
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    
    y_pred = knn.predict(X_test)
    
    df.loc[df[na_target].isna() == True, na_target] = y_pred
    
    return df

# %%
sns.histplot(data1['Age'], color= 'teal', kde= True);

# %%
data2 = knn_impute(data1, 'Age')

# %%
sns.countplot(x = data2['Embarked'], palette= 'Set2');

# %% [markdown]
# Majority of the people embarked from Southampton, so we will just fill the missing values in Embarked column with `S`

# %%
data2['Embarked'].fillna('S', inplace= True)

# %%
plt.figure(figsize= (10, 6))
sns.histplot(data2['Fare'], color= 'Teal', kde= True);

# %% [markdown]
# Distribution of `Fare` is clearly skewed, therefore we will just fill the only missing value we have in this column with median

# %%
data2['Fare'].fillna(data1['Fare'].median(), inplace= True)

# %%
data2.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# We don't have any more missing values in the dataset. Let's now move on to Encoding our categorical variables

# %% [markdown]
# ## **Encoding**

# %%
data3 = data2.copy()
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1309 non-null   int64
#  1   Sex       1309 non-null   object
#  2   Age       1309 non-null   float64
#  3   SibSp     1309 non-null   int64
#  4   Parch     1309 non-null   int64
#  5   Fare      1309 non-null   float64
#  6   Embarked  1309 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 71.7+ KB

# %%
data3 = pd.get_dummies(data3)

# %%
data3.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3  22.0      1      0   7.2500       False      True       False
# 1       1  38.0      1      0  71.2833        True     False        True
# 2       3  26.0      0      0   7.9250        True     False       False
# 3       1  35.0      1      0  53.1000        True     False       False
# 4       3  35.0      0      0   8.0500       False      True       False
#
#    Embarked_Q  Embarked_S
# 0       False        True
# 1       False       False
# 2       False        True
# 3       False        True
# 4       False        True

# %% [markdown]
# ## **Scaling**

# %%
sc = StandardScaler()
data3[['Age', 'Fare']] = sc.fit_transform(data3[['Age', 'Fare']])

# %%
data3.head()
# Out:
#    Pclass       Age  SibSp  Parch      Fare  Sex_female  Sex_male  Embarked_C  \
# 0       3 -0.534915      1      0 -0.503291       False      True       False
# 1       1  0.639651      1      0  0.734744        True     False        True
# 2       3 -0.241273      0      0 -0.490240        True     False       False
# 3       1  0.419420      1      0  0.383183        True     False       False
# 4       3  0.419420      0      0 -0.487824       False      True       False
#
#    Embarked_Q  Embarked_S
# 0       False        True
# 1       False       False
# 2       False        True
# 3       False        True
# 4       False        True

# %% [markdown]
# ## **Feature Enginerring**

# %% [markdown]
# Both the `SibSp` and `Parch` column suggests whether the person was person was travelling with his family or not. So we will convert these features into a single feature called family

# %%
data3['Family'] = np.where(data3['SibSp'] + data3['Parch'] > 0, 1, 0)
data3.drop(['SibSp', 'Parch'], axis= 1, inplace= True)

# %%
data3.head()
# Out:
#    Pclass       Age      Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0       3 -0.534915 -0.503291       False      True       False       False
# 1       1  0.639651  0.734744        True     False        True       False
# 2       3 -0.241273 -0.490240        True     False       False       False
# 3       1  0.419420  0.383183        True     False       False       False
# 4       3  0.419420 -0.487824       False      True       False       False
#
#    Embarked_S  Family
# 0        True       1
# 1       False       1
# 2        True       0
# 3        True       1
# 4        True       0

# %%
train_final = data3.loc[:train.index.max(), :].copy()
test_final = data3.loc[train.index.max() + 1:, :].reset_index(drop=True).copy()

# %% [markdown]
# ## **Modelling**

# %%
models = {
    'xgboost' : XGBClassifier(),
    'catboost' : CatBoostClassifier(verbose=0),
    'lightgbm' : LGBMClassifier(),
    'gradient boosing' : GradientBoostingClassifier(),
    'random forest' : RandomForestClassifier(),
    'logistic regression': LogisticRegression(),
    'naive bayes': GaussianNB(),
}

# %%
target = target.astype(int)

# %%
for name, model in models.items():
    model.fit(train_final, target)
    print(f'{name} trained')
# Out:
# xgboost trained
# catboost trained
# lightgbm trained
# gradient boosing trained
# random forest trained
# logistic regression trained
# naive bayes trained

# %% [markdown]
# ## **Evaluation**

# %%
results = {}

kf = KFold(n_splits= 10)

for name, model in models.items():
    result = cross_val_score(model, train_final, target, scoring = 'roc_auc', cv= kf)
    results[name] = np.mean(result)

# %%
for name, result in results.items():
    print("-------\n" + name)
    print(f'ROC score: {round(result, 3)}')
# Out:
# -------
# xgboost
# ROC score: 0.863
# -------
# catboost
# ROC score: 0.871
# -------
# lightgbm
# ROC score: 0.868
# -------
# gradient boosing
# ROC score: 0.869
# -------
# random forest
# ROC score: 0.862
# -------
# logistic regression
# ROC score: 0.843
# -------
# naive bayes
# ROC score: 0.815

# %%
results_df = pd.DataFrame(results, index=range(0,1)).T.rename(columns={0: 'ROC Score'}).sort_values('ROC Score', ascending=False)
results_df
# Out:
#                      ROC Score
# catboost              0.870660
# gradient boosing      0.868820
# lightgbm              0.868386
# xgboost               0.862638
# random forest         0.861886
# logistic regression   0.843001
# naive bayes           0.814649

# %%
plt.figure(figsize = (15, 6))
sns.barplot(x= results_df.index, y = results_df['ROC Score'], palette = 'summer')
plt.xlabel('Model')
plt.ylabel('ROC Score')
plt.title('ROC Score of different models');

# %% [markdown]
# #### Clearly, catboost had the best ROC Score, lets do some hyperparameter optimization and make the final predictions based on it

# %% [markdown]
# ## **Hyperparamer Optimization**

# %%
# def catboost_objective(trial):
#     learning_rate = trial.suggest_float('learning_rate', 0, 0.5)
#     depth = trial.suggest_int('depth', 3, 10)
#     n_estimators = trial.suggest_int('n_estimators', 50, 600)
    
#     model = CatBoostClassifier(
#         learning_rate= learning_rate,
#         depth= depth,
#         n_estimators= n_estimators,
#         verbose= 0
#     )

#     model.fit(train_final, target)
#     cv_score = cross_val_score(model, train_final, target, scoring= 'roc_auc', cv= kf)

#     return np.mean(cv_score)

# study = optuna.create_study(direction= 'maximize')
# study.optimize(catboost_objective, n_trials= 100)

# %%
catboost_params = {
    'learning_rate': 0.1682046368673911, 
     'depth': 6, 
     'n_estimators': 540,
     'verbose':0
}

# %%
cb = CatBoostClassifier(**catboost_params)
cb.fit(train_final, target)
pred_cb = cb.predict(test_final)

# %% [markdown]
# ## **ANN**

# %%
train_final.shape
# Out:
# (891, 9)

# %%
train_final = np.asarray(train_final).astype(np.float32)
test_final = np.asarray(test_final).astype(np.float32)
target = np.asarray(target).astype(np.float32)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(9),
    tf.keras.layers.Dense(100, activation = 'relu'),
    tf.keras.layers.Dense(100, activation = 'relu'),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
])

model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001),
    loss = 'binary_crossentropy',
    metrics = [tf.keras.metrics.AUC(name='auc')]
)

EPOCHS = 100

history = model.fit(train_final, target, validation_split = 0.20, epochs = EPOCHS)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 2s 18ms/step - loss: 0.6873 - auc: 0.4359 - val_loss: 0.6515 - val_auc: 0.5937
# Epoch 2/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6580 - auc: 0.6314 - val_loss: 0.6221 - val_auc: 0.7412
# Epoch 3/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6374 - auc: 0.7132 - val_loss: 0.5996 - val_auc: 0.7990
# Epoch 4/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.6213 - auc: 0.7552 - val_loss: 0.5797 - val_auc: 0.8319
# Epoch 5/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6066 - auc: 0.7831 - val_loss: 0.5630 - val_auc: 0.8586
# Epoch 6/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5928 - auc: 0.8008 - val_loss: 0.5480 - val_auc: 0.8621
# Epoch 7/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5807 - auc: 0.8049 - val_loss: 0.5338 - val_auc: 0.8664
# Epoch 8/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5697 - auc: 0.8094 - val_loss: 0.5215 - val_auc: 0.8687
# Epoch 9/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5596 - auc: 0.8147 - val_loss: 0.5094 - val_auc: 0.8698
# Epoch 10/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5500 - auc: 0.8186 - val_loss: 0.4982 - val_auc: 0.8717
# Epoch 11/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5420 - auc: 0.8197 - val_loss: 0.4883 - val_auc: 0.8704
# Epoch 12/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5332 - auc: 0.8230 - val_loss: 0.4786 - val_auc: 0.8728
# Epoch 13/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5259 - auc: 0.8232 - val_loss: 0.4705 - val_auc: 0.8721
# Epoch 14/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5190 - auc: 0.8256 - val_loss: 0.4623 - val_auc: 0.8730
# Epoch 15/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5130 - auc: 0.8288 - val_loss: 0.4561 - val_auc: 0.8730
# Epoch 16/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5082 - auc: 0.8282 - val_loss: 0.4492 - val_auc: 0.8764
# Epoch 17/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5034 - auc: 0.8303 - val_loss: 0.4439 - val_auc: 0.8751
# Epoch 18/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4990 - auc: 0.8313 - val_loss: 0.4399 - val_auc: 0.8773
# Epoch 19/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4960 - auc: 0.8311 - val_loss: 0.4358 - val_auc: 0.8793
# Epoch 20/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4925 - auc: 0.8317 - val_loss: 0.4309 - val_auc: 0.8779
# Epoch 21/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4892 - auc: 0.8343 - val_loss: 0.4284 - val_auc: 0.8792
# Epoch 22/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4869 - auc: 0.8334 - val_loss: 0.4252 - val_auc: 0.8808
# Epoch 23/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4838 - auc: 0.8353 - val_loss: 0.4224 - val_auc: 0.8814
# Epoch 24/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4815 - auc: 0.8368 - val_loss: 0.4203 - val_auc: 0.8816
# Epoch 25/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4794 - auc: 0.8387 - val_loss: 0.4179 - val_auc: 0.8835
# Epoch 26/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4776 - auc: 0.8384 - val_loss: 0.4157 - val_auc: 0.8838
# Epoch 27/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4757 - auc: 0.8399 - val_loss: 0.4139 - val_auc: 0.8830
# Epoch 28/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4740 - auc: 0.8408 - val_loss: 0.4136 - val_auc: 0.8861
# Epoch 29/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4736 - auc: 0.8402 - val_loss: 0.4119 - val_auc: 0.8827
# Epoch 30/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4709 - auc: 0.8436 - val_loss: 0.4101 - val_auc: 0.8838
# Epoch 31/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4695 - auc: 0.8427 - val_loss: 0.4083 - val_auc: 0.8843
# Epoch 32/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4683 - auc: 0.8439 - val_loss: 0.4067 - val_auc: 0.8833
# Epoch 33/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4669 - auc: 0.8441 - val_loss: 0.4061 - val_auc: 0.8835
# Epoch 34/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4650 - auc: 0.8449 - val_loss: 0.4044 - val_auc: 0.8851
# Epoch 35/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4638 - auc: 0.8457 - val_loss: 0.4021 - val_auc: 0.8852
# Epoch 36/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4635 - auc: 0.8450 - val_loss: 0.4025 - val_auc: 0.8858
# Epoch 37/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4616 - auc: 0.8467 - val_loss: 0.4002 - val_auc: 0.8846
# Epoch 38/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4600 - auc: 0.8491 - val_loss: 0.4001 - val_auc: 0.8851
# Epoch 39/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4588 - auc: 0.8493 - val_loss: 0.3994 - val_auc: 0.8855
# Epoch 40/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4578 - auc: 0.8498 - val_loss: 0.3984 - val_auc: 0.8855
# Epoch 41/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4565 - auc: 0.8505 - val_loss: 0.3978 - val_auc: 0.8858
# Epoch 42/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4555 - auc: 0.8515 - val_loss: 0.3975 - val_auc: 0.8858
# Epoch 43/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4547 - auc: 0.8513 - val_loss: 0.3964 - val_auc: 0.8861
# Epoch 44/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4537 - auc: 0.8521 - val_loss: 0.3944 - val_auc: 0.8874
# Epoch 45/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4532 - auc: 0.8508 - val_loss: 0.3939 - val_auc: 0.8860
# Epoch 46/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4516 - auc: 0.8520 - val_loss: 0.3930 - val_auc: 0.8860
# Epoch 47/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4509 - auc: 0.8524 - val_loss: 0.3922 - val_auc: 0.8855
# Epoch 48/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4497 - auc: 0.8520 - val_loss: 0.3919 - val_auc: 0.8857
# Epoch 49/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4492 - auc: 0.8529 - val_loss: 0.3916 - val_auc: 0.8889
# Epoch 50/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4480 - auc: 0.8538 - val_loss: 0.3896 - val_auc: 0.8878
# Epoch 51/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4476 - auc: 0.8530 - val_loss: 0.3884 - val_auc: 0.8865
# Epoch 52/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4473 - auc: 0.8524 - val_loss: 0.3889 - val_auc: 0.8872
# Epoch 53/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4457 - auc: 0.8544 - val_loss: 0.3875 - val_auc: 0.8859
# Epoch 54/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4449 - auc: 0.8550 - val_loss: 0.3880 - val_auc: 0.8889
# Epoch 55/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4440 - auc: 0.8556 - val_loss: 0.3864 - val_auc: 0.8873
# Epoch 56/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4434 - auc: 0.8569 - val_loss: 0.3851 - val_auc: 0.8882
# Epoch 57/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4422 - auc: 0.8566 - val_loss: 0.3860 - val_auc: 0.8892
# Epoch 58/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4414 - auc: 0.8577 - val_loss: 0.3848 - val_auc: 0.8899
# Epoch 59/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4414 - auc: 0.8579 - val_loss: 0.3835 - val_auc: 0.8908
# Epoch 60/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4408 - auc: 0.8568 - val_loss: 0.3833 - val_auc: 0.8895
# Epoch 61/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4401 - auc: 0.8572 - val_loss: 0.3830 - val_auc: 0.8905
# Epoch 62/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4388 - auc: 0.8585 - val_loss: 0.3815 - val_auc: 0.8910
# Epoch 63/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4382 - auc: 0.8588 - val_loss: 0.3820 - val_auc: 0.8901
# Epoch 64/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4384 - auc: 0.8588 - val_loss: 0.3811 - val_auc: 0.8903
# Epoch 65/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4380 - auc: 0.8576 - val_loss: 0.3806 - val_auc: 0.8919
# Epoch 66/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4365 - auc: 0.8601 - val_loss: 0.3799 - val_auc: 0.8903
# Epoch 67/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4362 - auc: 0.8596 - val_loss: 0.3803 - val_auc: 0.8925
# Epoch 68/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4354 - auc: 0.8603 - val_loss: 0.3795 - val_auc: 0.8921
# Epoch 69/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4349 - auc: 0.8603 - val_loss: 0.3793 - val_auc: 0.8916
# Epoch 70/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4344 - auc: 0.8597 - val_loss: 0.3785 - val_auc: 0.8923
# Epoch 71/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4335 - auc: 0.8602 - val_loss: 0.3771 - val_auc: 0.8918
# Epoch 72/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4329 - auc: 0.8610 - val_loss: 0.3777 - val_auc: 0.8908
# Epoch 73/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4321 - auc: 0.8615 - val_loss: 0.3787 - val_auc: 0.8914
# Epoch 74/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4322 - auc: 0.8605 - val_loss: 0.3780 - val_auc: 0.8918
# Epoch 75/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4311 - auc: 0.8608 - val_loss: 0.3761 - val_auc: 0.8914
# Epoch 76/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4310 - auc: 0.8619 - val_loss: 0.3762 - val_auc: 0.8904
# Epoch 77/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4308 - auc: 0.8606 - val_loss: 0.3760 - val_auc: 0.8934
# Epoch 78/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4309 - auc: 0.8605 - val_loss: 0.3765 - val_auc: 0.8916
# Epoch 79/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4300 - auc: 0.8608 - val_loss: 0.3754 - val_auc: 0.8914
# Epoch 80/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4292 - auc: 0.8620 - val_loss: 0.3755 - val_auc: 0.8904
# Epoch 81/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4284 - auc: 0.8624 - val_loss: 0.3759 - val_auc: 0.8922
# Epoch 82/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4284 - auc: 0.8617 - val_loss: 0.3758 - val_auc: 0.8910
# Epoch 83/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4280 - auc: 0.8626 - val_loss: 0.3744 - val_auc: 0.8921
# Epoch 84/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4276 - auc: 0.8629 - val_loss: 0.3734 - val_auc: 0.8914
# Epoch 85/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4271 - auc: 0.8622 - val_loss: 0.3745 - val_auc: 0.8932
# Epoch 86/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4268 - auc: 0.8619 - val_loss: 0.3741 - val_auc: 0.8907
# Epoch 87/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4267 - auc: 0.8624 - val_loss: 0.3732 - val_auc: 0.8907
# Epoch 88/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4260 - auc: 0.8620 - val_loss: 0.3745 - val_auc: 0.8916
# Epoch 89/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4256 - auc: 0.8628 - val_loss: 0.3732 - val_auc: 0.8894
# Epoch 90/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4252 - auc: 0.8629 - val_loss: 0.3722 - val_auc: 0.8936
# Epoch 91/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4248 - auc: 0.8634 - val_loss: 0.3730 - val_auc: 0.8897
# Epoch 92/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4242 - auc: 0.8639 - val_loss: 0.3737 - val_auc: 0.8923
# Epoch 93/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4242 - auc: 0.8633 - val_loss: 0.3728 - val_auc: 0.8916
# Epoch 94/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4239 - auc: 0.8641 - val_loss: 0.3742 - val_auc: 0.8910
# Epoch 95/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4233 - auc: 0.8642 - val_loss: 0.3722 - val_auc: 0.8912
# Epoch 96/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4230 - auc: 0.8640 - val_loss: 0.3728 - val_auc: 0.8923
# Epoch 97/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4229 - auc: 0.8635 - val_loss: 0.3736 - val_auc: 0.8927
# Epoch 98/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4229 - auc: 0.8646 - val_loss: 0.3726 - val_auc: 0.8933
# Epoch 99/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4220 - auc: 0.8652 - val_loss: 0.3726 - val_auc: 0.8929
# Epoch 100/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4221 - auc: 0.8643 - val_loss: 0.3726 - val_auc: 0.8912

# %%
plt.figure(figsize=(10, 6))

epochs = range(1, EPOCHS + 1)
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, train_loss, label="Training Loss")
plt.plot(epochs, val_loss, label="Validation Loss")

plt.title("Training and Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %% [markdown]
# Clearly our ANN is doing a better job in classifying our target column

# %%
pred_ann = model.predict(test_final)
# Out:
# 14/14 [==============================] - 0s 1ms/step

# %%
submission = pd.DataFrame(test_ids, index= None)

# %%
submission['Survived'] = pred_ann

# %%
submission['Survived'] = submission['Survived'].apply(lambda x: 1 if x>0.5 else 0)

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
submission.to_csv('submission.csv', index= None)

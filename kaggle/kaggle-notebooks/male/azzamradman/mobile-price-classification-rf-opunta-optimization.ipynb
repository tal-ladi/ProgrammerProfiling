# %%
# import libraries
from functools import partial
import numpy as np
import pandas as pd
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection
from hyperopt import hp, fmin, tpe, Trials
from hyperopt.pyll.base import scope
import optuna

# %%
# read the files
df = pd.read_csv('../input/mobile-price-classification/train.csv')
X = df.drop('price_range', axis=1).values
y = df['price_range'].values

# %%
# define an optimization function
def optimize(trial, x, y):
    # hyperparameters to optimize
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])
    n_estimators = trial.suggest_int('n_estimators', 100, 1500)
    max_depth = trial.suggest_int('max_depth', 3, 15)
    max_features = trial.suggest_uniform('max_features', 0.01, 1)

    # use Random Forest Classifier
    model = ensemble.RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        max_features=max_features,
        criterion=criterion,
    )
    
    # use Stratified K-fold
    kf = model_selection.StratifiedKFold(n_splits=5)
    accuracies = []
    for idx in kf.split(X=x, y=y):
        train_idx, val_idx = idx[0], idx[1]
        xtrain = x[train_idx]
        ytrain = y[train_idx]

        xval = x[val_idx]
        yval = y[val_idx]

        model.fit(xtrain, ytrain)
        preds = model.predict(xval) # here we assume to use 0.5 threshold, otherwise you can use predict_proba

        fold_acc = metrics.accuracy_score(yval, preds)
        accuracies.append(fold_acc)

    return -1.0 * np.mean(accuracies) # multiplied by -1 because the function finds the minimum.

# %%
optimization_function = partial(optimize, x=X, y=y)
# you can use maximized, but you have to remove the -1 in the otimization function
study = optuna.create_study(direction='minimize')
study.optimize(optimization_function, n_trials=15)
# Out:
# [I 2021-04-28 20:11:03,911] A new study created in memory with name: no-name-f4557275-9508-4a2c-aae9-7b4a9e2d970c
# [I 2021-04-28 20:11:49,565] Trial 0 finished with value: -0.8959999999999999 and parameters: {'criterion': 'entropy', 'n_estimators': 1351, 'max_depth': 14, 'max_features': 0.2602068925402137}. Best is trial 0 with value: -0.8959999999999999.
# [I 2021-04-28 20:12:04,126] Trial 1 finished with value: -0.893 and parameters: {'criterion': 'gini', 'n_estimators': 592, 'max_depth': 11, 'max_features': 0.30382877929220153}. Best is trial 0 with value: -0.8959999999999999.
# [I 2021-04-28 20:12:19,373] Trial 2 finished with value: -0.8355 and parameters: {'criterion': 'gini', 'n_estimators': 590, 'max_depth': 4, 'max_features': 0.8037793905153324}. Best is trial 0 with value: -0.8959999999999999.
# [I 2021-04-28 20:12:43,366] Trial 3 finished with value: -0.8684999999999998 and parameters: {'criterion': 'gini', 'n_estimators': 1219, 'max_depth': 14, 'max_features': 0.19329331902297814}. Best is trial 0 with value: -0.8959999999999999.
# [I 2021-04-28 20:13:55,097] Trial 4 finished with value: -0.908 and parameters: {'criterion': 'entropy', 'n_estimators': 1460, 'max_depth': 14, 'max_features': 0.6505238775555798}. Best is trial 4 with value: -0.908.
# [I 2021-04-28 20:14:28,851] Trial 5 finished with value: -0.7675 and parameters: {'criterion': 'gini', 'n_estimators': 1424, 'max_depth': 3, 'max_features': 0.9987361138376463}. Best is trial 4 with value: -0.908.
# [I 2021-04-28 20:14:45,247] Trial 6 finished with value: -0.876 and parameters: {'criterion': 'entropy', 'n_estimators': 347, 'max_depth': 5, 'max_features': 0.9002176868764766}. Best is trial 4 with value: -0.908.
# [I 2021-04-28 20:15:45,218] Trial 7 finished with value: -0.8934999999999998 and parameters: {'criterion': 'entropy', 'n_estimators': 1468, 'max_depth': 6, 'max_features': 0.6356900829681601}. Best is trial 4 with value: -0.908.
# [I 2021-04-28 20:16:33,190] Trial 8 finished with value: -0.885 and parameters: {'criterion': 'entropy', 'n_estimators': 1493, 'max_depth': 6, 'max_features': 0.41594081028048624}. Best is trial 4 with value: -0.908.
# [I 2021-04-28 20:16:38,151] Trial 9 finished with value: -0.8030000000000002 and parameters: {'criterion': 'gini', 'n_estimators': 283, 'max_depth': 3, 'max_features': 0.5136554795729594}. Best is trial 4 with value: -0.908.
# [I 2021-04-28 20:17:27,667] Trial 10 finished with value: -0.9085000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1004, 'max_depth': 11, 'max_features': 0.6807497282234343}. Best is trial 10 with value: -0.9085000000000001.
# [I 2021-04-28 20:18:17,392] Trial 11 finished with value: -0.9055 and parameters: {'criterion': 'entropy', 'n_estimators': 1019, 'max_depth': 11, 'max_features': 0.6930660686778308}. Best is trial 10 with value: -0.9085000000000001.
# [I 2021-04-28 20:19:04,739] Trial 12 finished with value: -0.906 and parameters: {'criterion': 'entropy', 'n_estimators': 1003, 'max_depth': 11, 'max_features': 0.6075047149938428}. Best is trial 10 with value: -0.9085000000000001.
# [I 2021-04-28 20:20:03,930] Trial 13 finished with value: -0.9075000000000001 and parameters: {'criterion': 'entropy', 'n_estimators': 1114, 'max_depth': 15, 'max_features': 0.7869715418805223}. Best is trial 10 with value: -0.9085000000000001.
# [I 2021-04-28 20:20:18,446] Trial 14 finished with value: -0.7495 and parameters: {'criterion': 'entropy', 'n_estimators': 857, 'max_depth': 9, 'max_features': 0.01478161863965205}. Best is trial 10 with value: -0.9085000000000001.
